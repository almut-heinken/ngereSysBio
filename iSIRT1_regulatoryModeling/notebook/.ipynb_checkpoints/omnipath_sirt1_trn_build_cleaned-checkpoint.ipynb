# %%
# This is a code cell. Adjust and customize as needed.
from pypath import omnipath

# %%
# This is a code cell. Adjust and customize as needed.
tft = omnipath.db.get_db('tf_target')

# %%
# This is a code cell. Adjust and customize as needed.
from pypath.utils import mapping

# %%
# This is a code cell. Adjust and customize as needed.
from pypath.omnipath import export
e = export.Export(tft)
e.make_df(unique_pairs = False)
tft_df = e.df

# %%
# This is a code cell. Adjust and customize as needed.
tft_df
# Out:
#                   source  target source_genesymbol target_genesymbol  \
# 0                 P01106  O14746               MYC              TERT
# 1                 P17947  P02818              SPI1             BGLAP
# 2       (P05412, P17535)  P05412          JUN_JUND               JUN
# 3               (P17535)  P05412              JUND               JUN
# 4               (P17275)  P05412              JUNB               JUN
# ...                  ...     ...               ...               ...
# 376011            P26651  P05120             ZFP36          SERPINB2
# 376012            P26651  P15692             ZFP36             VEGFA
# 376013            Q07352  P15692           ZFP36L1             VEGFA
# 376014            Q9P1U0  P08183            POLR1H             ABCB1
# 376015            Q9P1U0  P10415            POLR1H              BCL2
#
#         is_directed  is_stimulation  is_inhibition  consensus_direction  \
# 0                 1               1              0                    1
# 1                 1               1              0                    1
# 2                 1               1              0                    1
# 3                 1               1              0                    1
# 4                 1               1              0                    1
# ...             ...             ...            ...                  ...
# 376011            1               0              0                    0
# 376012            1               0              1                    1
# 376013            1               0              1                    1
# 376014            1               1              0                    1
# 376015            1               1              0                    1
#
#         consensus_stimulation  consensus_inhibition  \
# 0                           1                     0
# 1                           1                     0
# 2                           1                     0
# 3                           1                     0
# 4                           1                     0
# ...                       ...                   ...
# 376011                      0                     0
# 376012                      0                     1
# 376013                      0                     1
# 376014                      1                     0
# 376015                      1                     0
#
#                                                   sources  \
# 0       CollecTRI;DoRothEA;DoRothEA-A_CollecTRI;ExTRI_...
# 1                               CollecTRI;ExTRI_CollecTRI
# 2       CollecTRI;ExTRI_CollecTRI;NTNU.Curated_CollecT...
# 3       CollecTRI;ExTRI_CollecTRI;NTNU.Curated_CollecT...
# 4       CollecTRI;ExTRI_CollecTRI;NTNU.Curated_CollecT...
# ...                                                   ...
# 376011                                             TRRUST
# 376012                                             TRRUST
# 376013                                             TRRUST
# 376014                                             TRRUST
# 376015                                             TRRUST
#
#                                                references
# 0       CollecTRI:10022128;CollecTRI:10491298;CollecTR...
# 1                                      CollecTRI:10022617
# 2       CollecTRI:10022869;CollecTRI:10037172;CollecTR...
# 3       CollecTRI:10022869;CollecTRI:10037172;CollecTR...
# 4       CollecTRI:10022869;CollecTRI:10037172;CollecTR...
# ...                                                   ...
# 376011                                    TRRUST:12578825
# 376012                    TRRUST:21507959;TRRUST:21656745
# 376013                                    TRRUST:19801654
# 376014                                    TRRUST:16373708
# 376015                    TRRUST:16373708;TRRUST:16609701
#
# [376016 rows x 12 columns]

# %%
# This is a code cell. Adjust and customize as needed.
from collections import deque
graph = {}
for index, row in tft_df.iterrows():
    source = row['source_genesymbol']
    target = row['target_genesymbol']
    if source not in graph:
        graph[source] = []
    graph[source].append(target)

queue = deque(['SIRT1'])
visited = set()

while queue:
    current = queue.popleft()
    if current not in visited:
        visited.add(current)
        neighbors = graph.get(current, [])
        queue.extend(neighbors)

visited_molecules = list(visited)

print("Molecules that SIRT1 interacts with and their downstream interactions:")
print(visited_molecules)
# Out:
# Molecules that SIRT1 interacts with and their downstream interactions:
# ['CIITA', 'NUDT14', 'MORC1', 'ZBTB38', 'WDR72', 'SLC5A3', 'RPSA2', 'LMAN2L', 'CHKB', 'TNNT3', 'DUOXA1', 'GOLGA6L10', 'KCNMB3', 'CHGB', 'AQP2', 'UGT2A1', 'FGFRL1', 'SEL1L2', 'MPP7', 'FTH1', 'CBL', 'ORC3', 'EIF2D', 'TOMT', 'PIF1', 'FBXL15', 'FAM183BP', 'ENHO', 'TMC5', 'ARHGDIB', 'HIGD1A', 'PHLDA1', 'H3-7', 'ZNF621', 'COL26A1', 'RAD9B', 'ZNRF1', 'RNF141', 'MTERF2', 'MSI1', 'ERMARD', 'SLC35A1', 'RBMS2', 'HUNK', 'CARMIL1', 'CSRP2', 'EXTL1', 'CD5L', 'ACY1', 'PTPRH', 'MAK', 'SCAMP3', 'CYP24A1', 'SH3BGRL2', 'IQCD', 'GDF3', 'DCBLD1', 'ARHGEF15', 'GGA3', 'ZNF444', 'C6orf15', 'TMEM115', 'ACER3', 'SYNJ2BP', 'AKAP5', 'AKT1', 'INHA', 'BARX2', 'GTF3C1', 'SARAF', 'CCNG1', 'KLRB1', 'GRAMD2A', 'MTFMT', 'FZR1', 'ASPDH', 'DOLPP1', 'DDX59', 'MEMO1', 'C21orf58', 'TRAJ3', 'DSN1', 'BTBD16', 'ERBB4', 'EIF1AX', 'SPIN4', 'AURKB', 'CCP110', 'UBC', 'STX17', 'CEBPB', 'STRN3', 'ZNF160', 'ATP6V1C2', 'ZNF616', 'LHX6', 'ADGRL2', 'NF2', 'MPPED2', 'YJU2B', 'FAM104B', 'RAB27B', 'PPP2R2D', 'ALOXE3', 'OLIG1', 'ATMIN', 'LRRC45', 'APRG1', 'NCR3', 'SELL', 'TMEM200A', 'PDE6H', 'FSD2', 'ULK2', 'CALCR', 'RGMB', 'PRB3', 'NTAQ1', 'EPN1', 'ANO5', 'ST8SIA5', 'IL3', 'LMOD1', 'ZNF34', 'KCNH3', 'LCOR', 'ZGLP1', 'DNAJB2', 'ARMC6', 'RHOV', 'SYT14', 'ISG20', 'ZNF785', 'PLEK2', 'FOXB1', 'IQCF3', 'TIGD7', 'POR', 'FBRSL1', 'CAMK2D', 'U2AF1', 'ZMYM3', 'PIR', 'GDF5-AS1', 'GPBP1L1', 'C2orf83', 'DTYMK', 'ARMH4', 'TUBAL3', 'SMARCD3', 'OR5B17', 'ICMT', 'FOXR2', 'C6orf132', 'MTHFR', 'SCN7A', 'ZBED4', 'SPDYE1', 'IL11', 'PTHLH', 'BAALC-AS2', 'DYNC1H1', 'XKR3', 'PRSS38', 'CNOT8', 'ADH1B', 'GP6', 'MATCAP2', 'DOCK8-AS1', 'VPS4B', 'ABI3', 'PRELID1', 'TAP1', 'BLVRB', 'SSMEM1', 'LIAS', 'SEPHS1', 'H2BC3', 'SLC26A6', 'ZNF486', 'RNF39', 'XAGE1A', 'TGFB1', 'SIRT3', 'TBX5', 'SERPINB6', 'NANOGP1', 'PFKP', 'SLX9', 'DNAH5', 'SLC38A11', 'CHRNB3', 'CCL3', 'ZC3HAV1', 'AEN', 'DCDC1', 'RFTN2', 'TMEM176A', 'ZNF30', 'BACH2', 'GRIK1', 'ID2', 'TMEM209', 'CAPS2', 'NPY1R', 'RECQL4', 'PDIA3', 'AP4B1', 'XKR6', 'NDUFS8', 'MRPL47', 'MED9', 'KNSTRN', 'MRPS11', 'LHX1', 'ZGPAT', 'CCNT1', 'IL13', 'HECW1', 'FGF4', 'SYTL4', 'OLFM1', 'AGAP6', 'RAB40A', 'PPIL1', 'PRKAB2', 'RABEP2', 'CEACAM21', 'CNP', 'NUDT11', 'BRSK2', 'RPS3', 'RHEBL1', 'SRSF2', 'CRYBA2', 'BORA', 'SLC26A9', 'TBX4', 'CNOT11', 'HS6ST3', 'PRR20C', 'GKN1', 'APOBEC4', 'TRMT61B', 'DPP7', 'RAD23A', 'CDK19', 'ARFGAP1', 'FGF12', 'C17orf80', 'CASP12', 'UBE4B', 'CLEC9A', 'TMEM237', 'TRPS1', 'FAM53C', 'GCFC2', 'SIGLEC15', 'CST9LP1', 'PLA2G4A', 'LENG9', 'ANKRD63', 'PRSS35', 'NEURL3', 'SFN', 'UGT1A7', 'KIR3DL1', 'ANAPC16', 'ATF7', 'CHCHD3', 'KIAA1549L', 'FRMD6-AS1', 'UCN3', 'ARL15', 'PIGU', 'TUB', 'ABCC5', 'MITD1', 'PPP2R3B', 'DRP2', 'CTAG1B', 'IRGQ', 'NCOA2', 'DCAF7', 'SLFN12L', 'GLRA1', 'WFIKKN2', 'DR1', 'ZSCAN22', 'HCK', 'CD22', 'DYRK2', 'TECTB', 'WT1-AS', 'CCDC144NL', 'ZNF692', 'CST9', 'ZNF652', 'IL5', 'OPRL1', 'TPTE2P1', 'COL2A1', 'DSTN', 'LRP5', 'INCA1', 'TRNP1', 'FAIM', 'RAB37', 'ADGRG6', 'DNAI7', 'WDR83OS', 'PPP3R2', 'SNRNP27', 'SLC41A1', 'IGHV3-38', 'MUC5B', 'BSCL2', 'GRID2', 'FKBP14', 'RPLP1', 'ERI2', 'FMN2', 'TLR9', 'GBP4', 'UGT1A3', 'ADAT3', 'POTEB2', 'OGFR', 'BCL2L2', 'OR5I1', 'CTAGE1', 'ACY3', 'TMSB4Y', 'PANX3', 'ZNF429', 'PLP1', 'C6orf120', 'XPR1', 'RMI1', 'C8orf82', 'DNAJB6', 'ANXA8', 'SLC30A10', 'FARP2', 'RTN3', 'ACSF2', 'CCDC51', 'DMP1', 'FGF1', 'DEPDC1', 'RASGEF1A', 'APCDD1', 'BEAN1', 'ZEB2', 'CACTIN', 'IGSF9B', 'FAAP24', 'TCTE1', 'ZBTB18', 'SEPSECS', 'TMEM248', 'NAXD', 'TEX29', 'SLC26A10P', 'RLF', 'IFI35', 'COL5A1-AS1', 'PYY3', 'CD99', 'CRCP', 'ABCA7', 'RBM34', 'GNB3', 'EBNA1BP2', 'FAM156B', 'RBL1', 'SPATA25', 'KLLN', 'CCDC115', 'ZNF155', 'PDZK1P1', 'SDF2L1', 'IPO9', 'PPP1R13B', 'DDR1', 'ALAS2', 'DNA2', 'CDH22', 'SOWAHD', 'ATG12', 'TMED2', 'TAF8', 'SIRPG', 'NANS', 'EVC2', 'FECH', 'BCL7A', 'CYRIA', 'DYNLL1', 'SLC9A9', 'FAM135A', 'NR1D1', 'VCAM1', 'CCL25', 'SERHL2', 'SMAP', 'MBD3', 'CABYR', 'NLRP6', 'SH3GLB1', 'OR1E1', 'IGHV1-24', 'REEP4', 'HSPA7', 'PSMB10', 'SQSTM1', 'DCUN1D3', 'SEMA3E', 'BMF', 'GFPT1', 'ANKRD50', 'FOXP3', 'GLRX3', 'FAM184A', 'DAPK3', 'CASK ...

# %%
# This is a code cell. Adjust and customize as needed.
len(visited_molecules)
# Out:
# 18973

# %%
# This is a code cell. Adjust and customize as needed.
graph_keys = list(graph.keys())

sub_df = tft_df[tft_df['source_genesymbol'].isin(graph_keys)]

# %%
# This is a code cell. Adjust and customize as needed.
len(graph_keys)
# Out:
# 1486

# %%
# This is a code cell. Adjust and customize as needed.
visited = set()

def traverse_molecules(molecule):
    if molecule not in visited:
        visited.add(molecule)
        neighbors = graph.get(molecule, [])
        for neighbor in neighbors:
            traverse_molecules(neighbor)

traverse_molecules('SIRT1')

sub_df = tft_df[tft_df['source_genesymbol'].isin(visited)]

print(sub_df)
# Out:
#           source  target source_genesymbol target_genesymbol  is_directed  \
# 0         P01106  O14746               MYC              TERT            1
# 1         P17947  P02818              SPI1             BGLAP            1
# 3       (P17535)  P05412              JUND               JUN            1
# 4       (P17275)  P05412              JUNB               JUN            1
# 6       (P05412)  P05412               JUN               JUN            1
# ...          ...     ...               ...               ...          ...
# 376011    P26651  P05120             ZFP36          SERPINB2            1
# 376012    P26651  P15692             ZFP36             VEGFA            1
# 376013    Q07352  P15692           ZFP36L1             VEGFA            1
# 376014    Q9P1U0  P08183            POLR1H             ABCB1            1
# 376015    Q9P1U0  P10415            POLR1H              BCL2            1
#
#         is_stimulation  is_inhibition  consensus_direction  \
# 0                    1              0                    1
# 1                    1              0                    1
# 3                    1              0                    1
# 4                    1              0                    1
# 6                    1              0                    1
# ...                ...            ...                  ...
# 376011               0              0                    0
# 376012               0              1                    1
# 376013               0              1                    1
# 376014               1              0                    1
# 376015               1              0                    1
#
#         consensus_stimulation  consensus_inhibition  \
# 0                           1                     0
# 1                           1                     0
# 3                           1                     0
# 4                           1                     0
# 6                           1                     0
# ...                       ...                   ...
# 376011                      0                     0
# 376012                      0                     1
# 376013                      0                     1
# 376014                      1                     0
# 376015                      1                     0
#
#                                                   sources  \
# 0       CollecTRI;DoRothEA;DoRothEA-A_CollecTRI;ExTRI_...
# 1                               CollecTRI;ExTRI_CollecTRI
# 3       CollecTRI;ExTRI_CollecTRI;NTNU.Curated_CollecT...
# 4       CollecTRI;ExTRI_CollecTRI;NTNU.Curated_CollecT...
# 6       CollecTRI;ExTRI_CollecTRI;NTNU.Curated_CollecT...
# ...                                                   ...
# 376011                                             TRRUST
# 376012                                             TRRUST
# 376013                                             TRRUST
# 376014                                             TRRUST
# 376015                                             TRRUST
#
#                                                references
# 0       CollecTRI:10022128;CollecTRI:10491298;CollecTR...
# 1                                      CollecTRI:10022617
# 3       CollecTRI:10022869;CollecTRI:10037172;CollecTR...
# 4       CollecTRI:10022869;CollecTRI:10037172;CollecTR...
# 6       CollecTRI:10022869;CollecTRI:10037172;CollecTR...
# ...                                                   ...
# 376011                                    TRRUST:12578825
# 376012                    TRRUST:21507959;TRRUST:21656745
# 376013                                    TRRUST:19801654
# 376014                                    TRRUST:16373708
# 376015                    TRRUST:16373708;TRRUST:16609701
#
# [358835 rows x 12 columns]

# %%
# This is a code cell. Adjust and customize as needed.
sub_df = sub_df[sub_df["consensus_direction"] == 1]

# %%
# This is a code cell. Adjust and customize as needed.
def create_rule(row):
    if row['consensus_stimulation'] == 0:
        return "NOT " + row['source_genesymbol']
    else:
        return row['source_genesymbol']

sub_df['rule'] = sub_df.apply(lambda row: create_rule(row), axis=1)

# %%
# This is a code cell. Adjust and customize as needed.
sub_df[(sub_df["source_genesymbol"] == "SIRT1") & (sub_df["target_genesymbol"].str.contains('TP', na=False))]
# Out:
#        source  target source_genesymbol target_genesymbol  is_directed  \
# 56134  Q96EB6  O15350             SIRT1              TP73            1
#
#        is_stimulation  is_inhibition  consensus_direction  \
# 56134               1              0                    1
#
#        consensus_stimulation  consensus_inhibition  \
# 56134                      1                     0
#
#                                  sources                          references  \
# 56134  CollecTRI;TRRUST;TRRUST_CollecTRI  CollecTRI:19188449;TRRUST:19188449
#
#         rule
# 56134  SIRT1

# %%
# This is a code cell. Adjust and customize as needed.
sub_df
# Out:
#           source  target source_genesymbol target_genesymbol  is_directed  \
# 0         P01106  O14746               MYC              TERT            1
# 1         P17947  P02818              SPI1             BGLAP            1
# 3       (P17535)  P05412              JUND               JUN            1
# 4       (P17275)  P05412              JUNB               JUN            1
# 6       (P05412)  P05412               JUN               JUN            1
# ...          ...     ...               ...               ...          ...
# 376010    P26651  P05231             ZFP36               IL6            1
# 376012    P26651  P15692             ZFP36             VEGFA            1
# 376013    Q07352  P15692           ZFP36L1             VEGFA            1
# 376014    Q9P1U0  P08183            POLR1H             ABCB1            1
# 376015    Q9P1U0  P10415            POLR1H              BCL2            1
#
#         is_stimulation  is_inhibition  consensus_direction  \
# 0                    1              0                    1
# 1                    1              0                    1
# 3                    1              0                    1
# 4                    1              0                    1
# 6                    1              0                    1
# ...                ...            ...                  ...
# 376010               0              1                    1
# 376012               0              1                    1
# 376013               0              1                    1
# 376014               1              0                    1
# 376015               1              0                    1
#
#         consensus_stimulation  consensus_inhibition  \
# 0                           1                     0
# 1                           1                     0
# 3                           1                     0
# 4                           1                     0
# 6                           1                     0
# ...                       ...                   ...
# 376010                      0                     1
# 376012                      0                     1
# 376013                      0                     1
# 376014                      1                     0
# 376015                      1                     0
#
#                                                   sources  \
# 0       CollecTRI;DoRothEA;DoRothEA-A_CollecTRI;ExTRI_...
# 1                               CollecTRI;ExTRI_CollecTRI
# 3       CollecTRI;ExTRI_CollecTRI;NTNU.Curated_CollecT...
# 4       CollecTRI;ExTRI_CollecTRI;NTNU.Curated_CollecT...
# 6       CollecTRI;ExTRI_CollecTRI;NTNU.Curated_CollecT...
# ...                                                   ...
# 376010                                             TRRUST
# 376012                                             TRRUST
# 376013                                             TRRUST
# 376014                                             TRRUST
# 376015                                             TRRUST
#
#                                                references         rule
# 0       CollecTRI:10022128;CollecTRI:10491298;CollecTR...          MYC
# 1                                      CollecTRI:10022617         SPI1
# 3       CollecTRI:10022869;CollecTRI:10037172;CollecTR...         JUND
# 4       CollecTRI:10022869;CollecTRI:10037172;CollecTR...         JUNB
# 6       CollecTRI:10022869;CollecTRI:10037172;CollecTR...          JUN
# ...                                                   ...          ...
# 376010                                    TRRUST:21656745    NOT ZFP36
# 376012                    TRRUST:21507959;TRRUST:21656745    NOT ZFP36
# 376013                                    TRRUST:19801654  NOT ZFP36L1
# 376014                                    TRRUST:16373708       POLR1H
# 376015                    TRRUST:16373708;TRRUST:16609701       POLR1H
#
# [47916 rows x 13 columns]

# %%
# This is a code cell. Adjust and customize as needed.
sub_df[sub_df["target_genesymbol"].str.contains('PTGS2', na=False)]
# Out:
#           source  target source_genesymbol target_genesymbol  is_directed  \
# 760       P04637  P35354              TP53             PTGS2            1
# 761       P20226  P35354               TBP             PTGS2            1
# 876     (Q04864)  P35354               REL             PTGS2            1
# 878     (P19838)  P35354             NFKB1             PTGS2            1
# 882     (Q01201)  P35354              RELB             PTGS2            1
# ...          ...     ...               ...               ...          ...
# 63431     P23246  P35354              SFPQ             PTGS2            1
# 64185     P52747  P35354            ZNF143             PTGS2            1
# 64377     O75030  P35354              MITF             PTGS2            1
# 64753     P15822  P35354            HIVEP1             PTGS2            1
# 375636    P25054  P35354               APC             PTGS2            1
#
#         is_stimulation  is_inhibition  consensus_direction  \
# 760                  0              1                    1
# 761                  1              0                    1
# 876                  1              0                    1
# 878                  1              0                    1
# 882                  1              0                    1
# ...                ...            ...                  ...
# 63431                1              0                    1
# 64185                0              1                    1
# 64377                1              0                    1
# 64753                0              1                    1
# 375636               0              1                    1
#
#         consensus_stimulation  consensus_inhibition  \
# 760                         0                     1
# 761                         1                     0
# 876                         1                     0
# 878                         1                     0
# 882                         1                     0
# ...                       ...                   ...
# 63431                       1                     0
# 64185                       0                     1
# 64377                       1                     0
# 64753                       0                     1
# 375636                      0                     1
#
#                                                   sources  \
# 760     CollecTRI;DoRothEA;ExTRI_CollecTRI;NTNU.Curate...
# 761      CollecTRI;ExTRI_CollecTRI;NTNU.Curated_CollecTRI
# 876     CollecTRI;ExTRI_CollecTRI;GEREDB_CollecTRI;NTN...
# 878     CollecTRI;ExTRI_CollecTRI;GEREDB_CollecTRI;NTN...
# 882     CollecTRI;ExTRI_CollecTRI;GEREDB_CollecTRI;NTN...
# ...                                                   ...
# 63431                          CollecTRI;GEREDB_CollecTRI
# 64185                          CollecTRI;GEREDB_CollecTRI
# 64377                    CollecTRI;NTNU.Curated_CollecTRI
# 64753                    CollecTRI;NTNU.Curated_CollecTRI
# 375636                                             TRRUST
#
#                                                references        rule  \
# 760     CollecTRI:10196169;CollecTRI:11161397;CollecTR...    NOT TP53
# 761                 CollecTRI:10196169;CollecTRI:18204072         TBP
# 876     CollecTRI:10210266;CollecTRI:10395693;CollecTR...         REL
# 878     CollecTRI:10210266;CollecTRI:10395693;CollecTR...       NFKB1
# 882     CollecTRI:10210266;CollecTRI:10395693;CollecTR...        RELB
# ...                                                   ...         ...
# 63431                                  CollecTRI:19339282        SFPQ
# 64185                                  CollecTRI:15763366  NOT ZNF143
# 64377                                  CollecTRI:24471568        MITF
# 64753               CollecTRI:19846662;CollecTRI:23421821  NOT HIVEP1
# 375636    TRRUST:10772828;TRRUST:11396184;TRRUST:12566320     NOT APC
#
#                 Rule
# 760       (NOT TP53)
# 761            (TBP)
# 876            (REL)
# 878          (NFKB1)
# 882           (RELB)
# ...              ...
# 63431         (SFPQ)
# 64185   (NOT ZNF143)
# 64377         (MITF)
# 64753   (NOT HIVEP1)
# 375636     (NOT APC)
#
# [118 rows x 14 columns]

# %%
# This is a code cell. Adjust and customize as needed.
signor_tft_df = sub_df[sub_df["sources"].str.contains('SIGNOR', na=False)]

# %%
# This is a code cell. Adjust and customize as needed.
signor_tft_df[signor_tft_df["target_genesymbol"].str.contains('PTGS2', na=False)]
# Out:
#        source  target source_genesymbol target_genesymbol  is_directed  \
# 7650   O95644  P35354            NFATC1             PTGS2            1
# 22221  Q14934  P35354            NFATC4             PTGS2            1
# 27079  Q13469  P35354            NFATC2             PTGS2            1
# 39035  Q12968  P35354            NFATC3             PTGS2            1
# 59818  P78414  P35354              IRX1             PTGS2            1
#
#        is_stimulation  is_inhibition  consensus_direction  \
# 7650                1              0                    1
# 22221               1              0                    1
# 27079               1              0                    1
# 39035               1              0                    1
# 59818               1              0                    1
#
#        consensus_stimulation  consensus_inhibition  \
# 7650                       1                     0
# 22221                      1                     0
# 27079                      1                     0
# 39035                      1                     0
# 59818                      1                     0
#
#                                                  sources  \
# 7650   CollecTRI;ExTRI_CollecTRI;GEREDB_CollecTRI;KEG...
# 22221  CollecTRI;ExTRI_CollecTRI;GEREDB_CollecTRI;KEG...
# 27079  CollecTRI;ExTRI_CollecTRI;KEGG-MEDICUS;NTNU.Cu...
# 39035  CollecTRI;ExTRI_CollecTRI;KEGG-MEDICUS;NTNU.Cu...
# 59818                         CollecTRI;SIGNOR_CollecTRI
#
#                                               references    rule
# 7650   CollecTRI:11423565;CollecTRI:16909108;CollecTR...  NFATC1
# 22221  CollecTRI:16718377;CollecTRI:16803872;CollecTR...  NFATC4
# 27079  CollecTRI:18006811;CollecTRI:21871017;CollecTR...  NFATC2
# 39035  CollecTRI:21642596;CollecTRI:21871017;CollecTR...  NFATC3
# 59818                                 CollecTRI:20440264    IRX1

# %%
# This is a code cell. Adjust and customize as needed.
len(sub_df[sub_df["source_genesymbol"].str.contains('LXR', na=False)])
# Out:
# 0

# %%
# This is a code cell. Adjust and customize as needed.
len(signor_tft_df[signor_tft_df["source_genesymbol"].str.contains('PPARGC', na=False)])
# Out:
# 19

# %%
# This is a code cell. Adjust and customize as needed.
import pandas as pd

# %%
# This is a code cell. Adjust and customize as needed.
recon3d_genes = pd.read_csv("..\\data\\vmh\\recon-store-genes-1.tsv",sep="\t")["symbol"].to_list()

# %%
# This is a code cell. Adjust and customize as needed.
SIRT1_TARGETS = ["FOXO1", "PPARGC1A", "PPARG","TP53","FOXO3", "EP300", "PPARA"]

# %%
# This is a code cell. Adjust and customize as needed.
sub_df[(sub_df.source_genesymbol.isin(SIRT1_TARGETS)) 
                 & sub_df["target_genesymbol"].str.contains('PTGS2', na=False)]
# Out:
#        source  target source_genesymbol target_genesymbol  is_directed  \
# 760    P04637  P35354              TP53             PTGS2            1
# 6921   P37231  P35354             PPARG             PTGS2            1
# 29420  Q07869  P35354             PPARA             PTGS2            1
# 53926  Q09472  P35354             EP300             PTGS2            1
#
#        is_stimulation  is_inhibition  consensus_direction  \
# 760                 0              1                    1
# 6921                1              1                    1
# 29420               1              1                    1
# 53926               1              0                    1
#
#        consensus_stimulation  consensus_inhibition  \
# 760                        0                     1
# 6921                       0                     1
# 29420                      0                     1
# 53926                      1                     0
#
#                                                  sources  \
# 760    CollecTRI;DoRothEA;ExTRI_CollecTRI;NTNU.Curate...
# 6921   CollecTRI;DoRothEA;ExTRI_CollecTRI;GEREDB_Coll...
# 29420  CollecTRI;DoRothEA;ExTRI_CollecTRI;GEREDB_Coll...
# 53926                  CollecTRI;TRRUST;TRRUST_CollecTRI
#
#                                               references       rule  \
# 760    CollecTRI:10196169;CollecTRI:11161397;CollecTR...   NOT TP53
# 6921   CollecTRI:10827178;CollecTRI:11278336;CollecTR...  NOT PPARG
# 29420  CollecTRI:11007963;CollecTRI:11412039;CollecTR...  NOT PPARA
# 53926  CollecTRI:12057991;CollecTRI:12471036;CollecTR...      EP300
#
#               Rule
# 760     (NOT TP53)
# 6921   (NOT PPARG)
# 29420  (NOT PPARA)
# 53926      (EP300)

# %%
# This is a code cell. Adjust and customize as needed.
signor_interactions = pd.read_csv("..\\data\\signor\\all_data_03_01_24.tsv",sep="\t")

# %%
# This is a code cell. Adjust and customize as needed.
signor_interactions[(signor_interactions["ENTITYA"] == "TP53") & (signor_interactions["ENTITYB"] == "PTGS2")]
# Out:
# Empty DataFrame
# Columns: [ENTITYA, TYPEA, IDA, DATABASEA, ENTITYB, TYPEB, IDB, DATABASEB, EFFECT, MECHANISM, RESIDUE, SEQUENCE, TAX_ID, CELL_DATA, TISSUE_DATA, MODULATOR_COMPLEX, TARGET_COMPLEX, MODIFICATIONA, MODASEQ, MODIFICATIONB, MODBSEQ, PMID, DIRECT, NOTES, ANNOTATOR, SENTENCE, SCORE, SIGNOR_ID]
# Index: []
#
# [0 rows x 28 columns]

# %%
# This is a code cell. Adjust and customize as needed.
signor_interactions[signor_interactions["ENTITYB"] == "CPT1B"]
# Out:
#            ENTITYA          TYPEA          IDA DATABASEA ENTITYB    TYPEB  \
# 4433         MEF2C        protein       Q06413   UNIPROT   CPT1B  protein
# 9738         EP300        protein       Q09472   UNIPROT   CPT1B  protein
# 14839  malonyl-CoA  smallmolecule  CHEBI:15531     ChEBI   CPT1B  protein
# 16509         RXRA        protein       P19793   UNIPROT   CPT1B  protein
# 17334     PPARGC1A        protein       Q9UBK2   UNIPROT   CPT1B  protein
# 35497        PPARG        protein       P37231   UNIPROT   CPT1B  protein
# 35593         RORA        protein       P35398   UNIPROT   CPT1B  protein
#
#           IDB DATABASEB                               EFFECT  \
# 4433   Q92523   UNIPROT  up-regulates quantity by expression
# 9738   Q92523   UNIPROT  up-regulates quantity by expression
# 14839  Q92523   UNIPROT              down-regulates activity
# 16509  Q92523   UNIPROT  up-regulates quantity by expression
# 17334  Q92523   UNIPROT  up-regulates quantity by expression
# 35497  Q92523   UNIPROT  up-regulates quantity by expression
# 35593  Q92523   UNIPROT  up-regulates quantity by expression
#
#                         MECHANISM  ... MODASEQ MODIFICATIONB  MODBSEQ  \
# 4433   transcriptional regulation  ...     NaN           NaN      NaN
# 9738   transcriptional regulation  ...     NaN           NaN      NaN
# 14839                     binding  ...     NaN           NaN      NaN
# 16509  transcriptional regulation  ...     NaN           NaN      NaN
# 17334  transcriptional regulation  ...     NaN           NaN      NaN
# 35497  transcriptional regulation  ...     NaN           NaN      NaN
# 35593  transcriptional regulation  ...     NaN           NaN      NaN
#
#            PMID DIRECT NOTES ANNOTATOR  \
# 4433   15356291     NO   NaN    miannu
# 9738   15199055     NO   NaN       NaN
# 14839  14517221    YES   NaN    miannu
# 16509  15356291     NO   NaN    miannu
# 17334  15199055     NO   NaN       NaN
# 35497  15356291     NO   NaN    miannu
# 35593  15199055     NO   NaN       NaN
#
#                                                 SENTENCE  SCORE      SIGNOR_ID
# 4433   Mutation analysis indicated that the MEF2 site...  0.200  SIGNOR-254583
# 9738   Furthermore, we show that the muscle carnitine...  0.200  SIGNOR-254260
# 14839  Carnitine palmitoyltransferase 1A (CPT1A) is t...  0.800  SIGNOR-267115
# 16509  Mutation analysis indicated that the MEF2 site...  0.200  SIGNOR-254582
# 17334  Furthermore, we show that the muscle carnitine...  0.365  SIGNOR-254262
# 35497  Mutation analysis indicated that the MEF2 site...  0.357  SIGNOR-254581
# 35593  Furthermore, we show that the muscle carnitine...  0.200  SIGNOR-254256
#
# [7 rows x 28 columns]

# %%
# This is a code cell. Adjust and customize as needed.
import omnipath as op
collectri_interactions = op.interactions.CollecTRI.get(genesymbols=True, organism="human", loops=True)

# %%
# This is a code cell. Adjust and customize as needed.
collectri_interactions_gt_1 = collectri_interactions[collectri_interactions["n_references"] > 1]

# %%
# This is a code cell. Adjust and customize as needed.
collectri_interactions_gt_1_trn_df = collectri_interactions_gt_1[(collectri_interactions_gt_1.source_genesymbol.isin(SIRT1_TARGETS)) 
                 & (collectri_interactions_gt_1.target_genesymbol.isin(recon3d_genes))
                ][["source_genesymbol","target_genesymbol","consensus_stimulation","consensus_inhibition"]]

# %%
# This is a code cell. Adjust and customize as needed.
def create_rule(row):
    if row['consensus_inhibition'] == 1:
        return "(NOT " + row['source_genesymbol'] + ")"
    else:
        return "("+row['source_genesymbol']+")"

sub_df['Rule'] = sub_df.apply(lambda row: create_rule(row), axis=1)

# %%
# This is a code cell. Adjust and customize as needed.
sub_df
# Out:
#           source  target source_genesymbol target_genesymbol  is_directed  \
# 0         P01106  O14746               MYC              TERT            1
# 1         P17947  P02818              SPI1             BGLAP            1
# 3       (P17535)  P05412              JUND               JUN            1
# 4       (P17275)  P05412              JUNB               JUN            1
# 6       (P05412)  P05412               JUN               JUN            1
# ...          ...     ...               ...               ...          ...
# 376010    P26651  P05231             ZFP36               IL6            1
# 376012    P26651  P15692             ZFP36             VEGFA            1
# 376013    Q07352  P15692           ZFP36L1             VEGFA            1
# 376014    Q9P1U0  P08183            POLR1H             ABCB1            1
# 376015    Q9P1U0  P10415            POLR1H              BCL2            1
#
#         is_stimulation  is_inhibition  consensus_direction  \
# 0                    1              0                    1
# 1                    1              0                    1
# 3                    1              0                    1
# 4                    1              0                    1
# 6                    1              0                    1
# ...                ...            ...                  ...
# 376010               0              1                    1
# 376012               0              1                    1
# 376013               0              1                    1
# 376014               1              0                    1
# 376015               1              0                    1
#
#         consensus_stimulation  consensus_inhibition  \
# 0                           1                     0
# 1                           1                     0
# 3                           1                     0
# 4                           1                     0
# 6                           1                     0
# ...                       ...                   ...
# 376010                      0                     1
# 376012                      0                     1
# 376013                      0                     1
# 376014                      1                     0
# 376015                      1                     0
#
#                                                   sources  \
# 0       CollecTRI;DoRothEA;DoRothEA-A_CollecTRI;ExTRI_...
# 1                               CollecTRI;ExTRI_CollecTRI
# 3       CollecTRI;ExTRI_CollecTRI;NTNU.Curated_CollecT...
# 4       CollecTRI;ExTRI_CollecTRI;NTNU.Curated_CollecT...
# 6       CollecTRI;ExTRI_CollecTRI;NTNU.Curated_CollecT...
# ...                                                   ...
# 376010                                             TRRUST
# 376012                                             TRRUST
# 376013                                             TRRUST
# 376014                                             TRRUST
# 376015                                             TRRUST
#
#                                                references         rule  \
# 0       CollecTRI:10022128;CollecTRI:10491298;CollecTR...          MYC
# 1                                      CollecTRI:10022617         SPI1
# 3       CollecTRI:10022869;CollecTRI:10037172;CollecTR...         JUND
# 4       CollecTRI:10022869;CollecTRI:10037172;CollecTR...         JUNB
# 6       CollecTRI:10022869;CollecTRI:10037172;CollecTR...          JUN
# ...                                                   ...          ...
# 376010                                    TRRUST:21656745    NOT ZFP36
# 376012                    TRRUST:21507959;TRRUST:21656745    NOT ZFP36
# 376013                                    TRRUST:19801654  NOT ZFP36L1
# 376014                                    TRRUST:16373708       POLR1H
# 376015                    TRRUST:16373708;TRRUST:16609701       POLR1H
#
#                  Rule
# 0               (MYC)
# 1              (SPI1)
# 3              (JUND)
# 4              (JUNB)
# 6               (JUN)
# ...               ...
# 376010    (NOT ZFP36)
# 376012    (NOT ZFP36)
# 376013  (NOT ZFP36L1)
# 376014       (POLR1H)
# 376015       (POLR1H)
#
# [47916 rows x 14 columns]

# %%
# This is a code cell. Adjust and customize as needed.
sub_df[sub_df["target_genesymbol"] == "PTGS2"]
# Out:
#           source  target source_genesymbol target_genesymbol  is_directed  \
# 760       P04637  P35354              TP53             PTGS2            1
# 761       P20226  P35354               TBP             PTGS2            1
# 876     (Q04864)  P35354               REL             PTGS2            1
# 878     (P19838)  P35354             NFKB1             PTGS2            1
# 882     (Q01201)  P35354              RELB             PTGS2            1
# ...          ...     ...               ...               ...          ...
# 63431     P23246  P35354              SFPQ             PTGS2            1
# 64185     P52747  P35354            ZNF143             PTGS2            1
# 64377     O75030  P35354              MITF             PTGS2            1
# 64753     P15822  P35354            HIVEP1             PTGS2            1
# 375636    P25054  P35354               APC             PTGS2            1
#
#         is_stimulation  is_inhibition  consensus_direction  \
# 760                  0              1                    1
# 761                  1              0                    1
# 876                  1              0                    1
# 878                  1              0                    1
# 882                  1              0                    1
# ...                ...            ...                  ...
# 63431                1              0                    1
# 64185                0              1                    1
# 64377                1              0                    1
# 64753                0              1                    1
# 375636               0              1                    1
#
#         consensus_stimulation  consensus_inhibition  \
# 760                         0                     1
# 761                         1                     0
# 876                         1                     0
# 878                         1                     0
# 882                         1                     0
# ...                       ...                   ...
# 63431                       1                     0
# 64185                       0                     1
# 64377                       1                     0
# 64753                       0                     1
# 375636                      0                     1
#
#                                                   sources  \
# 760     CollecTRI;DoRothEA;ExTRI_CollecTRI;NTNU.Curate...
# 761      CollecTRI;ExTRI_CollecTRI;NTNU.Curated_CollecTRI
# 876     CollecTRI;ExTRI_CollecTRI;GEREDB_CollecTRI;NTN...
# 878     CollecTRI;ExTRI_CollecTRI;GEREDB_CollecTRI;NTN...
# 882     CollecTRI;ExTRI_CollecTRI;GEREDB_CollecTRI;NTN...
# ...                                                   ...
# 63431                          CollecTRI;GEREDB_CollecTRI
# 64185                          CollecTRI;GEREDB_CollecTRI
# 64377                    CollecTRI;NTNU.Curated_CollecTRI
# 64753                    CollecTRI;NTNU.Curated_CollecTRI
# 375636                                             TRRUST
#
#                                                references        rule  \
# 760     CollecTRI:10196169;CollecTRI:11161397;CollecTR...    NOT TP53
# 761                 CollecTRI:10196169;CollecTRI:18204072         TBP
# 876     CollecTRI:10210266;CollecTRI:10395693;CollecTR...         REL
# 878     CollecTRI:10210266;CollecTRI:10395693;CollecTR...       NFKB1
# 882     CollecTRI:10210266;CollecTRI:10395693;CollecTR...        RELB
# ...                                                   ...         ...
# 63431                                  CollecTRI:19339282        SFPQ
# 64185                                  CollecTRI:15763366  NOT ZNF143
# 64377                                  CollecTRI:24471568        MITF
# 64753               CollecTRI:19846662;CollecTRI:23421821  NOT HIVEP1
# 375636    TRRUST:10772828;TRRUST:11396184;TRRUST:12566320     NOT APC
#
#                 Rule
# 760       (NOT TP53)
# 761            (TBP)
# 876            (REL)
# 878          (NFKB1)
# 882           (RELB)
# ...              ...
# 63431         (SFPQ)
# 64185   (NOT ZNF143)
# 64377         (MITF)
# 64753   (NOT HIVEP1)
# 375636     (NOT APC)
#
# [118 rows x 14 columns]

# %%
# This is a code cell. Adjust and customize as needed.
trn_df = sub_df[(sub_df.source_genesymbol.isin(SIRT1_TARGETS)) 
                 & (sub_df.target_genesymbol.isin(recon3d_genes))
                ][["source_genesymbol","target_genesymbol","consensus_stimulation","consensus_inhibition"]]

# %%
# This is a code cell. Adjust and customize as needed.
pd.read_csv("..\\data\\signor\\all_data_03_01_24.tsv",sep="\t")

# %%
# This is a code cell. Adjust and customize as needed.
def create_rule(row):
    if row['consensus_stimulation'] == 1:
        return "("+row['source_genesymbol']+")"
    return "(NOT " + row['source_genesymbol'] + ")"

collectri_interactions_gt_1_trn_df['Rule'] = collectri_interactions_gt_1_trn_df.apply(lambda row: create_rule(row), axis=1)

# %%
# This is a code cell. Adjust and customize as needed.
collectri_interactions_gt_1_trn_df.rename(columns={'target_genesymbol': 'Gene'}, inplace=True)

# %%
# This is a code cell. Adjust and customize as needed.
trn_df = collectri_interactions_gt_1_trn_df

# %%
# This is a code cell. Adjust and customize as needed.
rule_dict = {}

for index, row in trn_df.iterrows():
    target_gene = row["Gene"]
    rule = row["Rule"]
    
    if target_gene in rule_dict:
        if rule not in rule_dict[target_gene]:
            rule_dict[target_gene].append(rule)
    else:
        rule_dict[target_gene] = [rule]

result_data = {"Gene": [], "Rule": []}

for target_gene, rules in rule_dict.items():
    if any("(NOT" in rule for rule in rules):
        concatenated_rules = " AND ".join(rules)
    else:
        concatenated_rules = " OR ".join(rules)
    
    result_data["Gene"].append(target_gene)
    result_data["Rule"].append(concatenated_rules)

# %%
# This is a code cell. Adjust and customize as needed.
result_df = pd.DataFrame(result_data)

# %%
# This is a code cell. Adjust and customize as needed.
result_df
# Out:
#         Gene        Rule
# 0      IGF1R  (NOT TP53)
# 1       POLI      (TP53)
# 2       MDM2      (TP53)
# 3    EIF2AK2      (TP53)
# 4       CHKA      (TP53)
# ..       ...         ...
# 184  GPIHBP1     (PPARG)
# 185       KL     (PPARG)
# 186      ACE     (PPARG)
# 187     VRK1  (NOT TP53)
# 188    PYCR1      (TP53)
#
# [189 rows x 2 columns]

# %%
# This is a code cell. Adjust and customize as needed.
SIRT1_TARGETS.append("SIRT1")

# %%
# This is a code cell. Adjust and customize as needed.
result_df = result_df[~result_df['Gene'].isin(SIRT1_TARGETS)]

# %%
# This is a code cell. Adjust and customize as needed.
SIRT1_TARGETS = ["FOXO1", "PPARGC1A", "PPARG","TP53","FOXO3", "EP300", "FOXO4", "RELA", "CLOCK"]

# %%
# This is a code cell. Adjust and customize as needed.
curated_rules = {
    'Gene':SIRT1_TARGETS,
    'Rule': ["(SIRT1)", "(SIRT1)", "(NOT SIRT1)", "(NOT SIRT1)", "(NOT SIRT1)", "(NOT SIRT1)", "(SIRT1)", "(NOT SIRT1)","(NOT SIRT1)"]
}

# %%
# This is a code cell. Adjust and customize as needed.
result_df = pd.concat([result_df, pd.DataFrame(curated_rules)], ignore_index=True)

# %%
# This is a code cell. Adjust and customize as needed.
result_df
# Out:
#         Gene                                               Rule
# 0        FAS                        (RELA) OR (TP53) OR (PPARG)
# 1      IGF1R              (NOT TP53) AND (FOXO1) AND (NOT RELA)
# 2       POLI                                             (TP53)
# 3      ABCB1  (RELA) AND (NOT TP53) AND (FOXO3) AND (FOXO1) ...
# 4    SLC31A1                                   (RELA) OR (TP53)
# ..       ...                                                ...
# 553    FOXO3                                        (NOT SIRT1)
# 554    EP300                                        (NOT SIRT1)
# 555    FOXO4                                            (SIRT1)
# 556     RELA                                        (NOT SIRT1)
# 557    CLOCK                                        (NOT SIRT1)
#
# [558 rows x 2 columns]

# %%
# This is a code cell. Adjust and customize as needed.
result_df.to_csv("..\\data\\pypath\\sirt1_trn_targets_gt_1_reference.csv", sep = ",", index=False)

# %%
# This is a code cell. Adjust and customize as needed.
result_data['Rule']
# Out:
# ['(RELA) OR (TP53) OR (PPARG)',
#  '(NOT TP53) AND (FOXO1) AND (NOT RELA)',
#  '(TP53)',
#  '(RELA) AND (NOT TP53) AND (FOXO3) AND (FOXO1) AND (EP300)',
#  '(RELA) OR (TP53)',
#  '(TP53) OR (RELA) OR (EP300)',
#  '(RELA)',
#  '(RELA)',
#  '(RELA) AND (NOT PPARG) AND (NOT TP53) AND (FOXO3)',
#  '(TP53) OR (RELA)',
#  '(TP53)',
#  '(PPARG) OR (FOXO1) OR (RELA)',
#  '(NOT TP53) AND (RELA) AND (NOT PPARG) AND (EP300)',
#  '(TP53) OR (EP300)',
#  '(RELA) OR (TP53)',
#  '(TP53) OR (RELA) OR (FOXO3)',
#  '(TP53)',
#  '(NOT RELA) AND (FOXO3) AND (FOXO4) AND (NOT TP53)',
#  '(RELA) AND (NOT TP53) AND (NOT FOXO1) AND (NOT FOXO3) AND (PPARG)',
#  '(PPARG) OR (FOXO1)',
#  '(PPARG)',
#  '(TP53) OR (EP300)',
#  '(TP53)',
#  '(TP53) OR (PPARG)',
#  '(RELA) AND (TP53) AND (NOT FOXO1)',
#  '(RELA) OR (TP53)',
#  '(RELA) OR (TP53) OR (FOXO3) OR (FOXO4) OR (PPARGC1A) OR (FOXO1) OR (PPARG)',
#  '(NOT TP53) AND (NOT FOXO1)',
#  '(RELA) AND (NOT TP53)',
#  '(TP53) OR (PPARG) OR (RELA)',
#  '(PPARG) AND (NOT FOXO1) AND (PPARGC1A)',
#  '(TP53) OR (PPARG) OR (RELA) OR (EP300)',
#  '(RELA)',
#  '(TP53)',
#  '(TP53) OR (RELA)',
#  '(TP53) OR (RELA)',
#  '(RELA) OR (TP53)',
#  '(RELA) OR (PPARG)',
#  '(RELA) OR (PPARG)',
#  '(RELA) OR (PPARG) OR (TP53) OR (FOXO1) OR (PPARGC1A)',
#  '(RELA)',
#  '(NOT PPARG) AND (NOT RELA)',
#  '(RELA) OR (TP53)',
#  '(TP53) OR (EP300)',
#  '(NOT TP53)',
#  '(TP53)',
#  '(RELA)',
#  '(TP53) OR (RELA) OR (FOXO3)',
#  '(RELA) OR (PPARG) OR (FOXO1) OR (FOXO3)',
#  '(NOT RELA) AND (PPARG) AND (FOXO1)',
#  '(PPARG) AND (EP300) AND (NOT TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53) OR (RELA)',
#  '(NOT TP53)',
#  '(RELA)',
#  '(PPARG)',
#  '(NOT TP53)',
#  '(TP53)',
#  '(RELA) OR (FOXO1) OR (TP53) OR (PPARGC1A)',
#  '(TP53)',
#  '(RELA)',
#  '(FOXO3) OR (RELA) OR (TP53)',
#  '(NOT TP53) AND (RELA) AND (EP300)',
#  '(TP53) OR (RELA)',
#  '(NOT TP53)',
#  '(PPARG) OR (TP53) OR (RELA)',
#  '(NOT TP53)',
#  '(RELA)',
#  '(TP53) OR (RELA)',
#  '(RELA) OR (FOXO3)',
#  '(RELA)',
#  '(TP53)',
#  '(RELA) AND (NOT PPARG)',
#  '(NOT RELA) AND (TP53)',
#  '(RELA) AND (NOT PPARG) AND (TP53)',
#  '(RELA)',
#  '(TP53)',
#  '(TP53) AND (RELA) AND (FOXO3) AND (NOT PPARG)',
#  '(NOT TP53) AND (RELA)',
#  '(NOT TP53) AND (RELA)',
#  '(TP53)',
#  '(TP53) OR (FOXO1)',
#  '(TP53) OR (RELA) OR (FOXO3) OR (FOXO1) OR (FOXO4)',
#  '(RELA) OR (TP53)',
#  '(TP53) OR (RELA)',
#  '(TP53)',
#  '(TP53)',
#  '(PPARG) AND (NOT FOXO1)',
#  '(RELA)',
#  '(RELA)',
#  '(RELA)',
#  '(RELA)',
#  '(FOXO3) OR (RELA) OR (TP53)',
#  '(PPARG) OR (RELA)',
#  '(FOXO3)',
#  '(RELA)',
#  '(TP53) OR (RELA)',
#  '(RELA) OR (TP53)',
#  '(NOT TP53)',
#  '(TP53) OR (PPARG) OR (RELA)',
#  '(TP53)',
#  '(FOXO1) AND (NOT PPARG) AND (NOT TP53) AND (RELA) AND (PPARGC1A)',
#  '(NOT TP53) AND (RELA) AND (NOT PPARG) AND (FOXO1)',
#  '(PPARG) OR (TP53) OR (FOXO3) OR (FOXO1)',
#  '(RELA)',
#  '(RELA) AND (NOT TP53)',
#  '(NOT TP53) AND (RELA) AND (EP300)',
#  '(TP53)',
#  '(TP53)',
#  '(PPARG) OR (TP53)',
#  '(RELA)',
#  '(TP53) OR (RELA) OR (PPARG)',
#  '(TP53)',
#  '(TP53)',
#  '(NOT TP53) AND (RELA)',
#  '(NOT TP53) AND (NOT FOXO1)',
#  '(RELA)',
#  '(RELA) OR (FOXO1) OR (TP53)',
#  '(RELA)',
#  '(PPARG) OR (FOXO1)',
#  '(RELA)',
#  '(FOXO1) AND (FOXO3) AND (NOT RELA) AND (NOT PPARG)',
#  '(RELA) OR (PPARG)',
#  '(TP53) OR (RELA) OR (PPARG)',
#  '(NOT PPARG) AND (TP53)',
#  '(PPARG) OR (TP53) OR (RELA)',
#  '(TP53)',
#  '(RELA) AND (NOT PPARG)',
#  '(RELA)',
#  '(RELA)',
#  '(FOXO1)',
#  '(TP53) OR (RELA)',
#  '(TP53)',
#  '(RELA)',
#  '(PPARG) OR (TP53)',
#  '(PPARG) OR (RELA)',
#  '(RELA)',
#  '(PPARG) OR (RELA)',
#  '(RELA) OR (FOXO1)',
#  '(PPARG)',
#  '(PPARG) OR (RELA) OR (FOXO3)',
#  '(TP53) OR (EP300)',
#  '(TP53)',
#  '(RELA) OR (TP53)',
#  '(NOT TP53) AND (RELA) AND (FOXO1)',
#  '(RELA) OR (TP53)',
#  '(NOT PPARG) AND (RELA)',
#  '(RELA)',
#  '(RELA) OR (TP53) OR (EP300)',
#  '(NOT TP53)',
#  '(RELA)',
#  '(TP53) OR (RELA)',
#  '(NOT TP53) AND (RELA) AND (FOXO3) AND (PPARG)',
#  '(TP53)',
#  '(NOT RELA)',
#  '(RELA)',
#  '(RELA)',
#  '(TP53) OR (RELA)',
#  '(TP53)',
#  '(RELA) OR (TP53)',
#  '(TP53) OR (RELA)',
#  '(PPARG)',
#  '(NOT TP53)',
#  '(TP53) OR (RELA) OR (EP300)',
#  '(RELA)',
#  '(RELA) OR (PPARG) OR (FOXO3)',
#  '(RELA) AND (NOT TP53)',
#  '(NOT PPARG) AND (RELA) AND (FOXO1) AND (TP53)',
#  '(RELA) OR (FOXO4)',
#  '(RELA) OR (FOXO3)',
#  '(RELA)',
#  '(RELA)',
#  '(FOXO1)',
#  '(PPARG) OR (TP53) OR (PPARGC1A)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(PPARG) OR (EP300)',
#  '(PPARG) OR (TP53)',
#  '(RELA)',
#  '(TP53) AND (NOT PPARG)',
#  '(NOT TP53) AND (RELA)',
#  '(TP53) OR (RELA)',
#  '(TP53)',
#  '(TP53) OR (FOXO3)',
#  '(RELA) OR (PPARG)',
#  '(RELA)',
#  '(RELA) OR (TP53)',
#  '(PPARG) OR (RELA)',
#  '(PPARG) OR (TP53)',
#  '(TP53)',
#  '(RELA)',
#  '(FOXO1) OR (PPARG)',
#  '(PPARG)',
#  '(RELA) OR (FOXO1)',
#  '(TP53) OR (FOXO3)',
#  '(RELA)',
#  '(TP53)',
#  '(TP53) AND (NOT FOXO1)',
#  '(PPARG) AND (RELA) AND (NOT TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(NOT FOXO1) AND (PPARGC1A) AND (PPARG)',
#  '(NOT RELA)',
#  '(TP53)',
#  '(NOT TP53)',
#  '(TP53) AND (NOT RELA)',
#  '(TP53) OR (RELA)',
#  '(PPARG) AND (NOT RELA)',
#  '(TP53)',
#  '(RELA)',
#  '(RELA)',
#  '(RELA) OR (EP300)',
#  '(RELA)',
#  '(PPARG) OR (RELA)',
#  '(RELA)',
#  '(RELA)',
#  '(RELA)',
#  '(TP53)',
#  '(TP53) OR (RELA)',
#  '(PPARG)',
#  '(RELA) AND (NOT TP53)',
#  '(PPARG)',
#  '(PPARG) OR (TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(FOXO3) OR (RELA)',
#  '(RELA) OR (TP53) OR (FOXO1)',
#  '(PPARG) OR (FOXO1)',
#  '(TP53) OR (FOXO1) OR (PPARG) OR (FOXO3)',
#  '(TP53) OR (RELA)',
#  '(RELA) AND (NOT PPARG)',
#  '(FOXO3)',
#  '(RELA) OR (FOXO3)',
#  '(RELA)',
#  '(TP53)',
#  '(FOXO3)',
#  '(TP53)',
#  '(RELA) OR (TP53)',
#  '(RELA) OR (PPARG)',
#  '(NOT TP53) AND (FOXO3) AND (RELA)',
#  '(RELA)',
#  '(TP53)',
#  '(RELA)',
#  '(TP53)',
#  '(FOXO3) OR (RELA)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53) AND (NOT RELA) AND (RELA)',
#  '(TP53)',
#  '(RELA)',
#  '(FOXO1) OR (FOXO3) OR (RELA) OR (FOXO4)',
#  '(PPARG) OR (FOXO1)',
#  '(TP53) OR (RELA) OR (PPARG)',
#  '(RELA)',
#  '(RELA)',
#  '(RELA)',
#  '(RELA) AND (NOT TP53)',
#  '(RELA)',
#  '(RELA)',
#  '(RELA)',
#  '(FOXO1)',
#  '(TP53)',
#  '(NOT TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(NOT RELA)',
#  '(RELA)',
#  '(RELA)',
#  '(TP53)',
#  '(RELA)',
#  '(TP53) OR (FOXO1) OR (FOXO3)',
#  '(NOT RELA)',
#  '(RELA)',
#  '(NOT PPARG) AND (RELA)',
#  '(TP53)',
#  '(RELA)',
#  '(TP53)',
#  '(RELA) AND (FOXO1) AND (NOT PPARG)',
#  '(RELA)',
#  '(RELA)',
#  '(NOT PPARG)',
#  '(RELA)',
#  '(NOT PPARG)',
#  '(RELA)',
#  '(RELA)',
#  '(RELA)',
#  '(FOXO3) AND (TP53) AND (NOT RELA)',
#  '(NOT RELA)',
#  '(RELA)',
#  '(RELA) OR (FOXO3)',
#  '(PPARG)',
#  '(TP53) OR (RELA)',
#  '(TP53)',
#  '(RELA)',
#  '(RELA)',
#  '(RELA)',
#  '(RELA)',
#  '(TP53)',
#  '(PPARG)',
#  '(TP53)',
#  '(RELA) OR (PPARGC1A)',
#  '(TP53)',
#  '(RELA)',
#  '(TP53) OR (RELA)',
#  '(RELA) OR (TP53)',
#  '(RELA) OR (EP300)',
#  '(FOXO3)',
#  '(RELA)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53) AND (NOT RELA) AND (FOXO1)',
#  '(PPARG)',
#  '(TP53)',
#  '(RELA)',
#  '(RELA)',
#  '(RELA) OR (FOXO3)',
#  '(TP53)',
#  '(RELA)',
#  '(RELA)',
#  '(FOXO1)',
#  '(RELA)',
#  '(TP53)',
#  '(PPARG)',
#  '(TP53)',
#  '(TP53) OR (FOXO3) OR (FOXO4)',
#  '(RELA) OR (TP53)',
#  '(RELA)',
#  '(NOT TP53)',
#  '(TP53)',
#  '(PPARG) OR (FOXO3)',
#  '(RELA) OR (EP300)',
#  '(TP53)',
#  '(TP53)',
#  '(RELA)',
#  '(TP53) OR (RELA)',
#  '(RELA)',
#  '(NOT FOXO1)',
#  '(NOT PPARG)',
#  '(NOT PPARG)',
#  '(NOT TP53)',
#  '(RELA)',
#  '(RELA)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(RELA)',
#  '(RELA)',
#  '(TP53) OR (PPARG)',
#  '(TP53) OR (RELA)',
#  '(TP53)',
#  '(PPARG) OR (RELA)',
#  '(RELA) OR (FOXO3)',
#  '(PPARG) AND (NOT TP53)',
#  '(FOXO3)',
#  '(PPARG)',
#  '(TP53)',
#  '(PPARG)',
#  '(FOXO1)',
#  '(NOT PPARG) AND (NOT PPARGC1A)',
#  '(RELA) AND (NOT PPARG)',
#  '(TP53)',
#  '(RELA)',
#  '(PPARG)',
#  '(PPARG)',
#  '(FOXO1) OR (FOXO3)',
#  '(NOT TP53)',
#  '(TP53) AND (NOT PPARG)',
#  '(TP53)',
#  '(TP53)',
#  '(NOT FOXO1)',
#  '(TP53)',
#  '(RELA)',
#  '(RELA)',
#  '(TP53)',
#  '(RELA)',
#  '(NOT TP53) AND (NOT FOXO1)',
#  '(NOT TP53)',
#  '(PPARG)',
#  '(TP53)',
#  '(TP53)',
#  '(RELA)',
#  '(RELA)',
#  '(FOXO1) OR (TP53)',
#  '(RELA)',
#  '(RELA)',
#  '(RELA) OR (TP53)',
#  '(TP53) OR (PPARG)',
#  '(RELA)',
#  '(TP53)',
#  '(NOT TP53) AND (NOT FOXO1)',
#  '(PPARG)',
#  '(RELA) AND (NOT PPARG)',
#  '(RELA)',
#  '(TP53)',
#  '(RELA)',
#  '(TP53)',
#  '(FOXO4)',
#  '(PPARG)',
#  '(FOXO1) AND (NOT TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(FOXO1)',
#  '(TP53)',
#  '(TP53)',
#  '(RELA)',
#  '(RELA)',
#  '(NOT TP53)',
#  '(RELA)',
#  '(TP53)',
#  '(NOT TP53) AND (PPARG)',
#  '(NOT TP53)',
#  '(RELA)',
#  '(RELA)',
#  '(TP53)',
#  '(FOXO1) AND (PPARGC1A) AND (NOT RELA)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(EP300)',
#  '(EP300)',
#  '(FOXO1)',
#  '(PPARG)',
#  '(PPARG) OR (EP300) OR (PPARGC1A)',
#  '(NOT PPARG)',
#  '(PPARG)',
#  '(PPARGC1A)',
#  '(PPARGC1A)',
#  '(PPARGC1A)',
#  '(PPARGC1A)',
#  '(PPARGC1A)',
#  '(RELA)',
#  '(RELA)',
#  '(NOT RELA)',
#  '(RELA)',
#  '(NOT RELA)',
#  '(RELA)',
#  '(RELA)',
#  '(RELA)',
#  '(RELA)',
#  '(NOT RELA)',
#  '(NOT RELA) AND (PPARGC1A)',
#  '(TP53)',
#  '(FOXO1)',
#  '(NOT FOXO1)',
#  '(NOT FOXO1)',
#  '(FOXO1)',
#  '(FOXO1) OR (FOXO3)',
#  '(NOT FOXO1)',
#  '(FOXO1)',
#  '(NOT FOXO1)',
#  '(NOT FOXO1)',
#  '(NOT FOXO1) AND (PPARG)',
#  '(NOT FOXO1)',
#  '(FOXO1)',
#  '(FOXO1)',
#  '(FOXO1)',
#  '(FOXO1)',
#  '(NOT FOXO1)',
#  '(NOT FOXO1)',
#  '(NOT FOXO1)',
#  '(FOXO1)',
#  '(NOT FOXO1) AND (PPARG)',
#  '(NOT FOXO1)',
#  '(FOXO1)',
#  '(RELA)',
#  '(TP53)',
#  '(NOT TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(FOXO3)',
#  '(FOXO3)',
#  '(FOXO3)',
#  '(FOXO3) OR (RELA)',
#  '(FOXO3)',
#  '(NOT PPARG)',
#  '(NOT PPARG)',
#  '(EP300)',
#  '(FOXO3)',
#  '(FOXO4) OR (FOXO3) OR (FOXO1)',
#  '(NOT PPARG)',
#  '(NOT TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(PPARGC1A)',
#  '(PPARGC1A)',
#  '(FOXO1)',
#  '(FOXO1) AND (NOT FOXO3)',
#  '(FOXO1)',
#  '(FOXO1)',
#  '(FOXO3)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(PPARG)',
#  '(RELA)',
#  '(NOT RELA)',
#  '(NOT TP53)',
#  '(TP53)',
#  '(NOT TP53)',
#  '(NOT TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(NOT TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(NOT TP53)',
#  '(TP53)',
#  '(TP53)',
#  '(NOT TP53)',
#  '(TP53)',
#  '(PPARGC1A)',
#  '(FOXO1)',
#  '(NOT FOXO1)',
#  '(FOXO1)',
#  '(FOXO1)',
#  '(NOT FOXO1)']

# %%
# This is a code cell. Adjust and customize as needed.
from statistics import mean

data = [0.4,0.6]
average = mean(data)

print(average)
# Out:
# 0.5

# %%
# This is a code cell. Adjust and customize as needed.
