# %%
from mewpy.io import Reader, Engines, read_model, read_json
from mewpy.germ.analysis import get_real_initial_state, ifva, SRFBA, FBA
import pandas as pd
import os
import numpy as np
import re

# %%
import re

# %%
generic_sbml_fname = "..\\data\\models\\sirt1_recon3d\\iSIRT1.xml"
trn_fname = "..\\data\\pypath\\regulatory_rules.csv"

# %%
trn_reader = Reader(Engines.BooleanRegulatoryCSV,
                            trn_fname, sep=',', id_col=0, rule_col=1, header=0)
generic_recon_reader = Reader(Engines.MetabolicSBML, generic_sbml_fname)

generic_model = read_model(generic_recon_reader, trn_reader)

# %%
import pandas as pd

# %%
irreversibles = list(pd.read_excel("..\\data\\reaction_constraints\\irreversible.xlsx", header=None)[0])

# %%
closed = list(pd.read_excel("..\\data\\reaction_constraints\\closed.xlsx", header=None)[0])

# %%
diets = pd.read_excel("..\\data\\diets\\NewDiets.xlsx").set_index("Index")

# %%
diet = diets.to_dict()["High-fat diet"]

# %%
for rxn in generic_model.reactions.keys():
    rxn_name = rxn
    if re.search(r"^EX", rxn_name):
        if rxn_name in diet:
            generic_model.get(rxn_name).bounds = (-1 * diet[rxn_name], 1000)
        else:
            generic_model.get(rxn_name).bounds = (0, 1000)
    elif re.search("sink", rxn) or rxn_name in closed:
        generic_model.get(rxn_name).bounds = (0,0)
    elif rxn_name in irreversibles:
        generic_model.get(rxn_name).bounds = (0,1000)

# %%
for rxn in generic_model.reactions.keys():
    rxn_name = rxn
    if re.search(r"^EX", rxn_name):
        if rxn_name in diet:
            print(rxn_name, generic_model.get(rxn_name).bounds)
        else:
            print(rxn_name, generic_model.get(rxn_name).bounds)
    elif re.search("sink", rxn) or rxn_name in closed:
        print(rxn_name, generic_model.get(rxn_name).bounds)
    elif rxn_name in irreversibles:
        print(rxn_name, generic_model.get(rxn_name).bounds)
# Out:
# EX_10fthf[e] (0, 1000)
# EX_10fthf5glu[e] (0, 1000)
# EX_10fthf6glu[e] (0, 1000)
# EX_10fthf7glu[e] (0, 1000)
# EX_11_cis_retfa[e] (-1.0, 1000)
# EX_13_cis_retnglc[e] (0, 1000)
# EX_1glyc_hs[e] (0, 1000)
# EX_2425dhvitd2[e] (0, 1000)
# EX_2425dhvitd3[e] (0, 1000)
# EX_24nph[e] (0, 1000)
# EX_25hvitd2[e] (0, 1000)
# EX_25hvitd3[e] (0, 1000)
# EX_2hb[e] (0, 1000)
# EX_2mcit[e] (0, 1000)
# EX_34dhoxpeg[e] (0, 1000)
# EX_34dhphe[e] (0, 1000)
# EX_35cgmp[e] (0, 1000)
# EX_3aib[e] (0, 1000)
# EX_3aib_D[e] (0, 1000)
# EX_3mlda[e] (0, 1000)
# EX_4hdebrisoquine[e] (0, 1000)
# EX_4hphac[e] (0, 1000)
# EX_4mptnl[e] (0, 1000)
# EX_4mtolbutamide[e] (0, 1000)
# EX_4nph[e] (0, 1000)
# EX_4nphsf[e] (0, 1000)
# EX_4pyrdx[e] (0, 1000)
# EX_5adtststerone[e] (0, 1000)
# EX_5adtststeroneglc[e] (0, 1000)
# EX_5adtststerones[e] (0, 1000)
# EX_5dhf[e] (0, 1000)
# EX_5fthf[e] (0, 1000)
# EX_5homeprazole[e] (0, 1000)
# EX_5htrp[e] (0, 1000)
# EX_5mthf[e] (0, 1000)
# EX_5thf[e] (0, 1000)
# EX_6dhf[e] (0, 1000)
# EX_6htststerone[e] (0, 1000)
# EX_6thf[e] (0, 1000)
# EX_7dhf[e] (0, 1000)
# EX_7thf[e] (0, 1000)
# EX_9_cis_retfa[e] (0, 1000)
# EX_abt[e] (0, 1000)
# EX_acetone[e] (0, 1000)
# EX_acgalfucgalacgalfuc12gal14acglcgalgluside_hs[e] (0, 1000)
# EX_acgalfucgalacgalfucgalacglcgal14acglcgalgluside_hs[e] (0, 1000)
# EX_ach[e] (0, 1000)
# EX_acn13acngalgbside_hs[e] (0, 1000)
# EX_acn23acngalgbside_hs[e] (0, 1000)
# EX_acnacngal14acglcgalgluside_hs[e] (0, 1000)
# EX_acnacngalgbside_hs[e] (0, 1000)
# EX_acngalacglcgal14acglcgalgluside_hs[e] (0, 1000)
# EX_adp[e] (-2.0, 1000)
# EX_adprbp[e] (0, 1000)
# EX_adrn[e] (0, 1000)
# EX_adrnl[e] (0, 1000)
# EX_aflatoxin[e] (0, 1000)
# EX_ahandrostanglc[e] (0, 1000)
# EX_ak2lgchol_hs[e] (0, 1000)
# EX_ala_B[e] (0, 1000)
# EX_ala_D[e] (0, 1000)
# EX_aldstrn[e] (0, 1000)
# EX_amp[e] (0, 1000)
# EX_andrstrn[e] (0, 1000)
# EX_andrstrnglc[e] (0, 1000)
# EX_antipyrene[e] (0, 1000)
# EX_apnnox[e] (0, 1000)
# EX_appnn[e] (0, 1000)
# EX_aprgstrn[e] (0, 1000)
# EX_aqcobal[e] (-1.0, 1000)
# EX_arach[e] (-0.3125, 1000)
# EX_arachd[e] (-0.3125, 1000)
# EX_ascb_L[e] (0, 1000)
# EX_asp_D[e] (0, 1000)
# EX_atp[e] (0, 1000)
# EX_avite1[e] (-1.0, 1000)
# EX_avite2[e] (0, 1000)
# EX_bhb[e] (0, 1000)
# EX_bildglcur[e] (0, 1000)
# EX_bilglcur[e] (0, 1000)
# EX_bilirub[e] (0, 1000)
# EX_biocyt[e] (0, 1000)
# EX_bvite[e] (0, 1000)
# EX_camp[e] (0, 1000)
# EX_caro[e] (0, 1000)
# EX_carveol[e] (0, 1000)
# EX_chol[e] (-1.0, 1000)
# EX_cholate[e] (0, 1000)
# EX_chsterol[e] (-0.231481481481481, 1000)
# EX_chtn[e] (0, 1000)
# EX_clpnd[e] (0, 1000)
# EX_cmp[e] (0, 1000)
# EX_co[e] (0, 1000)
# EX_coumarin[e] (0, 1000)
# EX_creat[e] (-1.0, 1000)
# EX_crmp_hs[e] (0, 1000)
# EX_crn[e] (0, 1000)
# EX_crtsl[e] (0, 1000)
# EX_crtstrn[e] (0, 1000)
# EX_crvnc[e] (0, 1000)
# EX_cspg_a[e] (0, 1000)
# EX_cspg_b[e] (0, 1000)
# EX_cspg_c[e] (0, 1000)
# EX_cspg_d[e] (0, 1000)
# EX_cspg_e[e] (0, 1000)
# EX_cyan[e] (0, 1000)
# EX_dag_hs[e] (0, 1000)
# EX_dcsptn1[e] (0, 1000)
# EX_debrisoquine[e] (0, 1000)
# EX_dgchol[e] (0, 1000)
# EX_dhdascb[e] (0, 1000)
# EX_dheas[e] (0, 1000)
# EX_dhf[e] (0, 1000)
# EX_digalsgalside_hs[e] (0, 1000)
# EX_dlnlcg[e] (0, 1000)
# EX_dmantipyrine[e] (0, 1000)
# EX_dmhptcrn[e] (0, 1000)
# EX_dopa[e] (0, 1000)
# EX_dopasf[e] (0, 1000)
# EX_eaflatoxin[e] (0, 1000)
# EX_ebastine[e] (0, 1000)
# EX_ebastineoh[e] (0, 1000)
# EX_eicostet[e] (0, 1000)
# EX_elaid[e] (0, 1000)
# EX_estradiol[e] (0, 1000)
# EX_estradiolglc[e] (0, 1000)
# EX_estriolglc[e] (0, 1000)
# EX_estroneglc[e] (0, 1000)
# EX_estrones[e] (0, 1000)
# EX_fuc13galacglcgal14acglcgalgluside_hs[e] (0, 1000)
# EX_fuc14galacglcgalgluside_hs[e] (0, 1000)
# EX_fucacgalfucgalacglcgalgluside_hs[e] (0, 1000)
# EX_fucacngal14acglcgalgluside_hs[e] (0, 1000)
# EX_fucacngalacglcgalgluside_hs[e] (0, 1000)
# EX_fucfuc12gal14acglcgalgluside_hs[e] (0, 1000)
# EX_fucfuc132galacglcgal14acglcgalgluside_hs[e] (0, 1000)
# EX_fucfucfucgalacglc13galacglcgal14acglcgalgluside_hs[e] (0, 1000)
# EX_fucfucfucgalacglcgal14acglcgalgluside_hs[e] (0, 1000)
# EX_fucfucgalacglcgalgluside_hs[e] (0, 1000)
# EX_fucgal14acglcgalgluside_hs[e] (0, 1000)
# EX_fucgalfucgalacglcgalgluside_hs[e] (0, 1000)
# EX_fucgalgbside_hs[e] (0, 1000)
# EX_fuc_L[e] (0, 1000)
# EX_galacglcgalgbside_hs[e] (0, 1000)
# EX_galfuc12gal14acglcgalgluside_hs[e] (0, 1000)
# EX_galfucgalacglcgal14acglcgalgluside_hs[e] (0, 1000)
# EX_galgalfucfucgalacglcgalacglcgal14acglcgalgluside_hs[e] (0, 1000)
# EX_galgalgalthcrm_hs[e] (0, 1000)
# EX_gbside_hs[e] (0, 1000)
# EX_gchola[e] (0, 1000)
# EX_gd1b2_hs[e] (0, 1000)
# EX_gd1c_hs[e] (0, 1000)
# EX_gdp[e] (0, 1000)
# EX_gluala[e] (0, 1000)
# EX_glyc_S[e] (0, 1000)
# EX_glygn2[e] (0, 1000)
# EX_glygn4[e] (0, 1000)
# EX_glygn5[e] (0, 1000)
# EX_gmp[e] (0, 1000)
# EX_gp1c_hs[e] (0, 1000)
# EX_gp1calpha_hs[e] (0, 1000)
# EX_gq1b_hs[e] (0, 1000)
# EX_gq1balpha_hs[e] (0, 1000)
# EX_gsn[e] (0, 1000)
# EX_gt1a_hs[e] (0, 1000)
# EX_gthox[e] (0, 1000)
# EX_gthrd[e] (0, 1000)
# EX_gtp[e] (0, 1000)
# EX_h2o2[e] (0, 1000)
# EX_ha[e] (0, 1000)
# EX_ha_pre1[e] (0, 1000)
# EX_hco3[e] (-100.0, 1000)
# EX_hcoumarin[e] (0, 1000)
# EX_hdca[e] (-0.390625, 1000)
# EX_hdcea[e] (-0.390625, 1000)
# EX_hestratriol[e] (0, 1000)
# EX_hexc[e] (0, 1000)
# EX_hista[e] (0, 1000)
# EX_hom_L[e] (0, 1000)
# EX_hpdca[e] (0, 1000)
# EX_hspg[e] (0, 1000)
# EX_htaxol[e] (0, 1000)
# EX_i[e] (0, 1000)
# EX_idp[e] (0, 1000)
# EX_imp[e] (0, 1000)
# EX_inost[e] (-1.0, 1000)
# EX_ksi[e] (0, 1000)
# EX_ksi_deg1[e] (0, 1000)
# EX_ksii_core2[e] (0, 1000)
# EX_ksii_core4[e] (0, 1000)
# EX_lac_D[e] (0, 1000)
# EX_Lcystin[e] (0, 1000)
# EX_leuktrA4[e] (0, 1000)
# EX_leuktrB4[e] (0, 1000)
# EX_leuktrC4[e] (0, 1000)
# EX_leuktrD4[e] (0, 1000)
# EX_leuktrE4[e] (0, 1000)
# EX_leuktrF4[e] (0, 1000)
# EX_lgnc[e] (0, 1000)
# EX_limnen[e] (0, 1000)
# EX_lipoate[e] (-1.0, 1000)
# EX_lneldc[e] (0, 1000)
# EX_lnlc[e] (-0.347222222222222, 1000)
# EX_lnlnca[e] (-0.347222222222222, 1000)
# EX_lnlncg[e] (0, 1000)
# EX_lpchol_hs[e] (0, 1000)
# EX_mag_hs[e] (0, 1000)
# EX_meoh[e] (0, 1000)
# EX_mercplaccys[e] (0, 1000)
# EX_mthgxl[e] (0, 1000)
# EX_n2m2nmasn[e] (0, 1000)
# EX_nad[e] (0, 1000)
# EX_nadp[e] (0, 1000)
# EX_ncam[e] (-1.0, 1000)
# EX_nifedipine[e] (0, 1000)
# EX_no[e] (0, 1000)
# EX_npthl[e] (0, 1000)
# EX_nrpphr[e] (0, 1000)
# EX_nrpphrsf[e] (0, 1000)
# EX_nrvnc[e] (0, 1000)
# EX_o2s[e] (0, 1000)
# EX_oagd3_hs[e] (0, 1000)
# EX_oagt3_hs[e] (0, 1000)
# EX_ocdca[e] (-0.347222222222222, 1000)
# EX_ocdcea[e] (-0.347222222222222, 1000)
# EX_octa[e] (-0.78125, 1000)
# EX_omeprazole[e] (0, 1000)
# EX_onpthl[e] (0, 1000)
# EX_oxa[e] (0, 1000)
# EX_paf_hs[e] (0, 1000)
# EX_pchol_hs[e] (0, 1000)
# EX_pe_hs[e] (0, 1000)
# EX_peplys[e] (0, 1000)
# EX_perillyl[e] (0, 1000)
# EX_pglyc_hs[e] (0, 1000)
# EX_pheacgln[e] (0, 1000)
# EX_phyQ[e] (0, 1000)
# EX_phyt[e] (0, 1000)
# EX_prgstrn[e] (0, 1000)
# EX_prostgd2[e] (0, 1000)
# EX_prostge1[e] (0, 1000)
# EX_prostge2[e] (0, 1000)
# EX_prostgf2[e] (0, 1000)
# EX_ps_hs[e] (0, 1000)
# EX_ptdca[e] (0, 1000)
# EX_rbt[e] (0, 1000)
# EX_retfa[e] (0, 1000)
# EX_retinol[e] (0, 1000)
# EX_retinol_9_cis[e] (0, 1000)
# EX_retinol_cis_11[e] (0, 1000)
# EX_retn[e] (-1.0, 1000)
# EX_retnglc[e] (0, 1000)
# EX_Rtotal[e] (0, 1000)
# EX_Rtotal2[e] (0, 1000)
# EX_Rtotal3[e] (0, 1000)
# EX_s2l2fn2m2masn[e] (0, 1000)
# EX_s2l2n2m2masn[e] (0, 1000)
# EX_sarcs[e] (0, 1000)
# EX_sl_L[e] (0, 1000)
# EX_spc_hs[e] (0, 1000)
# EX_sph1p[e] (0, 1000)
# EX_sphs1p[e] (0, 1000)
# EX_srtn[e] (0, 1000)
# EX_strch1[e] (-0.0126262626262626, 1000)
# EX_strch2[e] (0, 1000)
# EX_strdnc[e] (0, 1000)
# EX_tag_hs[e] (0, 1000)
# EX_tagat_D[e] (0, 1000)
# EX_taxol[e] (0, 1000)
# EX_tchola[e] (0, 1000)
# EX_tcynt[e] (0, 1000)
# EX_tdchola[e] (0, 1000)
# EX_tethex3[e] (0, 1000)
# EX_tetpent3[e] (0, 1000)
# EX_tetpent6[e] (0, 1000)
# EX_tettet6[e] (0, 1000)
# EX_thf[e] (0, 1000)
# EX_thmmp[e] (0, 1000)
# EX_thmtp[e] (0, 1000)
# EX_thym[e] (0, 1000)
# EX_thyox_L[e] (0, 1000)
# EX_tmndnc[e] (0, 1000)
# EX_tolbutamide[e] (0, 1000)
# EX_triodthy[e] (0, 1000)
# EX_triodthysuf[e] (0, 1000)
# EX_tststerone[e] (0, 1000)
# EX_tststeroneglc[e] (0, 1000)
# EX_tststerones[e] (0, 1000)
# EX_tsul[e] (0, 1000)
# EX_ttdca[e] (-0.446428571428571, 1000)
# EX_txa2[e] (0, 1000)
# EX_tymsf[e] (0, 1000)
# EX_Tyr_ggn[e] (0, 1000)
# EX_udp[e] (0, 1000)
# EX_ump[e] (0, 1000)
# EX_urate[e] (0, 1000)
# EX_utp[e] (0, 1000)
# EX_vacc[e] (0, 1000)
# EX_vitd3[e] (0, 1000)
# EX_whddca[e] (0, 1000)
# EX_whhdca[e] (0, 1000)
# EX_whtststerone[e] (0, 1000)
# EX_whttdca[e] (0, 1000)
# EX_xolest_hs[e] (0, 1000)
# EX_xolest2_hs[e] (0, 1000)
# EX_xoltri24[e] (0, 1000)
# EX_xoltri25[e] (0, 1000)
# EX_xoltri27[e] (0, 1000)
# EX_xylt[e] (0, 1000)
# EX_yvite[e] (0, 1000)
# sink_citr[c] (0, 0)
# sink_pre_prot[r] (0, 0)
# UDPGLCAter (0, 1000)
# EX_4abutn[e] (0, 1000)
# EX_acmana[e] (0, 1000)
# EX_ahdt[e] (0, 1000)
# EX_ctp[e] (0, 1000)
# EX_dgmp[e] (0, 1000)
# EX_dgtp[e] (0, 1000)
# EX_dha[e] (0, 1000)
# EX_dhap[e] (0, 1000)
# EX_dtmp[e] (0, 1000)
# EX_dttp[e] (0, 1000)
# EX_fad[e] (0, 1000)
# EX_fald[e] (0, 1000)
# EX_g1p[e] (0, 1000)
# EX_HC00229[e] (0, 1000)
# EX_HC00250[e] (0, 1000)
# EX_HC01104[e] (0, 1000)
# EX_HC01361[e] (0, 1000)
# EX_HC01440[e] (0, 1000)
# EX_HC01441[e] (0, 1000)
# EX_HC01444[e] (0, 1000)
# EX_HC01446[e] (0, 1000)
# EX_HC01577[e] (0, 1000)
# EX_HC01609[e] (0, 1000)
# EX_HC01610[e] (0, 1000)
# EX_HC01700[e] (0, 1000)
# EX_HC02160[e] (0, 1000)
# EX_HC02161[e] (0, 1000)
# EX_itp[e] (0, 1000)
# EX_orot[e] (0, 1000)
# EX_prpp[e] (0, 1000)
# EX_pydx5p[e] (0, 1000)
# EX_udpg[e] (0, 1000)
# r0571 (0, 1000)
# r0643 (0, 1000)
# EX_so3[e] (0, 1000)
# EX_sprm[e] (0, 1000)
# EX_prostgh2[e] (0, 1000)
# EX_prostgi2[e] (0, 1000)
# EX_cdp[e] (0, 1000)
# EX_dtdp[e] (0, 1000)
# EX_HC00955[e] (0, 1000)
# EX_HC00004[e] (0, 1000)
# EX_citr_L[e] (0, 1000)
# EX_C02470[e] (0, 1000)
# EX_HC00822[e] (0, 1000)
# EX_C02528[e] (0, 1000)
# EX_HC02192[e] (0, 1000)
# EX_HC02193[e] (0, 1000)
# EX_HC02195[e] (0, 1000)
# EX_HC02196[e] (0, 1000)
# EX_HC02220[e] (0, 1000)
# EX_HC02191[e] (0, 1000)
# EX_HC02194[e] (0, 1000)
# EX_HC02197[e] (0, 1000)
# EX_HC02198[e] (0, 1000)
# EX_HC02187[e] (0, 1000)
# EX_HC02180[e] (0, 1000)
# EX_HC02202[e] (0, 1000)
# EX_HC02203[e] (0, 1000)
# EX_HC02204[e] (0, 1000)
# EX_HC02205[e] (0, 1000)
# EX_HC02206[e] (0, 1000)
# EX_HC02207[e] (0, 1000)
# EX_HC02213[e] (0, 1000)
# EX_HC02217[e] (0, 1000)
# EX_malcoa[e] (0, 1000)
# EX_arachcoa[e] (0, 1000)
# EX_coa[e] (0, 1000)
# EX_CE2250[e] (0, 1000)
# EX_CE1935[e] (0, 1000)
# EX_CE1940[e] (0, 1000)
# EX_CE1943[e] (0, 1000)
# EX_CE1936[e] (0, 1000)
# EX_CE1939[e] (0, 1000)
# EX_maltpt[e] (0, 1000)
# EX_CE2915[e] (0, 1000)
# EX_CE4722[e] (0, 1000)
# EX_CE2916[e] (0, 1000)
# EX_CE4723[e] (0, 1000)
# EX_CE2917[e] (0, 1000)
# EX_CE4724[e] (0, 1000)
# EX_malthp[e] (0, 1000)
# EX_CE2839[e] (0, 1000)
# EX_CE2838[e] (0, 1000)
# EX_CE1950[e] (0, 1000)
# EX_cynt[e] (0, 1000)
# EX_23cump[e] (0, 1000)
# EX_3ump[e] (0, 1000)
# EX_CE5786[e] (0, 1000)
# EX_CE5788[e] (0, 1000)
# EX_CE5789[e] (0, 1000)
# EX_CE5797[e] (0, 1000)
# EX_CE5798[e] (0, 1000)
# EX_CE5787[e] (0, 1000)
# EX_CE5791[e] (0, 1000)
# EX_CE5867[e] (0, 1000)
# EX_CE5868[e] (0, 1000)
# EX_CE5869[e] (0, 1000)
# EX_CE4633[e] (0, 1000)
# EX_CE4881[e] (0, 1000)
# EX_CE5854[e] (0, 1000)
# EX_CE1926[e] (0, 1000)
# EX_udpgal[e] (0, 1000)
# EX_crm_hs[e] (0, 1000)
# EX_galside_hs[e] (0, 1000)
# EX_CE0074[e] (0, 1000)
# EX_cdpea[e] (0, 1000)
# EX_12dgr120[e] (0, 1000)
# EX_CE5853[e] (0, 1000)
# EX_CE1925[e] (0, 1000)
# EX_C04849[e] (0, 1000)
# sink_c101coa[c] (0, 0)
# sink_c81coa[c] (0, 0)
# sink_dd2coa[c] (0, 0)
# sink_decdicoa[c] (0, 0)
# EX_3bcrn[e] (0, 1000)
# EX_3ddcrn[e] (0, 1000)
# EX_3deccrn[e] (0, 1000)
# EX_3hdececrn[e] (0, 1000)
# EX_3hexdcrn[e] (0, 1000)
# EX_3ivcrn[e] (0, 1000)
# EX_3octdec2crn[e] (0, 1000)
# EX_3octdeccrn[e] (0, 1000)
# EX_3octdece1crn[e] (0, 1000)
# EX_3tdcrn[e] (0, 1000)
# EX_3tetd7ecoacrn[e] (0, 1000)
# EX_3thexddcoacrn[e] (0, 1000)
# EX_3ttetddcoacrn[e] (0, 1000)
# EX_c101crn[e] (0, 1000)
# EX_c10crn[e] (0, 1000)
# EX_c10dc[e] (0, 1000)
# EX_c12dc[e] (0, 1000)
# EX_c16dc[e] (0, 1000)
# EX_c3dc[e] (0, 1000)
# EX_c4crn[e] (0, 1000)
# EX_c4dc[e] (0, 1000)
# EX_c51crn[e] (0, 1000)
# EX_c5dc[e] (0, 1000)
# EX_c6crn[e] (0, 1000)
# EX_c6dc[e] (0, 1000)
# EX_c81crn[e] (0, 1000)
# EX_c8crn[e] (0, 1000)
# EX_c8dc[e] (0, 1000)
# EX_ddece1crn[e] (0, 1000)
# EX_ddecrn[e] (0, 1000)
# EX_decdicrn[e] (0, 1000)
# EX_doco13ac[e] (0, 1000)
# EX_docosac[e] (0, 1000)
# EX_docosdiac[e] (0, 1000)
# EX_ivcrn[e] (0, 1000)
# EX_tetdec2crn[e] (0, 1000)
# EX_tetdece1crn[e] (0, 1000)
# EX_dca[e] (0, 1000)
# sink_octdececoa[c] (0, 0)
# sink_tetdec2coa[c] (0, 0)
# sink_tetdece1coa[c] (0, 0)
# EX_4hpro[e] (0, 1000)
# EX_alaala[e] (0, 1000)
# EX_bglc[e] (0, 1000)
# EX_carn[e] (0, 1000)
# EX_dchac[e] (0, 1000)
# EX_glgchlo[e] (0, 1000)
# EX_gltcho[e] (0, 1000)
# EX_gltdechol[e] (0, 1000)
# EX_glygly[e] (0, 1000)
# EX_glysar[e] (0, 1000)
# EX_gum[e] (0, 1000)
# EX_gumdchac[e] (0, 1000)
# EX_gumgchol[e] (0, 1000)
# EX_gumtchol[e] (0, 1000)
# EX_leugly[e] (0, 1000)
# EX_leuleu[e] (0, 1000)
# EX_pect[e] (0, 1000)
# EX_pectindchac[e] (0, 1000)
# EX_pectingchol[e] (0, 1000)
# EX_pectintchol[e] (0, 1000)
# EX_psyl[e] (0, 1000)
# EX_psylchol[e] (0, 1000)
# EX_psyltchol[e] (0, 1000)
# EX_psyltdechol[e] (0, 1000)
# EX_sfcys[e] (0, 1000)
# EX_tdechola[e] (0, 1000)
# EX_cysam[e] (0, 1000)
# EX_dpcoa[e] (0, 1000)
# EX_fmn[e] (0, 1000)
# EX_hyptaur[e] (0, 1000)
# EX_oh1[e] (0, 1000)
# EX_pan4p[e] (0, 1000)
# EX_ptth[e] (0, 1000)
# EX_q10[e] (0, 1000)
# EX_q10h2[e] (0, 1000)
# sink_5hpet[c] (0, 0)
# EX_34hpp[e] (0, 1000)
# EX_3mob[e] (0, 1000)
# EX_3mop[e] (0, 1000)
# EX_4mop[e] (0, 1000)
# EX_5mta[e] (0, 1000)
# EX_5oxpro[e] (0, 1000)
# EX_ahcys[e] (0, 1000)
# EX_aicar[e] (0, 1000)
# EX_anth[e] (0, 1000)
# EX_cbasp[e] (0, 1000)
# EX_idour[e] (0, 1000)
# EX_2pg[e] (0, 1000)
# EX_5hoxindoa[e] (0, 1000)
# EX_cala[e] (0, 1000)
# EX_cholp[e] (0, 1000)
# EX_crtn[e] (0, 1000)
# EX_cyst_L[e] (0, 1000)
# EX_dcmp[e] (0, 1000)
# EX_dmgly[e] (0, 1000)
# EX_ethamp[e] (0, 1000)
# EX_g3pc[e] (0, 1000)
# EX_glyald[e] (0, 1000)
# EX_gudac[e] (0, 1000)
# EX_hcys_L[e] (0, 1000)
# EX_icit[e] (0, 1000)
# EX_kynate[e] (0, 1000)
# EX_L2aadp[e] (0, 1000)
# EX_Lkynr[e] (0, 1000)
# EX_pep[e] (0, 1000)
# EX_quln[e] (0, 1000)
# EX_xmp[e] (0, 1000)
# EX_xtsn[e] (0, 1000)
# EX_3pg[e] (0, 1000)
# EX_3hanthrn[e] (0, 1000)
# EX_udpglcur[e] (0, 1000)
# EX_hLkynr[e] (0, 1000)
# EX_nicrnt[e] (0, 1000)
# EX_orot5p[e] (0, 1000)
# EX_glyc3p[e] (0, 1000)
# EX_argsuc[e] (0, 1000)
# EX_acrn[e] (0, 1000)
# EX_pcrn[e] (0, 1000)
# EX_lneldccrn[e] (0, 1000)
# EX_odecrn[e] (0, 1000)
# EX_stcrn[e] (0, 1000)
# EX_pmtcrn[e] (0, 1000)
# EX_hdcecrn[e] (0, 1000)
# EX_3mtp[e] (0, 1000)
# EX_C14769[e] (0, 1000)
# EX_12HPET[e] (0, 1000)
# EX_15HPET[e] (0, 1000)
# EX_15kprostgf2[e] (0, 1000)
# EX_21hprgnlone[e] (0, 1000)
# EX_2oxoadp[e] (0, 1000)
# EX_34hpl[e] (0, 1000)
# EX_3hmp[e] (0, 1000)
# EX_3hpp[e] (0, 1000)
# EX_3hpppnohgluc[e] (0, 1000)
# EX_3mhis[e] (0, 1000)
# EX_3uib[e] (0, 1000)
# EX_4aabutn[e] (0, 1000)
# EX_4tmeabutn[e] (0, 1000)
# EX_56dthm[e] (0, 1000)
# EX_56dura[e] (0, 1000)
# EX_5HPET[e] (0, 1000)
# EX_7dhchsterol[e] (0, 1000)
# EX_acgly[e] (0, 1000)
# EX_aclys[e] (0, 1000)
# EX_acorn[e] (0, 1000)
# EX_acthr_L[e] (0, 1000)
# EX_adpac[e] (0, 1000)
# EX_adpoh[e] (0, 1000)
# EX_amet[e] (0, 1000)
# EX_and19one[e] (0, 1000)
# EX_aracheth[e] (0, 1000)
# EX_biliverd[e] (0, 1000)
# EX_C02356[e] (0, 1000)
# EX_C02712[e] (0, 1000)
# EX_C04717[e] (0, 1000)
# EX_C04805[e] (0, 1000)
# EX_C05957[e] (0, 1000)
# EX_C06314[e] (0, 1000)
# EX_C06315[e] (0, 1000)
# EX_C11695[e] (0, 1000)
# EX_C14768[e] (0, 1000)
# EX_C14770[e] (0, 1000)
# EX_C14771[e] (0, 1000)
# EX_C14825[e] (0, 1000)
# EX_C14826[e] (0, 1000)
# EX_CE0955[e] (0, 1000)
# EX_CE1273[e] (0, 1000)
# EX_CE1557[e] (0, 1000)
# EX_CE2028[e] (0, 1000)
# EX_CE2176[e] (0, 1000)
# EX_CE2445[e] (0, 1000)
# EX_CE2537[e] (0, 1000)
# EX_CE4843[e] (0, 1000)
# EX_CE5304[e] (0, 1000)
# EX_CE6031[e] (0, 1000)
# EX_CE6247[e] (0, 1000)
# EX_CE7082[e] (0, 1000)
# EX_CE7083[e] (0, 1000)
# EX_CE7172[e] (0, 1000)
# EX_cortsn[e] (0, 1000)
# EX_didecaeth[e] (0, 1000)
# EX_diholineth[e] (0, 1000)
# EX_docohxeth[e] (0, 1000)
# EX_docteteth[e] (0, 1000)
# EX_dodecanac[e] (0, 1000)
# EX_elaidcrn[e] (0, 1000)
# EX_forglu[e] (0, 1000)
# EX_HC00900[e] (0, 1000)
# EX_hepdeceth[e] (0, 1000)
# EX_hexdeceeth[e] (0, 1000)
# EX_hexdiac[e] (0, 1000)
# EX_hgentis[e] (0, 1000)
# EX_hmcarn[e] (0, 1000)
# EX_hmcr[e] (0, 1000)
# EX_hxcoa[e] (0, 1000)
# EX_leuktrB4wcooh[e] (0, 1000)
# EX_leuktrB4woh[e] (0, 1000)
# EX_lineth[e] (0, 1000)
# EX_lnlccrn[e] (0, 1000)
# EX_Lpipecol[e] (0, 1000)
# EX_lthstrl[e] (0, 1000)
# EX_magarachi_hs[e] (0, 1000)
# EX_maglinl_hs[e] (0, 1000)
# EX_magole_hs[e] (0, 1000)
# EX_magpalm_hs[e] (0, 1000)
# EX_magste_hs[e] (0, 1000)
# EX_mev_R[e] (0, 1000)
# EX_mi1p_D[e] (0, 1000)
# EX_Nacasp[e] (0, 1000)
# EX_nwharg[e] (0, 1000)
# EX_oleth[e] (0, 1000)
# EX_pailar_hs[e] (0, 1000)
# EX_pailpalm_hs[e] (0, 1000)
# EX_pailste_hs[e] (0, 1000)
# EX_pchol2linl_hs[e] (0, 1000)
# EX_pchol2ole_hs[e] (0, 1000)
# EX_pchol2palm_hs[e] (0, 1000)
# EX_pchol2ste_hs[e] (0, 1000)
# EX_pcholar_hs[e] (0, 1000)
# EX_pcholdoc_hs[e] (0, 1000)
# EX_pcholeic_hs[e] (0, 1000)
# EX_pcholet_hs[e] (0, 1000)
# EX_pcholhep_hs[e] (0, 1000)
# EX_pchollinl_hs[e] (0, 1000)
# EX_pcholmyr_hs[e] (0, 1000)
# EX_pcholn15_hs[e] (0, 1000)
# EX_pcholn183_hs[e] (0, 1000)
# EX_pcholn1836_hs[e] (0, 1000)
# EX_pcholn19_hs[e] (0, 1000)
# EX_pcholn201_hs[e] (0, 1000)
# EX_pcholn203_hs[e] (0, 1000)
# EX_pcholn204_hs[e] (0, 1000)
# EX_pcholn205_hs[e] (0, 1000)
# EX_pcholn224_hs[e] (0, 1000)
# EX_pcholn225_hs[e] (0, 1000)
# EX_pcholn2254_hs[e] (0, 1000)
# EX_pcholn226_hs[e] (0, 1000)
# EX_pcholn24_hs[e] (0, 1000)
# EX_pcholn261_hs[e] (0, 1000)
# EX_pcholn28_hs[e] (0, 1000)
# EX_pcholn281_hs[e] (0, 1000)
# EX_pcholole_hs[e] (0, 1000)
# EX_pcholpalm_hs[e] (0, 1000)
# EX_pcholpalme_hs[e] (0, 1000)
# EX_pcholste_hs[e] (0, 1000)
# EX_pcollg5hlys[e] (0, 1000)
# EX_pe12_hs[e] (0, 1000)
# EX_pe13_hs[e] (0, 1000)
# EX_pe14_hs[e] (0, 1000)
# EX_pe15_hs[e] (0, 1000)
# EX_pe161_hs[e] (0, 1000)
# EX_pe17_hs[e] (0, 1000)
# EX_pe203_hs[e] (0, 1000)
# EX_pe224_hs[e] (0, 1000)
# EX_pe226_hs[e] (0, 1000)
# EX_pe2linl_hs[e] (0, 1000)
# EX_pear_hs[e] (0, 1000)
# EX_pedh203_hs[e] (0, 1000)
# EX_pelinl_hs[e] (0, 1000)
# EX_pendecaeth[e] (0, 1000)
# EX_peole_hs[e] (0, 1000)
# EX_pepalm_hs[e] (0, 1000)
# EX_peste_hs[e] (0, 1000)
# EX_pmeth[e] (0, 1000)
# EX_saccrp_L[e] (0, 1000)
# EX_sebacid[e] (0, 1000)
# EX_sphmyln180241_hs[e] (0, 1000)
# EX_sphmyln18114_hs[e] (0, 1000)
# EX_sphmyln18115_hs[e] (0, 1000)
# EX_sphmyln18116_hs[e] (0, 1000)
# EX_sphmyln181161_hs[e] (0, 1000)
# EX_sphmyln18117_hs[e] (0, 1000)
# EX_sphmyln18118_hs[e] (0, 1000)
# EX_sphmyln181181_hs[e] (0, 1000)
# EX_sphmyln18120_hs[e] (0, 1000)
# EX_sphmyln181201_hs[e] (0, 1000)
# EX_sphmyln18121_hs[e] (0, 1000)
# EX_sphmyln18122_hs[e] (0, 1000)
# EX_sphmyln181221_hs[e] (0, 1000)
# EX_sphmyln18123_hs[e] (0, 1000)
# EX_sphmyln1824_hs[e] (0, 1000)
# EX_sphmyln1825_hs[e] (0, 1000)
# EX_steeth[e] (0, 1000)
# EX_subeac[e] (0, 1000)
# EX_tetdeca511ac[e] (0, 1000)
# EX_tetdecaeth[e] (0, 1000)
# EX_thrnt[e] (0, 1000)
# EX_tmlys[e] (0, 1000)
# EX_trideceth[e] (0, 1000)
# EX_ttdcrn[e] (0, 1000)
# EX_txb2[e] (0, 1000)
# EX_urcan[e] (0, 1000)
# EX_wharachd[e] (0, 1000)
# EX_xolest181_hs[e] (0, 1000)
# EX_xolest182_hs[e] (0, 1000)
# EX_xolest183_hs[e] (0, 1000)
# EX_xolest204_hs[e] (0, 1000)
# EX_xolest205_hs[e] (0, 1000)
# EX_xolest226_hs[e] (0, 1000)
# EX_acile_L[e] (0, 1000)
# EX_acleu_L[e] (0, 1000)
# EX_achom_L[e] (0, 1000)
# EX_phacgly[e] (0, 1000)
# EX_estriol[e] (0, 1000)
# EX_3hpppn[e] (0, 1000)
# EX_3moxtyr[e] (0, 1000)
# EX_5aop[e] (0, 1000)
# EX_abt_D[e] (0, 1000)
# EX_acglu[e] (0, 1000)
# EX_alltn[e] (0, 1000)
# EX_CE2510[e] (0, 1000)
# EX_ddca[e] (0, 1000)
# EX_glyc_R[e] (0, 1000)
# EX_glyc2p[e] (0, 1000)
# EX_glyclt[e] (0, 1000)
# EX_Lcyst[e] (0, 1000)
# EX_oaa[e] (0, 1000)
# EX_pac[e] (0, 1000)
# EX_phlac[e] (0, 1000)
# EX_pser_L[e] (0, 1000)
# EX_ttdcea[e] (0, 1000)
# EX_bgly[e] (0, 1000)
# EX_pheacgly[e] (0, 1000)
# EX_bz[e] (0, 1000)
# EX_pcresol[e] (0, 1000)
# EX_pcs[e] (0, 1000)
# EX_normete_L[e] (0, 1000)
# EX_mepi[e] (0, 1000)
# EX_C05300[e] (0, 1000)
# EX_retinal[e] (0, 1000)
# EX_maltttr[e] (0, 1000)
# EX_1mncam[e] (0, 1000)
# EX_progly[e] (0, 1000)
# EX_dhbpt[e] (0, 1000)
# EX_thbpt[e] (0, 1000)
# EX_adprib[e] (0, 1000)
# EX_alaargcys[e] (0, 1000)
# EX_alaarggly[e] (0, 1000)
# EX_alaasnleu[e] (0, 1000)
# EX_alaglylys[e] (0, 1000)
# EX_alahisala[e] (0, 1000)
# EX_alalysthr[e] (0, 1000)
# EX_argalaala[e] (0, 1000)
# EX_argalaphe[e] (0, 1000)
# EX_argalathr[e] (0, 1000)
# EX_argarg[e] (0, 1000)
# EX_argarglys[e] (0, 1000)
# EX_argargmet[e] (0, 1000)
# EX_argcysgly[e] (0, 1000)
# EX_argcysser[e] (0, 1000)
# EX_arggluglu[e] (0, 1000)
# EX_argglupro[e] (0, 1000)
# EX_argglygly[e] (0, 1000)
# EX_arghisthr[e] (0, 1000)
# EX_argleuphe[e] (0, 1000)
# EX_arglysasp[e] (0, 1000)
# EX_argphearg[e] (0, 1000)
# EX_argpromet[e] (0, 1000)
# EX_argprothr[e] (0, 1000)
# EX_argserser[e] (0, 1000)
# EX_argtyrval[e] (0, 1000)
# EX_argvalcys[e] (0, 1000)
# EX_argvaltrp[e] (0, 1000)
# EX_asnasnarg[e] (0, 1000)
# EX_asncyscys[e] (0, 1000)
# EX_asnmetpro[e] (0, 1000)
# EX_asnpheasp[e] (0, 1000)
# EX_asnphecys[e] (0, 1000)
# EX_asntyrgly[e] (0, 1000)
# EX_asntyrphe[e] (0, 1000)
# EX_asntyrthr[e] (0, 1000)
# EX_aspalaarg[e] (0, 1000)
# EX_aspasnglu[e] (0, 1000)
# EX_aspglu[e] (0, 1000)
# EX_aspglupro[e] (0, 1000)
# EX_aspglutrp[e] (0, 1000)
# EX_asphiscys[e] (0, 1000)
# EX_asphispro[e] (0, 1000)
# EX_asplysglu[e] (0, 1000)
# EX_asplyshis[e] (0, 1000)
# EX_aspmetasp[e] (0, 1000)
# EX_aspprolys[e] (0, 1000)
# EX_aspvalasn[e] (0, 1000)
# EX_cysasnmet[e] (0, 1000)
# EX_cysaspphe[e] (0, 1000)
# EX_cyscys[e] (0, 1000)
# EX_cysglnmet[e] (0, 1000)
# EX_cysgluhis[e] (0, 1000)
# EX_cysglutrp[e] (0, 1000)
# EX_cysleuthr[e] (0, 1000)
# EX_cyssermet[e] (0, 1000)
# EX_cystyrasn[e] (0, 1000)
# EX_glnasngln[e] (0, 1000)
# EX_glnhishis[e] (0, 1000)
# EX_glnhislys[e] (0, 1000)
# EX_glnlyslys[e] (0, 1000)
# EX_glnlystrp[e] (0, 1000)
# EX_glnproglu[e] (0, 1000)
# EX_glntrpglu[e] (0, 1000)
# EX_glntyrleu[e] (0, 1000)
# EX_gluargleu[e] (0, 1000)
# EX_gluasnleu[e] (0, 1000)
# EX_gluglu[e] (0, 1000)
# EX_gluilelys[e] (0, 1000)
# EX_gluleu[e] (0, 1000)
# EX_glumet[e] (0, 1000)
# EX_glumethis[e] (0, 1000)
# EX_gluthr[e] (0, 1000)
# EX_gluthrlys[e] (0, 1000)
# EX_glutrpala[e] (0, 1000)
# EX_glyhisasn[e] (0, 1000)
# EX_glyhislys[e] (0, 1000)
# EX_glylyscys[e] (0, 1000)
# EX_glylysphe[e] (0, 1000)
# EX_glytyrlys[e] (0, 1000)
# EX_glyvalhis[e] (0, 1000)
# EX_hisargcys[e] (0, 1000)
# EX_hisargser[e] (0, 1000)
# EX_hisasp[e] (0, 1000)
# EX_hiscyscys[e] (0, 1000)
# EX_hisglnala[e] (0, 1000)
# EX_hisglu[e] (0, 1000)
# EX_hisglugln[e] (0, 1000)
# EX_hisglylys[e] (0, 1000)
# EX_hishislys[e] (0, 1000)
# EX_hislysala[e] (0, 1000)
# EX_hislysglu[e] (0, 1000)
# EX_hislysile[e] (0, 1000)
# EX_hislysthr[e] (0, 1000)
# EX_hislysval[e] (0, 1000)
# EX_hismet[e] (0, 1000)
# EX_hismetgln[e] (0, 1000)
# EX_hisphearg[e] (0, 1000)
# EX_hisprolys[e] (0, 1000)
# EX_histrphis[e] (0, 1000)
# EX_ileargile[e] (0, 1000)
# EX_ileasnhis[e] (0, 1000)
# EX_ileasp[e] (0, 1000)
# EX_ileglnglu[e] (0, 1000)
# EX_ileglyarg[e] (0, 1000)
# EX_ileprolys[e] (0, 1000)
# EX_ileserarg[e] (0, 1000)
# EX_iletrptyr[e] (0, 1000)
# EX_leualaarg[e] (0, 1000)
# EX_leuasnasp[e] (0, 1000)
# EX_leuasplys[e] (0, 1000)
# EX_leuleutrp[e] (0, 1000)
# EX_leupro[e] (0, 1000)
# EX_leuproarg[e] (0, 1000)
# EX_leusertrp[e] (0, 1000)
# EX_leutrp[e] (0, 1000)
# EX_leutrparg[e] (0, 1000)
# EX_leutyrtyr[e] (0, 1000)
# EX_leuval[e] (0, 1000)
# EX_lysargleu[e] (0, 1000)
# EX_lyscyshis[e] (0, 1000)
# EX_lysglnphe[e] (0, 1000)
# EX_lysgluglu[e] (0, 1000)
# EX_lyslyslys[e] (0, 1000)
# EX_lyspheile[e] (0, 1000)
# EX_lystrparg[e] (0, 1000)
# EX_lystyrile[e] (0, 1000)
# EX_lysvalphe[e] (0, 1000)
# EX_lysvaltrp[e] (0, 1000)
# EX_metargleu[e] (0, 1000)
# EX_metasntyr[e] (0, 1000)
# EX_metglntyr[e] (0, 1000)
# EX_metglyarg[e] (0, 1000)
# EX_methislys[e] (0, 1000)
# EX_metmetile[e] (0, 1000)
# EX_metphearg[e] (0, 1000)
# EX_mettrpphe[e] (0, 1000)
# EX_pheasnmet[e] (0, 1000)
# EX_pheasp[e] (0, 1000)
# EX_pheglnphe[e] (0, 1000)
# EX_pheleu[e] (0, 1000)
# EX_pheleuasp[e] (0, 1000)
# EX_pheleuhis[e] (0, 1000)
# EX_phelysala[e] (0, 1000)
# EX_phelyspro[e] (0, 1000)
# EX_phephe[e] (0, 1000)
# EX_phepheasn[e] (0, 1000)
# EX_phephethr[e] (0, 1000)
# EX_pheproarg[e] (0, 1000)
# EX_phesertrp[e] (0, 1000)
# EX_phethrlys[e] (0, 1000)
# EX_phetrpleu[e] (0, 1000)
# EX_phetyr[e] (0, 1000)
# EX_phetyrgln[e] (0, 1000)
# EX_phetyrlys[e] (0, 1000)
# EX_proargasp[e] (0, 1000)
# EX_proargcys[e] (0, 1000)
# EX_proasncys[e] (0, 1000)
# EX_procys[e] (0, 1000)
# EX_proglnpro[e] (0, 1000)
# EX_proglulys[e] (0, 1000)
# EX_prohis[e] (0, 1000)
# EX_prohistyr[e] (0, 1000)
# EX_proleuarg[e] (0, 1000)
# EX_prolyspro[e] (0, 1000)
# EX_prophe[e] (0, 1000)
# EX_proproarg[e] (0, 1000)
# EX_propropro[e] (0, 1000)
# EX_protrplys[e] (0, 1000)
# EX_protrpthr[e] (0, 1000)
# EX_provalgln[e] (0, 1000)
# EX_serargala[e] (0, 1000)
# EX_serargtrp[e] (0, 1000)
# EX_sercysarg[e] (0, 1000)
# EX_serglyglu[e] (0, 1000)
# EX_serlyshis[e] (0, 1000)
# EX_serphelys[e] (0, 1000)
# EX_sertrphis[e] (0, 1000)
# EX_thrargtyr[e] (0, 1000)
# EX_thrasntyr[e] (0, 1000)
# EX_thrglnglu[e] (0, 1000)
# EX_thrglntyr[e] (0, 1000)
# EX_thrhishis[e] (0, 1000)
# EX_thrilearg[e] (0, 1000)
# EX_thrmetarg[e] (0, 1000)
# EX_thrphearg[e] (0, 1000)
# EX_thrserarg[e] (0, 1000)
# EX_thrthrarg[e] (0, 1000)
# EX_thrtyrmet[e] (0, 1000)
# EX_trpalapro[e] (0, 1000)
# EX_trpargala[e] (0, 1000)
# EX_trpaspasp[e] (0, 1000)
# EX_trpglngln[e] (0, 1000)
# EX_trpglugly[e] (0, 1000)
# EX_trpgluleu[e] (0, 1000)
# EX_trpglupro[e] (0, 1000)
# EX_trpglutyr[e] (0, 1000)
# EX_trpglyleu[e] (0, 1000)
# EX_trpglyphe[e] (0, 1000)
# EX_trpglyval[e] (0, 1000)
# EX_trphismet[e] (0, 1000)
# EX_trpilelys[e] (0, 1000)
# EX_trpiletrp[e] (0, 1000)
# EX_trpleuval[e] (0, 1000)
# EX_trplys[e] (0, 1000)
# EX_trpmetarg[e] (0, 1000)
# EX_trpmetval[e] (0, 1000)
# EX_trpphe[e] (0, 1000)
# EX_trpprogly[e] (0, 1000)
# EX_trpproleu[e] (0, 1000)
# EX_trpproval[e] (0, 1000)
# EX_trpsertyr[e] (0, 1000)
# EX_trpthrglu[e] (0, 1000)
# EX_trpthrile[e] (0, 1000)
# EX_trpthrtyr[e] (0, 1000)
# EX_trptyrgln[e] (0, 1000)
# EX_trptyrtyr[e] (0, 1000)
# EX_trpvalasp[e] (0, 1000)
# EX_tyrala[e] (0, 1000)
# EX_tyralaphe[e] (0, 1000)
# EX_tyrargglu[e] (0, 1000)
# EX_tyrargser[e] (0, 1000)
# EX_tyrasparg[e] (0, 1000)
# EX_tyrcysgly[e] (0, 1000)
# EX_tyrcysthr[e] (0, 1000)
# EX_tyrglu[e] (0, 1000)
# EX_tyrleuarg[e] (0, 1000)
# EX_tyrphetyr[e] (0, 1000)
# EX_tyrthr[e] (0, 1000)
# EX_tyrtrpphe[e] (0, 1000)
# EX_tyrtyr[e] (0, 1000)
# EX_tyrvalmet[e] (0, 1000)
# EX_valarggly[e] (0, 1000)
# EX_valhisasn[e] (0, 1000)
# EX_valleuphe[e] (0, 1000)
# EX_vallystyr[e] (0, 1000)
# EX_valphearg[e] (0, 1000)
# EX_valprotrp[e] (0, 1000)
# EX_valserarg[e] (0, 1000)
# EX_valtrpphe[e] (0, 1000)
# EX_valtrpval[e] (0, 1000)
# EX_valval[e] (0, 1000)
# EX_trpglyasp[e] (0, 1000)
# ALAARGCYSr (0, 1000)
# ALAARGGLYr (0, 1000)
# ALAASNLEUr (0, 1000)
# ALAGLYLYSr (0, 1000)
# ALAHISALAr (0, 1000)
# ALALYSTHRr (0, 1000)
# ARGALAALAr (0, 1000)
# ARGALAPHEr (0, 1000)
# ARGALATHRr (0, 1000)
# ARGARGr (0, 1000)
# ARGARGLYSr (0, 1000)
# ARGARGMETr (0, 1000)
# ARGCYSGLYr (0, 1000)
# ARGCYSSERr (0, 1000)
# ARGGLUGLUr (0, 1000)
# ARGGLUPROr (0, 1000)
# ARGGLYGLYr (0, 1000)
# ARGHISTHRr (0, 1000)
# ARGLEUPHEr (0, 1000)
# ARGLYSASPr (0, 1000)
# ARGPHEARGr (0, 1000)
# ARGPROMETr (0, 1000)
# ARGPROTHRr (0, 1000)
# ARGSERSERr (0, 1000)
# ARGTYRVALr (0, 1000)
# ARGVALCYSr (0, 1000)
# ARGVALTRPr (0, 1000)
# ASNASNARGr (0, 1000)
# ASNCYSCYSr (0, 1000)
# ASNMETPROr (0, 1000)
# ASNPHEASPr (0, 1000)
# ASNPHECYSr (0, 1000)
# ASNTYRGLYr (0, 1000)
# ASNTYRPHEr (0, 1000)
# ASNTYRTHRr (0, 1000)
# ASPALAARGr (0, 1000)
# ASPASNGLUr (0, 1000)
# ASPGLUr (0, 1000)
# ASPGLUPROr (0, 1000)
# ASPGLUTRPr (0, 1000)
# ASPHISCYSr (0, 1000)
# ASPHISPROr (0, 1000)
# ASPLYSGLUr (0, 1000)
# ASPLYSHISr (0, 1000)
# ASPMETASPr (0, 1000)
# ASPPROLYSr (0, 1000)
# ASPVALASNr (0, 1000)
# CYSASNMETr (0, 1000)
# CYSASPPHEr (0, 1000)
# CYSCYSr (0, 1000)
# CYSGLNMETr (0, 1000)
# CYSGLUHISr (0, 1000)
# CYSGLUTRPr (0, 1000)
# CYSLEUTHRr (0, 1000)
# CYSSERMETr (0, 1000)
# CYSTYRASNr (0, 1000)
# GLNASNGLNr (0, 1000)
# GLNHISHISr (0, 1000)
# GLNHISLYSr (0, 1000)
# GLNLYSLYSr (0, 1000)
# GLNLYSTRPr (0, 1000)
# GLNPROGLUr (0, 1000)
# GLNTRPGLUr (0, 1000)
# GLNTYRLEUr (0, 1000)
# GLUARGLEUr (0, 1000)
# GLUASNLEUr (0, 1000)
# GLUGLUr (0, 1000)
# GLUILELYSr (0, 1000)
# GLULEUr (0, 1000)
# GLUMETr (0, 1000)
# GLUMETHISr (0, 1000)
# GLUTHRr (0, 1000)
# GLUTHRLYSr (0, 1000)
# GLUTRPALAr (0, 1000)
# GLYHISASNr (0, 1000)
# GLYHISLYSr (0, 1000)
# GLYLYSCYSr (0, 1000)
# GLYLYSPHEr (0, 1000)
# GLYTYRLYSr (0, 1000)
# GLYVALHISr (0, 1000)
# HISARGCYSr (0, 1000)
# HISARGSERr (0, 1000)
# HISASPr (0, 1000)
# HISCYSCYSr (0, 1000)
# HISGLNALAr (0, 1000)
# HISGLUr (0, 1000)
# HISGLUGLNr (0, 1000)
# HISGLYLYSr (0, 1000)
# HISHISLYSr (0, 1000)
# HISLYSALAr (0, 1000)
# HISLYSGLUr (0, 1000)
# HISLYSILEr (0, 1000)
# HISLYSTHRr (0, 1000)
# HISLYSVALr (0, 1000)
# HISMETr (0, 1000)
# HISMETGLNr (0, 1000)
# HISPHEARGr (0, 1000)
# HISPROLYSr (0, 1000)
# HISTRPHISr (0, 1000)
# ILEARGILEr (0, 1000)
# ILEASNHISr (0, 1000)
# ILEASPr (0, 1000)
# ILEGLNGLUr (0, 1000)
# ILEGLYARGr (0, 1000)
# ILEPROLYSr (0, 1000)
# ILESERARGr (0, 1000)
# ILETRPTYRr (0, 1000)
# LEUALAARGr (0, 1000)
# LEUASNASPr (0, 1000)
# LEUASPLYSr (0, 1000)
# LEULEUTRPr (0, 1000)
# LEUPROr (0, 1000)
# LEUPROARGr (0, 1000)
# LEUSERTRPr (0, 1000)
# LEUTRPr (0, 1000)
# LEUTRPARGr (0, 1000)
# LEUTYRTYRr (0, 1000)
# LEUVALr (0, 1000)
# LYSARGLEUr (0, 1000)
# LYSCYSHISr (0, 1000)
# LYSGLNPHEr (0, 1000)
# LYSGLUGLUr (0, 1000)
# LYSLYSLYSr (0, 1000)
# LYSPHEILEr (0, 1000)
# LYSTRPARGr (0, 1000)
# LYSTYRILEr (0, 1000)
# LYSVALPHEr (0, 1000)
# LYSVALTRPr (0, 1000)
# METARGLEUr (0, 1000)
# METASNTYRr (0, 1000)
# METGLNTYRr (0, 1000)
# METGLYARGr (0, 1000)
# METHISLYSr (0, 1000)
# METMETILEr (0, 1000)
# METPHEARGr (0, 1000)
# METTRPPHEr (0, 1000)
# PHEASNMETr (0, 1000)
# PHEASPr (0, 1000)
# PHEGLNPHEr (0, 1000)
# PHELEUr (0, 1000)
# PHELEUASPr (0, 1000)
# PHELEUHISr (0, 1000)
# PHELYSALAr (0, 1000)
# PHELYSPROr (0, 1000)
# PHEPHEr (0, 1000)
# PHEPHEASNr (0, 1000)
# PHEPHETHRr (0, 1000)
# PHEPROARGr (0, 1000)
# PHESERTRPr (0, 1000)
# PHETHRLYSr (0, 1000)
# PHETRPLEUr (0, 1000)
# PHETYRr (0, 1000)
# PHETYRGLNr (0, 1000)
# PHETYRLYSr (0, 1000)
# PROARGASPr (0, 1000)
# PROARGCYSr (0, 1000)
# PROASNCYSr (0, 1000)
# PROCYSr (0, 1000)
# PROGLNPROr (0, 1000)
# PROGLULYSr (0, 1000)
# PROHISr (0, 1000)
# PROHISTYRr (0, 1000)
# PROLEUARGr (0, 1000)
# PROLYSPROr (0, 1000)
# PROPHEr (0, 1000)
# PROPROARGr (0, 1000)
# PROPROPROr (0, 1000)
# PROTRPLYSr (0, 1000)
# PROTRPTHRr (0, 1000)
# PROVALGLNr (0, 1000)
# SERARGALAr (0, 1000)
# SERARGTRPr (0, 1000)
# SERCYSARGr (0, 1000)
# SERGLYGLUr (0, 1000)
# SERLYSHISr (0, 1000)
# SERPHELYSr (0, 1000)
# SERTRPHISr (0, 1000)
# THRARGTYRr (0, 1000)
# THRASNTYRr (0, 1000)
# THRGLNGLUr (0, 1000)
# THRGLNTYRr (0, 1000)
# THRHISHISr (0, 1000)
# THRILEARGr (0, 1000)
# THRMETARGr (0, 1000)
# THRPHEARGr (0, 1000)
# THRSERARGr (0, 1000)
# THRTHRARGr (0, 1000)
# THRTYRMETr (0, 1000)
# TRPALAPROr (0, 1000)
# TRPARGALAr (0, 1000)
# TRPASPASPr (0, 1000)
# TRPGLNGLNr (0, 1000)
# TRPGLUGLYr (0, 1000)
# TRPGLULEUr (0, 1000)
# TRPGLUPROr (0, 1000)
# TRPGLUTYRr (0, 1000)
# TRPGLYLEUr (0, 1000)
# TRPGLYPHEr (0, 1000)
# TRPGLYVALr (0, 1000)
# TRPHISMETr (0, 1000)
# TRPILELYSr (0, 1000)
# TRPILETRPr (0, 1000)
# TRPLEUVALr (0, 1000)
# TRPLYSr (0, 1000)
# TRPMETARGr (0, 1000)
# TRPMETVALr (0, 1000)
# TRPPHEr (0, 1000)
# TRPPROGLYr (0, 1000)
# TRPPROLEUr (0, 1000)
# TRPPROVALr (0, 1000)
# TRPSERTYRr (0, 1000)
# TRPTHRGLUr (0, 1000)
# TRPTHRILEr (0, 1000)
# TRPTHRTYRr (0, 1000)
# TRPTYRGLNr (0, 1000)
# TRPTYRTYRr (0, 1000)
# TRPVALASPr (0, 1000)
# TYRALAr (0, 1000)
# TYRALAPHEr (0, 1000)
# TYRARGGLUr (0, 1000)
# TYRARGSERr (0, 1000)
# TYRASPARGr (0, 1000)
# TYRCYSGLYr (0, 1000)
# TYRCYSTHRr (0, 1000)
# TYRGLUr (0, 1000)
# TYRLEUARGr (0, 1000)
# TYRPHETYRr (0, 1000)
# TYRTHRr (0, 1000)
# TYRTRPPHEr (0, 1000)
# TYRTYRr (0, 1000)
# TYRVALMETr (0, 1000)
# VALARGGLYr (0, 1000)
# VALHISASNr (0, 1000)
# VALLEUPHEr (0, 1000)
# VALLYSTYRr (0, 1000)
# VALPHEARGr (0, 1000)
# VALPROTRPr (0, 1000)
# VALSERARGr (0, 1000)
# VALTRPPHEr (0, 1000)
# VALTRPVALr (0, 1000)
# VALVALr (0, 1000)
# TRPGLYASPr (0, 1000)
# EX_homoval[e] (0, 1000)
# EX_sphmyln_hs[e] (0, 1000)
# EX_hxa[e] (0, 1000)
# EX_Lhcystin[e] (0, 1000)
# sink_band[c] (0, 0)
# EX_core4[e] (0, 1000)
# EX_core5[e] (0, 1000)
# EX_core7[e] (0, 1000)
# EX_core8[e] (0, 1000)
# EX_dsT_antigen[e] (0, 1000)
# EX_f1a[e] (0, 1000)
# EX_galam[e] (0, 1000)
# EX_gncore1[e] (0, 1000)
# EX_gncore2[e] (0, 1000)
# EX_mqn10[e] (0, 1000)
# EX_mqn11[e] (0, 1000)
# EX_mqn7[e] (0, 1000)
# EX_mqn9[e] (0, 1000)
# EX_s2l2n2m2m[e] (0, 1000)
# EX_sTn_antigen[e] (0, 1000)
# EX_lpam[e] (0, 1000)
# EX_acgal[e] (0, 1000)
# EX_acnam[e] (0, 1000)
# EX_pcreat[e] (0, 1000)
# EX_HC00342[e] (0, 1000)
# EX_pa_hs[e] (0, 1000)
# EX_CE2934[e] (0, 1000)
# sink_11_cis_retfa[c] (0, 0)
# sink_25hvitd2[c] (0, 0)
# sink_9_cis_retfa[c] (0, 0)
# sink_C02528[c] (0, 0)
# sink_HC02191[c] (0, 0)
# sink_HC02192[c] (0, 0)
# sink_HC02193[c] (0, 0)
# sink_HC02194[c] (0, 0)
# sink_HC02195[c] (0, 0)
# sink_HC02196[c] (0, 0)
# sink_HC02197[c] (0, 0)
# sink_HC02198[c] (0, 0)
# sink_HC02220[c] (0, 0)
# sink_Tyr_ggn[c] (0, 0)
# sink_avite1[c] (0, 0)
# sink_btn[c] (0, 0)
# sink_c226coa[c] (0, 0)
# sink_chol[c] (0, 0)
# sink_cholate[c] (0, 0)
# sink_coa[c] (0, 0)
# sink_crvnc[c] (0, 0)
# sink_dgchol[c] (0, 0)
# sink_doco13ecoa[c] (0, 0)
# sink_fad[c] (0, 0)
# sink_fe3[c] (0, 0)
# sink_gchola[c] (0, 0)
# sink_glygn2[c] (0, 0)
# sink_hdca[c] (0, 0)
# sink_lnlc[c] (0, 0)
# sink_lnlccoa[c] (0, 0)
# sink_lnlncacoa[c] (0, 0)
# sink_lnlncgcoa[c] (0, 0)
# sink_nad[c] (0, 0)
# sink_nadp[c] (0, 0)
# sink_odecoa[c] (0, 0)
# sink_phyQ[c] (0, 0)
# sink_pmtcoa[c] (0, 0)
# sink_pydam[c] (0, 0)
# sink_pydx[c] (0, 0)
# sink_pydxn[c] (0, 0)
# sink_retfa[c] (0, 0)
# sink_retinol[c] (0, 0)
# sink_stcoa[c] (0, 0)
# sink_tag_hs[c] (0, 0)
# sink_tchola[c] (0, 0)
# sink_tdchola[c] (0, 0)
# sink_tdechola[c] (0, 0)
# sink_thf[c] (0, 0)
# sink_thmpp[c] (0, 0)
# sink_thmtp[c] (0, 0)
# sink_tmndnc[c] (0, 0)
# sink_tmndnccoa[c] (0, 0)
# sink_vitd3[c] (0, 0)
# EX_dxtrn[e] (0, 1000)
# EX_dhcholestanate[e] (0, 1000)
# sink_dhcholestanate[c] (0, 0)
# EX_thcholstoic[e] (0, 1000)
# sink_thcholstoic[c] (0, 0)
# EX_xol7ah3[e] (0, 1000)
# sink_xol7ah3[c] (0, 0)
# EX_xol7aone[e] (0, 1000)
# sink_xol7aone[c] (0, 0)
# EX_xoldiolone[e] (0, 1000)
# sink_xoldiolone[c] (0, 0)
# EX_7klitchol[e] (0, 1000)
# sink_7klitchol[c] (0, 0)
# sink_dchac[c] (0, 0)
# sink_CE1273[c] (0, 0)
# EX_2obut[e] (0, 1000)
# EX_glcn[e] (0, 1000)
# EX_acac[e] (0, 1000)
# EX_adn[e] (0, 1000)
# EX_akg[e] (0, 1000)
# EX_asn_L[e] (-0.25, 1000)
# EX_asp_L[e] (-0.25, 1000)
# EX_but[e] (0, 1000)
# EX_cgly[e] (0, 1000)
# EX_co2[e] (-100.0, 1000)
# EX_cytd[e] (0, 1000)
# EX_dad_2[e] (0, 1000)
# EX_dcyt[e] (0, 1000)
# EX_dgsn[e] (0, 1000)
# EX_din[e] (0, 1000)
# EX_duri[e] (0, 1000)
# EX_fe2[e] (-1.0, 1000)
# EX_fe3[e] (-1.0, 1000)
# EX_fum[e] (0, 1000)
# EX_gal[e] (0, 1000)
# EX_glu_L[e] (-0.2, 1000)
# EX_glyb[e] (0, 1000)
# EX_glyleu[e] (0, 1000)
# EX_glyphe[e] (0, 1000)
# EX_glypro[e] (0, 1000)
# EX_h[e] (0, 1000)
# EX_h2o[e] (-1000.0, 1000)
# EX_ile_L[e] (-0.166666666666666, 1000)
# EX_ins[e] (0, 1000)
# EX_k[e] (-1.0, 1000)
# EX_lac_L[e] (0, 1000)
# EX_leu_L[e] (-0.166666666666666, 1000)
# EX_lys_L[e] (-0.166666666666666, 1000)
# EX_mal_L[e] (0, 1000)
# EX_met_L[e] (-0.2, 1000)
# EX_na1[e] (-1.0, 1000)
# EX_no2[e] (0, 1000)
# EX_o2[e] (-100.0, 1000)
# EX_orn[e] (0, 1000)
# EX_pi[e] (-10.0, 1000)
# EX_ppi[e] (0, 1000)
# EX_pro_L[e] (-0.2, 1000)
# EX_ribflv[e] (-1.0, 1000)
# EX_ser_L[e] (-0.333333333333333, 1000)
# EX_so4[e] (-1.0, 1000)
# EX_succ[e] (0, 1000)
# EX_thymd[e] (-1.0, 1000)
# EX_urea[e] (0, 1000)
# EX_uri[e] (0, 1000)
# EX_val_L[e] (-0.2, 1000)
# EX_pnto_R[e] (-1.0, 1000)
# EX_gly[e] (-0.5, 1000)
# EX_cys_L[e] (-0.333333333333333, 1000)
# EX_ala_L[e] (-0.333333333333333, 1000)
# EX_his_L[e] (-0.166666666666666, 1000)
# EX_thr_L[e] (-0.25, 1000)
# EX_gln_L[e] (-0.2, 1000)
# EX_phe_L[e] (-0.111111111111111, 1000)
# EX_tyr_L[e] (-0.111111111111111, 1000)
# EX_arg_L[e] (-0.166666666666666, 1000)
# EX_for[e] (0, 1000)
# EX_nac[e] (0, 1000)
# EX_ind3ac[e] (0, 1000)
# EX_nh4[e] (0, 1000)
# EX_ac[e] (0, 1000)
# EX_acgam[e] (0, 1000)
# EX_cit[e] (0, 1000)
# EX_csn[e] (0, 1000)
# EX_drib[e] (0, 1000)
# EX_etha[e] (0, 1000)
# EX_fol[e] (-1.0, 1000)
# EX_fru[e] (-0.138888888888888, 1000)
# EX_galt[e] (0, 1000)
# EX_glcr[e] (0, 1000)
# EX_glcur[e] (0, 1000)
# EX_glyc[e] (-2.08333333333333, 1000)
# EX_hxan[e] (-1.0, 1000)
# EX_malt[e] (-0.0694444444444444, 1000)
# EX_malthx[e] (0, 1000)
# EX_malttr[e] (0, 1000)
# EX_man[e] (0, 1000)
# EX_ptrc[e] (0, 1000)
# EX_rib_D[e] (0, 1000)
# EX_spmd[e] (0, 1000)
# EX_thm[e] (-1.0, 1000)
# EX_trp_L[e] (-0.0909090909090909, 1000)
# EX_ura[e] (0, 1000)
# EX_xan[e] (0, 1000)
# EX_xyl_D[e] (0, 1000)
# EX_pydxn[e] (-1.0, 1000)
# EX_pydx[e] (0, 1000)
# EX_pydam[e] (0, 1000)
# EX_4hbz[e] (0, 1000)
# EX_34dhpha[e] (0, 1000)
# EX_ppa[e] (0, 1000)
# EX_arab_L[e] (0, 1000)
# EX_gam[e] (0, 1000)
# EX_pyr[e] (0, 1000)
# EX_tre[e] (0, 1000)
# EX_btn[e] (-1.0, 1000)
# EX_lcts[e] (-0.0694444444444444, 1000)
# EX_ade[e] (0, 1000)
# EX_etoh[e] (0, 1000)
# EX_acald[e] (0, 1000)
# EX_sucr[e] (-0.0694444444444444, 1000)
# EX_pheme[e] (-1.0, 1000)
# EX_mqn8[e] (0, 1000)
# EX_gua[e] (0, 1000)
# EX_4abut[e] (0, 1000)
# EX_taur[e] (0, 1000)
# EX_phpyr[e] (0, 1000)
# EX_tym[e] (0, 1000)
# EX_2hyoxplac[e] (0, 1000)
# EX_lanost[e] (0, 1000)
# EX_3mox4hoxm[e] (0, 1000)
# EX_glx[e] (0, 1000)
# EX_CE4970[e] (0, 1000)
# EX_CE2026[e] (0, 1000)
# EX_CE4968[e] (0, 1000)
# EX_actyr[e] (0, 1000)
# EX_sucaceto[e] (0, 1000)
# EX_vanillac[e] (0, 1000)
# EX_nacvanala[e] (0, 1000)
# EX_2h3mv[e] (0, 1000)
# EX_2hiv[e] (0, 1000)
# EX_2m3hbu[e] (0, 1000)
# EX_2m3hvac[e] (0, 1000)
# EX_3h3mglt[e] (0, 1000)
# EX_3mglutac[e] (0, 1000)
# EX_3mglutr[e] (0, 1000)
# EX_ppiogly[e] (0, 1000)
# EX_mvlac[e] (0, 1000)
# EX_tiggly[e] (0, 1000)
# EX_3ohglutac[e] (0, 1000)
# EX_glutcon[e] (0, 1000)
# EX_3hivac[e] (0, 1000)
# EX_3hadpac[e] (0, 1000)
# EX_3ohsebac[e] (0, 1000)
# EX_3ohsubac[e] (0, 1000)
# EX_5ohhexa[e] (0, 1000)
# EX_7ohocata[e] (0, 1000)
# EX_ethmalac[e] (0, 1000)
# EX_hexgly[e] (0, 1000)
# EX_methsucc[e] (0, 1000)
# EX_subgly[e] (0, 1000)
# EX_4ohbut[e] (0, 1000)
# EX_thexdd[e] (0, 1000)
# EX_hexdtr[e] (0, 1000)
# EX_hpdece[e] (0, 1000)
# EX_eic21114tr[e] (0, 1000)
# EX_5eipenc[e] (0, 1000)
# EX_CE4969[e] (0, 1000)
# EX_CE1310[e] (0, 1000)
# EX_agm[e] (0, 1000)
# EX_T4hcinnm[e] (0, 1000)
# EX_sucsal[e] (0, 1000)
# EX_CE7081[e] (0, 1000)
# EX_egme[e] (0, 1000)
# EX_12harachd[e] (0, 1000)
# EX_18harachd[e] (0, 1000)
# EX_sql[e] (0, 1000)
# EX_orn_D[e] (0, 1000)
# EX_5g2oxpt[e] (0, 1000)
# EX_andrstndn[e] (0, 1000)
# EX_dhea[e] (0, 1000)
# EX_eandrstrn[e] (0, 1000)
# EX_ahandrostan[e] (0, 1000)
# EX_andrstandn[e] (0, 1000)
# EX_CE2209[e] (0, 1000)
# EX_estrone[e] (0, 1000)
# EX_C05298[e] (0, 1000)
# EX_C05301[e] (0, 1000)
# EX_C05299[e] (0, 1000)
# EX_C05302[e] (0, 1000)
# EX_CE5072[e] (0, 1000)
# EX_11docrtsl[e] (0, 1000)
# EX_11docrtstrn[e] (0, 1000)
# EX_prgnlone[e] (0, 1000)
# EX_CE2211[e] (0, 1000)
# EX_17ahprgstrn[e] (0, 1000)
# EX_17ahprgnlone[e] (0, 1000)
# EX_C03681[e] (0, 1000)
# EX_HC02020[e] (0, 1000)
# EX_prgnlones[e] (0, 1000)
# EX_CE1352[e] (0, 1000)
# EX_xol24oh[e] (0, 1000)
# EX_xol27oh[e] (0, 1000)
# EX_xol25oh[e] (0, 1000)
# EX_dsmsterol[e] (0, 1000)
# EX_chsterols[e] (0, 1000)
# EX_3ityr_L[e] (0, 1000)
# EX_35diotyr[e] (0, 1000)
# EX_13_cis_retn[e] (0, 1000)
# EX_CE1617[e] (0, 1000)
# EX_HC00460[e] (0, 1000)
# EX_34dhoxmand[e] (0, 1000)
# EX_fna5moxam[e] (0, 1000)
# EX_CE5643[e] (0, 1000)
# EX_CE7090[e] (0, 1000)
# EX_CE7085[e] (0, 1000)
# EX_CE7096[e] (0, 1000)
# EX_CE4877[e] (0, 1000)
# EX_CE1447[e] (0, 1000)
# EX_CE2006[e] (0, 1000)
# EX_CE1401[e] (0, 1000)
# EX_glucys[e] (0, 1000)
# EX_n8aspmd[e] (0, 1000)
# EX_CE6205[e] (0, 1000)
# EX_melatn[e] (0, 1000)
# EX_6hoxmelatn[e] (0, 1000)
# EX_trypta[e] (0, 1000)
# EX_C10164[e] (0, 1000)
# EX_CE4890[e] (0, 1000)
# EX_C09642[e] (0, 1000)
# EX_C05769[e] (0, 1000)
# EX_C05767[e] (0, 1000)
# EX_C05770[e] (0, 1000)
# EX_mhista[e] (0, 1000)
# EX_ppbng[e] (0, 1000)
# EX_13dampp[e] (0, 1000)
# EX_mma[e] (0, 1000)
# EX_12ppd_R[e] (0, 1000)
# EX_ametam[e] (0, 1000)
# EX_xylu_L[e] (0, 1000)
# EX_xylu_D[e] (0, 1000)
# EX_CE0737[e] (0, 1000)
# EX_sphings[e] (0, 1000)
# EX_hdd2crn[e] (0, 1000)
# EX_im4ac[e] (0, 1000)
# EX_CE1918[e] (0, 1000)
# EX_mlthf[e] (0, 1000)
# EX_ppp9[e] (0, 1000)
# EX_aact[e] (0, 1000)
# EX_CE2705[e] (0, 1000)
# EX_sphgn[e] (0, 1000)
# EX_N1aspmd[e] (0, 1000)
# EX_1a25dhvitd3[e] (0, 1000)
# EX_prist[e] (0, 1000)
# EX_CE2049[e] (0, 1000)
# EX_CE2047[e] (0, 1000)
# EX_fdp[e] (0, 1000)
# EX_coke[e] (0, 1000)
# EX_5a2opntn[e] (0, 1000)
# EX_arg_D[e] (0, 1000)
# EX_idl_hs[e] (0, 1000)
# EX_ldl_hs[e] (0, 1000)
# EX_hdl_hs[e] (0, 1000)
# EX_HC00005[e] (0, 1000)
# EX_HC00006[e] (0, 1000)
# EX_HC00007[e] (0, 1000)
# EX_HC00008[e] (0, 1000)
# EX_HC00009[e] (0, 1000)
# EX_dopa4sf[e] (0, 1000)
# EX_dopa4glcur[e] (0, 1000)
# EX_dopa3glcur[e] (0, 1000)
# EX_4glu56dihdind[e] (0, 1000)
# EX_5cysdopa[e] (0, 1000)
# EX_CE5025[e] (0, 1000)
# EX_CE2172[e] (0, 1000)
# EX_CE5629[e] (0, 1000)
# EX_gd3_hs[e] (0, 1000)
# EX_gluside_hs[e] (0, 1000)
# EX_gm3_hs[e] (0, 1000)
# EX_cmpacna[e] (0, 1000)
# EX_gd2_hs[e] (0, 1000)
# EX_gd1a_hs[e] (0, 1000)
# sink_34dhpac[c] (0, 0)
# EX_34dhpe[c] (0, 1000)
# sink_Ser_Gly_Ala_X_Gly[r] (0, 0)
# EX_pail_hs[e] (0, 1000)
# EX_CE1243[e] (0, 1000)
# EX_CE5026[e] (0, 1000)
# EX_5cysgly34dhphe[e] (0, 1000)
# EX_CE1261[e] (0, 1000)
# EX_galgluside_hs[e] (0, 1000)
# EX_ga1_hs[e] (0, 1000)
# EX_gm1_hs[e] (0, 1000)
# EX_gm2_hs[e] (0, 1000)
# EX_gm1b_hs[e] (0, 1000)
# EX_gd1b_hs[e] (0, 1000)
# EX_gt1b_hs[e] (0, 1000)
# sink_xolest2_hs[l] (0, 0)
# EX_nadh[e] (0, 1000)
# EX_glc_D[e] (-0.138888888888888, 1000)
# EX_sbt_D[e] (0, 1000)
# EX_12dhchol[e] (0, 1000)
# EX_3dhcdchol[e] (0, 1000)
# EX_3dhchol[e] (0, 1000)
# EX_3dhdchol[e] (0, 1000)
# EX_3dhlchol[e] (0, 1000)
# EX_7dhcdchol[e] (0, 1000)
# EX_7dhchol[e] (0, 1000)
# EX_ca24g[e] (0, 1000)
# EX_ca3s[e] (0, 1000)
# EX_cdca24g[e] (0, 1000)
# EX_cdca3g[e] (0, 1000)
# EX_coprost[e] (0, 1000)
# EX_dca24g[e] (0, 1000)
# EX_dca3g[e] (0, 1000)
# EX_dca3s[e] (0, 1000)
# EX_gca3s[e] (0, 1000)
# EX_gcdca3s[e] (0, 1000)
# EX_gdca3s[e] (0, 1000)
# EX_gudca3s[e] (0, 1000)
# EX_hca24g[e] (0, 1000)
# EX_hca6g[e] (0, 1000)
# EX_hdca24g[e] (0, 1000)
# EX_hdca6g[e] (0, 1000)
# EX_hyochol[e] (0, 1000)
# EX_icdchol[e] (0, 1000)
# EX_isochol[e] (0, 1000)
# EX_lca24g[e] (0, 1000)
# EX_lca3g[e] (0, 1000)
# EX_lca3s[e] (0, 1000)
# EX_tca3s[e] (0, 1000)
# EX_tcdca3s[e] (0, 1000)
# EX_tdca3s[e] (0, 1000)
# EX_thyochol[e] (0, 1000)
# EX_tudca3s[e] (0, 1000)
# EX_uchol[e] (0, 1000)
# EX_udca3s[e] (0, 1000)
# 1331TAALThr (0, 0)
# 1331TACRhr (0, 0)
# 1331TACRtev (0, 0)
# 13DMThr (0, 0)
# 13DMTtep (0, 0)
# 14HMDZALThr (0, 0)
# 14MDZtev (0, 0)
# 1513DTALThr (0, 0)
# 1513DTACRhr (0, 0)
# 1513TACRtu (0, 0)
# 1513TACRtep (0, 0)
# 1531TACRhr (0, 0)
# 1531TACRtev (0, 0)
# 1531TALThr (0, 0)
# 15DMThr (0, 0)
# 15DMTtu (0, 0)
# 15DMTtep (0, 0)
# 1HMDGLUChr (0, 0)
# 1HMDZGLUChc (0, 0)
# 1OHMDZhr (0, 0)
# 1OHMDZtep (0, 0)
# 2HATVLAChc (0, 0)
# 2HATVACIDGLUChr (0, 0)
# 2HATVACIDGLUCteb (0, 0)
# 2HATVACIDhc (0, 0)
# 2HATVACIDtep (0, 0)
# 2HATVACIDthc (0, 0)
# 2HATVLACteb (0, 0)
# 2HATVLACtep (0, 0)
# 2HATVLACthc (0, 0)
# 2HIBUP_Rthv (0, 0)
# 31DMThr (0, 0)
# 31DMTtu (0, 0)
# 31DMTtep (0, 0)
# 35DHPVSthc (0, 0)
# 3HIBUP_Rthv (0, 0)
# 3HPVSTETCOAhcm (0, 0)
# 3HPVSTETCOAhcx (0, 0)
# 3HPVSTETteb (0, 0)
# 3HPVSTETtev (0, 0)
# 3HPVStep (0, 0)
# 3HPVSthc (0, 0)
# 3ISPVSthc (0, 0)
# 3MEACMPhc (0, 0)
# 3OHACMPhr (0, 0)
# 3OHACMPtev (0, 0)
# 4HATVACIDOXDhc (0, 0)
# 4HATVACIDhc (0, 0)
# 4HATVACIDtep (0, 0)
# 4HATVACIDthc (0, 0)
# 4HATVLACOXDhc (0, 0)
# 4HATVLACtep (0, 0)
# 4HATVLACthc (0, 0)
# 4HMDGLUCtev (0, 0)
# 4HMDZGLUChr (0, 0)
# 4OHMDZtev (0, 0)
# 56DHPVShc (0, 0)
# 56DHPVSteb (0, 0)
# 56EPPVShc (0, 0)
# 56EPPVSteb (0, 0)
# 5OHFVShc (0, 0)
# 6BHGLZhr (0, 0)
# 6BHGLZtev (0, 0)
# 6EPVSthc (0, 0)
# 6HSMVACIDhep (0, 0)
# 6HSMVACIDteb (0, 0)
# 6HSMVhep (0, 0)
# 6MELACAChep (0, 0)
# 6MELVACtbc (0, 0)
# 6MELVSTthep (0, 0)
# 6OHFVSGLUhc (0, 0)
# 6OHFVSGLUtev (0, 0)
# 6OHFVShc (0, 0)
# 6OHFVSteb (0, 0)
# 7BHGLZABCt (0, 0)
# 7BHGLZhr (0, 0)
# 7BHGLZtev (0, 0)
# ACMPGLUTdt (0, 0)
# ACMPGLUTtep (0, 0)
# ACMPGLUTthc (0, 0)
# ACMPGLUtep (0, 0)
# ACMPGLUthc (0, 0)
# ACMPShc (0, 0)
# ACMPdt (0, 0)
# ACMPthc (0, 0)
# ALLOP1tu (0, 0)
# ALLOPOXDhep (0, 0)
# ALLOPtepvb (0, 0)
# AM19CSALThr (0, 0)
# AM1A4NCShc (0, 0)
# AM1A4NCSteb (0, 0)
# AM1ACShr (0, 0)
# AM1ACStep (0, 0)
# AM1ALCShr (0, 0)
# AM1ALCStep (0, 0)
# AM1C4N9CShc (0, 0)
# AM1C4N9CSteb (0, 0)
# AM1C9CShr (0, 0)
# AM1C9CSteb (0, 0)
# AM1C9CStev (0, 0)
# AM1CCShr (0, 0)
# AM1CCSteb (0, 0)
# AM1CCStev (0, 0)
# AM1CSAhr (0, 0)
# AM1CSAtep (0, 0)
# AM4N9CShc (0, 0)
# AM4N9CShr (0, 0)
# AM4N9CStev (0, 0)
# AM4NC9CSteb (0, 0)
# AM4NCShr (0, 0)
# AM4NCSteb (0, 0)
# AM4NCStep (0, 0)
# AM9CSAtep (0, 0)
# ATVACIDMCTtu (0, 0)
# ATVACIDOATPtu (0, 0)
# ATVACIDhc (0, 0)
# ATVACIDhr (0, 0)
# ATVACIDtdu (0, 0)
# ATVACYLGLUChc (0, 0)
# ATVETHGLUChc (0, 0)
# ATVLACThc (0, 0)
# ATVLACh2r (0, 0)
# ATVLAChc (0, 0)
# ATVLACtdhc (0, 0)
# Am19CStev (0, 0)
# Am1CSAteb (0, 0)
# CARIBUP_Rthv (0, 0)
# CARIBUP_Sthv (0, 0)
# CRGLZhr (0, 0)
# CRGLZtev (0, 0)
# CRVS1M24hc (0, 0)
# CRVSATPthc (0, 0)
# CRVSATPtu (0, 0)
# CRVSM1hc (0, 0)
# CRVSM1hr (0, 0)
# CRVSM23hr (0, 0)
# CRVSM24teb (0, 0)
# CRVStu (0, 0)
# CRVSthc (0, 0)
# CSASULPhc (0, 0)
# CSASULPteb (0, 0)
# CSASULPtev (0, 0)
# CSAtd (0, 0)
# CVM1GLUChc (0, 0)
# CVM23GLUChc (0, 0)
# CYSAMPtev (0, 0)
# DEOXFVShc (0, 0)
# DEOXFVStev (0, 0)
# DESFVShc (0, 0)
# DESFVSteb (0, 0)
# DSPVShc (0, 0)
# DSPVSteb (0, 0)
# DSPVStev (0, 0)
# EX_12htacr[e] (0, 1000)
# EX_1331tacr[e] (0, 1000)
# EX_13dmt[e] (0, 1000)
# EX_14hmdz[e] (0, 1000)
# EX_1513tacr[e] (0, 1000)
# EX_1531tacr[e] (0, 1000)
# EX_15dmt[e] (0, 1000)
# EX_1hibup_S[e] (0, 1000)
# EX_1hibupglu_S[e] (0, 1000)
# EX_1hmdgluc[e] (0, 1000)
# EX_1ohmdz[e] (0, 1000)
# EX_2hatvacid[e] (0, 1000)
# EX_2hatvacidgluc[e] (0, 1000)
# EX_2hatvlac[e] (0, 1000)
# EX_2hatvlacgluc[e] (0, 1000)
# EX_2hibup_R[e] (0, 1000)
# EX_2hibup_S[e] (0, 1000)
# EX_2hibupglu_S[e] (0, 1000)
# EX_31dmt[e] (0, 1000)
# EX_35dhpvs[e] (0, 1000)
# EX_35dsmv[e] (0, 1000)
# EX_3hibup_R[e] (0, 1000)
# EX_3hibup_S[e] (0, 1000)
# EX_3hibupglu_S[e] (0, 1000)
# EX_3hlvstacid[e] (0, 1000)
# EX_3hpvs[e] (0, 1000)
# EX_3hpvstet[e] (0, 1000)
# EX_3hsmvacid[e] (0, 1000)
# EX_3ispvs[e] (0, 1000)
# EX_3ohacmp[e] (0, 1000)
# EX_4bhglz[e] (0, 1000)
# EX_4hatvacid[e] (0, 1000)
# EX_4hatvlac[e] (0, 1000)
# EX_4hmdgluc[e] (0, 1000)
# EX_4ohmdz[e] (0, 1000)
# EX_56dhpvs[e] (0, 1000)
# EX_56eppvs[e] (0, 1000)
# EX_5ohfvs[e] (0, 1000)
# EX_5ohfvsglu[e] (0, 1000)
# EX_6ahglz[e] (0, 1000)
# EX_6bhglz[e] (0, 1000)
# EX_6bhglzglc[e] (0, 1000)
# EX_6csmvacid[e] (0, 1000)
# EX_6epvs[e] (0, 1000)
# EX_6hlvst[e] (0, 1000)
# EX_6hmsmvacid[e] (0, 1000)
# EX_6hsmvacid[e] (0, 1000)
# EX_6melvacid[e] (0, 1000)
# EX_6melvst[e] (0, 1000)
# EX_6ohfvs[e] (0, 1000)
# EX_6ohfvsglu[e] (0, 1000)
# EX_7ahglz[e] (0, 1000)
# EX_7bhglz[e] (0, 1000)
# EX_7bhglzglc[e] (0, 1000)
# EX_7hpvs[e] (0, 1000)
# EX_acmp[e] (0, 1000)
# EX_acmpglu[e] (0, 1000)
# EX_acmpglut[e] (0, 1000)
# EX_allop[e] (0, 1000)
# EX_am19cs[e] (0, 1000)
# EX_am1a4ncs[e] (0, 1000)
# EX_am1accs[e] (0, 1000)
# EX_am1acs[e] (0, 1000)
# EX_am1alcs[e] (0, 1000)
# EX_am1c4n9cs[e] (0, 1000)
# EX_am1c9cs[e] (0, 1000)
# EX_am1ccs[e] (0, 1000)
# EX_am1cglc[e] (0, 1000)
# EX_am1csa[e] (0, 1000)
# EX_am4n9cs[e] (0, 1000)
# EX_am4ncs[e] (0, 1000)
# EX_am9csa[e] (0, 1000)
# EX_atvacid[e] (0, 1000)
# EX_atvlac[e] (0, 1000)
# EX_caribup_R[e] (0, 1000)
# EX_caribup_s[e] (0, 1000)
# EX_caribupglu_S[e] (0, 1000)
# EX_crglz[e] (0, 1000)
# EX_crvs[e] (0, 1000)
# EX_crvsm1[e] (0, 1000)
# EX_crvsm23[e] (0, 1000)
# EX_crvsm24[e] (0, 1000)
# EX_csa[e] (0, 1000)
# EX_csasulp[e] (0, 1000)
# EX_cysacmp[e] (0, 1000)
# EX_deoxfvs[e] (0, 1000)
# EX_desfvs[e] (0, 1000)
# EX_dhglz[e] (0, 1000)
# EX_dspvs[e] (0, 1000)
# EX_epoxtac[e] (0, 1000)
# EX_fvs[e] (0, 1000)
# EX_fvstet[e] (0, 1000)
# EX_fvstetglu[e] (0, 1000)
# EX_glc3meacp[e] (0, 1000)
# EX_glz[e] (0, 1000)
# EX_gtacmp[e] (0, 1000)
# EX_ibup_R[e] (0, 1000)
# EX_ibup_S[e] (0, 1000)
# EX_ibupgluc[e] (0, 1000)
# EX_isolvstacid[e] (0, 1000)
# EX_lst4exp[e] (0, 1000)
# EX_lstn[e] (0, 1000)
# EX_lstn1gluc[e] (0, 1000)
# EX_lstnm1[e] (0, 1000)
# EX_lstnm2[e] (0, 1000)
# EX_lstnm4[e] (0, 1000)
# EX_lstnm5[e] (0, 1000)
# EX_lstnm7[e] (0, 1000)
# EX_lvst[e] (0, 1000)
# EX_mdz[e] (0, 1000)
# EX_mdzglc[e] (0, 1000)
# EX_meracmp[e] (0, 1000)
# EX_mhglz[e] (0, 1000)
# EX_ndersv[e] (0, 1000)
# EX_nfd[e] (0, 1000)
# EX_nfdac[e] (0, 1000)
# EX_nfdlac[e] (0, 1000)
# EX_nfdnpy[e] (0, 1000)
# EX_nfdoh[e] (0, 1000)
# EX_oxyp[e] (0, 1000)
# EX_oxyp1rb[e] (0, 1000)
# EX_oxyp7rb[e] (0, 1000)
# EX_profvs[e] (0, 1000)
# EX_ptvst[e] (0, 1000)
# EX_ptvstlac[e] (0, 1000)
# EX_ptvstm3[e] (0, 1000)
# EX_pvs[e] (0, 1000)
# EX_pvsgluc[e] (0, 1000)
# EX_rsv[e] (0, 1000)
# EX_rsvlac[e] (0, 1000)
# EX_s3meacmp[e] (0, 1000)
# EX_smv[e] (0, 1000)
# EX_smvacid[e] (0, 1000)
# EX_stacmp[ev] (0, 1000)
# EX_sulpacmp[e] (0, 1000)
# EX_tacr[e] (0, 1000)
# EX_tauribup_S[e] (0, 1000)
# EX_thrfvs[e] (0, 1000)
# EX_tlacfvs[e] (0, 1000)
# EX_tmd[e] (0, 1000)
# EX_tmdm1[e] (0, 1000)
# EX_tmdm3[e] (0, 1000)
# EX_tmdm5[e] (0, 1000)
# EX_tripvs[e] (0, 1000)
# EX_tsacmgluc[e] (0, 1000)
# EX_tsacmsul[e] (0, 1000)
# FVSGLUChc (0, 0)
# FVShc (0, 0)
# FVStep (0, 0)
# FVStu (0, 0)
# GLZtd (0, 0)
# IBUP_RCYP2hep (0, 0)
# IBUP_RCYP3hep (0, 0)
# IBUP_RCYPCARhep (0, 0)
# IBUP_Rtdhep (0, 0)
# IBUP_Rtdu (0, 0)
# IBUP_SCYP3hep (0, 0)
# IBUP_SCYPCARhep (0, 0)
# IBUP_Stdhep (0, 0)
# IBUP_Stdu (0, 0)
# LST4EXPTDhc (0, 0)
# LST4EXPhr (0, 0)
# LST4EXPthc (0, 0)
# LSTNM1hr (0, 0)
# LSTNM1tev (0, 0)
# LSTNM4hr (0, 0)
# LSTNM4tev (0, 0)
# LSTNM7TDhc (0, 0)
# LSTNM7thc (0, 0)
# LSTNRATt (0, 0)
# LSTNtd (0, 0)
# LVACLAChep (0, 0)
# LVSTACIDhep (0, 0)
# LVSTACOXD6MEhep (0, 0)
# LVSTOXD6METhep (0, 0)
# LVSTtu (0, 0)
# MDZtd (0, 0)
# MERACMPtep (0, 0)
# MERACMPthc (0, 0)
# MHGLZABCt (0, 0)
# MHGLZhr (0, 0)
# MHGLZtev (0, 0)
# NDERSVhc (0, 0)
# NDERSVteb (0, 0)
# NFDACOXDhc (0, 0)
# NFDACtep (0, 0)
# NFDDMEThr (0, 0)
# NFDLAChc (0, 0)
# NFDLACtep (0, 0)
# NFDNPYtep (0, 0)
# NFDOHtep (0, 0)
# NFDOXDhc (0, 0)
# NFDtd (0, 0)
# OXYP1CONJ (0, 0)
# OXYP2CONJ (0, 0)
# OXYPR1tehv (0, 0)
# OXYPR7tehv (0, 0)
# OXYPthc (0, 0)
# OXYPtepv (0, 0)
# PTVSTATPtu (0, 0)
# PTVSTGLUChc (0, 0)
# PTVSTLAChc (0, 0)
# PTVSTLACtev (0, 0)
# PTVSTM13hr (0, 0)
# PTVSThc (0, 0)
# PTVSTtep (0, 0)
# PTVSTtu (0, 0)
# PVSGLUChc (0, 0)
# PVSGLUCtev (0, 0)
# PVSHtu (0, 0)
# PVSOATPtu (0, 0)
# PVStep (0, 0)
# RSVGLUChc (0, 0)
# RSVhc (0, 0)
# RSVtev (0, 0)
# RSVtu (0, 0)
# S3MEACMPhc (0, 0)
# S3MEACMPtev (0, 0)
# SMVACIDhep (0, 0)
# SMVACIDtev (0, 0)
# SMVGLUChep (0, 0)
# SMVHYDROhep (0, 0)
# SMVtv (0, 0)
# SMVthep (0, 0)
# SULPACMPtev (0, 0)
# TACRDtsc (0, 0)
# THRFVShc (0, 0)
# THRFVStev (0, 0)
# TLACFVShc (0, 0)
# TLACFVStev (0, 0)
# TMDM1OATt (0, 0)
# TMDM1hr (0, 0)
# TMDM3OATt (0, 0)
# TMDM3hr (0, 0)
# TMDM5OATt (0, 0)
# TMDM5hr (0, 0)
# TMDOATPtsc (0, 0)
# TMDOATtev (0, 0)
# TMDOATthc (0, 0)
# TMDtd (0, 0)
# TRIPVShc (0, 0)
# TRIPVSteb (0, 0)
# 13HTACRitr (0, 0)
# 14HMDZitr (0, 0)
# 1513TACRitr (0, 0)
# 1531TACRitr (0, 0)
# 1HMDGLUCitr (0, 0)
# 2HATVACIDGLUCitr (0, 0)
# 2HIBUP_Ritr (0, 0)
# 3HIBUP_Ritr (0, 0)
# 3HPVSCOAitm (0, 0)
# 3HPVSCOAitx (0, 0)
# 3HPVSTETCOAitm (0, 0)
# 3HPVSTETCOAitx (0, 0)
# 3ISPVSitr (0, 0)
# 3OHACMPitr (0, 0)
# 4HATVACIDitr (0, 0)
# 4HATVLACitr (0, 0)
# 4HMDGLUCitr (0, 0)
# 4OHMDZitr (0, 0)
# 56DHPVSitr (0, 0)
# 56EPPVSitr (0, 0)
# 6HSMVitr (0, 0)
# 6MELVACIDitr (0, 0)
# 6MELVSTitr (0, 0)
# 6OHFVSitr (0, 0)
# 6OHFVSGLUitr (0, 0)
# ACMPitr (0, 0)
# AM19CSitr (0, 0)
# AM1ACSitr (0, 0)
# AM1ALCSitr (0, 0)
# AM1C9CSitr (0, 0)
# AM4N9CSitr (0, 0)
# AM4NCSitr (0, 0)
# CRGLZitr (0, 0)
# CRVSitr (0, 0)
# CRVSM24itr (0, 0)
# CSAitr (0, 0)
# DEOXFVSitx (0, 0)
# DESFVSitr (0, 0)
# DSPVSitr (0, 0)
# FVSitx (0, 0)
# GLZitr (0, 0)
# IBUP_Ritr (0, 0)
# IBUP_Sitr (0, 0)
# LSTNitr (0, 0)
# LSTNM1itr (0, 0)
# LSTNM4itr (0, 0)
# LVSTitr (0, 0)
# EX_lvstacid[e] (0, 1000)
# LVSTACIDitr (0, 0)
# MDZitr (0, 0)
# NDERSVitr (0, 0)
# NFDNPYitr (0, 0)
# NFDOHitr (0, 0)
# PTVSTLACitr (0, 0)
# PTVSTM13itr (0, 0)
# PTVSTM13te (0, 0)
# EX_ptvstm13[e] (0, 1000)
# PVSitr (0, 0)
# PVSGLUCitr (0, 0)
# TACRitr (0, 0)
# TLACFVSitr (0, 0)
# TMDitr (0, 0)
# TMDM1itr (0, 0)
# TMDM3itr (0, 0)
# TMDM5itr (0, 0)
# 3HPVSCOAhc (0, 0)
# 3HPVSTEThc (0, 0)
# ACMPGLUTTRsc (0, 0)
# 1OHMDZitr (0, 0)
# CYSACMPitr (0, 0)
# NFDACitr (0, 0)
# ACMPGLUTitr (0, 0)
# H2O2itr (0, 0)
# UDPRIBc (0, 0)
# GLYitr (0, 0)
# 13DMTitr (0, 0)
# 15DMTitr (0, 0)
# ATVACIDitr (0, 0)
# ATVLACitr (0, 0)
# 31DMTitr (0, 0)
# SMVitr (0, 0)
# 6BHGLZitr (0, 0)
# 7BHGLZitr (0, 0)
# AM1CCSitr (0, 0)
# MHGLZitr (0, 0)
# RSVitr (0, 0)
# TRIPVSitr (0, 0)
# PTVSTitr (0, 0)
# 3HIBUP_Sitr (0, 0)
# FVSitr (0, 0)
# AM1CSAitr (0, 0)
# 2HATVACIDitr (0, 0)
# EX_caproic[e] (0, 1000)
# EX_1a25dhvitd2[e] (0, 1000)
# EX_C13856[e] (0, 1000)
# EX_M02956[e] (0, 1000)
# EX_M00234[e] (0, 1000)
# EX_M01807[e] (0, 1000)
# EX_M00503[e] (0, 1000)
# EX_M00241[e] (0, 1000)
# EX_M01820[e] (0, 1000)
# EX_M00510[e] (0, 1000)
# EX_M00003[e] (0, 1000)
# EX_M00008[e] (0, 1000)
# EX_M00010[e] (0, 1000)
# EX_M00017[e] (0, 1000)
# EX_M00019[e] (0, 1000)
# EX_M00021[e] (0, 1000)
# EX_M00115[e] (0, 1000)
# EX_M00117[e] (0, 1000)
# EX_M00260[e] (0, 1000)
# EX_M00265[e] (0, 1000)
# EX_M00315[e] (0, 1000)
# EX_M00341[e] (0, 1000)
# EX_M01197[e] (0, 1000)
# EX_M01207[e] (0, 1000)
# EX_M01235[e] (0, 1000)
# EX_M01238[e] (0, 1000)
# EX_M01582[e] (0, 1000)
# EX_M02053[e] (0, 1000)
# EX_M02457[e] (0, 1000)
# EX_M02613[e] (0, 1000)
# EX_M02745[e] (0, 1000)
# EX_M03045[e] (0, 1000)
# EX_M03051[e] (0, 1000)
# EX_M03153[e] (0, 1000)
# EX_M02560[e] (0, 1000)
# EX_M02561[e] (0, 1000)
# EX_C01601[e] (0, 1000)
# EX_M02909[e] (0, 1000)
# EX_M02108[e] (0, 1000)
# EX_M03117[e] (0, 1000)
# EX_M03134[e] (0, 1000)
# EX_M01111[e] (0, 1000)
# EX_h2co3[e] (0, 1000)
# EX_M01872[e] (0, 1000)
# EX_M01870[e] (0, 1000)
# EX_ditp[e] (0, 1000)
# EX_hnifedipine[e] (0, 1000)
# EX_M02446[e] (0, 1000)
# EX_M02447[e] (0, 1000)
# EX_M02449[e] (0, 1000)
# EX_M02451[e] (0, 1000)
# EX_itacon[e] (0, 1000)
# EX_adpman[e] (0, 1000)
# EX_rbl_D[e] (0, 1000)
# EX_M01966[e] (0, 1000)
# EX_M02155[e] (0, 1000)
# EX_M01989[e] (0, 1000)
# EX_M02837[e] (0, 1000)
# EX_gpi_sig[e] (0, 1000)
# EX_M01881[e] (0, 1000)
# EX_M03131[e] (0, 1000)
# EX_n5m2masn[e] (0, 1000)
# EX_hretn[e] (0, 1000)
# EX_kdn[e] (0, 1000)
# EX_m3gacpail_prot_hs[e] (0, 1000)
# EX_dolichol_L[e] (0, 1000)
# sink_his_L[c] (0, 0)
# sink_ile_L[c] (0, 0)
# sink_leu_L[c] (0, 0)
# sink_lys_L[c] (0, 0)
# sink_met_L[c] (0, 0)
# sink_phe_L[c] (0, 0)
# sink_thr_L[c] (0, 0)
# sink_trp_L[c] (0, 0)
# sink_val_L[c] (0, 0)
# sink_ala_L[c] (0, 0)
# sink_arg_L[c] (0, 0)
# sink_asn_L[c] (0, 0)
# sink_asp_L[c] (0, 0)
# sink_cys_L[c] (0, 0)
# sink_gln_L[c] (0, 0)
# sink_glu_L[c] (0, 0)
# sink_pro_L[c] (0, 0)
# sink_ser_L[c] (0, 0)
# sink_tyr_L[c] (0, 0)
# sink_gly[c] (0, 0)
# sink_4abut[l] (0, 0)
# EX_adprbp[n] (0, 1000)

# %%
srfba = SRFBA(generic_model).build()

# %%
microbiome_fluxes = pd.read_excel("..\\data\\infant_microbiomes\\microbiome_fluxes_recon3d.xlsx").set_index("Index")

# %%
microbiome_fluxes = microbiome_fluxes.loc["Butyrate"].to_dict()

# %%
metadata = pd.read_excel("..\\data\\infant_microbiomes\\43856_2024_715_MOESM7_ESM.xlsx", header=3).set_index("Sample ID")

# %%
butyrate_fluxes = pd.read_excel("..\\data\\infant_microbiomes\\43856_2024_715_MOESM7_ESM.xlsx", header=3).set_index("Sample ID")

# %%
butyrate_fluxes = butyrate_fluxes["Adjusted Butyrate Flux"].to_dict()

# %%
results = {}
for sample, butyrate_flux in butyrate_fluxes.items():
    print("Sample:", sample, "butyrate flux:", butyrate_flux)
    sirt1_expression = max(0, -1.385 * butyrate_flux + 0.879)
    print("Sirt1 Expression = ", sirt1_expression)
    real_initial_state = get_real_initial_state(generic_model, initial_state={"SIRT1": sirt1_expression}, strategy="mean")
    sol = srfba.optimize(initial_state = real_initial_state)
    print("Solution =",sol.objective_value)
    results[sample] = sol.to_series()
    print("----------------------------------")
# Out:
# Sample: V3_C005 butyrate flux: 0.014761111111111112
# Sirt1 Expression =  0.8585558611111112
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V3_C009 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V3_C010 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.28147732812706466
# ----------------------------------
# Sample: V3_C016 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.28147732812706466
# ----------------------------------
# Sample: V3_C018 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.28147732812706466
# ----------------------------------
# Sample: V3_C019 butyrate flux: 0.012165833333333336
# Sirt1 Expression =  0.8621503208333333
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V3_C100 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V3_C101 butyrate flux: 0.08569148795149654
# Sirt1 Expression =  0.7603172891871773
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V3_C105 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V3_C106 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.28147732812706466
# ----------------------------------
# Sample: V3_C110 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.28147732812706466
# ----------------------------------
# Sample: V3_C111 butyrate flux: 0.0064516666666666654
# Sirt1 Expression =  0.8700644416666666
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V3_C112 butyrate flux: 0.07039180555555555
# Sirt1 Expression =  0.7815073493055555
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V3_C113 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V3_C114 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.28147732812706466
# ----------------------------------
# Sample: V3_C117 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.28147732812706466
# ----------------------------------
# Sample: V3_C119 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.28147732812706466
# ----------------------------------
# Sample: V3_C120 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.28147732812706466
# ----------------------------------
# Sample: V4_C005 butyrate flux: 0.0067176388888888884
# Sirt1 Expression =  0.8696960701388889
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C009 butyrate flux: 0.2482222222222222
# Sirt1 Expression =  0.5352122222222222
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C010 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C016 butyrate flux: 0.2530877777777778
# Sirt1 Expression =  0.5284734277777777
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C018 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C019 butyrate flux: 0.05324333333333334
# Sirt1 Expression =  0.8052579833333333
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C100 butyrate flux: 0.016730555555555554
# Sirt1 Expression =  0.8558281805555555
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C101 butyrate flux: 0.13576333333333332
# Sirt1 Expression =  0.6909677833333334
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C105 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C106 butyrate flux: 0.023780555555555555
# Sirt1 Expression =  0.8460639305555555
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C110 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C111 butyrate flux: 0.009067222222222223
# Sirt1 Expression =  0.8664418972222222
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C112 butyrate flux: 0.14190777777777777
# Sirt1 Expression =  0.6824577277777778
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C113 butyrate flux: 0.021684583333333333
# Sirt1 Expression =  0.8489668520833333
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C114 butyrate flux: 0.024175
# Sirt1 Expression =  0.845517625
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C117 butyrate flux: 0.052403333333333336
# Sirt1 Expression =  0.8064213833333334
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C119 butyrate flux: 0.11722777777777778
# Sirt1 Expression =  0.7166395277777777
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V4_C120 butyrate flux: 0.0032359722222222225
# Sirt1 Expression =  0.8745181784722222
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C005 butyrate flux: 0.14724749999999998
# Sirt1 Expression =  0.6750622125000001
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C009 butyrate flux: 0.08870666666666666
# Sirt1 Expression =  0.7561412666666667
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C010 butyrate flux: 0.3220791666666667
# Sirt1 Expression =  0.43292035416666663
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C018 butyrate flux: 0.04848680555555556
# Sirt1 Expression =  0.8118457743055556
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C019 butyrate flux: 0.09518452631266666
# Sirt1 Expression =  0.7471694310569567
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C100 butyrate flux: 0.0021158333333333302
# Sirt1 Expression =  0.8760695708333334
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C101 butyrate flux: 0.20808888888888888
# Sirt1 Expression =  0.5907968888888889
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C105 butyrate flux: 0.0690135674610243
# Sirt1 Expression =  0.7834162090664814
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C106 butyrate flux: 0.0035393055555555555
# Sirt1 Expression =  0.8740980618055556
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C110 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C111 butyrate flux: 0.026331944444444446
# Sirt1 Expression =  0.8425302569444444
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C112 butyrate flux: 0.0732998209547375
# Sirt1 Expression =  0.7774797479776886
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C113 butyrate flux: 0.1575427275495302
# Sirt1 Expression =  0.6608033223439007
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C114 butyrate flux: 0.05069597222222222
# Sirt1 Expression =  0.8087860784722223
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C117 butyrate flux: 0.0
# Sirt1 Expression =  0.879
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C119 butyrate flux: 0.03989694444444445
# Sirt1 Expression =  0.8237427319444445
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V5_C120 butyrate flux: 0.0025281944444444475
# Sirt1 Expression =  0.8754984506944444
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C005 butyrate flux: 0.08726652777777777
# Sirt1 Expression =  0.7581358590277778
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C009 butyrate flux: 0.23019944444444443
# Sirt1 Expression =  0.5601737694444444
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C010 butyrate flux: 0.1950101388888889
# Sirt1 Expression =  0.6089109576388889
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C016 butyrate flux: 0.2846522628228778
# Sirt1 Expression =  0.4847566159903142
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C018 butyrate flux: 0.22733222222222224
# Sirt1 Expression =  0.5641448722222222
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C019 butyrate flux: 0.16124847222222222
# Sirt1 Expression =  0.6556708659722222
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C100 butyrate flux: 0.08944736111111112
# Sirt1 Expression =  0.7551154048611111
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C101 butyrate flux: 0.14857194444444444
# Sirt1 Expression =  0.6732278569444444
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C105 butyrate flux: 0.13437453963219131
# Sirt1 Expression =  0.692891262609415
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C106 butyrate flux: 0.1615284722222222
# Sirt1 Expression =  0.6552830659722223
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C110 butyrate flux: 0.04923972222222222
# Sirt1 Expression =  0.8108029847222222
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C111 butyrate flux: 0.07757133409228126
# Sirt1 Expression =  0.7715637022821904
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C112 butyrate flux: 0.18928574185492983
# Sirt1 Expression =  0.6168392475309221
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C113 butyrate flux: 0.11424222222222222
# Sirt1 Expression =  0.7207745222222223
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C114 butyrate flux: 0.16644055555555556
# Sirt1 Expression =  0.6484798305555556
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C117 butyrate flux: 0.14862194444444443
# Sirt1 Expression =  0.6731586069444444
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C119 butyrate flux: 0.2562617128016638
# Sirt1 Expression =  0.5240775277696956
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: V6_C120 butyrate flux: 0.1015973611111111
# Sirt1 Expression =  0.7382876548611111
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: M_C100 butyrate flux: 0.11895638888888888
# Sirt1 Expression =  0.7142454013888889
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: M_C105 butyrate flux: 0.37453833333333336
# Sirt1 Expression =  0.3602644083333333
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: M_C106 butyrate flux: 0.41194305555555555
# Sirt1 Expression =  0.30845886805555556
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: M_C109 butyrate flux: 0.09032805555555556
# Sirt1 Expression =  0.7538956430555556
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: M_C110 butyrate flux: 0.5249691666666667
# Sirt1 Expression =  0.1519177041666666
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: M_C111 butyrate flux: 0.5752683333333334
# Sirt1 Expression =  0.08225335833333325
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: M_C117 butyrate flux: 0.37629833333333335
# Sirt1 Expression =  0.35782680833333336
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: M_C118 butyrate flux: 0.34695194444444444
# Sirt1 Expression =  0.39847155694444447
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: M_C120 butyrate flux: 0.35646861111111106
# Sirt1 Expression =  0.3852909736111112
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: M_C115 butyrate flux: 0.6089904166666666
# Sirt1 Expression =  0.035548272916666734
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: M_C101 butyrate flux: 0.06631055555555555
# Sirt1 Expression =  0.7871598805555555
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: M_C114 butyrate flux: 0.3379434722222222
# Sirt1 Expression =  0.41094829097222224
# Solution = 0.2814773281271275
# ----------------------------------
# Sample: M_C119 butyrate flux: 0.3616244444444444
# Sirt1 Expression =  0.3781501444444445
# Solution = 0.2814773281271275
# ----------------------------------

# %%
reactions = []
for reaction in generic_model.reactions.keys():
    model_reaction = generic_model.get(reaction)
    if not "target" in model_reaction.types:
        reactions.append(reaction)

# %%
from cobra.io import read_sbml_model
import cobra
config = cobra.Configuration()
config.solver = 'cplex'

# %%
cobraModel = read_sbml_model(generic_sbml_fname)

# %%
rxn2subsystem = {}
for r in cobraModel.reactions:
    r_id = r.id
    rxn2subsystem[r_id] = cobraModel.reactions.get_by_id(r_id).subsystem

# %%
rxn2subsystem
# Out:
# {'10FTHF5GLUtl': 'Transport, lysosomal',
#  '10FTHF5GLUtm': 'Transport, mitochondrial',
#  '10FTHF6GLUtl': 'Transport, lysosomal',
#  '10FTHF6GLUtm': 'Transport, mitochondrial',
#  '10FTHF7GLUtl': 'Transport, lysosomal',
#  '10FTHF7GLUtm': 'Transport, mitochondrial',
#  '10FTHFtl': 'Transport, lysosomal',
#  '10FTHFtm': 'Transport, mitochondrial',
#  '11DOCRTSLtm': 'Transport, mitochondrial',
#  '11DOCRTSLtr': 'Transport, endoplasmic reticular',
#  '11DOCRTSTRNtm': 'Transport, mitochondrial',
#  '11DOCRTSTRNtr': 'Transport, endoplasmic reticular',
#  '13DAMPPOX': 'Beta-Alanine metabolism',
#  '1a_24_25VITD2Hm': 'Vitamin D metabolism',
#  '1a_25VITD2Hm': 'Vitamin D metabolism',
#  '1MNCAMti': 'Transport, extracellular',
#  '1PPDCRp': 'Lysine metabolism',
#  '24_25DHVITD2t': 'Transport, extracellular',
#  '24_25DHVITD2tm': 'Transport, mitochondrial',
#  '24_25DHVITD3t': 'Transport, extracellular',
#  '24_25DHVITD3tm': 'Transport, mitochondrial',
#  '24_25VITD2Hm': 'Vitamin D metabolism',
#  '24_25VITD3Hm': 'Vitamin D metabolism',
#  '24NPHte': 'Transport, extracellular',
#  '25HVITD2t': 'Transport, extracellular',
#  '25HVITD2tin_m': 'Transport, mitochondrial',
#  '25HVITD3t': 'Transport, extracellular',
#  '25HVITD3tin_m': 'Transport, mitochondrial',
#  '25VITD2Hm': 'Vitamin D metabolism',
#  '25VITD3Hm': 'Vitamin D metabolism',
#  '2AMACHYD': 'Glycine, serine, alanine, and threonine metabolism',
#  '2AMACSULT': 'Methionine and cysteine metabolism',
#  '2AMADPTm': 'Lysine metabolism',
#  '2DR1PP': 'Pyrimidine catabolism',
#  '2HBO': 'Propanoate metabolism',
#  '2HBt2': 'Transport, extracellular',
#  '2HCO3_NAt': 'Transport, extracellular',
#  '2MCITt': 'Transport, extracellular',
#  '2OXOADOXm': 'Lysine metabolism',
#  '2OXOADPTm': 'Tryptophan metabolism',
#  '34DHOXPEGOX': 'Tyrosine metabolism',
#  '34DHOXPEGt': 'Transport, extracellular',
#  '34DHPHAMT': 'Tyrosine metabolism',
#  '34DHPHEt': 'Transport, extracellular',
#  '34DHPLACOX': 'Tyrosine metabolism',
#  '34DHPLACOX_NADP_': 'Tyrosine metabolism',
#  '34DHXMANDACOX': 'Tyrosine metabolism',
#  '34DHXMANDACOX_NADP_': 'Tyrosine metabolism',
#  '34HPLFM': 'Ubiquinone synthesis',
#  '34HPPOR': 'Tyrosine metabolism',
#  '35CGMPtn': 'Transport, nuclear',
#  '3AIBTm': 'Valine, leucine, and isoleucine metabolism',
#  '3AIBtmi': 'Transport, mitochondrial',
#  '3DPHBH1': 'Ubiquinone synthesis',
#  '3DPHBH2': 'Ubiquinone synthesis',
#  '3DSPHR': 'Sphingolipid metabolism',
#  '3HAO': 'Tryptophan metabolism',
#  '3HBCDm': 'Butanoate metabolism',
#  '3HBCOAHLm': 'Valine, leucine, and isoleucine metabolism',
#  '3HKYNAKGAT': 'Tryptophan metabolism',
#  '3HLYTCL': 'Tyrosine metabolism',
#  '3M4HDXPAC': 'Tyrosine metabolism',
#  '3MLDAt': 'Transport, extracellular',
#  '3MOBt2im': 'Transport, mitochondrial',
#  '3MOPt2im': 'Transport, mitochondrial',
#  '3MOX4HOXPGALDOX': 'Tyrosine metabolism',
#  '3MOX4HOXPGALDOX_NADP_': 'Tyrosine metabolism',
#  '3MOXTYROX': 'Tyrosine metabolism',
#  '3SALAASPm': 'Transport, mitochondrial',
#  '3SALACBOXL': 'Taurine and hypotaurine metabolism',
#  '3SALAOX': 'Taurine and hypotaurine metabolism',
#  '3SALATAi': 'Methionine and cysteine metabolism',
#  '3SALATAim': 'Methionine and cysteine metabolism',
#  '3SPYRSP': 'Methionine and cysteine metabolism',
#  '3SPYRSPm': 'Methionine and cysteine metabolism',
#  '41R1H2MAE12BOOX': 'Tyrosine metabolism',
#  '41R2A1H12BOOX': 'Tyrosine metabolism',
#  '42A12BOOX': 'Tyrosine metabolism',
#  '4ABUTtm': 'Transport, mitochondrial',
#  '4HBZCOAFm': 'Ubiquinone synthesis',
#  '4HBZFm': 'Ubiquinone synthesis',
#  '4HDEBRISOQUINEte': 'Transport, extracellular',
#  '4HGLSDm': 'Arginine and proline metabolism',
#  '4HOXPACDOX_NADP_': 'Tyrosine metabolism',
#  '4MOPt2im': 'Transport, mitochondrial',
#  '4MPTNLte': 'Transport, extracellular',
#  '4MPTNLtm': 'Transport, mitochondrial',
#  '4MTOLBUTAMIDEte': 'Transport, extracellular',
#  '4NPHSFte': 'Transport, extracellular',
#  '4NPHSULT': 'Cytochrome metabolism',
#  '4NPHte': 'Transport, extracellular',
#  '4PYRDX': 'Transport, extracellular',
#  '5ADTSTSTERONEGLCte': 'Transport, extracellular',
#  '5ADTSTSTERONEGLCtr': 'Transport, endoplasmic reticular',
#  '5ADTSTSTERONESte': 'Transport, extracellular',
#  '5ADTSTSTERONESULT': 'Steroid metabolism',
#  '5ADTSTSTERONEte': 'Transport, extracellular',
#  '5ADTSTSTERONEtr': 'Transport, endoplasmic reticular',
#  '5AOPtm': 'Heme synthesis',
#  '5DHFtl': 'Transport, lysosomal',
#  '5FTHFt2': 'Transport, extracellular',
#  '5HLTDL': 'Tryptophan metabolism',
#  '5HOMEPRAZOLEte': 'Transport, extracellular',
#  '5HOXINDACTO2OX': 'Tryptophan metabolism',
#  '5HOXINOXDA': 'Tryptophan metabolism',
#  '5HTRPVESSEC': 'Transport, extracellular',
#  '5MTHFt': 'Transport, extracellular',
#  '5MTHFt2': 'Transport, extracellular',
#  '5THFtl': 'Transport, lysosomal',
#  '5THFtm': 'Transport, mitochondrial',
#  '6DHFtl': 'Transport, lysosomal',
#  '6DHFtm': 'Transport, mitochondrial',
#  '6HTSTSTERONEte': 'Transport, extracellular',
#  '6HTSTSTERONEtr': 'Transport, endoplasmic reticular',
#  '6THFtl': 'Transport, lysosomal',
#  '6THFtm': 'Transport, mitochondrial',
#  '7DHCHSTEROLtr': 'Transport, endoplasmic reticular',
#  '7DHFtl': 'Transport, lysosomal',
#  '7DHFtm': 'Transport, mitochondrial',
#  '7THFtl': 'Transport, lysosomal',
#  '7THFtm': 'Transport, mitochondrial',
#  'A_MANASEly': 'N-glycan degradation',
#  'A4GALTc': 'Sphingolipid metabolism',
#  'A4GALTg': 'Sphingolipid metabolism',
#  'A4GNT1g': 'O-glycan metabolism',
#  'A4GNT2g': 'O-glycan metabolism',
#  'AACTOOR': 'Glycine, serine, alanine, and threonine metabolism',
#  'AACTtm': 'Transport, mitochondrial',
#  'AASAD3m': 'Lysine metabolism',
#  'AATAi': 'Lysine metabolism',
#  'ABO1g': 'Blood group synthesis',
#  'ABO2g': 'Blood group synthesis',
#  'ABO3g': 'Blood group synthesis',
#  'ABO4g': 'Blood group synthesis',
#  'ABO5g': 'Blood group synthesis',
#  'ABO6g': 'Blood group synthesis',
#  'ABO7g': 'Blood group synthesis',
#  'ABO8g': 'Blood group synthesis',
#  'ABO9g': 'Blood group synthesis',
#  'ABTArm': 'Glutamate metabolism',
#  'ABTD': 'Pentose phosphate pathway',
#  'ABTti': 'Transport, extracellular',
#  'ABUTt2rL': 'Transport, lysosomal',
#  'ABUTt4_2_r': 'Transport, extracellular',
#  'ACACT10m': 'Valine, leucine, and isoleucine metabolism',
#  'ACACT1rm': 'Tryptophan metabolism',
#  'ACACT1x': 'Cholesterol metabolism',
#  'ACACt2m': 'Transport, mitochondrial',
#  'ACACT4p': 'Fatty acid oxidation',
#  'ACACT5p': 'Fatty acid oxidation',
#  'ACACT6p': 'Fatty acid oxidation',
#  'ACACT7p': 'Fatty acid oxidation',
#  'ACACT8p': 'Fatty acid oxidation',
#  'ACACT9p': 'Fatty acid oxidation',
#  'ACACtx': 'Transport, peroxisomal',
#  'ACALDtm': 'Transport, mitochondrial',
#  'ACALDtr': 'Transport, endoplasmic reticular',
#  'ACALDtx': 'Transport, peroxisomal',
#  'ACCOACm': 'Fatty acid oxidation',
#  'ACCOAgt': 'Transport, extracellular',
#  'ACCOALm': 'Propanoate metabolism',
#  'ACCOAtn': 'Transport, nuclear',
#  'ACCOAtr': 'Transport, endoplasmic reticular',
#  'ACETONEt2': 'Transport, extracellular',
#  'ACETONEt2m': 'Transport, mitochondrial',
#  'ACGAGBSIDEtg': 'Transport, golgi apparatus',
#  'ACGAGBSIDEtl': 'Transport, lysosomal',
#  'ACGALFUCGALACGALFUC12GAL14ACGLCGALGLUSIDEte': 'Transport, extracellular',
#  'ACGALFUCGALACGALFUC12GAL14ACGLCGALGLUSIDEtg': 'Transport, golgi apparatus',
#  'ACGALFUCGALACGALFUCGALACGLCGAL14ACGLCGALGLUSIDEte': 'Transport, extracellular',
#  'ACGALFUCGALACGALFUCGALACGLCGAL14ACGLCGALGLUSIDEtg': 'Transport, golgi apparatus',
#  'ACGALK': 'Aminosugar metabolism',
#  'ACGALK2': 'Aminosugar metabolism',
#  'ACGALtlg': 'Transport, golgi apparatus',
#  'ACGALtly': 'Transport, lysosomal',
#  'ACGAM6PSi': 'Aminosugar metabolism',
#  'ACGAMK': 'Aminosugar metabolism',
#  'ACGAMPM': 'Aminosugar metabolism',
#  'ACGAMtly': 'Transport, lysosomal',
#  'ACGBGBSIDEtg': 'Transport, golgi apparatus',
#  'ACGBGBSIDEtl': 'Transport, lysosomal',
#  'ACGPID': 'Phosphatidylinositol phosphate metabolism',
#  'ACGSm': 'Urea cycle',
#  'ACHEe': 'Glycerophospholipid metabolism',
#  'ACHtn': 'Transport, nuclear',
#  'ACHVESSEC': 'Transport, extracellular',
#  'ACITL': 'Citric acid cycle',
#  'ACN13ACNGALGBSIDEte': 'Transport, extracellular',
#  'ACN13ACNGALGBSIDEtg': 'Transport, golgi apparatus',
#  'ACN23ACNGALGBSIDEte': 'Transport, extracellular',
#  'ACN23ACNGALGBSIDEtg': 'Transport, golgi apparatus',
#  'ACNACNGAL14ACGLCGALGLUSIDEte': 'Transport, extracellular',
#  'ACNACNGAL14ACGLCGALGLUSIDEtg': 'Transport, golgi apparatus',
#  'ACNACNGALGBSIDEte': 'Transport, extracellular',
#  'ACNACNGALGBSIDEtg': 'Transport, golgi apparatus',
#  'ACNAM9PL': 'Aminosugar metabolism',
#  'ACNAM9PL2': 'Aminosugar metabolism',
#  'ACNAMlt': 'Transport, lysosomal',
#  'ACNAMPH': 'Aminosugar metabolism',
#  'ACNAMtn': 'Transport, nuclear',
#  'ACNGALACGLCGAL14ACGLCGALGLUSIDEte': 'Transport, extracellular',
#  'ACNGALACGLCGAL14ACGLCGALGLUSIDEtg': 'Transport, golgi apparatus',
#  'ACNMLr': 'Aminosugar metabolism',
#  'ACOAD10m': 'Valine, leucine, and isoleucine metabolism',
#  'ACOAD1fm': 'Butanoate metabolism',
#  'ACOAD8m': 'Valine, leucine, and isoleucine metabolism',
#  'ACOAD9m': 'Valine, leucine, and isoleucine metabolism',
#  'ACOAHi': 'Pyruvate metabolism',
#  'ACOAO7p': 'Fatty acid oxidation',
#  'ACODA': 'Urea cycle',
#  'ACONTm': 'Citric acid cycle',
#  'ACOX22x': 'Bile acid synthesis',
#  'ACOX2x': 'Bile acid synthesis',
#  'ACP1_FMN_': 'Vitamin B2 metabolism',
#  'ACRNtm': 'Transport, mitochondrial',
#  'ACS2': 'Propanoate metabolism',
#  'ACSm': 'Glycolysis/gluconeogenesis',
#  'ACSRTNMT': 'Tryptophan metabolism',
#  'ACt2m': 'Transport, mitochondrial',
#  'ACt2r': 'Transport, extracellular',
#  'ACtg': 'Transport, golgi apparatus',
#  'ACTLMO': 'Pyruvate metabolism',
#  'ACTNMO': 'Pyruvate metabolism',
#  'ADA': 'Purine catabolism',
#  'ADAe': 'Purine catabolism',
#  'ADCim': 'Propanoate metabolism',
#  'ADEt': 'Transport, extracellular',
#  'ADK1m': 'Nucleotide interconversion',
#  'ADK3': 'Nucleotide interconversion',
#  'ADK3m': 'Nucleotide interconversion',
#  'ADKd': 'Nucleotide interconversion',
#  'ADMDC': 'Arginine and proline metabolism',
#  'ADNCYC': 'Nucleotide interconversion',
#  'ADNK1m': 'Nucleotide interconversion',
#  'ADNt': 'Transport, extracellular',
#  'ADNt4': 'Transport, extracellular',
#  'ADNtl': 'Transport, lysosomal',
#  'ADNtm': 'Transport, mitochondrial',
#  'ADPMAN': 'Nucleotide interconversion',
#  'ADPRIBt': 'Transport, extracellular',
#  'ADPtx': 'Transport, peroxisomal',
#  'ADRNCOAtx': 'Transport, peroxisomal',
#  'ADRNCPT1': 'Fatty acid oxidation',
#  'ADRNCPT2': 'Fatty acid oxidation',
#  'ADRNCRNt': 'Fatty acid oxidation',
#  'ADRNLPVESSEC': 'Transport, extracellular',
#  'ADRNt': 'Transport, extracellular',
#  'ADSK': 'Nucleotide interconversion',
#  'ADSL1': 'Nucleotide interconversion',
#  'ADSL2': 'Purine synthesis',
#  'AFLATOXINte': 'Transport, extracellular',
#  'AG13T16g': 'Keratan sulfate synthesis',
#  'AG13T17g': 'Keratan sulfate synthesis',
#  'AG13T18g': 'Keratan sulfate synthesis',
#  'AG13T1g': 'Keratan sulfate synthesis',
#  'AG13T2g': 'Keratan sulfate synthesis',
#  'AG13T3g': 'Keratan sulfate synthesis',
#  'AGMTm': 'Arginine and proline metabolism',
#  'AGPAT1': 'Triacylglycerol synthesis',
#  'AGTim': 'Alanine and aspartate metabolism',
#  'AGTix': 'Alanine and aspartate metabolism',
#  'AHANDROSTANGLCte': 'Transport, extracellular',
#  'AHANDROSTANGLCtr': 'Transport, endoplasmic reticular',
#  'AHCYStr': 'Transport, endoplasmic reticular',
#  'AHEXASE2ly': 'N-glycan degradation',
#  'AHEXASEly': 'N-glycan degradation',
#  'AIRCr': 'Purine synthesis',
#  'AKGDm': 'Citric acid cycle',
#  'AKGMALtm': 'Transport, mitochondrial',
#  'AKGt4_3': 'Transport, extracellular',
#  'AKGtp': 'Transport, peroxisomal',
#  'AKR1C1': 'Steroid metabolism',
#  'AKR1C41': 'Bile acid synthesis',
#  'AKR1C42': 'Bile acid synthesis',
#  'AKR1D': 'Bile acid synthesis',
#  'AKR1D2': 'Bile acid synthesis',
#  'ALAASNNaEx': 'Transport, extracellular',
#  'ALACYSNaEx': 'Transport, extracellular',
#  'ALADGLNexR': 'Transport, extracellular',
#  'ALADGLYexR': 'Transport, extracellular',
#  'ALAGLNexR': 'Transport, extracellular',
#  'ALAGLNNaEx': 'Transport, extracellular',
#  'ALAGLYexR': 'Transport, extracellular',
#  'ALASERNaEx': 'Transport, extracellular',
#  'ALASm': 'Glycine, serine, alanine, and threonine metabolism',
#  'ALAt4': 'Transport, extracellular',
#  'ALATA_L': 'Glutamate metabolism',
#  'ALATHRNaEx': 'Transport, extracellular',
#  'ALAtN1': 'Transport, extracellular',
#  'ALCD21_D': 'Pyruvate metabolism',
#  'ALCD21_L': 'Pyruvate metabolism',
#  'ALCD22_D': 'Pyruvate metabolism',
#  'ALCD22_L': 'Pyruvate metabolism',
#  'ALCD2if': 'Glycolysis/gluconeogenesis',
#  'ALCD2yf': 'Glycolysis/gluconeogenesis',
#  'ALDD20x': 'Tryptophan metabolism',
#  'ALDD20xm': 'Tryptophan metabolism',
#  'ALDD21': 'Fatty acid oxidation',
#  'ALDD2xm': 'Glycolysis/gluconeogenesis',
#  'ALDD2y': 'Glycolysis/gluconeogenesis',
#  'ALDSTRNte': 'Transport, extracellular',
#  'ALDSTRNtm': 'Transport, mitochondrial',
#  'ALOX12': 'Eicosanoid metabolism',
#  'ALOX15': 'Eicosanoid metabolism',
#  'ALOX5': 'Eicosanoid metabolism',
#  'ALOX52': 'Eicosanoid metabolism',
#  'ALR2': 'Pyruvate metabolism',
#  'ALR3': 'Pyruvate metabolism',
#  'AMACR2p': 'Bile acid synthesis',
#  'AMACRp': 'Bile acid synthesis',
#  'AMCOXO': 'Tryptophan metabolism',
#  'AMETr': 'Transport, endoplasmic reticular',
#  'AMETt2m': 'Transport, mitochondrial',
#  'AMPDA': 'Nucleotide interconversion',
#  'AMPTASECGe': 'Glutathione metabolism',
#  'AMPtp': 'Transport, peroxisomal',
#  'AMY1e': 'Starch and sucrose metabolism',
#  'AMY2e': 'Starch and sucrose metabolism',
#  'ANDRSTRNGLCte': 'Transport, extracellular',
#  'ANDRSTRNGLCtr': 'Transport, endoplasmic reticular',
#  'ANDRSTRNte': 'Transport, extracellular',
#  'ANDRSTRNtr': 'Transport, endoplasmic reticular',
#  'ANTIPYRENEte': 'Transport, extracellular',
#  'AOBUTDsm': 'Glycine, serine, alanine, and threonine metabolism',
#  'APAT2rm': 'Beta-Alanine metabolism',
#  'APNNOXte': 'Transport, extracellular',
#  'APOCF': 'Biotin metabolism',
#  'APOCFm': 'Biotin metabolism',
#  'APOC_LYS_BTNP': 'Biotin metabolism',
#  'APOC_LYS_BTNPm': 'Biotin metabolism',
#  'APPNNte': 'Transport, extracellular',
#  'APRTO2': 'Arginine and proline metabolism',
#  'AQCOBALt': 'Transport, extracellular',
#  'ARAB_Lt': 'Transport, extracellular',
#  'ARABR': 'Pentose phosphate pathway',
#  'ARACHCOAtx': 'Transport, peroxisomal',
#  'ARACHCPT1': 'Fatty acid oxidation',
#  'ARACHCPT2': 'Fatty acid oxidation',
#  'ARACHCRNt': 'Fatty acid oxidation',
#  'ARACHDCOAtx': 'Transport, peroxisomal',
#  'ARACHDt2': 'Transport, extracellular',
#  'ARACHDtr': 'Transport, endoplasmic reticular',
#  'ARACHt': 'Transport, extracellular',
#  'ARGDCm': 'Arginine and proline metabolism',
#  'ARGLYSex': 'Transport, extracellular',
#  'ARGNm': 'Urea cycle',
#  'ARGSS': 'Alanine and aspartate metabolism',
#  'ARGt4': 'Transport, extracellular',
#  'ARGtm': 'Transport, mitochondrial',
#  'ARSA': 'Sphingolipid metabolism',
#  'ARTCOAL1': 'R group synthesis',
#  'ARTCOAL2': 'R group synthesis',
#  'ARTCOAL3': 'R group synthesis',
#  'R_group_phosphotase_1': 'Miscellaneous',
#  'R_group_phosphotase_2': 'Miscellaneous',
#  'R_group_phosphotase_3': 'Miscellaneous',
#  'ARTFR208': 'R group synthesis',
#  'ARTPLM3': 'R group synthesis',
#  'ARTPLM3m': 'R group synthesis',
#  'ASAH1': 'Sphingolipid metabolism',
#  'ASCBOX': 'Vitamin C metabolism',
#  'ASCBt': 'Transport, extracellular',
#  'ASCBt4': 'Transport, extracellular',
#  'ASNALANaEx': 'Transport, extracellular',
#  'ASNCYSNaEx': 'Transport, extracellular',
#  'ASNGLNNaEx': 'Transport, extracellular',
#  'ASNNm': 'Alanine and aspartate metabolism',
#  'ASNS1': 'Alanine and aspartate metabolism',
#  'ASNSERNaEx': 'Transport, extracellular',
#  'ASNt4': 'Transport, extracellular',
#  'ASNTHRNaEx': 'Transport, extracellular',
#  'ASNtm': 'Transport, mitochondrial',
#  'ASNtN1': 'Transport, extracellular',
#  'ASPCTr': 'Pyrimidine synthesis',
#  'ASPDt6': 'Transport, extracellular',
#  'ASPDxt': 'Transport, peroxisomal',
#  'ASPGLUm': 'Transport, mitochondrial',
#  'ASPNATm': 'Alanine and aspartate metabolism',
#  'ASPt6': 'Transport, extracellular',
#  'ASPTAm': 'Alanine and aspartate metabolism',
#  'ATP1ter': 'Transport, endoplasmic reticular',
#  'ATP2ter': 'Transport, endoplasmic reticular',
#  'ATPasel': 'Transport, lysosomal',
#  'ATPH1e': 'Nucleotide interconversion',
#  'ATPH2e': 'Nucleotide interconversion',
#  'ATPtm': 'Transport, mitochondrial',
#  'ATPtn': 'Transport, nuclear',
#  'ATPtx': 'Transport, peroxisomal',
#  'AVITE2t': 'Transport, extracellular',
#  'B_MANNASEly': 'N-glycan degradation',
#  'B3GALT3g': 'Sphingolipid metabolism',
#  'B3GALT41g': 'Sphingolipid metabolism',
#  'B3GALT42g': 'Sphingolipid metabolism',
#  'B3GALT43g': 'Sphingolipid metabolism',
#  'B3GALT44g': 'Sphingolipid metabolism',
#  'B3GALT5g': 'Sphingolipid metabolism',
#  'B3GALTg': 'Blood group synthesis',
#  'B3GNT11g': 'Blood group synthesis',
#  'B3GNT12g': 'Blood group synthesis',
#  'B3GNT310g': 'Blood group synthesis',
#  'B3GNT311g': 'Blood group synthesis',
#  'B3GNT312g': 'Blood group synthesis',
#  'B3GNT313g': 'Blood group synthesis',
#  'B3GNT314g': 'Blood group synthesis',
#  'B3GNT315g': 'Blood group synthesis',
#  'B3GNT31g': 'Sphingolipid metabolism',
#  'B3GNT32g': 'Sphingolipid metabolism',
#  'B3GNT33g': 'Sphingolipid metabolism',
#  'B3GNT34g': 'Sphingolipid metabolism',
#  'B3GNT35g': 'Sphingolipid metabolism',
#  'B3GNT36g': 'Sphingolipid metabolism',
#  'B3GNT37g': 'Sphingolipid metabolism',
#  'B3GNT39g': 'Sphingolipid metabolism',
#  'B3GNT51g': 'Blood group synthesis',
#  'BAAT1x': 'Bile acid synthesis',
#  'BAAT2x': 'Bile acid synthesis',
#  'BAAT3x': 'Bile acid synthesis',
#  'BAAT4x': 'Bile acid synthesis',
#  'BACCL': 'Biotin metabolism',
#  'BACCLm': 'Biotin metabolism',
#  'BALAtmr': 'Transport, mitochondrial',
#  'BALAVECSEC': 'Transport, extracellular',
#  'BAMPPALDOX': 'Beta-Alanine metabolism',
#  'BBHOX': 'Lysine metabolism',
#  'BCDO': 'Vitamin A metabolism',
#  'BDHm': 'Butanoate metabolism',
#  'BETALDHxm': 'Glycine, serine, alanine, and threonine metabolism',
#  'BHBt': 'Transport, extracellular',
#  'BHBtm': 'Transport, mitochondrial',
#  'BHMT': 'Glycine, serine, alanine, and threonine metabolism',
#  'BILDGLCURt': 'Transport, extracellular',
#  'BILDGLCURte': 'Transport, extracellular',
#  'BILDGLCURtr': 'Transport, endoplasmic reticular',
#  'BILGLCURt': 'Transport, extracellular',
#  'BILGLCURte': 'Transport, extracellular',
#  'BILGLCURtr': 'Transport, endoplasmic reticular',
#  'BILIRED': 'Heme degradation',
#  'BILIRUBt2': 'Transport, extracellular',
#  'BILIRUBtr': 'Transport, endoplasmic reticular',
#  'BIOCYTtn': 'Transport, nuclear',
#  'BMTer_U': 'Phosphatidylinositol phosphate metabolism',
#  'BPNT2': 'Nucleotide interconversion',
#  'BTND1': 'Biotin metabolism',
#  'BTND1n': 'Biotin metabolism',
#  'BTNDe': 'Biotin metabolism',
#  'BTNDm': 'Biotin metabolism',
#  'BTNPL': 'Biotin metabolism',
#  'BTNPLm': 'Biotin metabolism',
#  'BTNt2': 'Transport, extracellular',
#  'BTNt2m': 'Transport, mitochondrial',
#  'BTNt3i': 'Transport, extracellular',
#  'BTNt4i': 'Transport, extracellular',
#  'BTNtn': 'Transport, nuclear',
#  'BUP2': 'Pyrimidine catabolism',
#  'BUTt2m': 'Transport, mitochondrial',
#  'BVITEt': 'Transport, extracellular',
#  'BZt': 'Transport, extracellular',
#  'BZtr': 'Transport, endoplasmic reticular',
#  'C14STRr': 'Cholesterol metabolism',
#  'C160CPT1': 'Fatty acid oxidation',
#  'C160CPT2': 'Fatty acid oxidation',
#  'C160CRNt': 'Fatty acid oxidation',
#  'C161CPT1': 'Fatty acid oxidation',
#  'C161CPT12': 'Fatty acid oxidation',
#  'C161CPT2': 'Fatty acid oxidation',
#  'C161CPT22': 'Fatty acid oxidation',
#  'C161CRN2t': 'Fatty acid oxidation',
#  'C161CRNt': 'Fatty acid oxidation',
#  'C180CPT1': 'Fatty acid oxidation',
#  'C180CPT2': 'Fatty acid oxidation',
#  'C180CRNt': 'Fatty acid oxidation',
#  'C181CPT1': 'Fatty acid oxidation',
#  'C181CPT2': 'Fatty acid oxidation',
#  'C181CRNt': 'Fatty acid oxidation',
#  'C204CPT1': 'Fatty acid oxidation',
#  'C204CPT2': 'Fatty acid oxidation',
#  'C204CRNt': 'Fatty acid oxidation',
#  'C226COAtx': 'Transport, peroxisomal',
#  'C226CPT1': 'Fatty acid oxidation',
#  'C226CPT2': 'Fatty acid oxidation',
#  'C226CRNt': 'Fatty acid oxidation',
#  'C3STDH1Pr': 'Cholesterol metabolism',
#  'C3STDH1r': 'Cholesterol metabolism',
#  'C3STKR2r': 'Cholesterol metabolism',
#  'C4STMO1r': 'Cholesterol metabolism',
#  'C4STMO2Pr': 'Cholesterol metabolism',
#  'C4STMO2r': 'Cholesterol metabolism',
#  'CAATPS': 'Transport, extracellular',
#  'CAROtr': 'Transport, extracellular',
#  'CARVEOLte': 'Transport, extracellular',
#  'CAT2p': 'Glycolysis/gluconeogenesis',
#  'CAt7r': 'Transport, extracellular',
#  'CATm': 'ROS detoxification',
#  'CATp': 'Miscellaneous',
#  'CBL2OR': 'Vitamin B12 metabolism',
#  'CBL2tm': 'Transport, mitochondrial',
#  'CBPPer': 'Glycolysis/gluconeogenesis',
#  'CBPSam': 'Glutamate metabolism',
#  'CBPter': 'Transport, endoplasmic reticular',
#  'CBR2': 'Eicosanoid metabolism',
#  'CDIPTr': 'Glycerophospholipid metabolism',
#  'CDPDAGtm': 'Transport, mitochondrial',
#  'CDS': 'Glycerophospholipid metabolism',
#  'CDSm': 'Glycerophospholipid metabolism',
#  'CEPTC': 'Glycerophospholipid metabolism',
#  'CEPTE': 'Glycerophospholipid metabolism',
#  'CERK': 'Sphingolipid metabolism',
#  'CERT1gt': 'Transport, golgi apparatus',
#  'CERT1rt': 'Transport, endoplasmic reticular',
#  'CERT2gt': 'Transport, golgi apparatus',
#  'CERT2rt': 'Transport, endoplasmic reticular',
#  'CGLYt3_2_': 'Transport, extracellular',
#  'CH25H': 'Bile acid synthesis',
#  'CHAT': 'Glycerophospholipid metabolism',
#  'CHATn': 'Glycerophospholipid metabolism',
#  'CHLP': 'Glycerophospholipid metabolism',
#  'CHLPCTD': 'Glycerophospholipid metabolism',
#  'CHLtm': 'Transport, mitochondrial',
#  'CHOLATEt': 'Transport, extracellular',
#  'CHOLATEt2': 'Transport, extracellular',
#  'CHOLATEt3': 'Transport, extracellular',
#  'CHOLD2m': 'Glycine, serine, alanine, and threonine metabolism',
#  'CHOLK': 'Glycerophospholipid metabolism',
#  'CHOLPtg': 'Transport, golgi apparatus',
#  'CHOLPtl': 'Transport, lysosomal',
#  'CHOLt4': 'Transport, extracellular',
#  'CHOLtg': 'Transport, golgi apparatus',
#  'CHOLtn': 'Transport, nuclear',
#  'CHOLtr': 'Transport, endoplasmic reticular',
#  'CHOLtu': 'Transport, extracellular',
#  'CHSTEROLSULT': 'Steroid metabolism',
#  'CHSTEROLt1': 'Transport, mitochondrial',
#  'CHSTEROLt2': 'Transport, mitochondrial',
#  'CHSTEROLt3': 'Transport, mitochondrial',
#  'CHSTEROLtg': 'Transport, golgi apparatus',
#  'CHTNASE': 'Aminosugar metabolism',
#  'CHTNASEe': 'Aminosugar metabolism',
#  'CITMCOAHm': 'C5-branched dibasic acid metabolism',
#  'CITMCOALm': 'C5-branched dibasic acid metabolism',
#  'CITRtm': 'Transport, mitochondrial',
#  'CITt4_2': 'Transport, extracellular',
#  'CITtam': 'Transport, mitochondrial',
#  'CITtbm': 'Transport, mitochondrial',
#  'CK': 'Urea cycle',
#  'CKc': 'Urea cycle',
#  'CLFORtex': 'Transport, extracellular',
#  'CLHCO3tex2': 'Transport, extracellular',
#  'CLI2tex': 'Transport, extracellular',
#  'CLOHtex2': 'Transport, extracellular',
#  'CLOXAtex2': 'Transport, extracellular',
#  'CLPNDCOAtx': 'Transport, peroxisomal',
#  'CLPNDCPT1': 'Fatty acid oxidation',
#  'CLPNDCPT2': 'Fatty acid oxidation',
#  'CLPNDCRNt': 'Fatty acid oxidation',
#  'CLPNDt': 'Transport, extracellular',
#  'CLS_hs': 'Glycerophospholipid metabolism',
#  'CMPACNAtg': 'Transport, golgi apparatus',
#  'CMPACNAtn': 'Transport, nuclear',
#  'CMPSAS': 'Aminosugar metabolism',
#  'CMPSASn': 'Aminosugar metabolism',
#  'CO2ter': 'Transport, endoplasmic reticular',
#  'CO2tg': 'Transport, golgi apparatus',
#  'CO2tm': 'Transport, mitochondrial',
#  'CO2tp': 'Transport, peroxisomal',
#  'COAtg': 'Transport, golgi apparatus',
#  'COAtl': 'Transport, lysosomal',
#  'COAtm': 'Transport, mitochondrial',
#  'COAtn': 'Transport, nuclear',
#  'COAtp': 'Transport, peroxisomal',
#  'COAtr': 'Transport, endoplasmic reticular',
#  'COKECBESr': 'Alkaloid synthesis',
#  'COQ3m': 'Ubiquinone synthesis',
#  'COQ5m': 'Ubiquinone synthesis',
#  'COQ6m': 'Ubiquinone synthesis',
#  'COQ7m': 'Ubiquinone synthesis',
#  'CORE2GTg': 'O-glycan metabolism',
#  'CORE3GTg': 'O-glycan metabolism',
#  'CORE4GTg': 'O-glycan metabolism',
#  'CORE5GTg': 'O-glycan metabolism',
#  'CORE6GTg': 'O-glycan metabolism',
#  'CORE7GTg': 'O-glycan metabolism',
#  'CORE8GTg': 'O-glycan metabolism',
#  'COt': 'Transport, extracellular',
#  'COUCOAFm': 'Ubiquinone synthesis',
#  'COUMARINte': 'Transport, extracellular',
#  'CREATt4_2_r': 'Transport, extracellular',
#  'CREATtmdiffir': 'Urea cycle',
#  'CRMPte': 'Transport, extracellular',
#  'CRNCAR3tp': 'Transport, peroxisomal',
#  'CRNCARtp': 'Transport, peroxisomal',
#  'CRNt': 'Transport, extracellular',
#  'CRNtHa': 'Transport, extracellular',
#  'CRNtim': 'Transport, mitochondrial',
#  'CRNtuNa': 'Transport, extracellular',
#  'CRNtx': 'Transport, peroxisomal',
#  'CRTNsyn': 'Urea cycle',
#  'CRTSLt': 'Transport, extracellular',
#  'CRTSLtm': 'Transport, mitochondrial',
#  'CRTSLtr': 'Transport, endoplasmic reticular',
#  'CRTSTRNt': 'Transport, extracellular',
#  'CRTSTRNtm': 'Transport, mitochondrial',
#  'CRVNCtr': 'Transport, extracellular',
#  'CSAPASEly': 'Chondroitin sulfate degradation',
#  'CSBPASEly': 'Chondroitin sulfate degradation',
#  'CSCPASEly': 'Chondroitin sulfate degradation',
#  'CSDPASEly': 'Chondroitin sulfate degradation',
#  'CSEPASEly': 'Chondroitin sulfate degradation',
#  'CSm': 'Citric acid cycle',
#  'CSNAT2m': 'Fatty acid oxidation',
#  'CSNAT2x': 'Fatty acid oxidation',
#  'CSNAT3x': 'Fatty acid oxidation',
#  'CSNATer': 'Fatty acid oxidation',
#  'CSNATm': 'Fatty acid oxidation',
#  'CSNATp': 'Fatty acid oxidation',
#  'CSNATr': 'Fatty acid oxidation',
#  'CSNt': 'Transport, extracellular',
#  'CSPG_At': 'Transport, extracellular',
#  'CSPG_Atly': 'Transport, lysosomal',
#  'CSPG_Bt': 'Transport, extracellular',
#  'CSPG_Btly': 'Transport, lysosomal',
#  'CSPG_Ct': 'Transport, extracellular',
#  'CSPG_Ctly': 'Transport, lysosomal',
#  'CSPG_Dt': 'Transport, extracellular',
#  'CSPG_Dtly': 'Transport, lysosomal',
#  'CSPG_Et': 'Transport, extracellular',
#  'CSPG_Etly': 'Transport, lysosomal',
#  'CTPtn': 'Transport, nuclear',
#  'CYANt': 'Transport, extracellular',
#  'CYANtm': 'Transport, mitochondrial',
#  'CYSALANaEx': 'Transport, extracellular',
#  'CYSASNNaEx': 'Transport, extracellular',
#  'CYSGLNNaEx': 'Transport, extracellular',
#  'CYSGLTH': 'Methionine and cysteine metabolism',
#  'CYSGLUexR': 'Transport, extracellular',
#  'CYSGLYexR': 'Transport, extracellular',
#  'CYSO': 'Taurine and hypotaurine metabolism',
#  'CYSSERNaEx': 'Transport, extracellular',
#  'CYSt4': 'Transport, extracellular',
#  'CYSTA': 'Methionine and cysteine metabolism',
#  'CYStec': 'Transport, extracellular',
#  'CYSTGLUex': 'Transport, extracellular',
#  'CYSTHRNaEx': 'Transport, extracellular',
#  'CYSTSERex': 'Transport, extracellular',
#  'CYTD': 'Pyrimidine catabolism',
#  'CYTDK1': 'Nucleotide interconversion',
#  'CYTDK2m': 'Nucleotide interconversion',
#  'CYTDn': 'Nucleotide interconversion',
#  'CYTDt': 'Transport, extracellular',
#  'CYTDt4': 'Transport, extracellular',
#  'CYTDtl': 'Transport, lysosomal',
#  'CYTDtm': 'Transport, mitochondrial',
#  'CYTDtn': 'Transport, nuclear',
#  'CYTK10': 'Nucleotide interconversion',
#  'CYTK10n': 'Nucleotide interconversion',
#  'CYTK11': 'Nucleotide interconversion',
#  'CYTK11n': 'Nucleotide interconversion',
#  'CYTK12': 'Nucleotide interconversion',
#  'CYTK12n': 'Nucleotide interconversion',
#  'CYTK13': 'Nucleotide interconversion',
#  'CYTK13n': 'Nucleotide interconversion',
#  'CYTK14': 'Nucleotide interconversion',
#  'CYTK14n': 'Nucleotide interconversion',
#  'CYTK1m': 'Nucleotide interconversion',
#  'CYTK1n': 'Nucleotide interconversion',
#  'CYTK2n': 'Nucleotide interconversion',
#  'CYTK3': 'Nucleotide interconversion',
#  'CYTK3n': 'Nucleotide interconversion',
#  'CYTK4': 'Nucleotide interconversion',
#  'CYTK4n': 'Nucleotide interconversion',
#  'CYTK5': 'Nucleotide interconversion',
#  'CYTK5n': 'Nucleotide interconversion',
#  'CYTK6': 'Nucleotide interconversion',
#  'CYTK6n': 'Nucleotide interconversion',
#  'CYTK7': 'Nucleotide interconversion',
#  'CYTK7n': 'Nucleotide interconversion',
#  'CYTK8': 'Nucleotide interconversion',
#  'CYTK8n': 'Nucleotide interconversion',
#  'CYTK9': 'Nucleotide interconversion',
#  'CYTK9n': 'Nucleotide interconversion',
#  'D_3AIBt': 'Transport, extracellular',
#  'D3AIBTm': 'Pyrimidine catabolism',
#  'DADA': 'Nucleotide interconversion',
#  'DADAe': 'Nucleotide interconversion',
#  'DADNK': 'Nucleotide interconversion',
#  'DADNt4': 'Transport, extracellular',
#  'DAG_HSter': 'Transport, endoplasmic reticular',
#  'DAGK_hs': 'Glycerophospholipid metabolism',
#  'DAGKn_hs': 'Glycerophospholipid metabolism',
#  'DAGt': 'Transport, extracellular',
#  'DALAOXx': 'D-alanine metabolism',
#  'DALAt2r': 'Transport, extracellular',
#  'DALAxt': 'D-alanine metabolism',
#  'DARGOp': 'Arginine and proline metabolism',
#  'DASCBH': 'Vitamin C metabolism',
#  'DASCBR': 'Vitamin C metabolism',
#  'DASPO1p': 'Alanine and aspartate metabolism',
#  'DATPtn': 'Transport, nuclear',
#  'DCIm': 'Fatty acid oxidation',
#  'DCK1m': 'Nucleotide interconversion',
#  'DCK1n': 'Nucleotide interconversion',
#  'DCK2n': 'Nucleotide interconversion',
#  'DCSPTN1COAtx': 'Transport, peroxisomal',
#  'DCSPTN1CPT1': 'Fatty acid oxidation',
#  'DCSPTN1CPT2': 'Fatty acid oxidation',
#  'DCSPTN1CRNt': 'Fatty acid oxidation',
#  'DCSPTN1t': 'Transport, extracellular',
#  'DCT': 'Tyrosine metabolism',
#  'DCTPtn': 'Transport, nuclear',
#  'DCYTD': 'Pyrimidine catabolism',
#  'DCYTDn': 'Nucleotide interconversion',
#  'DCYTt': 'Transport, extracellular',
#  'DDPGAm': 'Arginine and proline metabolism',
#  'DEBRISOQUINEt': 'Transport, extracellular',
#  'DECDPtm': 'Transport, mitochondrial',
#  'DEDOLP1_L': 'N-glycan synthesis',
#  'DEDOLP2_L': 'N-glycan synthesis',
#  'DEDOLR_L': 'N-glycan synthesis',
#  'DESAT16_2': 'Fatty acid synthesis',
#  'DESAT18_10': 'Fatty acid synthesis',
#  'DESAT18_3': 'Fatty acid synthesis',
#  'DESAT18_4': 'Fatty acid synthesis',
#  'DESAT18_5': 'Fatty acid synthesis',
#  'DESAT18_6': 'Fatty acid synthesis',
#  'DESAT18_7': 'Fatty acid synthesis',
#  'DESAT18_8': 'Fatty acid synthesis',
#  'DESAT18_9': 'Fatty acid synthesis',
#  'DESAT20_1': 'Fatty acid synthesis',
#  'DESAT20_2': 'Fatty acid synthesis',
#  'DESAT22_1p': 'Fatty acid synthesis',
#  'DESAT22_2p': 'Fatty acid synthesis',
#  'DESAT24_1': 'Fatty acid synthesis',
#  'DGAT': 'Triacylglycerol synthesis',
#  'DGCHOLte': 'Transport, extracellular',
#  'DGCHOLtx': 'Transport, peroxisomal',
#  'DGK2m': 'Nucleotide interconversion',
#  'DGNSKm': 'Nucleotide interconversion',
#  'DGSNt': 'Transport, extracellular',
#  'DGSNtm': 'Transport, mitochondrial',
#  'DGTPtn': 'Transport, nuclear',
#  'DGULND': 'Pentose phosphate pathway',
#  'DHAAt1r': 'Transport, extracellular',
#  'DHCHOLESTANATEtm': 'Transport, peroxisomal',
#  'DHCR241r': 'Cholesterol metabolism',
#  'DHCR242r': 'Cholesterol metabolism',
#  'DHCR243r': 'Cholesterol metabolism',
#  'DHCR71r': 'Cholesterol metabolism',
#  'DHCR72r': 'Cholesterol metabolism',
#  'DHCRD1': 'Sphingolipid metabolism',
#  'DHCRD2': 'Sphingolipid metabolism',
#  'DHDPBMTm': 'Ubiquinone synthesis',
#  'DHEASt': 'Transport, extracellular',
#  'DHEAStr': 'Transport, extracellular',
#  'DHEASULT': 'Steroid metabolism',
#  'DHEAtr': 'Transport, endoplasmic reticular',
#  'DHFtl': 'Transport, lysosomal',
#  'DHFtm': 'Transport, mitochondrial',
#  'DHORD9': 'Pyrimidine synthesis',
#  'DHPM1': 'Pyrimidine catabolism',
#  'DHPM2': 'Pyrimidine catabolism',
#  'DHPR2': 'Tetrahydrobiopterin metabolism',
#  'DIDPtn': 'Transport, nuclear',
#  'DIGALSGALSIDEtg': 'Transport, golgi apparatus',
#  'DIGALSIDEtg': 'Transport, golgi apparatus',
#  'DIGALSIDEtl': 'Transport, lysosomal',
#  'DINt': 'Transport, extracellular',
#  'DITPtn': 'Transport, nuclear',
#  'DKMPPD': 'Arginine and proline metabolism',
#  'D_LACt2': 'Transport, extracellular',
#  'D_LACtm': 'Transport, mitochondrial',
#  'DLNLCGCPT1': 'Fatty acid oxidation',
#  'DLNLCGCPT2': 'Fatty acid oxidation',
#  'DLNLCGCRNt': 'Fatty acid oxidation',
#  'DLNLCGt': 'Transport, extracellular',
#  'DM_13_cis_oretn_n_': 'Exchange/demand reaction',
#  'DM_13_cis_retn_n_': 'Exchange/demand reaction',
#  'DM_Asn_X_Ser_Thr_ly_': 'Exchange/demand reaction',
#  'DM_avite2_c_': 'Exchange/demand reaction',
#  'DM_bvite_c_': 'Exchange/demand reaction',
#  'DM_core5_g_': 'Exchange/demand reaction',
#  'DM_core7_g_': 'Exchange/demand reaction',
#  'DM_core8_g_': 'Exchange/demand reaction',
#  'DM_datp_m_': 'Exchange/demand reaction',
#  'DM_datp_n_': 'Exchange/demand reaction',
#  'DM_dctp_m_': 'Exchange/demand reaction',
#  'DM_dctp_n_': 'Exchange/demand reaction',
#  'DM_dem2emgacpail_prot_hs_r_': 'Exchange/demand reaction',
#  'DM_dgpi_prot_hs_r_': 'Exchange/demand reaction',
#  'DM_dgtp_m_': 'Exchange/demand reaction',
#  'DM_dgtp_n_': 'Exchange/demand reaction',
#  'DM_dsT_antigen_g_': 'Exchange/demand reaction',
#  'DM_dttp_m_': 'Exchange/demand reaction',
#  'DM_dttp_n_': 'Exchange/demand reaction',
#  'DM_ethamp_r_': 'Exchange/demand reaction',
#  'DM_gncore2_g_': 'Exchange/demand reaction',
#  'DM_gpi_sig_er_': 'Exchange/demand reaction',
#  'DM_hretn_n_': 'Exchange/demand reaction',
#  'DM_kdn_c_': 'Exchange/demand reaction',
#  'DM_m_em_3gacpail_prot_hs_r_': 'Exchange/demand reaction',
#  'DM_melanin_c_': 'Exchange/demand reaction',
#  'DM_mem2emgacpail_prot_hs_r_': 'Exchange/demand reaction',
#  'DM_n5m2masn_g_': 'Exchange/demand reaction',
#  'DM_oretn_n_': 'Exchange/demand reaction',
#  'DM_Ser_Thr_ly_': 'Exchange/demand reaction',
#  'DM_Ser_Gly_Ala_X_Gly_ly_': 'Exchange/demand reaction',
#  'DM_sprm_c_': 'Exchange/demand reaction',
#  'DM_sTn_antigen_g_': 'Exchange/demand reaction',
#  'DM_T_antigen_g_': 'Exchange/demand reaction',
#  'DM_yvite_c_': 'Exchange/demand reaction',
#  'DMANTIPYRINEte': 'Transport, extracellular',
#  'DMATTx': 'Cholesterol metabolism',
#  'DMGDHm': 'Glycine, serine, alanine, and threonine metabolism',
#  'DMGtm': 'Transport, mitochondrial',
#  'DMHPTCRNCPT2': 'Fatty acid oxidation',
#  'DMHPTCRNt': 'Fatty acid oxidation',
#  'DMHPTCRNte': 'Transport, extracellular',
#  'DMNONCOACRNCPT1': 'Fatty acid oxidation',
#  'DMNONCRNCPT2': 'Fatty acid oxidation',
#  'DMNONCRNt': 'Fatty acid oxidation',
#  'DNADtn': 'Transport, nuclear',
#  'DNDPt10m': 'Transport, mitochondrial',
#  'DNDPt11m': 'Transport, mitochondrial',
#  'DNDPt12m': 'Transport, mitochondrial',
#  'DNDPt13m': 'Transport, mitochondrial',
#  'DNDPt14m': 'Transport, mitochondrial',
#  'DNDPt15m': 'Transport, mitochondrial',
#  'DNDPt16m': 'Transport, mitochondrial',
#  'DNDPt17m': 'Transport, mitochondrial',
#  'DNDPt18m': 'Transport, mitochondrial',
#  'DNDPt19m': 'Transport, mitochondrial',
#  'DNDPt1m': 'Transport, mitochondrial',
#  'DNDPt20m': 'Transport, mitochondrial',
#  'DNDPt21m': 'Transport, mitochondrial',
#  'DNDPt23m': 'Transport, mitochondrial',
#  'DNDPt24m': 'Transport, mitochondrial',
#  'DNDPt25m': 'Transport, mitochondrial',
#  'DNDPt28m': 'Transport, mitochondrial',
#  'DNDPt2m': 'Transport, mitochondrial',
#  'DNDPt30m': 'Transport, mitochondrial',
#  'DNDPt31m': 'Transport, mitochondrial',
#  'DNDPt32m': 'Transport, mitochondrial',
#  'DNDPt37m': 'Transport, mitochondrial',
#  'DNDPt38m': 'Transport, mitochondrial',
#  'DNDPt39m': 'Transport, mitochondrial',
#  'DNDPt3m': 'Transport, mitochondrial',
#  'DNDPt40m': 'Transport, mitochondrial',
#  'DNDPt41m': 'Transport, mitochondrial',
#  'DNDPt42m': 'Transport, mitochondrial',
#  'DNDPt43m': 'Transport, mitochondrial',
#  'DNDPt44m': 'Transport, mitochondrial',
#  'DNDPt45m': 'Transport, mitochondrial',
#  'DNDPt46m': 'Transport, mitochondrial',
#  'DNDPt47m': 'Transport, mitochondrial',
#  'DNDPt48m': 'Transport, mitochondrial',
#  'DNDPt49m': 'Transport, mitochondrial',
#  'DNDPt4m': 'Transport, mitochondrial',
#  'DNDPt50m': 'Transport, mitochondrial',
#  'DNDPt51m': 'Transport, mitochondrial',
#  'DNDPt52m': 'Transport, mitochondrial',
#  'DNDPt53m': 'Transport, mitochondrial',
#  'DNDPt54m': 'Transport, mitochondrial',
#  'DNDPt55m': 'Transport, mitochondrial',
#  'DNDPt56m': 'Transport, mitochondrial',
#  'DNDPt57m': 'Transport, mitochondrial',
#  'DNDPt58m': 'Transport, mitochondrial',
#  'DNDPt59m': 'Transport, mitochondrial',
#  'DNDPt5m': 'Transport, mitochondrial',
#  'DNDPt60m': 'Transport, mitochondrial',
#  'DNDPt61m': 'Transport, mitochondrial',
#  'DNDPt62m': 'Transport, mitochondrial',
#  'DNDPt63m': 'Transport, mitochondrial',
#  'DNDPt6m': 'Transport, mitochondrial',
#  'DNDPt7m': 'Transport, mitochondrial',
#  'DOGULNO1': 'Vitamin C metabolism',
#  'DOLGLCP_Lter': 'N-glycan synthesis',
#  'DOLGPP_Ler': 'N-glycan synthesis',
#  'DOLICHOL_Lter': 'N-glycan synthesis',
#  'DOLICHOL_Uter': 'N-glycan synthesis',
#  'DOLK_L': 'N-glycan synthesis',
#  'DOLK_U': 'N-glycan synthesis',
#  'DOLMANP_Uter': 'N-glycan synthesis',
#  'DOLPGT3_Ler': 'N-glycan synthesis',
#  'DOLPGT3_Uer': 'N-glycan synthesis',
#  'DOLPMT3_Uer': 'N-glycan synthesis',
#  'DOLPMT4_Ler': 'N-glycan synthesis',
#  'DOLPMT4_Uer': 'N-glycan synthesis',
#  'DOPABMO': 'Tyrosine metabolism',
#  'DOPACHRMISO': 'Tyrosine metabolism',
#  'DOPAMT': 'Tyrosine metabolism',
#  'DOPAQNISO1': 'Tyrosine metabolism',
#  'DOPASFt': 'Transport, extracellular',
#  'DOPASULT': 'Tyrosine metabolism',
#  'DOPAt4_2_r': 'Transport, extracellular',
#  'DOPAtu': 'Transport, extracellular',
#  'DOPAVESSEC': 'Transport, extracellular',
#  'DORNOp': 'Arginine and proline metabolism',
#  'DPCOAtl': 'Transport, lysosomal',
#  'DPGase': 'Glycolysis/gluconeogenesis',
#  'DPGM': 'Glycolysis/gluconeogenesis',
#  'DPHMBDCm': 'Ubiquinone synthesis',
#  'DPMVDx': 'Cholesterol metabolism',
#  'DPPS': 'Miscellaneous',
#  'DRIBt': 'Transport, extracellular',
#  'DRPA': 'Pentose phosphate pathway',
#  'DSAT': 'Sphingolipid metabolism',
#  'DTDPtn': 'Transport, nuclear',
#  'DTTPtn': 'Transport, nuclear',
#  'DUDPtn': 'Transport, nuclear',
#  'DUMPtn': 'Transport, nuclear',
#  'DURAD': 'Pyrimidine catabolism',
#  'DURAD2': 'Pyrimidine catabolism',
#  'DURIK1': 'Nucleotide interconversion',
#  'DURIK1m': 'Nucleotide interconversion',
#  'DURIt': 'Transport, extracellular',
#  'DURItn': 'Transport, nuclear',
#  'DUTPDPm': 'Nucleotide interconversion',
#  'DUTPDPn': 'Nucleotide interconversion',
#  'EAFLATOXINte': 'Transport, extracellular',
#  'EBASTINEOHte': 'Transport, extracellular',
#  'EBASTINEOHtr': 'Transport, endoplasmic reticular',
#  'EBASTINEte': 'Transport, extracellular',
#  'EBASTINEtr': 'Transport, endoplasmic reticular',
#  'EBP1r': 'Cholesterol metabolism',
#  'EBP2r': 'Cholesterol metabolism',
#  'ECOAH12m': 'Valine, leucine, and isoleucine metabolism',
#  'ECOAH1m': 'Tryptophan metabolism',
#  'ECOAH1x': 'Tryptophan metabolism',
#  'ECOAH9m': 'Valine, leucine, and isoleucine metabolism',
#  'EHGLAT2m': 'Arginine and proline metabolism',
#  'EHGLATm': 'Arginine and proline metabolism',
#  'EICOSTETCPT1': 'Fatty acid oxidation',
#  'EICOSTETCPT2': 'Fatty acid oxidation',
#  'EICOSTETCRNt': 'Fatty acid oxidation',
#  'EICOSTETt': 'Transport, extracellular',
#  'ELAIDCPT1': 'Fatty acid oxidation',
#  'ELAIDCPT2': 'Fatty acid oxidation',
#  'ELAIDCRNt': 'Fatty acid oxidation',
#  'ELAIDt': 'Transport, extracellular',
#  'ENGASE2ly': 'N-glycan degradation',
#  'ENGASE3ly': 'Keratan sulfate degradation',
#  'ENGASEly': 'N-glycan degradation',
#  'ESTRADIOLGLCt': 'Transport, extracellular',
#  'ESTRADIOLGLCt2': 'Transport, extracellular',
#  'ESTRADIOLGLCtr': 'Transport, endoplasmic reticular',
#  'ESTRADIOLt': 'Transport, extracellular',
#  'ESTRADIOLtr': 'Transport, endoplasmic reticular',
#  'ESTRIOLGLCte': 'Transport, extracellular',
#  'ESTRIOLGLCtr': 'Transport, endoplasmic reticular',
#  'ESTRIOLtr': 'Transport, endoplasmic reticular',
#  'ESTRONEGLCt': 'Transport, extracellular',
#  'ESTRONEGLCtr': 'Transport, endoplasmic reticular',
#  'ESTRONESt': 'Transport, extracellular',
#  'ESTRONESt2': 'Transport, extracellular',
#  'ESTRONEtr': 'Transport, endoplasmic reticular',
#  'ESTSULT': 'Steroid metabolism',
#  'ETF': 'Fatty acid oxidation',
#  'ETFQO': 'Fatty acid oxidation',
#  'ETHAK': 'Glycerophospholipid metabolism',
#  'ETHP': 'Glycerophospholipid metabolism',
#  'ETOHMO': 'Glycolysis/gluconeogenesis',
#  'ETOHtx': 'Transport, peroxisomal',
#  'EX_10fthf[e]': 'Exchange/demand reaction',
#  'EX_10fthf5glu[e]': 'Exchange/demand reaction',
#  'EX_10fthf6glu[e]': 'Exchange/demand reaction',
#  'EX_10fthf7glu[e]': 'Exchange/demand reaction',
#  'EX_11_cis_retfa[e]': 'Exchange/demand reaction',
#  'EX_13_cis_retnglc[e]': 'Exchange/demand reaction',
#  'EX_1glyc_hs[e]': 'Exchange/demand reaction',
#  'EX_2425dhvitd2[e]': 'Exchange/demand reaction',
#  'EX_2425dhvitd3[e]': 'Exchange/demand reaction',
#  'EX_24nph[e]': 'Exchange/demand reaction',
#  'EX_25hvitd2[e]': 'Exchange/demand reaction',
#  'EX_25hvitd3[e]': 'Exchange/demand reaction',
#  'EX_2hb[e]': 'Exchange/demand reaction',
#  'EX_2mcit[e]': 'Exchange/demand reaction',
#  'EX_34dhoxpeg[e]': 'Exchange/demand reaction',
#  'EX_34dhphe[e]': 'Exchange/demand reaction',
#  'EX_35cgmp[e]': 'Exchange/demand reaction',
#  'EX_3aib[e]': 'Exchange/demand reaction',
#  'EX_3aib_D[e]': 'Exchange/demand reaction',
#  'EX_3mlda[e]': 'Exchange/demand reaction',
#  'EX_4hdebrisoquine[e]': 'Exchange/demand reaction',
#  'EX_4hphac[e]': 'Exchange/demand reaction',
#  'EX_4mptnl[e]': 'Exchange/demand reaction',
#  'EX_4mtolbutamide[e]': 'Exchange/demand reaction',
#  'EX_4nph[e]': 'Exchange/demand reaction',
#  'EX_4nphsf[e]': 'Exchange/demand reaction',
#  'EX_4pyrdx[e]': 'Exchange/demand reaction',
#  'EX_5adtststerone[e]': 'Exchange/demand reaction',
#  'EX_5adtststeroneglc[e]': 'Exchange/demand reaction',
#  'EX_5adtststerones[e]': 'Exchange/demand reaction',
#  'EX_5dhf[e]': 'Exchange/demand reaction',
#  'EX_5fthf[e]': 'Exchange/demand reaction',
#  'EX_5homeprazole[e]': 'Exchange/demand reaction',
#  'EX_5htrp[e]': 'Exchange/demand reaction',
#  'EX_5mthf[e]': 'Exchange/demand reaction',
#  'EX_5thf[e]': 'Exchange/demand reaction',
#  'EX_6dhf[e]': 'Exchange/demand reaction',
#  'EX_6htststerone[e]': 'Exchange/demand reaction',
#  'EX_6thf[e]': 'Exchange/demand reaction',
#  'EX_7dhf[e]': 'Exchange/demand reaction',
#  ...}

# %%
import pandas as pd

# Step 1: Use the full reactions list directly
all_reactions = list(reactions)  # Ensure it's a list

# Step 2: Create an empty DataFrame with reactions as columns
df = pd.DataFrame(index=results.keys(), columns=all_reactions).fillna(0.0)

# Step 3: Fill in only those reactions that exist in both the Series and reactions list
for key, series in results.items():
    filtered_series = series[series.index.isin(all_reactions)]
    df.loc[key, filtered_series.index] = filtered_series.values

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
# Step 1: Filter reactions with non-zero variance
reaction_variance = df.var(axis=0)
df_filtered = df.loc[:, reaction_variance > 0]
df_filtered = df_filtered.abs()
df_filtered
# Out:
#            10FTHFtm  11DOCRTSTRNtm  11DOCRTSTRNtr  2AMACHYD      2HBO   2HBt2  \
# V3_C005    0.000000       0.000000       0.000000       0.0  0.000000  1000.0
# V3_C009    0.000000       0.000000       0.000000       0.0  0.000000  1000.0
# V3_C010    0.000000       0.000000       0.000000       0.0  0.000000  1000.0
# V3_C016    0.000000       0.000000       0.000000       0.0  0.000000  1000.0
# V3_C018    0.000000       0.000000       0.000000       0.0  0.000000  1000.0
# ...             ...            ...            ...       ...       ...     ...
# M_C120   716.084653       0.000000       0.000000       0.0  0.161985  1000.0
# M_C115   764.403518       0.225739       0.225739       0.0  0.000000  1000.0
# M_C101     0.000000       0.000000       0.000000       0.0  0.000000  1000.0
# M_C114     0.000000       0.000000       0.000000       0.0  0.000000  1000.0
# M_C119     0.000000       0.000000       0.000000       0.0  0.000000  1000.0
#
#          2HCO3_NAt  34HPPOR    3DSPHR      3HAO  ...  DM_4abut[c]  DM_srtn[c]  \
# V3_C005     1000.0      0.0  0.004922  0.000000  ...          0.0         0.0
# V3_C009     1000.0      0.0  0.004922  0.000000  ...          0.0         0.0
# V3_C010     1000.0      0.0  0.004922  0.000000  ...          0.0         0.0
# V3_C016     1000.0      0.0  0.004922  0.000000  ...          0.0         0.0
# V3_C018     1000.0      0.0  0.004922  0.000000  ...          0.0         0.0
# ...            ...      ...       ...       ...  ...          ...         ...
# M_C120      1000.0      0.0  0.004922  0.000000  ...          0.0         0.0
# M_C115      1000.0      0.0  0.004922  0.001017  ...          0.0         0.0
# M_C101      1000.0      0.0  0.004922  0.000000  ...          0.0         0.0
# M_C114      1000.0      0.0  0.004922  0.002968  ...          0.0         0.0
# M_C119      1000.0      0.0  0.004922  0.000000  ...          0.0         0.0
#
#          DM_ach[c]  DM_kynate[c]       DCMPtm     ATPS4mi  CYOR_u10mi  \
# V3_C005        0.0      0.035978   980.563779   35.902643   23.606042
# V3_C009        0.0      0.035978   974.798723   36.619729   24.084099
# V3_C010        0.0      0.035978   974.798723   36.619729   24.084099
# V3_C016        0.0      0.035978   974.798723   36.619729   24.084099
# V3_C018        0.0      0.035978   974.798723   36.619729   24.084099
# ...            ...           ...          ...         ...         ...
# M_C120         0.0      0.000000  1000.000000  297.405873  198.270582
# M_C115         0.0      0.000000  1000.000000   30.961132   20.634940
# M_C101         0.0      0.000000  1000.000000  294.952116  196.305690
# M_C114         0.0      0.000000  1000.000000  359.128583  153.431953
# M_C119         0.0      0.000000  1000.000000  454.072153  198.256300
#
#          NADH2_u10mi  CYOOm3i    CYOOm2i
# V3_C005     0.000000      0.0  12.296601
# V3_C009     0.000000      0.0  12.535630
# V3_C010     0.000000      0.0  12.535630
# V3_C016     0.000000      0.0  12.535630
# V3_C018     0.000000      0.0  12.535630
# ...              ...      ...        ...
# M_C120      0.000000      0.0  99.135291
# M_C115      0.000000      0.0  10.326192
# M_C101      0.000000      0.0  98.646426
# M_C114    128.980654      0.0  76.715976
# M_C119    156.687703      0.0  99.128150
#
# [84 rows x 2916 columns]

# %%
# Step 2: (Optional) Focus on top N most variable reactions
top_n = 200  # Change to 50, 200, etc., depending on resolution
top_reactions = reaction_variance.sort_values(ascending=False).head(top_n).index
df_top = df_filtered[top_reactions]
df_top
# Out:
#          HCO3_CLt  UREAt5        UREAt        r2324        r2359    KCCt  \
# V3_C005    1000.0  1000.0  1000.000000   718.922783   718.922783  1000.0
# V3_C009    1000.0  1000.0  1000.000000   759.831505   759.831505  1000.0
# V3_C010    1000.0  1000.0  1000.000000   759.831505   759.831505  1000.0
# V3_C016    1000.0  1000.0  1000.000000   759.831505   759.831505  1000.0
# V3_C018    1000.0  1000.0  1000.000000   759.831505   759.831505  1000.0
# ...           ...     ...          ...          ...          ...     ...
# M_C120     1000.0  1000.0  1000.000000  1000.000000  1000.000000  1000.0
# M_C115     1000.0  1000.0  1000.000000  1000.000000  1000.000000  1000.0
# M_C101     1000.0  1000.0   999.000000  1000.000000  1000.000000  1000.0
# M_C114     1000.0  1000.0   999.324313  1000.000000  1000.000000  1000.0
# M_C119     1000.0  1000.0   999.556307  1000.000000  1000.000000  1000.0
#
#            CA2t   2HBt2     HMR_0155       DITPtn  ...         MDHm  \
# V3_C005   999.0  1000.0   961.166208   820.722069  ...    64.424840
# V3_C009   999.0  1000.0   930.500000   810.500000  ...    73.252564
# V3_C010   999.0  1000.0   930.500000   810.500000  ...    73.252564
# V3_C016   999.0  1000.0   930.500000   810.500000  ...    73.252564
# V3_C018   999.0  1000.0   930.500000   810.500000  ...    73.252564
# ...         ...     ...          ...          ...  ...          ...
# M_C120   1000.0  1000.0  1000.000000  1000.000000  ...  1000.000000
# M_C115   1000.0  1000.0  1000.000000  1000.000000  ...  1000.000000
# M_C101   1000.0  1000.0  1000.000000   166.131496  ...  1000.000000
# M_C114   1000.0  1000.0  1000.000000     1.177154  ...  1000.000000
# M_C119   1000.0  1000.0  1000.000000     1.169733  ...  1000.000000
#
#               r2516       PIter      GALt2_2        GALt4        NDPK1  \
# V3_C005  679.277931  143.138583     0.069444  1000.000000     5.580580
# V3_C009  689.500000  122.694444     0.069444  1000.000000     8.223408
# V3_C010  689.500000  122.694444     0.069444  1000.000000     8.223408
# V3_C016  689.500000  122.694444     0.069444  1000.000000     8.223408
# V3_C018  689.500000  122.694444     0.069444  1000.000000     8.223408
# ...             ...         ...          ...          ...          ...
# M_C120   442.645487  385.290974   926.095040    73.974404  1000.000000
# M_C115   267.774136   35.548273  1000.000000     0.069444  1000.000000
# M_C101     0.000000  787.159881  1000.000000     0.069444  1000.000000
# M_C114    66.325879  410.948291  1000.000000     0.069444  1000.000000
# M_C119    91.387392  378.150144  1000.000000     0.069444  1000.000000
#
#          APRGSTRNt1e    HMR_7977       UMPK6n       r2108
# V3_C005   858.555861  858.555861   820.722069  679.277931
# V3_C009   879.000000  879.000000   810.500000  689.500000
# V3_C010   879.000000  879.000000   810.500000  689.500000
# V3_C016   879.000000  879.000000   810.500000  689.500000
# V3_C018   879.000000  879.000000   810.500000  689.500000
# ...              ...         ...          ...         ...
# M_C120      0.000000    0.000000   999.990846  441.824618
# M_C115      0.000000    0.000000   999.986355  267.774136
# M_C101      0.000000    0.000000   424.683924  643.579940
# M_C114      0.000000    0.000000  1000.000000    9.215600
# M_C119      0.000000    0.000000  1000.000000  170.174206
#
# [84 rows x 200 columns]

# %%
# Step 3: Z-score normalization (column-wise)
df_scaled = (df_top_abs) / df_top_abs.max()
df_scaled = df_scaled.fillna(0.0)  # In case any reaction was flat post-filtering

# %%
df_scaled
# Out:
#          HCO3_CLt  UREAt5     UREAt     r2324     r2359  KCCt   CA2t  2HBt2  \
# V3_C005       1.0     1.0  1.000000  0.718923  0.718923   1.0  0.999    1.0
# V3_C009       1.0     1.0  1.000000  0.759832  0.759832   1.0  0.999    1.0
# V3_C010       1.0     1.0  1.000000  0.759832  0.759832   1.0  0.999    1.0
# V3_C016       1.0     1.0  1.000000  0.759832  0.759832   1.0  0.999    1.0
# V3_C018       1.0     1.0  1.000000  0.759832  0.759832   1.0  0.999    1.0
# ...           ...     ...       ...       ...       ...   ...    ...    ...
# M_C120        1.0     1.0  1.000000  1.000000  1.000000   1.0  1.000    1.0
# M_C115        1.0     1.0  1.000000  1.000000  1.000000   1.0  1.000    1.0
# M_C101        1.0     1.0  0.999000  1.000000  1.000000   1.0  1.000    1.0
# M_C114        1.0     1.0  0.999324  1.000000  1.000000   1.0  1.000    1.0
# M_C119        1.0     1.0  0.999556  1.000000  1.000000   1.0  1.000    1.0
#
#          HMR_0155    DITPtn  ...      MDHm     r2516     PIter   GALt2_2  \
# V3_C005  0.961166  0.820722  ...  0.064425  0.985175  0.162843  0.000069
# V3_C009  0.930500  0.810500  ...  0.073253  1.000000  0.139584  0.000069
# V3_C010  0.930500  0.810500  ...  0.073253  1.000000  0.139584  0.000069
# V3_C016  0.930500  0.810500  ...  0.073253  1.000000  0.139584  0.000069
# V3_C018  0.930500  0.810500  ...  0.073253  1.000000  0.139584  0.000069
# ...           ...       ...  ...       ...       ...       ...       ...
# M_C120   1.000000  1.000000  ...  1.000000  0.641980  0.438329  0.926095
# M_C115   1.000000  1.000000  ...  1.000000  0.388360  0.040442  1.000000
# M_C101   1.000000  0.166131  ...  1.000000  0.000000  0.895517  1.000000
# M_C114   1.000000  0.001177  ...  1.000000  0.096194  0.467518  1.000000
# M_C119   1.000000  0.001170  ...  1.000000  0.132542  0.430205  1.000000
#
#             GALt4     NDPK1  APRGSTRNt1e  HMR_7977    UMPK6n     r2108
# V3_C005  1.000000  0.005581     0.976742  0.976742  0.820722  0.985175
# V3_C009  1.000000  0.008223     1.000000  1.000000  0.810500  1.000000
# V3_C010  1.000000  0.008223     1.000000  1.000000  0.810500  1.000000
# V3_C016  1.000000  0.008223     1.000000  1.000000  0.810500  1.000000
# V3_C018  1.000000  0.008223     1.000000  1.000000  0.810500  1.000000
# ...           ...       ...          ...       ...       ...       ...
# M_C120   0.073974  1.000000     0.000000  0.000000  0.999991  0.640790
# M_C115   0.000069  1.000000     0.000000  0.000000  0.999986  0.388360
# M_C101   0.000069  1.000000     0.000000  0.000000  0.424684  0.933401
# M_C114   0.000069  1.000000     0.000000  0.000000  1.000000  0.013366
# M_C119   0.000069  1.000000     0.000000  0.000000  1.000000  0.246808
#
# [84 rows x 200 columns]

# %%
# Step 4: Prepare metadata (make sure metadata index matches df_scaled index)
metadata_subset = metadata.loc[df_scaled.index]
meta_vars = ['Gender', 'Delivery mode', 'Time point']
meta_colors = {}

for var in meta_vars:
    unique_vals = metadata_subset[var].dropna().unique()
    palette = sns.color_palette("Set2", n_colors=len(unique_vals))
    meta_colors[var] = dict(zip(unique_vals, palette))

row_colors = pd.DataFrame({
    var: metadata_subset[var].map(meta_colors[var])
    for var in meta_vars
}, index=metadata_subset.index)

# Step 5: Plot clustermap
g = sns.clustermap(
    df_scaled,
    metric='euclidean',
    method='ward',
    cmap='coolwarm',
    center=0,
    figsize=(14, 12),
    row_colors=row_colors
)

# Step 6: Add legends for metadata
for idx, var in enumerate(meta_vars):
    handles = [
        mpatches.Patch(color=color, label=label)
        for label, color in meta_colors[var].items()
    ]
    g.ax_row_dendrogram.legend(
        handles=handles,
        title=var,
        bbox_to_anchor=(1.0 + 0.18 * idx, 0.85),
        loc='upper left',
        borderaxespad=0.
    )

plt.title("Clustering Heatmap of Variable Fluxes with Metadata", pad=100)
# Hide x-axis labels
g.ax_heatmap.set_xticklabels([])
g.ax_heatmap.tick_params(axis='x', bottom=False)
plt.show()
# Out:
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
metadata_subset = metadata.loc[df_scaled.index]
meta_vars = ['Delivery mode', 'Time point']
meta_colors = {}

# Use distinct color palettes (not red/blue)
palette_map = {
    'Delivery mode': sns.color_palette("Dark2"),
    'Time point': sns.color_palette("Set3", n_colors=metadata_subset['Time point'].nunique())
}

for var in meta_vars:
    unique_vals = metadata_subset[var].dropna().unique()
    meta_colors[var] = dict(zip(unique_vals, palette_map[var]))

# Create row_colors DataFrame
row_colors = pd.DataFrame({
    var: metadata_subset[var].map(meta_colors[var])
    for var in meta_vars
}, index=metadata_subset.index)

# Step 3: Plot clustermap (with x-axis labels off)
g = sns.clustermap(
    df_scaled,
    metric='euclidean',
    method='ward',
    cmap='coolwarm',
    center=0,
    figsize=(14, 12),
    row_colors=row_colors,
    xticklabels=False,
    yticklabels=False
)

# Step 4: Build grouped legend manually
legend_handles = []

# Delivery mode block
legend_handles.append(mpatches.Patch(color='white', label='Delivery mode'))  # Title (white patch, acts as spacer)
for label, color in meta_colors['Delivery mode'].items():
    legend_handles.append(mpatches.Patch(color=color, label=f"   {label}"))  # Indented

# Time point block
legend_handles.append(mpatches.Patch(color='white', label='Time point'))
for label, color in meta_colors['Time point'].items():
    legend_handles.append(mpatches.Patch(color=color, label=f"   {label}"))

# Plot legend to the right of the heatmap
g.ax_heatmap.legend(
    handles=legend_handles,
    title=None,
    bbox_to_anchor=(1.15, 1),
    loc='upper left',
    borderaxespad=0.,
    frameon=True
)

plt.title("Clustering Heatmap of Fluxes by Time Point and Delivery Mode", pad=100)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.patches as mpatches

# Ensure metadata subset aligns with df_scaled
metadata_subset = metadata.loc[df_scaled.index]
meta_vars = ['Delivery mode', 'Time point']
meta_colors = {}

# === Define row color palettes ===
palette_map = {
    'Delivery mode': sns.color_palette("Dark2"),
    'Time point': sns.color_palette("Set3", n_colors=metadata_subset['Time point'].nunique())
}

# Map metadata to colors
for var in meta_vars:
    unique_vals = metadata_subset[var].dropna().unique()
    meta_colors[var] = dict(zip(unique_vals, palette_map[var]))

# Create row_colors DataFrame
row_colors = pd.DataFrame({
    var: metadata_subset[var].map(meta_colors[var])
    for var in meta_vars
}, index=metadata_subset.index)

# === Define column color bar for reaction subsystems ===
# Step 1: Create a modified version of rxn2subsystem
rxn2subsystem_grouped = {
    rxn: ('Transport' if 'Transport' in subsystem else subsystem)
    for rxn, subsystem in rxn2subsystem.items()
}
# Map subsystems using rxn2subsystem dict
reaction_subsystems = df_scaled.columns.map(rxn2subsystem_grouped.get)

# Get unique subsystems and assign distinct colors
unique_subsystems = pd.Series(reaction_subsystems).dropna().unique()
subsystem_palette = sns.color_palette("tab20", n_colors=len(unique_subsystems))
subsystem_colors = dict(zip(unique_subsystems, subsystem_palette))

# Build col_colors DataFrame
col_colors = pd.DataFrame({
    'Subsystem': pd.Series(reaction_subsystems, index=df_scaled.columns).map(subsystem_colors)
})

# === Plot clustermap ===
g = sns.clustermap(
    df_scaled,
    metric='euclidean',
    method='ward',
    cmap='coolwarm',
    center=0,
    figsize=(16, 14),
    row_colors=row_colors,
    col_colors=col_colors,
    xticklabels=False,
    yticklabels=False
)

# === Build grouped legend manually ===
legend_handles = []

# Delivery mode block
legend_handles.append(mpatches.Patch(color='white', label='Delivery mode'))  # Title
for label, color in meta_colors['Delivery mode'].items():
    legend_handles.append(mpatches.Patch(color=color, label=f"   {label}"))

# Time point block
legend_handles.append(mpatches.Patch(color='white', label='Time point'))
for label, color in meta_colors['Time point'].items():
    legend_handles.append(mpatches.Patch(color=color, label=f"   {label}"))

# Subsystem block
legend_handles.append(mpatches.Patch(color='white', label='Subsystem'))
for label, color in subsystem_colors.items():
    legend_handles.append(mpatches.Patch(color=color, label=f"   {label}"))

# Add legend
g.ax_heatmap.legend(
    handles=legend_handles,
    title=None,
    bbox_to_anchor=(1.02, 1),
    loc='upper left',
    borderaxespad=0.,
    frameon=True,
    prop={'size': 9},  # Smaller font
    ncol=2
)

# === Final touches ===
plt.title("Clustering Heatmap of Fluxes by Time Point and Delivery Mode", pad=100)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.patches as mpatches
import os

# === Subset metadata to match df_scaled ===
metadata_subset = metadata.loc[df_scaled.index]
meta_vars = ['Delivery mode', 'Time point']
meta_colors = {}

# === Define row color palettes ===
palette_map = {
    'Delivery mode': sns.color_palette("Dark2"),
    'Time point': sns.color_palette("Set3", n_colors=metadata_subset['Time point'].nunique())
}

# Map metadata to colors
for var in meta_vars:
    unique_vals = metadata_subset[var].dropna().unique()
    meta_colors[var] = dict(zip(unique_vals, palette_map[var]))

# Build row_colors (combined for compact axis)
row_colors = pd.concat([
    metadata_subset['Delivery mode'].map(meta_colors['Delivery mode']),
    metadata_subset['Time point'].map(meta_colors['Time point'])
], axis=1)
row_colors.columns = ['Delivery', 'Time']

# === Define column color bar for reaction subsystems ===
rxn2subsystem_grouped = {
    rxn: ('Transport' if 'Transport' in subsystem else subsystem)
    for rxn, subsystem in rxn2subsystem.items()
}
reaction_subsystems = df_scaled.columns.map(rxn2subsystem_grouped.get)
unique_subsystems = pd.Series(reaction_subsystems).dropna().unique()
subsystem_palette = sns.color_palette("tab20", n_colors=len(unique_subsystems))
subsystem_colors = dict(zip(unique_subsystems, subsystem_palette))
col_colors = pd.DataFrame({
    'Subsystem': pd.Series(reaction_subsystems, index=df_scaled.columns).map(subsystem_colors)
})

# === Plot clustermap ===
g = sns.clustermap(
    df_scaled,
    metric='euclidean',
    method='ward',
    cmap='coolwarm',
    center=0,
    figsize=(20, 14),  # Bigger plot area
    row_colors=row_colors,
    col_colors=col_colors,
    xticklabels=False,
    yticklabels=False
)

# === Adjust layout to make space for legend ===
g.fig.subplots_adjust(right=0.75)

# === Build custom legend handles ===
legend_handles = []

# Delivery mode block
legend_handles.append(mpatches.Patch(color='white', label='Delivery mode'))
for label, color in meta_colors['Delivery mode'].items():
    legend_handles.append(mpatches.Patch(color=color, label=f"   {label}"))

# Time point block
legend_handles.append(mpatches.Patch(color='white', label='Time point'))
for label, color in meta_colors['Time point'].items():
    legend_handles.append(mpatches.Patch(color=color, label=f"   {label}"))

# Subsystem block
legend_handles.append(mpatches.Patch(color='white', label='Subsystem'))
for label, color in subsystem_colors.items():
    legend_handles.append(mpatches.Patch(color=color, label=f"   {label}"))

# === Add compact 2-column legend ===
g.ax_heatmap.legend(
    handles=legend_handles,
    title=None,
    bbox_to_anchor=(1.02, 1),
    loc='upper left',
    borderaxespad=0.,
    frameon=True,
    prop={'size': 9},  # Smaller font
    ncol=2
)

# === Final touches ===
plt.title("Clustering Heatmap of Fluxes by Time Point and Delivery Mode", pad=80, fontsize=16)
plt.tight_layout()
g.savefig("flux_clustermap.svg", format='svg', bbox_inches='tight', pad_inches=0.2)
plt.show()
# Out:
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\seaborn\matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Run PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_scaled)
pca_df = pd.DataFrame(pca_result, columns=['PC1', 'PC2'], index=df_scaled.index)

# Step 2: Run KMeans
n_clusters = 3  # Change this depending on how many you want
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
clusters = kmeans.fit_predict(pca_result)
pca_df['Cluster'] = clusters.astype(str)

# Step 3: Plot
plt.figure(figsize=(10, 7))
p = sns.scatterplot(
    data=pca_df,
    x='PC1', y='PC2',
    hue='Cluster',
    palette='tab10',
    s=100,
    edgecolor='black'
)

plt.title("PCA of Flux Profiles with K-Means Clustering")
plt.xlabel(f"PC1 ({pca.explained_variance_ratio_[0]*100:.1f}% variance)")
plt.ylabel(f"PC2 ({pca.explained_variance_ratio_[1]*100:.1f}% variance)")
plt.grid(True)
plt.tight_layout()
plt.legend(title="Cluster")
plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Run PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_scaled)
pca_df = pd.DataFrame(pca_result, columns=['PC1', 'PC2'], index=df_scaled.index)

# Step 2: Merge Time point from metadata
pca_df = pca_df.join(metadata[['Time point']])

# Step 3: Plot PCA colored by Time point
plt.figure(figsize=(8, 6))
sns.scatterplot(
    data=pca_df,
    x='PC1', y='PC2',
    hue='Time point',
    palette='Set2',
    s=100,
    edgecolor='black'
)

# Add variance explained
plt.title("PCA of Flux Profiles Colored by Time Point")
plt.xlabel(f"PC1 ({pca.explained_variance_ratio_[0]*100:.1f}% variance)")
plt.ylabel(f"PC2 ({pca.explained_variance_ratio_[1]*100:.1f}% variance)")
plt.grid(True)
plt.tight_layout()
plt.legend(title="Time point", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.savefig("pca_flux_profiles_fullHD.png", dpi=600, bbox_inches='tight', pad_inches=0.2)
plt.show()

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Run PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_scaled)
pca_df = pd.DataFrame(pca_result, columns=['PC1', 'PC2'], index=df_scaled.index)

# Step 2: Merge Time point from metadata
pca_df = pca_df.join(metadata[['Time point']])

# Step 3: Plot PCA
plt.figure(figsize=(8, 7))  # Slightly less wide (was 10)
sns.set_context("talk", font_scale=1.2)  # Larger font sizes

sns.scatterplot(
    data=pca_df,
    x='PC1', y='PC2',
    hue='Time point',
    palette='Set2',
    s=100,
    edgecolor='black'
)

# Add variance explained
plt.title("PCA of Flux Profiles Colored by Time Point", fontsize=16)
plt.xlabel(f"PC1 ({pca.explained_variance_ratio_[0]*100:.1f}% variance)", fontsize=14)
plt.ylabel(f"PC2 ({pca.explained_variance_ratio_[1]*100:.1f}% variance)", fontsize=14)
plt.grid(True)
plt.tight_layout()
plt.legend(title="Time point", bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12, title_fontsize=13)
plt.show()

# %%
# Step 1: Run PCA again (or reuse existing pca)
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_scaled)

# Step 2: Get PCA loadings (contributions of each reaction)
loadings = pd.DataFrame(
    pca.components_.T,
    index=df_scaled.columns,
    columns=['PC1', 'PC2']
)

# Step 3: Sort and view top contributors for each PC
top_pc1 = loadings['PC1'].abs().sort_values(ascending=False).head(10)
top_pc2 = loadings['PC2'].abs().sort_values(ascending=False).head(10)

print("Top contributors to PC1:")
print(top_pc1)

print("\nTop contributors to PC2:")
print(top_pc2)
# Out:
# Top contributors to PC1:
# r2110        0.087187
# HMR_2760     0.085539
# ADRNCRNt     0.085537
# H2Otn        0.085505
# r2433        0.085096
# HMR_2644     0.084633
# HPDCACRNt    0.084633
# ACRNtm       0.084320
# HMR_2757     0.084162
# HMR_2634     0.084160
# Name: PC1, dtype: float64
#
# Top contributors to PC2:
# r2090         0.150422
# NADPtru       0.143712
# NADPHtru      0.143712
# PYRt2p        0.142604
# r0783         0.136882
# FADtru        0.136882
# FADH2tru      0.136882
# DHCR242r      0.136882
# LNLNCGCPT1    0.134970
# r2537         0.134968
# Name: PC2, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# === Configurable ===
top_n_reactions = 20  # Change this to show more or fewer reactions

# Step 1: Compute variance and pick top variable reactions
reaction_variance = df.var(axis=0)
top_reactions = reaction_variance.sort_values(ascending=False).head(top_n_reactions).index
df_topvar = df[top_reactions]

# Step 2: Melt the dataframe for seaborn (long format)
df_long = df_topvar.reset_index().melt(id_vars='index', var_name='Reaction', value_name='Flux')
df_long.rename(columns={'index': 'Sample'}, inplace=True)

# Step 3: Add Time point from metadata
df_long = df_long.merge(metadata[['Time point']], left_on='Sample', right_index=True)

# Step 4: Plot using stripplot or swarmplot
plt.figure(figsize=(12, top_n_reactions * 0.5))
sns.stripplot(
    data=df_long,
    x='Flux',
    y='Reaction',
    hue='Time point',
    jitter=True,
    dodge=True,
    alpha=0.8,
    palette='Set2',
    size=5
)

plt.title(f"Top {top_n_reactions} Most Variable Reactions Across Samples")
plt.xlabel("Flux Value")
plt.ylabel("Reaction")
plt.grid(True, axis='x', linestyle='--', alpha=0.5)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='Time point')
plt.tight_layout()
plt.show()

# %%
# === Configurable ===
top_n_reactions = 20
exclude_hard_bounds = True
bound_threshold = 950  # Exclude reactions stuck at ±bound_threshold

# Step 1: Compute variance
reaction_variance = df.var(axis=0)

# Step 2: Filter out reactions mostly fixed at upper/lower bounds
if exclude_hard_bounds:
    valid_reactions = []
    for reaction in reaction_variance.index:
        vals = df[reaction]
        unique_vals = vals.unique()
        # If only a few unique values, and all are near bounds → skip
        if len(unique_vals) <= 2 and all(abs(v) >= bound_threshold for v in unique_vals):
            continue
        valid_reactions.append(reaction)
    filtered_variance = reaction_variance.loc[valid_reactions]
else:
    filtered_variance = reaction_variance

# Step 3: Get top N from filtered set
top_reactions = filtered_variance.sort_values(ascending=False).head(top_n_reactions).index
df_topvar = df[top_reactions]

# Step 4: Melt for plotting
df_long = df_topvar.reset_index().melt(id_vars='index', var_name='Reaction', value_name='Flux')
df_long.rename(columns={'index': 'Sample'}, inplace=True)
df_long = df_long.merge(metadata[['Time point']], left_on='Sample', right_index=True)

# Step 5: Plot
plt.figure(figsize=(12, top_n_reactions * 0.5))
sns.stripplot(
    data=df_long,
    x='Flux',
    y='Reaction',
    hue='Time point',
    jitter=True,
    dodge=True,
    alpha=0.8,
    palette='Set2',
    size=5
)

plt.title(f"Top {top_n_reactions} Variable Reactions (Excluding Bound-Constrained)")
plt.xlabel("Flux Value")
plt.ylabel("Reaction")
plt.grid(True, axis='x', linestyle='--', alpha=0.5)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', title='Time point')
plt.tight_layout()
plt.show()

# %%
subsystems = {}

for r in cobraModel.reactions:
    r_id = r.id
    try:
        _ = subsystems[cobraModel.reactions.get_by_id(r_id).subsystem]
    except:
        subsystems[cobraModel.reactions.get_by_id(r_id).subsystem] = set()
    
    
    subsystems[cobraModel.reactions.get_by_id(r_id).subsystem].update([(r_id)])

# %%
subsystems
# Out:
# {'Transport, lysosomal': {'10FTHF5GLUtl',
#   '10FTHF6GLUtl',
#   '10FTHF7GLUtl',
#   '10FTHFtl',
#   '5DHFtl',
#   '5THFtl',
#   '6DHFtl',
#   '6THFtl',
#   '7DHFtl',
#   '7THFtl',
#   'ABUTt2rL',
#   'ACGAGBSIDEtl',
#   'ACGALtly',
#   'ACGAMtly',
#   'ACGBGBSIDEtl',
#   'ACNAMlt',
#   'ADNtl',
#   'ATPasel',
#   'CHOLPtl',
#   'COAtl',
#   'CRVNCtl',
#   'CSPG_Atly',
#   'CSPG_Btly',
#   'CSPG_Ctly',
#   'CSPG_Dtly',
#   'CSPG_Etly',
#   'CYTDtl',
#   'DHFtl',
#   'DIGALSIDEtl',
#   'DPCOAtl',
#   'FALDtly',
#   'FUCtly',
#   'GALGLUSIDEtl',
#   'GALSIDEtl',
#   'GALtly',
#   'GBSIDEtl',
#   'GD1Btl',
#   'GD3tlc',
#   'GLCURtly',
#   'GLCtly',
#   'GLUt7l',
#   'GSNtl',
#   'H2O2tly',
#   'H2Otly',
#   'HAtly',
#   'HMR_0769',
#   'HMR_0831',
#   'HMR_0913',
#   'HMR_2087',
#   'HMR_2090',
#   'HMR_3597',
#   'HMR_5249',
#   'HMR_7198',
#   'HMR_7199',
#   'HMR_7711',
#   'HMR_7715',
#   'HMR_7720',
#   'HMR_7724',
#   'HMR_7727',
#   'HMR_8588',
#   'HMR_8590',
#   'HSPGtly',
#   'IDOURtly',
#   'KSII_CORE2tly',
#   'KSII_CORE4tly',
#   'KSItly',
#   'MANtly',
#   'MEOHtly',
#   'N2M2NMASNtly',
#   'NO2te',
#   'Rtotaltl',
#   'S2L2FN2M2MASNtly',
#   'S2L2N2M2MASNtly',
#   'SGALSIDEtl',
#   'SO4tl',
#   'SPHINGStl',
#   'SPHMYLNtl',
#   'THCRMtl',
#   'THFtl',
#   'THYMDtl',
#   'TMNDNCtl',
#   'UDPACGALtl',
#   'UDPtl',
#   'Uritl',
#   'XOLEST182tl',
#   'XOLEST183tl',
#   'XOLEST205tl',
#   'XOLEST226tl',
#   'XYLtly',
#   'r0932',
#   'r0937',
#   'r0984',
#   'r0986',
#   'r0987',
#   'r1052',
#   'r1150',
#   'r1298',
#   'r1299',
#   'r1301',
#   'r1302',
#   'r1304',
#   'r1364',
#   'r1365',
#   'r1367',
#   'r1368'},
#  'Transport, mitochondrial': {'10FTHF5GLUtm',
#   '10FTHF6GLUtm',
#   '10FTHF7GLUtm',
#   '10FTHFtm',
#   '11DOCRTSLtm',
#   '11DOCRTSTRNtm',
#   '1A25HVITD2tm',
#   '24_25DHVITD2tm',
#   '24_25DHVITD3tm',
#   '25HVITD2tin_m',
#   '25HVITD3tin_m',
#   '2M3HBUtm',
#   '2M3OVACtm',
#   '2MOPtm',
#   '34HPLtm',
#   '3AIB_Dtm',
#   '3AIBtmi',
#   '3HIVActm',
#   '3HMPtm',
#   '3HPPtm',
#   '3MGLUTACtm',
#   '3MOBt2im',
#   '3MOPt2im',
#   '3OHGLUTACtm',
#   '3SALAASPm',
#   '4ABUTtm',
#   '4HBZtm',
#   '4MOPt2im',
#   '4MPTNLtm',
#   '4OHBUTtmc',
#   '5EIPENCtm',
#   '5THFtm',
#   '6DHFtm',
#   '6THFtm',
#   '7DHFtm',
#   '7THFtm',
#   'AACTtm',
#   'ACACt2m',
#   'ACALDtm',
#   'ACETONEt2m',
#   'ACGLUtm',
#   'ACGLYtc',
#   'ACHOMtm',
#   'ACILEtm',
#   'ACLEUtm',
#   'ACRNtm',
#   'ACTHRtc',
#   'ACTYRtc',
#   'ACt2m',
#   'ADNtm',
#   'AGRMtm',
#   'AHCYStd',
#   'AKGMALtm',
#   'ALDSTRNtm',
#   'AMETt2m',
#   'AMETtd',
#   'ARGtm',
#   'ASNtm',
#   'ASPGLUm',
#   'ATPtm',
#   'BALAtmr',
#   'BGLYtm',
#   'BHBtm',
#   'BTNt2m',
#   'BUTt2m',
#   'BZtm',
#   'C02712tm',
#   'C05953tm',
#   'C4tmc',
#   'CBL2tm',
#   'CDPDAGtm',
#   'CE2026tm',
#   'CE2176tm',
#   'CE4968tm',
#   'CE4970tm',
#   'CHLtm',
#   'CHSTEROLt1',
#   'CHSTEROLt2',
#   'CHSTEROLt3',
#   'CITRtm',
#   'CITtam',
#   'CITtbm',
#   'CO2tm',
#   'COAtm',
#   'CRNtim',
#   'CRTSLtm',
#   'CRTSTRNtm',
#   'CYANtm',
#   'CYTDtm',
#   'DATPtm',
#   'DCMPtm',
#   'DCTPtm',
#   'DECDPtm',
#   'DGSNtm',
#   'DGTPtm',
#   'DHAPtc',
#   'DHFtm',
#   'DMGtm',
#   'DNDPt10m',
#   'DNDPt11m',
#   'DNDPt12m',
#   'DNDPt13m',
#   'DNDPt14m',
#   'DNDPt15m',
#   'DNDPt16m',
#   'DNDPt17m',
#   'DNDPt18m',
#   'DNDPt19m',
#   'DNDPt1m',
#   'DNDPt20m',
#   'DNDPt21m',
#   'DNDPt23m',
#   'DNDPt24m',
#   'DNDPt25m',
#   'DNDPt28m',
#   'DNDPt2m',
#   'DNDPt30m',
#   'DNDPt31m',
#   'DNDPt32m',
#   'DNDPt37m',
#   'DNDPt38m',
#   'DNDPt39m',
#   'DNDPt3m',
#   'DNDPt40m',
#   'DNDPt41m',
#   'DNDPt42m',
#   'DNDPt43m',
#   'DNDPt44m',
#   'DNDPt45m',
#   'DNDPt46m',
#   'DNDPt47m',
#   'DNDPt48m',
#   'DNDPt49m',
#   'DNDPt4m',
#   'DNDPt50m',
#   'DNDPt51m',
#   'DNDPt52m',
#   'DNDPt53m',
#   'DNDPt54m',
#   'DNDPt55m',
#   'DNDPt56m',
#   'DNDPt57m',
#   'DNDPt58m',
#   'DNDPt59m',
#   'DNDPt5m',
#   'DNDPt60m',
#   'DNDPt61m',
#   'DNDPt62m',
#   'DNDPt63m',
#   'DNDPt6m',
#   'DNDPt7m',
#   'DTTPtm',
#   'D_LACtm',
#   'FALDtm',
#   'FE2tm',
#   'FORTHFC',
#   'FORt2m',
#   'FUMSO3tm',
#   'FUMSO4tm',
#   'FUMTSULtm',
#   'FUMtm',
#   'GD3tm',
#   'GLNtm',
#   'GLU5SAtmc',
#   'GLUTCONtm',
#   'GLUt2m',
#   'GLXtm',
#   'GLYBtm',
#   'GLYC3Ptm',
#   'GLYCLTtm',
#   'GLYCtm',
#   'GLYtm',
#   'H2O2tm',
#   'H2Otm',
#   'HEXDTRtm',
#   'HMGCOAtm',
#   'HMR_0157',
#   'HMR_0166',
#   'HMR_0172',
#   'HMR_0178',
#   'HMR_0182',
#   'HMR_0185',
#   'HMR_0587',
#   'HMR_0962',
#   'HMR_1243',
#   'HMR_1284',
#   'HMR_1620',
#   'HMR_1630',
#   'HMR_1666',
#   'HMR_1744',
#   'HMR_1745',
#   'HMR_1752',
#   'HMR_1753',
#   'HMR_1764',
#   'HMR_2127',
#   'HMR_2603',
#   'HMR_2604',
#   'HMR_2609',
#   'HMR_2610',
#   'HMR_2612',
#   'HMR_2613',
#   'HMR_2621',
#   'HMR_2622',
#   'HMR_2624',
#   'HMR_2634',
#   'HMR_2635',
#   'HMR_2644',
#   'HMR_2649',
#   'HMR_2650',
#   'HMR_2652',
#   'HMR_2653',
#   'HMR_2655',
#   'HMR_2659',
#   'HMR_2661',
#   'HMR_2662',
#   'HMR_2667',
#   'HMR_2668',
#   'HMR_2670',
#   'HMR_2671',
#   'HMR_2673',
#   'HMR_2676',
#   'HMR_2677',
#   'HMR_2679',
#   'HMR_2682',
#   'HMR_2683',
#   'HMR_2685',
#   'HMR_2686',
#   'HMR_2688',
#   'HMR_2689',
#   'HMR_2691',
#   'HMR_2692',
#   'HMR_2695',
#   'HMR_2697',
#   'HMR_2700',
#   'HMR_2701',
#   'HMR_2703',
#   'HMR_2704',
#   'HMR_2706',
#   'HMR_2707',
#   'HMR_2709',
#   'HMR_2710',
#   'HMR_2712',
#   'HMR_2713',
#   'HMR_2715',
#   'HMR_2718',
#   'HMR_2722',
#   'HMR_2727',
#   'HMR_2731',
#   'HMR_2734',
#   'HMR_2735',
#   'HMR_2737',
#   'HMR_2738',
#   'HMR_2740',
#   'HMR_2741',
#   'HMR_2744',
#   'HMR_2748',
#   'HMR_2753',
#   'HMR_2757',
#   'HMR_2760',
#   'HMR_2764',
#   'HMR_2769',
#   'HMR_2770',
#   'HMR_2772',
#   'HMR_2773',
#   'HMR_2775',
#   'HMR_2776',
#   'HMR_3520',
#   'HMR_3864',
#   'HMR_4266',
#   'HMR_4756',
#   'HMR_4957',
#   'HMR_4964',
#   'HMR_5101',
#   'HMR_5420',
#   'HMR_6408',
#   'HMR_7757',
#   'HMR_7758',
#   'HMR_8418',
#   'HMR_8475',
#   'HMR_8505',
#   'HMR_8510',
#   'HMR_8562',
#   'HMR_8776',
#   'HMR_9019',
#   'HMR_9174',
#   'HMR_9676',
#   'HPDECEtm',
#   'HXAt1',
#   'Htmi',
#   'ILEt5m',
#   'ISOBUTtm',
#   'LEUt5m',
#   'LPAMtm',
#   'LYStm',
#   'L_LACtcm',
#   'L_LACtm',
#   'MALOAtm',
#   'MALSO3tm',
#   'MALSO4tm',
#   'MALTSULtm',
#   'MALtm',
#   'MLTHFtm',
#   'MMALtm',
#   'NACASPtm',
#   'NACCYStm',
#   'NACVANALAtm',
#   'NADtm',
#   'O2Stm',
#   'O2tm',
#   'OCCOAtm',
#   'ORNt3m',
#   'ORNt4m',
#   'PACALDtm',
#   'PA_HStm',
#   'PCFLOPm',
#   'PEFLIPm',
#   'PE_HStm',
#   'PGLYCtm',
#   'PGP_hs_tm',
#   'PHEACGLYtm',
#   'PHEMEtm',
#   'PHPYRtm',
#   'PPAtm',
#   'PPIOGLYtm',
#   'PPItm',
#   'PRGNLONEtm',
#   'PROSTGE2t2m',
#   'PROtm',
#   'PSFLIPm',
#   'PYRt2m',
#   'SACCRP_Lte',
#   'SARCStm',
#   'SUCCt2m',
#   'SUCSALtm',
#   'T4HCINNMtm',
#   'TCYNTtm',
#   'TETPENT3COAtm',
#   'TETPENT6COAtm',
#   'TETTET6COAtm',
#   'THEXDDtm',
#   'THFtm',
#   'THMMPtm',
#   'THMPPtm',
#   'THMt2m',
#   'THYMDtm',
#   'TIGGLYtm',
#   'VALt5m',
#   'XOL27OHtm',
#   'XOL27OHtmc',
#   'XOL7AH2tm',
#   'XOLTRIOLtm',
#   'q10h2tc',
#   'q10tm',
#   'r0801',
#   'r0819',
#   'r0821',
#   'r0822',
#   'r0829',
#   'r0830',
#   'r0834',
#   'r0835',
#   'r0836',
#   'r0838',
#   'r0885',
#   'r0907',
#   'r0911',
#   'r0913',
#   'r0915',
#   'r0917',
#   'r0921',
#   'r0926',
#   'r0927',
#   'r0950',
#   'r0962',
#   'r0973',
#   'r0975',
#   'r1001',
#   'r1005',
#   'r1008',
#   'r1020',
#   'r1078',
#   'r1117',
#   'r1146',
#   'r1155',
#   'r1291',
#   'r1427',
#   'r1434',
#   'r1435',
#   'r1436',
#   'r1437',
#   'r1440',
#   'r1454',
#   'r1455',
#   'r1456',
#   'r1467',
#   'r1468',
#   'r2371',
#   'r2372',
#   'r2373',
#   'r2374',
#   'r2375',
#   'r2376',
#   'r2377',
#   'r2378',
#   'r2379',
#   'r2380',
#   'r2381',
#   'r2382',
#   'r2384',
#   'r2385',
#   'r2386',
#   'r2387',
#   'r2388',
#   'r2389',
#   'r2390',
#   'r2391',
#   'r2392',
#   'r2393',
#   'r2394',
#   'r2395',
#   'r2396',
#   'r2397',
#   'r2398',
#   'r2399',
#   'r2400',
#   'r2401',
#   'r2402',
#   'r2403',
#   'r2404',
#   'r2405',
#   'r2406',
#   'r2407',
#   'r2408',
#   'r2409',
#   'r2410',
#   'r2411',
#   'r2412',
#   'r2413',
#   'r2416',
#   'r2419',
#   'r2420',
#   'r2425',
#   'r2433',
#   'r2434',
#   'r2435',
#   'r2436',
#   'r2437',
#   'r2438',
#   'r2472',
#   'r2514m',
#   'r2520',
#   'r2535m',
#   'r2539'},
#  'Transport, endoplasmic reticular': {'11DOCRTSLtr',
#   '11DOCRTSTRNtr',
#   '12HARACHDtr',
#   '18HARACHDtr',
#   '5ADTSTSTERONEGLCtr',
#   '5ADTSTSTERONEtr',
#   '6HTSTSTERONEtr',
#   '7DHCHSTEROLtr',
#   'ACALDtr',
#   'ACCOAtr',
#   'AHANDROSTANGLCtr',
#   'AHANDROSTANtr',
#   'AHCYStr',
#   'AMETr',
#   'ANDRSTANDRtr',
#   'ANDRSTRNGLCtr',
#   'ANDRSTRNtr',
#   'ARACHDtr',
#   'ATP1ter',
#   'ATP2ter',
#   'BILDGLCURtr',
#   'BILGLCURtr',
#   'BILIRUBtr',
#   'BZtr',
#   'C03990tr',
#   'CBPter',
#   'CE7081tr',
#   'CERT1rt',
#   'CERT2rt',
#   'CHOLtr',
#   'CHSTEROLtrc',
#   'CO2ter',
#   'COAtr',
#   'COKEtr',
#   'CORTSNti',
#   'CRTSLtr',
#   'DAG_HSter',
#   'DHCRMter',
#   'DHEAtr',
#   'DSMSTEROLtr',
#   'EANDRSTRNtr',
#   'EBASTINEOHtr',
#   'EBASTINEtr',
#   'EGMEtr',
#   'ESTRADIOLGLCtr',
#   'ESTRADIOLtr',
#   'ESTRIOLGLCtr',
#   'ESTRIOLtr',
#   'ESTRONEGLCtr',
#   'ESTRONEtr',
#   'FADH2tru',
#   'FADtru',
#   'FORtr',
#   'FRDPtcr',
#   'G6Pter',
#   'GACPAILter',
#   'GALSIDEter',
#   'GLACter',
#   'GLCURter',
#   'GLCter',
#   'GLUtr',
#   'GTHRDtr',
#   'GULLACter',
#   'GULNter',
#   'H2Oter',
#   'HC02020tr',
#   'HDCAter',
#   'HESTRATRIOLtr',
#   'HMR_0020',
#   'HMR_0467',
#   'HMR_0771',
#   'HMR_0966',
#   'HMR_1306',
#   'HMR_1311',
#   'HMR_1316',
#   'HMR_1331',
#   'HMR_1392',
#   'HMR_1631',
#   'HMR_2569',
#   'HMR_2817',
#   'HMR_2819',
#   'HMR_2821',
#   'HMR_2827',
#   'HMR_2851',
#   'HMR_2852',
#   'HMR_2857',
#   'HMR_2859',
#   'HMR_2861',
#   'HMR_2862',
#   'HMR_2865',
#   'HMR_2866',
#   'HMR_2884',
#   'HMR_2886',
#   'HMR_2888',
#   'HMR_2890',
#   'HMR_3953',
#   'HMR_6385',
#   'HMR_6629',
#   'HMR_7257',
#   'HMR_7944',
#   'HMR_7947',
#   'HMR_7949',
#   'HMR_9177',
#   'HMR_9625',
#   'HMR_9626',
#   'HMR_9627',
#   'HMR_9628',
#   'HMR_9629',
#   'HMR_9630',
#   'HMR_9631',
#   'HMR_9634',
#   'HMR_9716',
#   'HPETFABP1tc',
#   'Htr',
#   'LANOSTtr',
#   'LEUKTRA4tr',
#   'LEUKTRB4tr',
#   'LEUKTRD4tr',
#   'LTHSTRLtr',
#   'NADHtru',
#   'NADPHtru',
#   'NADPtru',
#   'NADtru',
#   'NH4tr',
#   'O2ter',
#   'OCDEAFABP1tc',
#   'PA_HSter',
#   'PCHOL_HSter',
#   'PEHSFABPe',
#   'PE_HSter',
#   'PHCRMter',
#   'PHSPHINGStr',
#   'PIter',
#   'PMTCOAFABP1tc',
#   'PPItr',
#   'PRGNLONEtr',
#   'PROSTGE2t2r',
#   'PROSTGI2tr',
#   'RETNGLCt2',
#   'RETNGLCt2r',
#   'RETNGLCtr',
#   'RETNtr',
#   'RETNtr2',
#   'Rtotalter',
#   'SPH1Ptr',
#   'SPHGNtr',
#   'SPHINGStr',
#   'SPHS1Ptr',
#   'SQLtr',
#   'TSTSTERONEGLCtr',
#   'TSTSTERONEtr',
#   'TXA2tr',
#   'UDPGALt2r',
#   'UDPGLCAter',
#   'UDPGLCter',
#   'UDPXYLter',
#   'UMPtr',
#   'WHARACHDtr',
#   'WHTSTSTERONEtr',
#   'XOL24OHtr',
#   'XOL25OHtr',
#   'XOL7AONEtr',
#   'XOLDIOLONEt',
#   'XOLTRI24tc',
#   'XOLTRI25tc',
#   'XOLTRI27tc',
#   'r0002',
#   'r0826',
#   'r0840',
#   'r0841',
#   'r0842',
#   'r0845',
#   'r0886',
#   'r0908',
#   'r0909',
#   'r0931',
#   'r0936',
#   'r0960',
#   'r0968',
#   'r0970',
#   'r0983',
#   'r0989',
#   'r0994',
#   'r0995',
#   'r0998',
#   'r1000',
#   'r1002',
#   'r1011',
#   'r1013',
#   'r1018',
#   'r1024',
#   'r1051',
#   'r1159',
#   'r1303',
#   'r1318',
#   'r2473',
#   'r2505',
#   'r2506',
#   'r2507',
#   'r2508',
#   'r2509',
#   'r2510',
#   'r2511',
#   'r2512',
#   'r2513',
#   'r2514',
#   'r2515',
#   'r2519',
#   'r2521',
#   'r2537',
#   'r2538'},
#  'Beta-Alanine metabolism': {'13DAMPPOX',
#   'ABUTD',
#   'APAT2rm',
#   'ASP1DC',
#   'BAMPPALDOX',
#   'HMR_4078',
#   'HMR_4079',
#   'NBAHH_ir',
#   'SPMDOX',
#   'r0283'},
#  'Vitamin D metabolism': {'1a_24_25VITD2Hm',
#   '1a_25VITD2Hm',
#   '24_25VITD2Hm',
#   '24_25VITD3Hm',
#   '25HVITD3c',
#   '25VITD2Hm',
#   '25VITD3Hm',
#   'HMR_2114',
#   'PVD3',
#   'RE1303C',
#   'RE2240C',
#   'TS3',
#   'VD3'},
#  'Transport, extracellular': {'25HVITD3t',
#   'HMR_0436',
#   'NACSMCTte',
#   'r1726',
#   'CE2445t',
#   '3DHLCAt2',
#   'r1912',
#   'r2066',
#   '56DURAtd',
#   'r1967',
#   'CE4890te',
#   'r2088',
#   'TETPENT3t',
#   'r1498',
#   'HISARGSERt',
#   '5HTRPVESSEC',
#   '3H3MGLTte',
#   'ABUTt2r',
#   'PROPAT4te',
#   'r1850',
#   'r2278',
#   '5A2OPNTNte',
#   'r2261',
#   'r1824',
#   'ESTRONEte',
#   'r2133',
#   'C05769te',
#   'ARGLYSex',
#   'PROGLULYSt',
#   'URATEt',
#   'TYRLEUARGt',
#   'MK10t',
#   'r2067',
#   'PCHOLN2254_HSt1e',
#   'LNLCt',
#   'PCHOL2LINL_HSt1e',
#   'HPPPNte',
#   'FORGLUt',
#   'r2283',
#   'r1026',
#   'r1646',
#   'r1898',
#   'HMR_9614',
#   'r1760',
#   'UDCA3Sabc',
#   '25HVITD2t',
#   'r1979',
#   'LYSLYSLYSt',
#   'r1885',
#   'SERALANaEx',
#   'GLUSIDEtg',
#   'r2144',
#   'UREAt5',
#   'DHCHOLESTANATEt',
#   '2MCITt',
#   'r1687',
#   '3PGtr',
#   'r1716',
#   'BALABETAtc2',
#   'SPHMYLN18118_hs_SECt',
#   'HKt',
#   'ARGSUCte',
#   'r2165',
#   'FE2DMT1',
#   'ASNPHECYSt',
#   'PCHOLSTE_HSABCt',
#   'LEUTRPt',
#   'PCHOLN15_HSt1e',
#   'QULNtr',
#   'PHELYSALAt',
#   'WHTSTSTERONEte',
#   'r1559',
#   'r2190',
#   'LCA3Sabc',
#   'r1944',
#   'THMATPe',
#   'PIt7',
#   'WHDDCAte',
#   'r2292',
#   'FNA5MOXAMte',
#   'CE2006te',
#   'r2200',
#   'r1547',
#   'r1882',
#   'r1590',
#   'r1821',
#   'TRPGLULEUt',
#   'r2230',
#   'HKYNRtr',
#   'r2287',
#   'STCRNtr',
#   'CE6205te',
#   'HMR_9623',
#   'ACNGALACGLCGAL14ACGLCGALGLUSIDEte',
#   'r1914',
#   'r1957',
#   'PE203_HSt1e',
#   'SPHMYLN1824_hs_ATPt',
#   'r1938',
#   'r2322',
#   'r1801',
#   'GAMt1r',
#   'TTDCEAATP',
#   'THYOXt2',
#   'r1684',
#   'ALAGLYexR',
#   'AK2LGCHOLt1',
#   'CE2537ATP',
#   'r2128',
#   'THCHOLSTOICATP',
#   'r1630',
#   'TRPGLUGLYt',
#   'r1600',
#   'DST_ANTIGENt',
#   'HMR_9581',
#   'CYTDt4',
#   'r2215',
#   'HMR_0008',
#   'HMR_8670',
#   'r1862',
#   'r2171',
#   'MLTHFte2',
#   'THRASNNaEx',
#   'HISt4',
#   'r2036',
#   'r2022',
#   'CE7083t',
#   'SUBGLYte',
#   'LEUSERTRPt',
#   'FOLt2',
#   'CYSB0AT3tc',
#   'r1671',
#   'THRTHRARGt',
#   'r1634',
#   'r2026',
#   'r2004',
#   'r2494',
#   'r2130',
#   'MVLACte',
#   'MK9t',
#   'PEt',
#   'r1987',
#   'OLEICFATPtc',
#   'HCYSte',
#   'r2485',
#   'HMR_0244',
#   'GQ1Bte',
#   'SRTNt6_2_r',
#   '3DHCHOLabc',
#   'r1560',
#   'ACHVESSEC',
#   'C05463t1',
#   'GLULEUt',
#   'HISHISLYSt',
#   'GD1Cte',
#   'r1900',
#   'THRGLNGLUt',
#   'ARACHDt2',
#   'r1851',
#   'GD3tg',
#   'TCHOLAt',
#   'r1565',
#   '34HPPte',
#   'CBASPte',
#   'ASPHISCYSt',
#   'IDOURte',
#   'r1632',
#   'r2493',
#   'r1954',
#   'ASPLYSHISt',
#   'GLUTAROAT3t',
#   'SPHMYLN181221_hs_ATPt',
#   'PCHOLET_HSt1e',
#   'HMR_0359',
#   'THRTYRMETt',
#   'r1638',
#   'HMR_9647',
#   'r1531',
#   'MANt4',
#   'PHYQt',
#   'r2099',
#   'ACORNt',
#   'PCHOLN224_HSABCt',
#   'r1578',
#   'TRPGLYPHEt',
#   'FUC13GALACGLCGAL14ACGLCGALGLUSIDEte',
#   'r2131',
#   'r2227',
#   'HDCA6Gtr',
#   'TYRARGSERt',
#   'LEUKTRB4t',
#   'SFCYSe',
#   'ACLYStm',
#   'r1523',
#   'r1625',
#   'r2159',
#   'LEUKTRC4t',
#   'r1522',
#   'THYOXt',
#   'GLYGLYCNc',
#   'GABABGTtc',
#   'DHEASt',
#   'GLNTYRLEUt',
#   '5HPETATP',
#   'THRARGTYRt',
#   'r1999',
#   '15HPETATP',
#   'C05957td',
#   'PCHOLN19_HSABCt',
#   'r1549',
#   'ACACt2',
#   'GNCORE2te',
#   'r1723',
#   'DODECANACt',
#   'RETFAt1',
#   '3DHCDCHOLabc',
#   'C05770te',
#   '12HARACHDte',
#   'ARGCYSSERt',
#   'GALt2_2',
#   'TXB2t',
#   'ABUTt4_2_r',
#   'HMR_0392',
#   'ASNB0AT3tc',
#   'r2249',
#   'r1905',
#   'r2086',
#   'SUCCt4_2',
#   'PELINL_HSABCt',
#   'C05767te',
#   'r2030',
#   'SPHMYLN18115_hs_ATPt',
#   'r1997',
#   'LYSTRPARGt',
#   'r2263',
#   'PHACGLYt',
#   'CYSASPPHEt',
#   'ADNCNT3tc',
#   'r1613',
#   'ESTRADIOLt',
#   'r2302',
#   'r1858',
#   'GLCRt1',
#   'HMR_9639',
#   'r2051',
#   'TYRTRPPHEt',
#   'CE4877te',
#   'r1792',
#   'PRO1x',
#   'ESTRONESt2',
#   'r1806',
#   'CE5629t',
#   'ABT_Dt2',
#   'GLUt6',
#   'CA2t',
#   'PROTRPTHRt',
#   'BILGLCURte',
#   'TCA3St',
#   'PROPHEt',
#   'PROSTGI2t',
#   '12DHCHOLt',
#   'PHESERTRPt',
#   'r1883',
#   'HDD2CRNte',
#   'ETHAMPtr',
#   'r2123',
#   'SO4OXAtex2',
#   'RETFAt2',
#   'r2213',
#   'PHEPHEt',
#   'NRPPHRVESSEC',
#   'r2087',
#   'r1521',
#   '4AABUTNt',
#   'r1836',
#   'GLNTHRNaEx',
#   'r1752',
#   'r2295',
#   'HMR_9617',
#   'DCA3St',
#   'r2362',
#   'r1713',
#   'r2514e',
#   'r2052',
#   'r2310',
#   'r2199',
#   'GLYC2Pte',
#   'SPHMYLN18122_hs_SECt',
#   'GLUSIDEte',
#   'ABTti',
#   'UDCHOLt',
#   'PROHISt',
#   'GCHOLAte',
#   'r2149',
#   'HMR_0164',
#   'C04717td',
#   'C04805ATP',
#   'ACGALtr',
#   'CE2934t',
#   'HMR_9185',
#   'r2202',
#   'r1721',
#   'r1915',
#   'NRPPHRSFt',
#   'pac',
#   'LEUTYRTYRt',
#   'ILEGLNGLUt',
#   'HMR_9187',
#   'PROSTGH2t',
#   'SERLYSHISt',
#   'CE1556td',
#   'LTHSTRLABCt',
#   'r2041',
#   'ACGLUtd',
#   'HMR_9658',
#   'GLNB0AT3tc',
#   'LEUKTRE4t',
#   'CLOXAtex2',
#   'r1599',
#   'HMR_0321',
#   'CRNtuNa',
#   'CYSSNAT5tc',
#   '2HBt2',
#   'PCHOLN201_HSt1e',
#   '4NPHte',
#   'HISTRPHISt',
#   'CE5025t',
#   'HMR_8374',
#   'ACCOAgt',
#   'r1610',
#   'LTHSTRLt',
#   'r2001',
#   'SPHGNSte',
#   'HSPGt',
#   'THRGLYexR',
#   'r2238',
#   'OROT5Ptr',
#   'LNELDCt',
#   'XOLDIOLONEATP',
#   'GLYC_Rt',
#   'PCHOLN224_HSt1e',
#   'HYOCHOLt2',
#   'r2268',
#   'GD1B2te',
#   'r1913',
#   '12PPDRte',
#   'THBPTt',
#   'r2253',
#   'r2061',
#   'C05953t',
#   'ACt2r',
#   'URIt5le',
#   'COPROSTt',
#   'CE4890te2',
#   'XOL25OHte',
#   'SRTNtu',
#   'r2447',
#   '3DHCDCHOLt2',
#   'r2060',
#   'r2341',
#   'HC00900t2',
#   'LEUALAARGt',
#   'THMtrbc',
#   'HMR_8023',
#   'ACLEUte',
#   'GLNPROGLUt',
#   'THYMt',
#   'HMR_9648',
#   'r2044',
#   'HCO3_CLt',
#   'ACGALFUCGALACGALFUC12GAL14ACGLCGALGLUSIDEte',
#   'r1742',
#   'r2262',
#   'CYTDt',
#   'r2045',
#   'r1770',
#   'r2330',
#   'r1575',
#   'r0839',
#   'M02155tr',
#   'r2495',
#   'BTNt4i',
#   'r1755',
#   'r1813',
#   'r1690',
#   'r1861',
#   'r1144',
#   'r2323',
#   'PCt',
#   'ARACHDFATPtc',
#   'ADPOHt',
#   'CHSTEROLSte',
#   '5CYSDOPAt',
#   'DEBRISOQUINEt',
#   'r2183',
#   'ALAGLYLYSt',
#   'ALA-DTDe',
#   'PGLYCt',
#   '3MGLUTRte',
#   'ASNGLNNaEx',
#   'r2304',
#   'HISARGCYSt',
#   'UCHOLt',
#   'PYDXNtr',
#   'O2t',
#   'HMR_9662',
#   'HMR_7906',
#   'XOLEST183te',
#   'SPHMYLN18116_hs_ATPt',
#   'TCDCA3St',
#   'C03990ATP',
#   'PCHOLEIC_HSt1e',
#   'r1985',
#   'r2008',
#   'r1627',
#   'ILEATB0tc',
#   'CYSALANaEx',
#   'r1553',
#   'r2089',
#   'r2489',
#   'r2352',
#   'r1835',
#   'PE226_HSt1e',
#   'HMR_6359',
#   'r1725',
#   'DLNLCGt',
#   'r2172',
#   'r2356',
#   'r2224',
#   'ASPGLUPROt',
#   'r2285',
#   'HISPROLYSt',
#   'LPAMt',
#   'r1662',
#   '3OHGLUTACte',
#   'HTAXOLte',
#   'ESTRONEGLCt',
#   'VALPROTRPt',
#   'r1669',
#   'ACALDt',
#   'CE6031t',
#   'LYSCYSHISt',
#   'r1029',
#   'TYRVALMETt',
#   '2HCO3_NAt',
#   'SERB0AT3tc',
#   'r1759',
#   'RIBFLVte',
#   'TRPASPASPt',
#   'CE5026t',
#   'CDCA3Gte',
#   'PCHOLN204_HSt1e',
#   'C14826ATP',
#   'INSt4',
#   'ASPVALASNt',
#   'r1818',
#   'PROSTGE2t2',
#   'ANDRSTRNGLCte',
#   'PE161_HSABCt',
#   'TCHOLAt2',
#   'TRPTYRGLNt',
#   'GALAMtr',
#   '3MOX4HOXMte',
#   'PHETYRLYSt',
#   '3HCO3_NAt',
#   'GLYVALHISt',
#   'TCDCA3Sabc',
#   'C03681te',
#   'C14826td',
#   'ILEASPt',
#   'r1519',
#   'HMR_0367',
#   'r2306',
#   'r1983',
#   'KHte',
#   'PE2LINL_HSt1e',
#   'COt',
#   'r1857',
#   'r1569',
#   'r2222',
#   'r2239',
#   'PCHOLPALME-HSt1e',
#   'CGLYt3_2_',
#   'CSPG_Ct',
#   '7DHCHSTEROLtd',
#   'PROCYSt',
#   'PCHOL2STE_HSt1e',
#   'r2226',
#   '3OHSUBACte',
#   'XOLTRI25te',
#   'HMR_9657',
#   'r1767',
#   'HXCOAte',
#   'r2305',
#   'r1852',
#   'CLHCO3tex2',
#   'r2210',
#   'ORNtiDF',
#   'TRIODTHYt2',
#   'r0942',
#   'GLUTHRLYSt',
#   'MK7t',
#   'r2250',
#   'FOLABCCte',
#   '34DHPHELAT1tc',
#   'r1655',
#   'r2291',
#   'HISLYSILEt',
#   '3DHDCAt',
#   'XTSNtr',
#   'ARGPROTHRt',
#   'CHOLATEt',
#   'r1991',
#   'L2AADPtr',
#   'METARGLEUt',
#   'r1711',
#   'MLTHFte',
#   'FUCFUCGALACGLCGALGLUSIDEte',
#   'HMR_0300',
#   'r2046',
#   'r1707',
#   'r1790',
#   'r2256',
#   'TRPGLYASPt',
#   'r2015',
#   'HC00900t1',
#   'UCHOLt2',
#   'GLYt2r',
#   'SERGLNexR',
#   'r2050',
#   'HPACtr',
#   'DMGLYtr',
#   'PHEB0AT3tc',
#   'r2062',
#   'r1661',
#   'CLI2tex',
#   'ESTRADIOLGLCt2',
#   'PCHOLN15_HSABCt',
#   'r2113',
#   '17AHPRGSTRNte',
#   'CITt4_2',
#   'TYMSFt',
#   'ALAGLNNaEx',
#   'EICOSTETt',
#   'HC02220te',
#   'CHOLPtr',
#   'SPHMYLN18117_hs_ATPt',
#   'r1597',
#   'ALAGLNexR',
#   'TRPB0AT3tc',
#   'GLYLYSPHEt',
#   'GCHOLAt',
#   'HCA6Gte',
#   'ALAASNNaEx',
#   'r1969',
#   'r2057',
#   'GUDCA3Sabc',
#   'THMTPt',
#   'PCHOLN203_HSABCt',
#   'GLUASNLEUt',
#   'SERDGLYexR',
#   'FOLOATPtc',
#   'r1939',
#   'CE4843t',
#   'CRTSLt',
#   'AHANDROSTANGLCte',
#   'XOLEST2te',
#   'HMR_9663',
#   'NAt',
#   'r2332',
#   'r1617',
#   'GLYt7_311_r',
#   'r1576',
#   'r1803',
#   'SPHMYLN18114_hs_SECt',
#   'XYLt',
#   'r1675',
#   'r1816',
#   'r2297',
#   '18HARACHDte',
#   'r2294',
#   'C14771ATP',
#   '7KILTCHOLATP',
#   'r2093',
#   'HOMt4',
#   'LKYNRtr',
#   '3ITYR_Lte',
#   'r2321',
#   'HC00460te',
#   'HMR_6989',
#   'r1754',
#   'PSHSABCtc',
#   'r2053',
#   'ALAHISALAt',
#   'r2483',
#   'C14768ATP',
#   'r2308',
#   'TETDECA511ACtd',
#   'METGLNTYRt',
#   'r2203',
#   'r2211',
#   'METTRPPHEt',
#   'r2366',
#   'ILEB0AT3tc',
#   'ALAtN1',
#   'TRPTHRILEt',
#   'CRNATBtc',
#   'ARGARGt',
#   'r2276',
#   'STCRNte',
#   'r1908',
#   'CE1273t1',
#   'PEPALM_HSASBCt',
#   'PPBNGte',
#   'r1776',
#   'r2002',
#   'BILIRUBt2',
#   'r1589',
#   'RTOTALFATPc',
#   'FATP6t',
#   'TRPPROGLYt',
#   'THRGLNNaEx',
#   'r2037',
#   'SERDGLNexR',
#   'TRPPROLEUt',
#   'r2273',
#   'r2005',
#   'PHETYRt',
#   'C04717ATP',
#   'r1923',
#   'r0871',
#   'r1904',
#   'UDPGLCURtr',
#   'r2331',
#   'r1566',
#   'CYSAMOe',
#   'ORN_Dte',
#   'C05770te4',
#   'r1871',
#   'GLYC2P3Pc',
#   'TAGt',
#   'r1780',
#   'HMR_0428',
#   'BTNt3i',
#   'MEOHt2',
#   'r1736',
#   'r2358',
#   'THMt3',
#   'SRTNENT4tc',
#   'ASNMETPROt',
#   'MANt1r',
#   'r2019',
#   'ARGARGLYSt',
#   'LYSt4',
#   'HC00319t1',
#   'r2018',
#   'PCHOLN1836_HSt1e',
#   'BGLYte',
#   'ILETRPTYRt',
#   'r1615',
#   'H2O2t',
#   '7DHCHOLabc',
#   'DHAAt1r',
#   'ASNTYRTHRt',
#   'HMR_6534',
#   'CE0737te',
#   'r2240',
#   'r1744',
#   'r2491',
#   'CYSGLNNaEx',
#   'SUBEACtd',
#   'r2157',
#   'r2370',
#   'ALAARGGLYt',
#   'HMR_6365',
#   'r2147',
#   'r1691',
#   'r2234',
#   'r2021',
#   'HMR_0176',
#   'HMR_0317',
#   'HCOUMARINte',
#   'r1911',
#   'ELAIDt',
#   'GLYB0AT3tc',
#   'CYSATB0tc',
#   'HMR_0203',
#   'r1518',
#   'TAGAT_Dt',
#   'AQCOBALt',
#   'r1544',
#   'HMR_0770',
#   'DCA3Gtr',
#   'r1808',
#   'SPHMYLNte',
#   'r1637',
#   'r1880',
#   '3MHISt3',
#   'IMPtr',
#   'r1567',
#   'RIBt',
#   'ACNACNGAL14ACGLCGALGLUSIDEte',
#   'r1738',
#   'GLYt7_211_r',
#   'r1609',
#   'ASNTYRPHEt',
#   'r1822',
#   'r2073',
#   'r2320',
#   'HMR_1897',
#   'TRIODTHYSUFt',
#   '3DHDCAt2',
#   'PEFLIP',
#   'r1722',
#   'ASPMETASPt',
#   'HMR_0261',
#   'r2307',
#   'HMR_0017',
#   'VITD3t',
#   'PHEASPt',
#   'ARGGLUPROt',
#   'r0881',
#   'HMR_0191',
#   'KCC2t',
#   '5MTAte',
#   'COPROSTt2',
#   'GLUTHRt',
#   'ILEPROLYSt',
#   'r1749',
#   'r1764',
#   'XYLULte',
#   'r0944',
#   'HCA24Gte',
#   'HMR_0270',
#   'PTCRTD',
#   'CO2t',
#   'r2056',
#   'FUMtr',
#   'PHELEUASPt',
#   'FMNALKPle',
#   'GLYHISASNt',
#   'HMR_9602',
#   'METyLATthc',
#   'HMR_9612',
#   'LEULEUPEPT1tc',
#   'ARGPHEARGt',
#   'HDCA6Gte',
#   'CYSTHRNaEx',
#   'SBTle',
#   'PAFt1',
#   'r2274',
#   'r2228',
#   'GUDACtr2',
#   'PCHOL2STE_HSABCt',
#   'BHBt',
#   '56DTHMtd',
#   'EANDRSTRNte',
#   'r2176',
#   'EBASTINEOHte',
#   'r1814',
#   'CYSTALArBATtc',
#   'ARGtD',
#   'CE2209te',
#   'r1728',
#   'C14768td',
#   'CE1243ATP',
#   'r2194',
#   'r1864',
#   'r1876',
#   'r1929',
#   'r2184',
#   'C06439t',
#   'TRPMETARGt',
#   'GQ1BALPHAte',
#   'HMR_0469',
#   'MELATNte',
#   'STRDNCt',
#   'YVITEt',
#   'C10164te',
#   'GLUTARte',
#   'r1495',
#   'CE1243UPKt',
#   'KCCt',
#   '3MOXTYRESSte',
#   'ACNAMtr',
#   'HMR_0391',
#   'THRASNTYRt',
#   'AHANDROSTANte',
#   'TRPt4',
#   'PPP9ABCte',
#   'r2013',
#   'PCHOL2LINL_HSABCt',
#   'r1909',
#   'METGLYARGt',
#   'FUCGAL14ACGLCGALGLUSIDEte',
#   'r0963',
#   'r1830',
#   'r1516',
#   'PCHOL2OLE_HSABCt',
#   'HMR_0183',
#   'r1500',
#   'r1961',
#   'r1964',
#   '4HPRO_LTte',
#   'BILIVERDt',
#   'r1682',
#   'SERCYSARGt',
#   'D_LACt2',
#   'r2235',
#   '3MTPte',
#   'C14769td2',
#   'r2367',
#   'r1546',
#   'C11695td',
#   'PCHOLN205_HSABCt',
#   'ALALYSTHRt',
#   'CRMPte',
#   'HMR_9603',
#   'HMR_0291',
#   'TXA2te',
#   'ACTHRte',
#   'HMR_0278',
#   'TRIODTHYt',
#   'r2314',
#   'THRILEARGt',
#   'CHOLtu',
#   'r2365',
#   'PGLYCABCte',
#   'DCMPtr',
#   'HMR_8090',
#   'ICDCHOLt2',
#   'INSTt4',
#   'GNCORE1te',
#   'HMR_6364',
#   '4HDEBRISOQUINEte',
#   'r1796',
#   'EBASTINEte',
#   'PRGSTRNt',
#   'r1666',
#   'FUCGALGBSIDEte',
#   'ASNASNARGt',
#   'CYSSERNaEx',
#   'NAHCO3_HCLt',
#   'HCA6Gtr',
#   'HISyLATthc',
#   '3DHLCAt',
#   'XOLTRI27te',
#   'r1959',
#   'DCSPTN1t',
#   'SPHMYLN181201_hs_SECt',
#   'GLNHISLYSt',
#   '34HPLte',
#   'GLYC_St',
#   'CE2176t',
#   'r1563',
#   'r1829',
#   'PMTCRNte',
#   '2OBUTt',
#   'LYSTYRILEt',
#   '13DAMPPte',
#   'r1960',
#   'GLNLYSLYSt',
#   'r1788',
#   'PROSTGE1t',
#   'GUAt',
#   'r2070',
#   'ILESERARGt',
#   'r1652',
#   'r2167',
#   'r2195',
#   'CE4843td',
#   'TCHOLAte',
#   'r1756',
#   'FUCGALFUCGALACGLCGALGLUSIDEte',
#   'FOLOAT2tc',
#   'r2369',
#   '3UIBtd',
#   'r1717',
#   'ADNt',
#   'TYRPHETYRt',
#   'GLYALDtr',
#   'r1930',
#   '3HMPtd',
#   'r1492',
#   'r2335',
#   'GLUMETHISt',
#   'FUC14GALACGLCGALGLUSIDEte',
#   'ICDCHOLabc',
#   'r2049',
#   'r2035',
#   'CSPG_Et',
#   'FRUt1r',
#   'HDCEAtr',
#   'ALAARGCYSt',
#   'r2313',
#   'THMMPtrbc',
#   'PCHOLN203_HSt1e',
#   'r1896',
#   'r1774',
#   'SPRMt2r',
#   'r2102',
#   'PROGLyt',
#   'CALAtr',
#   'THMDt4',
#   'r2038',
#   'PHEt4',
#   'r2082',
#   'ASNCYSNaEx',
#   'CYSTGLUex',
#   '35DIODTYRte',
#   'ANDRSTRNte',
#   'r2317',
#   'PNTOt5',
#   'r1762',
#   'DCA24Gtr',
#   'AND19ONEt',
#   'GT1Ate',
#   'r1614',
#   'HMR_9638',
#   'HMR_9610',
#   'SPHMYLN1825_hs_SECt',
#   'LEULEUt',
#   'PRGNLONESte',
#   'SPHMYLN181161_hs_ATPt',
#   'r1686',
#   'ASCBt',
#   'r1693',
#   'CYSGLUexR',
#   'ARGN1ASPMDte',
#   'DMHPTCRNte',
#   'ACLYSt',
#   'r1043',
#   'r1530',
#   'r2081',
#   'r2017',
#   'GLUSIDEtl',
#   'URCANt',
#   'r1866',
#   'ARGTYRVALt',
#   'PPIOGLYte',
#   'FATP9t',
#   'r2312',
#   '34DHPHEt',
#   'r1527',
#   'HISGLUt',
#   'HMR_9720',
#   'HMR_0435',
#   'r1906',
#   'HMR_0194',
#   'C09642te',
#   'THYMDt1',
#   'GLUILELYSt',
#   'HMR_9176',
#   'r2334',
#   'r1778',
#   'r2108',
#   'C05301te',
#   'r2208',
#   'SERGLYexR',
#   'LEUKTRB4WOHtr',
#   'PCHOLHEP_HSt1e',
#   'r2042',
#   'ARGGLYGLYt',
#   'TYRTHRt',
#   'OCDCEAtr',
#   'AICARte',
#   'r1890',
#   'TTDCRNNAt',
#   'ADRNLPVESSEC',
#   'HC02020te',
#   'GSNt2r',
#   'GLYVESSEC',
#   'ARGVALTRPt',
#   'HMR_0415',
#   'r2117',
#   'GLUARGLEUt',
#   'r1701',
#   'HMR_9642',
#   'r1907',
#   'r2266',
#   'r2064',
#   'r2325',
#   'LYSVALPHEt',
#   'r1631',
#   'HISLYSVALt',
#   'r1874',
#   'r2094',
#   'RTOTAL2t',
#   'r1768',
#   'HISyLATtc',
#   'r2118',
#   'GALSGLT1le',
#   'ILEtec',
#   'DOPASFt',
#   'r1503',
#   'NWHARGtd',
#   'r2054',
#   'ASPDTDe',
#   'PROSTGE2t3',
#   'r1785',
#   ...},
#  'Lysine metabolism': {'1PPDCRp',
#   '2AMADPTm',
#   '2OXOADOXm',
#   '3HGLUTCOAm',
#   '3OHGLUTACm',
#   'AASAD3m',
#   'AATAi',
#   'ACLYSHYc',
#   'ADPOHc',
#   'BBHOX',
#   'GHMT3',
#   'GLUTACOAm',
#   'GLUTCONm',
#   'HMCRNc',
#   'HMR_6975',
#   'HMR_6976',
#   'HMR_6977',
#   'HMR_6978',
#   'LPCOXp',
#   'LYSACm',
#   'LYSOXp',
#   'PPD2CSPp',
#   'RE1254C',
#   'SACCD3m',
#   'SACCD4m',
#   'TD2GLTRCOAm',
#   'TMABADH',
#   'TMLYSOX',
#   'r0450',
#   'r0525',
#   'r0594'},
#  'Glycine, serine, alanine, and threonine metabolism': {'2AMACHYD',
#   'AACTOOR',
#   'ACHOMm',
#   'ALASm',
#   'AOBUTDsm',
#   'BETALDHxm',
#   'BHMT',
#   'CHOLD2m',
#   'DMGDHm',
#   'GCC2am',
#   'GCC2bim',
#   'GCC2cm',
#   'GCCam',
#   'GCCbim',
#   'GCCcm',
#   'GHMT2r',
#   'GHMT2rm',
#   'GLYACm',
#   'GLYATm',
#   'GLYOp',
#   'GNMT',
#   'HEXGLYc',
#   'HMR_4284',
#   'HMR_4696',
#   'HMR_4700',
#   'HMR_7703',
#   'HMR_9718',
#   'OBDHc',
#   'PGCD',
#   'PPIOGLYc',
#   'PSERT',
#   'PSP_L',
#   'RE2111M',
#   'RE2427M',
#   'RE2428M',
#   'RE2429M',
#   'SARCOXp',
#   'SERHL',
#   'SPTix',
#   'SUBGLYc',
#   'THRACm',
#   'THRD_L',
#   'THRS',
#   'TIGGLYc',
#   'r0160',
#   'r0552',
#   'r0553'},
#  'Methionine and cysteine metabolism': {'2AMACSULT',
#   '3SALATAi',
#   '3SALATAim',
#   '3SPYRSP',
#   '3SPYRSPm',
#   'AHC',
#   'CYSGLTH',
#   'CYSTA',
#   'CYSTGL',
#   'CYSTS',
#   'DKMPPD2',
#   'DKMPPD3',
#   'HMR_3915',
#   'HMR_3996',
#   'HMR_4701',
#   'HMR_5387',
#   'HMR_5389',
#   'HMR_5390',
#   'HMR_6515',
#   'HYPTROXe',
#   'LCYSTAT',
#   'LHCYSTIN',
#   'MCLACCYSR',
#   'MCLOR',
#   'MCPST',
#   'METAT',
#   'METDECARc',
#   'METS',
#   'METTRANSc',
#   'RE1933C',
#   'RE2030M',
#   'RE2223M',
#   'RE2640C',
#   'RE3009C',
#   'SFCYSc',
#   'SLDt',
#   'SLDx',
#   'SULFOX',
#   'UNK3r',
#   'r0027',
#   'r0060',
#   'r0142',
#   'r0193',
#   'r0210',
#   'r0281',
#   'r0595'},
#  'Pyrimidine catabolism': {'2DR1PP',
#   'BUP2',
#   'CSND',
#   'CYTD',
#   'D3AIBTm',
#   'DCMPDA',
#   'DCYTD',
#   'DHPM1',
#   'DHPM2',
#   'DURAD',
#   'DURAD2',
#   'DUTPDP',
#   'NTD1',
#   'NTD2',
#   'NTD2l',
#   'NTD3',
#   'NTD4',
#   'NTD4l',
#   'NTD5',
#   'NTD5l',
#   'PYNP2r',
#   'TMDPP',
#   'UPPN',
#   'r0139',
#   'r0149',
#   'r0166',
#   'r0236',
#   'r0330',
#   'r0331',
#   'r0377',
#   'r0410',
#   'r0483',
#   'r0494',
#   'r0497'},
#  'Propanoate metabolism': {'2HBO',
#   '2M3HVACc',
#   '2M3OVACm',
#   '2M3OVCOAm',
#   'AACOAT',
#   'ACCOAL',
#   'ACCOALm',
#   'ACS2',
#   'ADCim',
#   'HMR_9803',
#   'HMR_9804',
#   'MCITS',
#   'MMSAD3m',
#   'r0365',
#   'r1154'},
#  'Tryptophan metabolism': {'2OXOADPTm',
#   '3HAO',
#   '3HKYNAKGAT',
#   '5HLTDL',
#   '5HOXINDACTO2OX',
#   '5HOXINOXDA',
#   'ACACT1r',
#   'ACACT1rm',
#   'ACSRTNMT',
#   'ALDD20x',
#   'ALDD20xm',
#   'AMCOXO',
#   'ECOAH1m',
#   'ECOAH1x',
#   'FKYNH',
#   'GLUTCOADHm',
#   'HACD1m',
#   'HACD1x',
#   'HKYNH',
#   'KYN',
#   'KYN3OX',
#   'KYNAKGAT',
#   'KYNATESYN',
#   'LFORKYNHYD',
#   'LTDCL',
#   'MELATN23DOX',
#   'MELATNOX',
#   'PCLAD',
#   'QUILSYN',
#   'RE0549C',
#   'RE1233C',
#   'RE1711C',
#   'RE2349C',
#   'RE2426C',
#   'RE2439C',
#   'RE2562C',
#   'SRTNACT',
#   'TRPHYDRO2',
#   'TRPO2',
#   'TRYPTAOX',
#   'r0239',
#   'r0541',
#   'r0645',
#   'r0647',
#   'r0758'},
#  'Tyrosine metabolism': {'34DHOXPEGOX',
#   '34DHPEAR',
#   '34DHPHAMT',
#   '34DHPLACOX',
#   '34DHPLACOX_NADP_',
#   '34DHXMANDACOX',
#   '34DHXMANDACOX_NADP_',
#   '34HPPOR',
#   '3HLYTCL',
#   '3M4HDXPAC',
#   '3MOX4HOXPGALDOX',
#   '3MOX4HOXPGALDOX_NADP_',
#   '3MOXTYROX',
#   '41R1H2MAE12BOOX',
#   '41R2A1H12BOOX',
#   '42A12BOOX',
#   '4HOXPACDOX_NADP_',
#   'ACTYRm',
#   'CYSGLYPTASEe_1',
#   'DACGST',
#   'DACT',
#   'DCT',
#   'DOPABMO',
#   'DOPACCL',
#   'DOPACHRMDC',
#   'DOPACHRMISO',
#   'DOPAMT',
#   'DOPAOQCYS',
#   'DOPAOQNOX',
#   'DOPAQNISO1',
#   'DOPASULT',
#   'DOPASULT4',
#   'DOPAc',
#   'FALDH',
#   'FUMAC',
#   'GGTe_1',
#   'H2O2syn',
#   'HGNTOR',
#   'HMR_4702',
#   'IDHPOXOX2b',
#   'IDHPOXOX3',
#   'IDHPOXOX4',
#   'IDHPOXOXb',
#   'LACROX',
#   'MACACI',
#   'MAOLNOR',
#   'MAOX',
#   'NACVANALAm',
#   'NADPQNOXR',
#   'NADQNOXR',
#   'NORANMT',
#   'NRPPHRSULT',
#   'RE0908C',
#   'RE0912C',
#   'RE0916C',
#   'RE0918C',
#   'RE1915C',
#   'RE1916C',
#   'RE1918C',
#   'RE1919C',
#   'RE1921C',
#   'RE1923C',
#   'RE1925C',
#   'RE2122C',
#   'RE2130C',
#   'RE2296C',
#   'RE3095C',
#   'RE3198C',
#   'RE3201C',
#   'SALMCOM',
#   'SALMCOM2',
#   'SFGTH',
#   'SUCACETATALTc',
#   'SUCACETATc',
#   'SUCACETOc',
#   'THYPX',
#   'TRIODTHYSULT',
#   'TYMSULT',
#   'TYMc',
#   'TYR3MO2',
#   'TYRASE',
#   'TYRCBOX',
#   'TYRDHINDOX',
#   'TYRDOPO',
#   'TYRDOPO3',
#   'TYRDOPOX',
#   'TYROXDAc',
#   'TYRTA',
#   'TYRTAm',
#   'UDPG3DOPA',
#   'UDPG4DOPA',
#   'VANILLACc',
#   'VANILPYRc'},
#  'Ubiquinone synthesis': {'34HPLFM',
#   '3DPHBH1',
#   '3DPHBH2',
#   '4HBZCOAFm',
#   '4HBZFm',
#   'COQ3m',
#   'COQ5m',
#   'COQ6m',
#   'COQ7m',
#   'COUCOAFm',
#   'DHDPBMTm',
#   'DPHMBDCm',
#   'HBZOPT10m',
#   'HMR_6907',
#   'HMR_6908',
#   'HMR_6909',
#   'HMR_6910',
#   'T4HCINNMFM'},
#  'Transport, nuclear': {'1a25DHVITD3TRn',
#   '35CGMPtn',
#   '4ABUTtcn',
#   'ACCOAtn',
#   'ACHtn',
#   'ACNAMtn',
#   'ATPtn',
#   'BIOCYTtn',
#   'BTNtn',
#   'CERT1tn',
#   'CHOLPtn',
#   'CHOLtn',
#   'CMPACNAtn',
#   'COAtn',
#   'CTPtn',
#   'CYTDtn',
#   'DATPtn',
#   'DCTPtn',
#   'DGTPtn',
#   'DIDPtn',
#   'DITPtn',
#   'DNADtn',
#   'DTDPtn',
#   'DTTPtn',
#   'DUDPtn',
#   'DUMPtn',
#   'DURItn',
#   'GALSIDEtn',
#   'GD1Atn',
#   'GDA1tn',
#   'GMPtn',
#   'H2O2tn',
#   'H2Otn',
#   'HMR_0984',
#   'HMR_1095',
#   'HMR_2585',
#   'HMR_6617',
#   'HMR_6619',
#   'HMR_7712',
#   'HMR_8476',
#   'HMR_9674',
#   'HRETNtn',
#   'IDPtn',
#   'ITPtn',
#   'LYStn',
#   'MI14Ptn',
#   'MI1P_Dtn',
#   'MINOHPtn',
#   'NADtn',
#   'NH4tn',
#   'NICRNTtn',
#   'NMNtn',
#   'O2Stn',
#   'O2tn',
#   'ORETNtn',
#   'ORETNtn2',
#   'PAIL45P_HStn',
#   'PAIL4P_HStn',
#   'PAIL_HStn',
#   'PA_HStn',
#   'PCHOL_HStn',
#   'PItn',
#   'PPMI12346Ptn',
#   'RAtn',
#   'RAtn3',
#   'SPHGNtn',
#   'SPHINGStn',
#   'UDPGALt2n',
#   'UTPtn',
#   'Uritn',
#   'r1459'},
#  'Valine, leucine, and isoleucine metabolism': {'2H3MVc',
#   '2HIVc',
#   '2M3HBUc',
#   '3AIBTm',
#   '3H3MGLTc',
#   '3HBCOAHLm',
#   '3HIVAcm',
#   '3MGLUTACc',
#   '3MGLUTRc',
#   'ACACT10m',
#   'ACILEm',
#   'ACLEUm',
#   'ACOAD10m',
#   'ACOAD8m',
#   'ACOAD9m',
#   'ECOAH12m',
#   'ECOAH9m',
#   'HACD9m',
#   'HIBDm',
#   'ILETA',
#   'ILETAm',
#   'LEUTA',
#   'LEUTAm',
#   'MCCCrm',
#   'MGCHrm',
#   'MMCDm',
#   'MMEm',
#   'MMMm',
#   'MMSAD1m',
#   'MMTSADm',
#   'OCOAT1m',
#   'OIVD1m',
#   'OIVD2m',
#   'OIVD3m',
#   'PHACGLYc',
#   'RE1266C',
#   'VALTA',
#   'VALTAm',
#   'r0560',
#   'r0561',
#   'r0571',
#   'r0603',
#   'r0643',
#   'r0655',
#   'r0669'},
#  'Sphingolipid metabolism': {'3DSPHR',
#   'A4GALTc',
#   'A4GALTg',
#   'ACER11r',
#   'ACER22g',
#   'ACER23g',
#   'ACER31r',
#   'ARSA',
#   'ASAH1',
#   'B3GALT3g',
#   'B3GALT41g',
#   'B3GALT42g',
#   'B3GALT43g',
#   'B3GALT44g',
#   'B3GALT5g',
#   'B3GNT31g',
#   'B3GNT32g',
#   'B3GNT33g',
#   'B3GNT34g',
#   'B3GNT35g',
#   'B3GNT36g',
#   'B3GNT37g',
#   'B3GNT39g',
#   'BGAL1e',
#   'BGAL1l',
#   'BGAL2l',
#   'BGAL3l',
#   'CERK',
#   'CRMte',
#   'DES21',
#   'DHCRD1',
#   'DHCRD2',
#   'DSAT',
#   'FUT11g',
#   'GAL3ST11',
#   'GAL3ST12',
#   'GALC',
#   'GALGT1',
#   'GALGT2',
#   'GALGT3',
#   'GALGT4',
#   'GAO1',
#   'GAO1g',
#   'GAO2',
#   'GAO2g',
#   'GBA',
#   'GBA2e',
#   'GBAl',
#   'GBGT1',
#   'GLA2l',
#   'GLAl',
#   'GLB1',
#   'HEXA1l',
#   'HEXA2l',
#   'HEXA3e',
#   'HEXAHBl',
#   'HMR_0750',
#   'HMR_0753',
#   'HMR_0758',
#   'HMR_0761',
#   'HMR_0763',
#   'HMR_0765',
#   'HMR_0767',
#   'HMR_0775',
#   'HMR_0783',
#   'HMR_0795',
#   'NAGAlby',
#   'NAGAly',
#   'NEU11l',
#   'NEU21',
#   'NEU22',
#   'NEU23',
#   'NEU24',
#   'NEU25',
#   'NEU310e',
#   'NEU31e',
#   'NEU32e',
#   'NEU33e',
#   'NEU34e',
#   'NEU35e',
#   'NEU36e',
#   'NEU37e',
#   'NEU38n',
#   'NEU39e',
#   'PHSGPL11c',
#   'RE2675C',
#   'SBPP1er',
#   'SBPP3er',
#   'SERPT',
#   'SGPL12r',
#   'SIAT4Bg',
#   'SIAT9g',
#   'SLCBK1',
#   'SMPD3g',
#   'SMPD3l',
#   'SMPD4',
#   'SMS',
#   'SMS1S2',
#   'SMS21e',
#   'SMSn',
#   'SPHK11',
#   'SPHK21c',
#   'SPHK21n',
#   'SPHK22n',
#   'SPHMDAc',
#   'SPMD3n',
#   'ST3GAL21g',
#   'ST3GAL22g',
#   'ST3GAL23g',
#   'ST6GALNAC21',
#   'ST6GALNAC22',
#   'ST6GALNAC23',
#   'ST6GALNAC24',
#   'ST6GALNAC25',
#   'ST6GALNAC26',
#   'ST6GALNAC27',
#   'ST6GALNAC28',
#   'ST6GALNAC31',
#   'ST6GALNAC62',
#   'ST8SIA11',
#   'ST8SIA12',
#   'ST8SIA13e',
#   'ST8SIA51g',
#   'ST8SIA52g',
#   'ST8SIA53g',
#   'ST8SIA54g',
#   'ST8SIA55g',
#   'UGCG',
#   'r0786',
#   'r0787',
#   'r0788',
#   'r0789',
#   'r1457'},
#  'Butanoate metabolism': {'3HBCDm', 'ACOAD1fm', 'BDHm'},
#  'Taurine and hypotaurine metabolism': {'3SALACBOXL',
#   '3SALAOX',
#   'CYSO',
#   'HYPTROX',
#   'LCYSTCBOXL',
#   'TAURtcx',
#   'r0381',
#   'r0539'},
#  'Arginine and proline metabolism': {'4HGLSDm',
#   'ADMDC',
#   'AGMTm',
#   'APRTO2',
#   'ARGDCm',
#   'DARGOp',
#   'DDPGAm',
#   'DKMPPD',
#   'DORNOp',
#   'EHGLAT2m',
#   'EHGLATm',
#   'G5SADrm',
#   'HMR_3832',
#   'HMR_4422',
#   'HMR_4776',
#   'HMR_4777',
#   'HMR_4782',
#   'HMR_4783',
#   'MDRPD',
#   'MTAP',
#   'MTRI',
#   'NABTNO',
#   'NOS1',
#   'NOS2',
#   'P5CR',
#   'P5CRm',
#   'P5CRxm',
#   'PHCDm',
#   'PHCHGSm',
#   'PROD2',
#   'PROD2m',
#   'PTRCAT1',
#   'PTRCOX1',
#   'r0024',
#   'r0145',
#   'r0615',
#   'r0616',
#   'r0617',
#   'r0618',
#   'r0686'},
#  'Cytochrome metabolism': {'4NPHSULT',
#   'FAH1',
#   'FAH2',
#   'FAH3',
#   'P4502A6',
#   'P4502C18',
#   'P4502C19',
#   'P4502C8',
#   'P4502C9',
#   'P4502D6',
#   'P4502E1',
#   'P4502F1',
#   'P4503A4',
#   'P4503A5',
#   'P4504F123r'},
#  'Steroid metabolism': {'21HPRGNLONE',
#   '5ADTSTSTERONESULT',
#   'AKR1C1',
#   'AND19ONEc',
#   'CHSTEROLSULT',
#   'DHEASULT',
#   'ESTR2r',
#   'ESTRr',
#   'ESTSULT',
#   'HMR_1644',
#   'HMR_1651',
#   'HMR_1927',
#   'HMR_1928',
#   'HMR_1929',
#   'HMR_1940',
#   'HMR_1941',
#   'HMR_1948',
#   'HMR_1949',
#   'HMR_1979',
#   'HMR_1980',
#   'HMR_1981',
#   'HMR_1988',
#   'HMR_1989',
#   'HMR_1990',
#   'HMR_1991',
#   'HMR_1992',
#   'HMR_1993',
#   'HMR_1996',
#   'HMR_2002',
#   'HMR_2007',
#   'HMR_2010',
#   'HMR_2011',
#   'HMR_2041',
#   'HSD11B1r',
#   'HSD11B2r',
#   'HSD17B1',
#   'HSD17B2r',
#   'HSD17B3r',
#   'HSD17B7r',
#   'HSD17B8r',
#   'HSD17B9r',
#   'HSD3A1r',
#   'HSD3A2r',
#   'HSD3B11',
#   'HSD3B11r',
#   'HSD3B12r',
#   'HSD3B13',
#   'HSD3B13r',
#   'HSD3B2r',
#   'HSD3B3r',
#   'P45011A1m',
#   'P45011B11m',
#   'P45011B12m',
#   'P45011B21m',
#   'P45017A1r',
#   'P45017A2r',
#   'P45017A3r',
#   'P45017A4r',
#   'P45019A1r',
#   'P45019A2r',
#   'P4501B1r',
#   'P45021A1r',
#   'P45021A2r',
#   'P4503A43r',
#   'P4503A7r',
#   'PRGNLONESULT',
#   'RE1096C',
#   'RE1099C',
#   'RE1100C',
#   'RE1100R',
#   'RE1134C',
#   'RE1135C',
#   'RE1135R',
#   'RE2766C',
#   'SR5AR2r',
#   'SR5ARr',
#   'STS1',
#   'STS1r',
#   'STS2',
#   'STS2r',
#   'TSTSTERONESULT',
#   'UGT1A10r',
#   'UGT1A1r',
#   'UGT1A2r',
#   'UGT1A3r',
#   'UGT1A4r',
#   'UGT1A6r',
#   'UGT1A7r',
#   'UGT1A8r',
#   'UGT1A9r'},
#  'Heme synthesis': {'5AOPtm',
#   'CPPPGO',
#   'FCLTc',
#   'FCLTm',
#   'FE3R2e',
#   'HMBS',
#   'HMR_4757',
#   'HMR_4764',
#   'HMR_4771',
#   'HMR_4772',
#   'PPBNGS',
#   'PPPG9tm',
#   'PPPGOc',
#   'PPPGOm',
#   'RE3051C',
#   'RE3052C',
#   'RE3637C',
#   'UPP3S',
#   'UPPDC1'},
#  'N-glycan degradation': {'AHEXASE2ly',
#   'AHEXASEly',
#   'A_MANASEly',
#   'B_MANNASEly',
#   'ENGASE2ly',
#   'ENGASEly',
#   'FUCASEe',
#   'FUCASEly',
#   'GALASE1ly',
#   'GASNASE2ly',
#   'GASNASEly',
#   'SIAASEly'},
#  'O-glycan metabolism': {'A4GNT1g',
#   'A4GNT2g',
#   'CORE2GTg',
#   'CORE3GTg',
#   'CORE4GTg',
#   'CORE5GTg',
#   'CORE6GTg',
#   'CORE7GTg',
#   'CORE8GTg',
#   'GALNTg',
#   'HMR_7180',
#   'HMR_7181',
#   'HMR_7197',
#   'N3Tg',
#   'N4Tg',
#   'NS26T2g',
#   'NS26Tg',
#   'S23Tg'},
#  'Blood group synthesis': {'ABO1g',
#   'ABO2g',
#   'ABO3g',
#   'ABO4g',
#   'ABO5g',
#   'ABO6g',
#   'ABO7g',
#   'ABO8g',
#   'ABO9g',
#   'B3GALTg',
#   'B3GNT11g',
#   'B3GNT12g',
#   'B3GNT310g',
#   'B3GNT311g',
#   'B3GNT312g',
#   'B3GNT313g',
#   'B3GNT314g',
#   'B3GNT315g',
#   'B3GNT51g',
#   'FUT12g',
#   'FUT14g',
#   'FUT15g',
#   'FUT16g',
#   'FUT17g',
#   'FUT18g',
#   'FUT32g',
#   'FUT33g',
#   'FUT34g',
#   'FUT35g',
#   'FUT910g',
#   'FUT911g',
#   'FUT91g',
#   'FUT92g',
#   'FUT93g',
#   'FUT94g',
#   'FUT95g',
#   'FUT96g',
#   'FUT97g',
#   'FUT98g',
#   'FUT99g',
#   'GCNTg',
#   'HMR_8271',
#   'HMR_8287',
#   'ST3GAL31g',
#   'ST3GAL61g',
#   'ST3GAL62g',
#   'ST8SIA56g'},
#  'Glutamate metabolism': {'4OHBUTm',
#   'ABTArm',
#   'ALATA_L',
#   'CBPSam',
#   'GLNS',
#   'GLUDC',
#   'GLUDxm',
#   'GLUDym',
#   'GLUNm',
#   'GTHO',
#   'GTHOm',
#   'HMR_3831',
#   'HMR_9802',
#   'P5CDm',
#   'r0178',
#   'r0179'},
#  'Pentose phosphate pathway': {'ABTD',
#   'ABTD1',
#   'ARABR',
#   'DGULND',
#   'DRBK',
#   'DRPA',
#   'G6PDH1rer',
#   'G6PDH2c',
#   'G6PDH2r',
#   'G6PDH2rer',
#   'GLYPHEHYc',
#   'GND',
#   'GNDc',
#   'GNDer',
#   'GULN3D',
#   'GULNDer',
#   'GUR1PP',
#   'HMR_4592',
#   'PGL',
#   'PGLc',
#   'PGLer',
#   'PPM',
#   'PRPPS',
#   'RBK',
#   'RBK_D',
#   'RE0124C',
#   'RPE',
#   'RPEc',
#   'RPI',
#   'TALA',
#   'TKT1',
#   'TKT2',
#   'UDPG1P',
#   'UDPGNP',
#   'XYLK',
#   'XYLTD_Dr',
#   'XYLUR',
#   'r0249',
#   'r0570',
#   'r0784',
#   'r0796'},
#  'Cholesterol metabolism': {'ACACT1x',
#   'C14STRr',
#   'C3STDH1Pr',
#   'C3STDH1r',
#   'C3STKR2r',
#   'C4STMO1r',
#   'C4STMO2Pr',
#   'C4STMO2r',
#   'CHOLESACATc',
#   'DHCR241r',
#   'DHCR242r',
#   'DHCR243r',
#   'DHCR71r',
#   'DHCR72r',
#   'DMATT',
#   'DMATTx',
#   'DPMVDx',
#   'EBP1r',
#   'EBP2r',
#   'GRTT',
#   'GRTTx',
#   'HMGCOASi',
#   'HMGCOASim',
#   'HMGLm',
#   'HMGLx',
#   'HMR_1465',
#   'HMR_1467',
#   'HMR_1470',
#   'HMR_1473',
#   'HMR_1477',
#   'HMR_1478',
#   'HMR_1479',
#   'HMR_1484',
#   'HMR_1490',
#   'HMR_1493',
#   'HMR_1494',
#   'HMR_1495',
#   'HMR_1496',
#   'HMR_1500',
#   'HMR_1502',
#   'HMR_1503',
#   'HMR_1504',
#   'HMR_1505',
#   'HMR_1509',
#   'HMR_1512',
#   'HMR_1516',
#   'HMR_1526',
#   'HMR_1536',
#   'HMR_1538',
#   'HMR_1539',
#   'HMR_1540',
#   'HMR_1543',
#   'HMR_1544',
#   'HMR_1545',
#   'HMR_1546',
#   'HMR_1547',
#   'HMR_1548',
#   'HMR_1549',
#   'HMR_1550',
#   'HMR_1551',
#   'HMR_1552',
#   'HMR_1557',
#   'HMR_1558',
#   'HMR_1565',
#   'HMR_3625',
#   'HMR_3626',
#   'HMR_3627',
#   'HMR_3628',
#   'HMR_3629',
#   'HMR_3630',
#   'HMR_3631',
#   'HMR_3633',
#   'HMR_3635',
#   'HMR_3636',
#   'HMR_3637',
#   'HMR_3639',
#   'HMR_3640',
#   'HMR_3642',
#   'HMR_3644',
#   'HMR_3645',
#   'HMR_3646',
#   'HMR_3647',
#   'HMR_3648',
#   'HMR_3649',
#   'HMR_3650',
#   'HMR_3651',
#   'HMR_3652',
#   'HMR_3653',
#   'HMR_3654',
#   'HMR_3655',
#   'HMR_3656',
#   'HMR_3657',
#   'HMR_3658',
#   'HMR_3659',
#   'HMR_3660',
#   'HMR_3662',
#   'HMR_3663',
#   'HMR_3664',
#   'HMR_3665',
#   'HMR_3666',
#   'HMR_3667',
#   'HMR_3668',
#   'HMR_3669',
#   'HMR_3670',
#   'HMR_3675',
#   'HMR_3677',
#   'HMR_3678',
#   'HMR_3679',
#   'HMR_3680',
#   'HMR_3681',
#   'HMR_3682',
#   'HMR_3684',
#   'HMR_3685',
#   'HMR_3686',
#   'HMR_3687',
#   'HMR_3688',
#   'HMR_3689',
#   'HMR_3690',
#   'HMR_3692',
#   'HMR_3694',
#   'HMR_3695',
#   'HMR_3696',
#   'HMR_3698',
#   'HMR_3699',
#   'HMR_3701',
#   'HMR_3703',
#   'HMR_3704',
#   'HMR_3705',
#   'HMR_3706',
#   'HMR_3707',
#   'HMR_3708',
#   'HMR_3709',
#   'HMR_3710',
#   'HMR_3711',
#   'HMR_3712',
#   'HMR_3713',
#   'HMR_3714',
#   'HMR_3715',
#   'HMR_3716',
#   'HMR_3717',
#   'HMR_3718',
#   'HMR_3719',
#   'HMR_3721',
#   'HMR_3722',
#   'HMR_3723',
#   'HMR_3724',
#   'HMR_3725',
#   'HMR_3726',
#   'HMR_3727',
#   'HMR_3728',
#   'HMR_3729',
#   'HMR_3734',
#   'HMR_3736',
#   'HMR_3737',
#   'HMR_3738',
#   'HMR_3739',
#   'HMR_3740',
#   'HMR_3741',
#   'HMR_4630',
#   'IPDDIx',
#   'LCAT10e',
#   'LCAT11e',
#   'LCAT12e',
#   'LCAT13e',
#   'LCAT14e',
#   'LCAT15e',
#   'LCAT16e',
#   'LCAT17e',
#   'LCAT18e',
#   'LCAT19e',
#   'LCAT20e',
#   'LCAT21e',
#   'LCAT22e',
#   'LCAT23e',
#   'LCAT25e',
#   'LCAT27e',
#   'LCAT29e',
#   'LCAT2e',
#   'LCAT30e',
#   'LCAT31e',
#   'LCAT32e',
#   'LCAT33e',
#   'LCAT34e',
#   'LCAT35e',
#   'LCAT36e',
#   'LCAT37e',
#   'LCAT38e',
#   'LCAT39e',
#   'LCAT3e',
#   'LCAT40e',
#   'LCAT41e',
#   'LCAT42e',
#   'LCAT43e',
#   'LCAT44e',
#   'LCAT45e',
#   'LCAT46e',
#   'LCAT47e',
#   'LCAT48e',
#   'LCAT49e',
#   'LCAT4e',
#   'LCAT50e',
#   'LCAT51e',
#   'LCAT52e',
#   'LCAT53e',
#   'LCAT54e',
#   'LCAT55e',
#   'LCAT56e',
#   'LCAT57e',
#   'LCAT5e',
#   'LCAT6e',
#   'LCAT7e',
#   'LCAT8e',
#   'LCAT9e',
#   'LNS14DM',
#   'LNSTLSr',
#   'LSTO1r',
#   'LSTO2r',
#   'MEVK1x',
#   'MVLACc',
#   'P450SCC1m',
#   'PMEVKx',
#   'RE2407C',
#   'RE2410C',
#   'RE3134C',
#   'RE3136C',
#   'RE3180C',
#   'RE3181C',
#   'SOAT12',
#   'SQLEr',
#   'SQLSr',
#   'XOLEST182CEH',
#   'XOLEST183CEH',
#   'XOLEST205CEH',
#   'XOLEST226CEH',
#   'r0170',
#   'r0321',
#   'r0463',
#   'r0488',
#   'r0575',
#   'r0781',
#   'r0783',
#   'r1380'},
#  'Fatty acid oxidation': {'2MB2COAc',
#   '3HADICOAx',
#   '3HADPACx',
#   '3HBCOARc',
#   '3OHSEBACx',
#   '3OHSEBCOAx',
#   '3OHSUBACx',
#   '3OHSUBCOAx',
#   '5EIPENCm',
#   '5OHHEXAc',
#   '7OHOCTAc',
#   'ACACT4p',
#   'ACACT5p',
#   'ACACT6p',
#   'ACACT7p',
#   'ACACT8p',
#   'ACACT9p',
#   'ACCOAC',
#   'ACCOACm',
#   'ACOAO7p',
#   'ADPACDAc',
#   'ADPACtx',
#   'ADPCOACROT',
#   'ADPCOAPTE',
#   'ADRNCPT1',
#   'ADRNCPT2',
#   'ADRNCRNt',
#   'ALDD21',
#   'ARACHCPT1',
#   'ARACHCPT2',
#   'ARACHCRNt',
#   'BCRNe',
#   'C100CPT1',
#   'C101CPT1',
#   'C101CRNe',
#   'C102CPT1',
#   'C10CRNe',
#   'C10DCCACT',
#   'C10DCc',
#   'C10DCe',
#   'C10OHc',
#   'C120CPT1',
#   'C121CPT1',
#   'C12DCACOT',
#   'C12DCACT',
#   'C12DCTD',
#   'C12DCe',
#   'C12OHc',
#   'C140CPT1',
#   'C141ACBP',
#   'C141CPT1',
#   'C141OHc',
#   'C141OHe',
#   'C142ACBP',
#   'C142CPT1',
#   'C142OHc',
#   'C142OHe',
#   'C14825c',
#   'C14OHc',
#   'C160CPT1',
#   'C160CPT2',
#   'C160CRNt',
#   'C161CPT1',
#   'C161CPT12',
#   'C161CPT2',
#   'C161CPT22',
#   'C161CRN2t',
#   'C161CRNt',
#   'C161OHc',
#   'C162ACBP',
#   'C162OHc',
#   'C162OHe',
#   'C16DCc',
#   'C16DCe',
#   'C16OHc',
#   'C180CPT1',
#   'C180CPT2',
#   'C180CRNt',
#   'C181CPT1',
#   'C181CPT2',
#   'C181CRNt',
#   'C181OHc',
#   'C182OHc',
#   'C18OHc',
#   'C204CPT1',
#   'C204CPT2',
#   'C204CRNt',
#   'C226CPT1',
#   'C226CPT2',
#   'C226CRNt',
#   'C30CPT1',
#   'C3DCe',
#   'C40CPT1',
#   'C4CRNCPT2',
#   'C4CRNe',
#   'C4DCCACT',
#   'C4DCe',
#   'C4OHc',
#   'C50CPT1',
#   'C51CPT1',
#   'C5DCe',
#   'C60CPT1',
#   'C6CRNe',
#   'C6DCCACT',
#   'C6DCc',
#   'C6DCe',
#   'C80CPT1',
#   'C81CPT1',
#   'C81CRNe',
#   'C8CRNe',
#   'C8DCc',
#   'C8DCe',
#   'CAPROICc',
#   'CE4843HYDc',
#   'CLPNDCPT1',
#   'CLPNDCPT2',
#   'CLPNDCRNt',
#   'CSNAT2m',
#   'CSNAT2x',
#   'CSNAT3x',
#   'CSNATer',
#   'CSNATm',
#   'CSNATp',
#   'CSNATr',
#   'DCATDc',
#   'DCATDr',
#   'DCIm',
#   'DCSPTN1CPT1',
#   'DCSPTN1CPT2',
#   'DCSPTN1CRNt',
#   'DDCRNe',
#   'DDECCRNe',
#   'DDECE1CRNe',
#   'DECCRNe',
#   'DECDICRNe',
#   'DLNLCGCPT1',
#   'DLNLCGCPT2',
#   'DLNLCGCRNt',
#   'DMHPTCRNCPT2',
#   'DMHPTCRNt',
#   'DMNONCOACRNCPT1',
#   'DMNONCRNCPT2',
#   'DMNONCRNt',
#   'DOCO13EFATP',
#   'DOCOSACT',
#   'DOCOSACTDe',
#   'DOCOSACTDr',
#   'DOCOSADIACTD',
#   'DOCOSDIACTD',
#   'EIC21114TRc',
#   'EICOSTETCPT1',
#   'EICOSTETCPT2',
#   'EICOSTETCRNt',
#   'ELAIDCPT1',
#   'ELAIDCPT2',
#   'ELAIDCRNt',
#   'ETF',
#   'ETFQO',
#   'ETHMALACc',
#   'ETHMALCOAc',
#   'EX_CE4843[e]',
#   'EX_dca[e]',
#   'FACOAL140i',
#   'FACOAL150',
#   'FACOAL160i',
#   'FACOAL161',
#   'FACOAL170',
#   'FACOAL180i',
#   'FACOAL1812',
#   'FACOAL1813',
#   'FACOAL181i',
#   'FACOAL1821',
#   'FACOAL1822',
#   'FACOAL1831',
#   'FACOAL1832',
#   'FACOAL184',
#   'FACOAL191',
#   'FACOAL200',
#   'FACOAL203',
#   'FACOAL204',
#   'FACOAL2042',
#   'FACOAL205',
#   'FACOAL206',
#   'FACOAL224',
#   'FACOAL2251',
#   'FACOAL2252',
#   'FACOAL226',
#   'FACOAL240',
#   'FACOAL241',
#   'FACOAL244_1',
#   'FACOAL245_1',
#   'FACOAL245_2',
#   'FACOAL246_1',
#   'FACOAL260',
#   'FACOAL40im',
#   'FACOAL80i',
#   'FAOXC101C102m',
#   'FAOXC101C102x',
#   'FAOXC101C8m',
#   'FAOXC101C8x',
#   'FAOXC101x',
#   'FAOXC102C101m',
#   'FAOXC102C101x',
#   'FAOXC102C103m',
#   'FAOXC102C103x',
#   'FAOXC102C81m',
#   'FAOXC102C81x',
#   'FAOXC102m',
#   'FAOXC102x',
#   'FAOXC103C102m',
#   'FAOXC103C102x',
#   'FAOXC10C10OHm',
#   'FAOXC10C8m',
#   'FAOXC10C8x',
#   'FAOXC10DCC8DCx',
#   'FAOXC11',
#   'FAOXC11BRC9BRx',
#   'FAOXC11C9m',
#   'FAOXC121C101m',
#   'FAOXC121C10x',
#   'FAOXC121x',
#   'FAOXC122C101m',
#   'FAOXC122m',
#   'FAOXC122x',
#   'FAOXC123C102m',
#   'FAOXC123C102x',
#   'FAOXC123m',
#   'FAOXC123x',
#   'FAOXC12C10m',
#   'FAOXC12C10x',
#   'FAOXC12C12OHm',
#   'FAOXC12DCC10DCx',
#   'FAOXC12DCTc',
#   'FAOXC12DCc',
#   'FAOXC12DCx',
#   'FAOXC13BRC11BRx',
#   'FAOXC13C11m',
#   'FAOXC140',
#   'FAOXC141C121m',
#   'FAOXC141C121x',
#   'FAOXC141C141OHm',
#   'FAOXC142C122m',
#   'FAOXC142C122x',
#   'FAOXC142C142OHm',
#   'FAOXC143C123m',
#   'FAOXC143C123x',
#   'FAOXC14C12m',
#   'FAOXC14C12x',
#   'FAOXC14C14OHm',
#   'FAOXC14DCC12DCx',
#   'FAOXC150m',
#   'FAOXC15ATPx',
#   'FAOXC15BRC13BRx',
#   'FAOXC15C13m',
#   'FAOXC15NADPx',
#   'FAOXC15NADx',
#   'FAOXC160',
#   'FAOXC16080m',
#   'FAOXC16080x',
#   'FAOXC161802m',
#   'FAOXC16180m',
#   'FAOXC161C141m',
#   'FAOXC161C141x',
#   'FAOXC161C161OHm',
#   'FAOXC162C142m',
#   'FAOXC162C162OHm',
#   'FAOXC163C142x',
#   'FAOXC163C143m',
#   'FAOXC163C164Gm',
#   'FAOXC163C164x',
#   'FAOXC163GC142m',
#   'FAOXC163Gm',
#   'FAOXC163x',
#   'FAOXC164C143m',
#   'FAOXC164C143x',
#   'FAOXC164C163x',
#   'FAOXC164C165m',
#   'FAOXC164C165x',
#   'FAOXC164GC163m',
#   'FAOXC164m',
#   'FAOXC164x',
#   'FAOXC165C164m',
#   'FAOXC165C164x',
#   'FAOXC16BRx',
#   'FAOXC16C14m',
#   'FAOXC16C14x',
#   'FAOXC16C16OHm',
#   'FAOXC16DCC14DCx',
#   'FAOXC16DCr',
#   'FAOXC16OHC16r',
#   'FAOXC170m',
#   'FAOXC17C15m',
#   'FAOXC180',
#   'FAOXC180x',
#   'FAOXC1811601m',
#   'FAOXC1811602m',
#   'FAOXC1811603m',
#   'FAOXC181C161m',
#   'FAOXC181C161x',
#   'FAOXC181C181OHm',
#   'FAOXC182806m',
#   'FAOXC18280m',
#   'FAOXC182C162m',
#   'FAOXC182C182OHm',
#   'FAOXC183803m',
#   'FAOXC183806m',
#   'FAOXC183806x',
#   'FAOXC183C163Gm',
#   'FAOXC183C163m',
#   'FAOXC18480m',
#   'FAOXC18480x',
#   'FAOXC184C163m',
#   'FAOXC184C163x',
#   'FAOXC184C164m',
#   'FAOXC184C164x',
#   'FAOXC184m',
#   'FAOXC184x',
#   'FAOXC185C164m',
#   'FAOXC185m',
#   'FAOXC18C18OHm',
#   'FAOXC200180m',
#   'FAOXC200180x',
#   'FAOXC201C181x',
#   'FAOXC2031836m',
#   'FAOXC204',
#   'FAOXC204184m',
#   'FAOXC204C184m',
#   'FAOXC204C205x',
#   'FAOXC2051843m',
#   'FAOXC2051843x',
#   'FAOXC205C184x',
#   'FAOXC205C185m',
#   'FAOXC221C201x',
#   'FAOXC2242046m',
#   'FAOXC2242046x',
#   'FAOXC2251836m',
#   'FAOXC2251836x',
#   'FAOXC2252053m',
#   'FAOXC2252053x',
#   'FAOXC225C204m',
#   'FAOXC225C204x',
#   'FAOXC225C226m',
#   'FAOXC225C226x',
#   'FAOXC225m',
#   'FAOXC225x',
#   'FAOXC226',
#   'FAOXC226205m',
#   'FAOXC226205x',
#   'FAOXC226C205m',
#   'FAOXC226C225m',
#   'FAOXC226C225x',
#   'FAOXC226C227m',
#   'FAOXC226m',
#   'FAOXC227C226m',
#   'FAOXC22C20x',
#   'FAOXC22C22DCHYr',
#   'FAOXC22OHC22r',
#   'FAOXC240200x',
#   'FAOXC241181x',
#   'FAOXC241C221x',
#   'FAOXC2442246x',
#   'FAOXC2452253x',
#   'FAOXC2452256x',
#   'FAOXC246226x',
#   'FAOXC24C22x',
#   'FAOXC260240x',
#   'FAOXC3DC',
#   'FAOXC4C2m',
#   'FAOXC4C4DCc',
#   'FAOXC5C3x',
#   'FAOXC5C5DCc',
#   'FAOXC5C5OHm',
#   'FAOXC5OHc',
#   'FAOXC61C4m',
#   'FAOXC61C4x',
#   'FAOXC61m',
#   'FAOXC61x',
#   'FAOXC6C4m',
#   'FAOXC6C4x',
#   'FAOXC6DCC4DCx',
#   'FAOXC7C5m',
#   'FAOXC80',
#   'FAOXC81C61m',
#   'FAOXC81C61x',
#   'FAOXC8C6m',
#   'FAOXC8C6x',
#   'FAOXC8DCC6DCx',
#   'FAOXC9C7m',
#   'FAOXMC10OHMC10r',
#   'FAOXOHC16C16DCc',
#   'FAOXOHC22C22DCc',
#   'FAOXOHMC10DC10c',
#   'FAOXTC101TC102m',
#   'FAOXTC102C101m',
#   'FAOXTC122TC101m',
#   'FAOXTC122m',
#   'FAOXTC142TC122m',
#   'FAOXTC162TC142m',
#   'FAOXTC182TC162m',
#   'FCOAH',
#   'FDH',
#   'FOAXC122C101x',
#   'GLUTCOAACBP',
#   'HDCACBP',
#   'HDCAc',
#   'HDDACBP',
#   'HDECAACBP',
#   'HDECEACBP',
#   'HEDCECRNe',
#   'HEXCOAACBP',
#   'HEXDCRNe',
#   'HEXDIACtr',
#   'HEXDICOAACBP',
#   'HEXDICOAACBPx',
#   'HEXDTRm',
#   'HIVCACBP',
#   'HIVCRNe',
#   'HMR_0189',
#   'HMR_0193',
#   'HMR_0197',
#   'HMR_0201',
#   'HMR_0206',
#   'HMR_0210',
#   'HMR_0214',
#   'HMR_0230',
#   'HMR_0234',
#   'HMR_0238',
#   'HMR_0242',
#   'HMR_0246',
#   'HMR_0256',
#   'HMR_0260',
#   'HMR_0268',
#   'HMR_0272',
#   'HMR_0276',
#   'HMR_0280',
#   'HMR_0290',
#   'HMR_0298',
#   'HMR_0302',
#   'HMR_0306',
#   'HMR_0310',
#   'HMR_0324',
#   'HMR_0328',
#   'HMR_0342',
#   'HMR_0346',
#   'HMR_0350',
#   'HMR_0354',
#   'HMR_0358',
#   'HMR_0362',
#   'HMR_0366',
#   'HMR_0370',
#   'HMR_0374',
#   'HMR_0378',
#   'HMR_0382',
#   'HMR_0386',
#   'HMR_0390',
#   'HMR_0394',
#   'HMR_0398',
#   'HMR_0402',
#   'HMR_0406',
#   'HMR_0410',
#   'HMR_0414',
#   'HMR_0418',
#   'HMR_0422',
#   'HMR_0426',
#   'HMR_0430',
#   'HMR_0434',
#   'HMR_0438',
#   'HMR_2602',
#   'HMR_2608',
#   'HMR_2611',
#   'HMR_2620',
#   'HMR_2633',
#   'HMR_2648',
#   'HMR_2651',
#   'HMR_2657',
#   'HMR_2660',
#   'HMR_2666',
#   'HMR_2669',
#   'HMR_2675',
#   'HMR_2681',
#   'HMR_2684',
#   'HMR_2687',
#   'HMR_2690',
#   'HMR_2693',
#   'HMR_2699',
#   'HMR_2702',
#   'HMR_2705',
#   'HMR_2708',
#   'HMR_2711',
#   'HMR_2733',
#   'HMR_2736',
#   'HMR_2739',
#   'HMR_2768',
#   'HMR_2771',
#   'HMR_2774',
#   'HMR_3053',
#   'HMR_3054',
#   'HMR_3055',
#   'HMR_3056',
#   'HMR_3057',
#   'HMR_3058',
#   'HMR_3059',
#   'HMR_3062',
#   'HMR_3063',
#   'HMR_3064',
#   'HMR_3065',
#   'HMR_3066',
#   'HMR_3067',
#   'HMR_3068',
#   'HMR_3069',
#   'HMR_3070',
#   'HMR_3071',
#   'HMR_3072',
#   'HMR_3073',
#   'HMR_3074',
#   'HMR_3075',
#   'HMR_3076',
#   'HMR_3094',
#   'HMR_3095',
#   'HMR_3096',
#   'HMR_3097',
#   'HMR_3098',
#   'HMR_3099',
#   'HMR_3100',
# ...
#   'r0671'},
#  'Androgen and estrogen synthesis and metabolism': {'HMR_1944',
#   'HMR_1958',
#   'HMR_1962',
#   'HMR_1967',
#   'HMR_1968',
#   'HMR_1970',
#   'HMR_1971',
#   'HMR_1976',
#   'HMR_1982',
#   'HMR_1983',
#   'HMR_2014',
#   'HMR_2016',
#   'HMR_2018',
#   'HMR_2029',
#   'HMR_2088',
#   'HMR_2089',
#   'RE1587C',
#   'RE1630C',
#   'RE1632C',
#   'RE2235C',
#   'RE2235R',
#   'RE2386C',
#   'RE3013C',
#   'RE3108C',
#   'RE3218C',
#   'RE3220C'},
#  'Vitamin E metabolism': {'HMR_6456',
#   'HMR_6500',
#   'RE2327C',
#   'RE2705C',
#   'RE2948C'},
#  'Linoleate metabolism': {'HMR_2440',
#   'HMR_2457',
#   'RE2346C',
#   'RE3258C',
#   'RE3259C',
#   'RE3411C',
#   'RE3413C',
#   'RE3417C',
#   'RE3420C'},
#  'Arachidonic acid metabolism': {'HMR_0942',
#   'HMR_0946',
#   'HMR_0950',
#   'HMR_0954',
#   'HMR_0960',
#   'HMR_0963',
#   'HMR_0979',
#   'HMR_0980',
#   'HMR_0981',
#   'HMR_0985',
#   'HMR_0986',
#   'HMR_0987',
#   'HMR_1030',
#   'HMR_1033',
#   'HMR_1037',
#   'HMR_1039',
#   'HMR_1077',
#   'RE2563C',
#   'RE3033C',
#   'RE3036C',
#   'RE3038C',
#   'RE3040C',
#   'RE3041C',
#   'RE3044C',
#   'RE3286C',
#   'RE3287C',
#   'RE3288C',
#   'RE3289C',
#   'RE3470C',
#   'RE3470M',
#   'RE3475C',
#   'RE3476C',
#   'RE3476M',
#   'RE3513C',
#   'RE3513R',
#   'RE3520E',
#   'RE3525C',
#   'RE3525M',
#   'RE3525R',
#   'RE3526C',
#   'RE3526M'},
#  'Glycosphingolipid metabolism': {'HMR_0793',
#   'HMR_0803',
#   'HMR_0805',
#   'HMR_0806',
#   'HMR_0807',
#   'HMR_0808',
#   'HMR_0809',
#   'HMR_0810',
#   'HMR_0811',
#   'HMR_0812',
#   'HMR_0814',
#   'HMR_0815',
#   'HMR_0816',
#   'HMR_0817',
#   'HMR_0819',
#   'HMR_0820',
#   'HMR_0821',
#   'HMR_0822',
#   'HMR_0823',
#   'HMR_0824',
#   'HMR_0825',
#   'HMR_0827',
#   'HMR_0828',
#   'HMR_0829',
#   'HMR_0830',
#   'HMR_0835',
#   'HMR_0836',
#   'HMR_0837',
#   'HMR_0839',
#   'HMR_0841',
#   'HMR_0842',
#   'HMR_0843',
#   'HMR_0844',
#   'HMR_0846',
#   'HMR_0847',
#   'HMR_0848',
#   'HMR_0849',
#   'HMR_0851',
#   'HMR_0852',
#   'HMR_0853',
#   'HMR_0854',
#   'HMR_0855',
#   'HMR_0859',
#   'HMR_0860',
#   'HMR_0864',
#   'HMR_0867',
#   'HMR_0868',
#   'HMR_0870',
#   'HMR_0873',
#   'HMR_0875',
#   'HMR_0876',
#   'HMR_0877',
#   'HMR_0878',
#   'HMR_0889',
#   'HMR_0890',
#   'HMR_0906',
#   'HMR_0907',
#   'HMR_0908',
#   'HMR_0909',
#   'HMR_0910',
#   'HMR_0911',
#   'HMR_0912',
#   'RE2666C',
#   'RE2666G',
#   'RE2675C2',
#   'RE2677C',
#   'RE2677E',
#   'RE2677G',
#   'RE2677N',
#   'RE2677R',
#   'RE2717L'},
#  'Dietary fiber binding': {'BGLUGCHe',
#   'BGLUTCHLe',
#   'BGLUTDECHOe',
#   'GUMDCHAe',
#   'GUMGCHLe',
#   'GUMTCHOLe',
#   'PECDCHe',
#   'PECGCHLe',
#   'PECTCHLe',
#   'PSYGCHe',
#   'PSYTCHe',
#   'PSYTDECHe'},
#  'Squalene and cholesterol synthesis': {'DPMVDc',
#   'DSREDUCr',
#   'IPDDI',
#   'MEVK1c',
#   'PMEVKc'},
#  'Hippurate metabolism': {'BGLYFm', 'BZCOAFm'},
#  'Peptide metabolism': {'ALAARGCYSr',
#   'ALAARGGLYr',
#   'ALAASNLEUr',
#   'ALAGLYLYSr',
#   'ALAHISALAr',
#   'ALALYSTHRr',
#   'ARGALAALAr',
#   'ARGALAPHEr',
#   'ARGALATHRr',
#   'ARGARGLYSr',
#   'ARGARGMETr',
#   'ARGARGr',
#   'ARGCYSGLYr',
#   'ARGCYSSERr',
#   'ARGGLUGLUr',
#   'ARGGLUPROr',
#   'ARGGLYGLYr',
#   'ARGHISTHRr',
#   'ARGLEUPHEr',
#   'ARGLYSASPr',
#   'ARGPHEARGr',
#   'ARGPROMETr',
#   'ARGPROTHRr',
#   'ARGSERSERr',
#   'ARGTYRVALr',
#   'ARGVALCYSr',
#   'ARGVALTRPr',
#   'ASNASNARGr',
#   'ASNCYSCYSr',
#   'ASNMETPROr',
#   'ASNPHEASPr',
#   'ASNPHECYSr',
#   'ASNTYRGLYr',
#   'ASNTYRPHEr',
#   'ASNTYRTHRr',
#   'ASPALAARGr',
#   'ASPASNGLUr',
#   'ASPGLUPROr',
#   'ASPGLUTRPr',
#   'ASPGLUr',
#   'ASPHISCYSr',
#   'ASPHISPROr',
#   'ASPLYSGLUr',
#   'ASPLYSHISr',
#   'ASPMETASPr',
#   'ASPPROLYSr',
#   'ASPVALASNr',
#   'CYSASNMETr',
#   'CYSASPPHEr',
#   'CYSCYSr',
#   'CYSGLNMETr',
#   'CYSGLUHISr',
#   'CYSGLUTRPr',
#   'CYSLEUTHRr',
#   'CYSSERMETr',
#   'CYSTYRASNr',
#   'GLNASNGLNr',
#   'GLNHISHISr',
#   'GLNHISLYSr',
#   'GLNLYSLYSr',
#   'GLNLYSTRPr',
#   'GLNPROGLUr',
#   'GLNTRPGLUr',
#   'GLNTYRLEUr',
#   'GLUARGLEUr',
#   'GLUASNLEUr',
#   'GLUGLUr',
#   'GLUILELYSr',
#   'GLULEUr',
#   'GLUMETHISr',
#   'GLUMETr',
#   'GLUTHRLYSr',
#   'GLUTHRr',
#   'GLUTRPALAr',
#   'GLYHISASNr',
#   'GLYHISLYSr',
#   'GLYLYSCYSr',
#   'GLYLYSPHEr',
#   'GLYTYRLYSr',
#   'GLYVALHISr',
#   'HISARGCYSr',
#   'HISARGSERr',
#   'HISASPr',
#   'HISCYSCYSr',
#   'HISGLNALAr',
#   'HISGLUGLNr',
#   'HISGLUr',
#   'HISGLYLYSr',
#   'HISHISLYSr',
#   'HISLYSALAr',
#   'HISLYSGLUr',
#   'HISLYSILEr',
#   'HISLYSTHRr',
#   'HISLYSVALr',
#   'HISMETGLNr',
#   'HISMETr',
#   'HISPHEARGr',
#   'HISPROLYSr',
#   'HISTRPHISr',
#   'ILEARGILEr',
#   'ILEASNHISr',
#   'ILEASPr',
#   'ILEGLNGLUr',
#   'ILEGLYARGr',
#   'ILEPROLYSr',
#   'ILESERARGr',
#   'ILETRPTYRr',
#   'LEUALAARGr',
#   'LEUASNASPr',
#   'LEUASPLYSr',
#   'LEULEUTRPr',
#   'LEUPROARGr',
#   'LEUPROr',
#   'LEUSERTRPr',
#   'LEUTRPARGr',
#   'LEUTRPr',
#   'LEUTYRTYRr',
#   'LEUVALr',
#   'LYSARGLEUr',
#   'LYSCYSHISr',
#   'LYSGLNPHEr',
#   'LYSGLUGLUr',
#   'LYSLYSLYSr',
#   'LYSPHEILEr',
#   'LYSTRPARGr',
#   'LYSTYRILEr',
#   'LYSVALPHEr',
#   'LYSVALTRPr',
#   'METARGLEUr',
#   'METASNTYRr',
#   'METGLNTYRr',
#   'METGLYARGr',
#   'METHISLYSr',
#   'METMETILEr',
#   'METPHEARGr',
#   'METTRPPHEr',
#   'PHEASNMETr',
#   'PHEASPr',
#   'PHEGLNPHEr',
#   'PHELEUASPr',
#   'PHELEUHISr',
#   'PHELEUr',
#   'PHELYSALAr',
#   'PHELYSPROr',
#   'PHEPHEASNr',
#   'PHEPHETHRr',
#   'PHEPHEr',
#   'PHEPROARGr',
#   'PHESERTRPr',
#   'PHETHRLYSr',
#   'PHETRPLEUr',
#   'PHETYRGLNr',
#   'PHETYRLYSr',
#   'PHETYRr',
#   'PROARGASPr',
#   'PROARGCYSr',
#   'PROASNCYSr',
#   'PROCYSr',
#   'PROGLNPROr',
#   'PROGLULYSr',
#   'PROHISTYRr',
#   'PROHISr',
#   'PROLEUARGr',
#   'PROLYSPROr',
#   'PROPHEr',
#   'PROPROARGr',
#   'PROPROPROr',
#   'PROTRPLYSr',
#   'PROTRPTHRr',
#   'PROVALGLNr',
#   'SERARGALAr',
#   'SERARGTRPr',
#   'SERCYSARGr',
#   'SERGLYGLUr',
#   'SERLYSHISr',
#   'SERPHELYSr',
#   'SERTRPHISr',
#   'THRARGTYRr',
#   'THRASNTYRr',
#   'THRGLNGLUr',
#   'THRGLNTYRr',
#   'THRHISHISr',
#   'THRILEARGr',
#   'THRMETARGr',
#   'THRPHEARGr',
#   'THRSERARGr',
#   'THRTHRARGr',
#   'THRTYRMETr',
#   'TRPALAPROr',
#   'TRPARGALAr',
#   'TRPASPASPr',
#   'TRPGLNGLNr',
#   'TRPGLUGLYr',
#   'TRPGLULEUr',
#   'TRPGLUPROr',
#   'TRPGLUTYRr',
#   'TRPGLYASPr',
#   'TRPGLYLEUr',
#   'TRPGLYPHEr',
#   'TRPGLYVALr',
#   'TRPHISMETr',
#   'TRPILELYSr',
#   'TRPILETRPr',
#   'TRPLEUVALr',
#   'TRPLYSr',
#   'TRPMETARGr',
#   'TRPMETVALr',
#   'TRPPHEr',
#   'TRPPROGLYr',
#   'TRPPROLEUr',
#   'TRPPROVALr',
#   'TRPSERTYRr',
#   'TRPTHRGLUr',
#   'TRPTHRILEr',
#   'TRPTHRTYRr',
#   'TRPTYRGLNr',
#   'TRPTYRTYRr',
#   'TRPVALASPr',
#   'TYRALAPHEr',
#   'TYRALAr',
#   'TYRARGGLUr',
#   'TYRARGSERr',
#   'TYRASPARGr',
#   'TYRCYSGLYr',
#   'TYRCYSTHRr',
#   'TYRGLUr',
#   'TYRLEUARGr',
#   'TYRPHETYRr',
#   'TYRTHRr',
#   'TYRTRPPHEr',
#   'TYRTYRr',
#   'TYRVALMETr',
#   'VALARGGLYr',
#   'VALHISASNr',
#   'VALLEUPHEr',
#   'VALLYSTYRr',
#   'VALPHEARGr',
#   'VALPROTRPr',
#   'VALSERARGr',
#   'VALTRPPHEr',
#   'VALTRPVALr',
#   'VALVALr'},
#  'Nucleotide salvage pathway': {'ADPT', 'GUAPRT', 'HXPRT'},
#  'Leukotriene metabolism': {'HMR_1081',
#   'HMR_1084',
#   'HMR_1085',
#   'HMR_1102',
#   'HMR_1126',
#   'HMR_1127',
#   'HMR_1129',
#   'HMR_1280'},
#  'N-glycan metabolism': {'HMR_1532',
#   'HMR_7255',
#   'HMR_7256',
#   'HMR_7278',
#   'HMR_7328',
#   'HMR_7329'},
#  'Nucleotide metabolism': {'HMR_3966'},
#  'Lipoate metabolism': {'HMR_6397'},
#  'Drug metabolism': {'12HTACRhr',
#   '12HTACRitr',
#   '12HTACRtep',
#   '12HTACRtu',
#   '1331TAALThr',
#   '1331TACRhr',
#   '1331TACRteb',
#   '1331TACRtev',
#   '13DMThr',
#   '13DMTitr',
#   '13DMTtep',
#   '13DMTtu',
#   '13HTACRitr',
#   '14HMDZALThr',
#   '14HMDZhr',
#   '14HMDZitr',
#   '14MDZtev',
#   '1513DTACRhr',
#   '1513DTALThr',
#   '1513TACRitr',
#   '1513TACRtep',
#   '1513TACRtu',
#   '1531TACRhr',
#   '1531TACRitr',
#   '1531TACRteb',
#   '1531TACRtev',
#   '1531TALThr',
#   '15DMThr',
#   '15DMTitr',
#   '15DMTtep',
#   '15DMTtu',
#   '1HIBUPGLUC_Sthv',
#   '1HIBUPGLUitr',
#   '1HIBUP_SGLUhep',
#   '1HIBUP_Sitr',
#   '1HIBUP_Sthv',
#   '1HMDGLUChr',
#   '1HMDGLUCitr',
#   '1HMDZGLUChc',
#   '1OHMDZhr',
#   '1OHMDZitr',
#   '1OHMDZtep',
#   '2HATVACIDGLUChr',
#   '2HATVACIDGLUCitr',
#   '2HATVACIDGLUCteb',
#   '2HATVACIDOXDhc',
#   '2HATVACIDhc',
#   '2HATVACIDitr',
#   '2HATVACIDteb',
#   '2HATVACIDtep',
#   '2HATVACIDthc',
#   '2HATVLACGLUChr',
#   '2HATVLACGLUCitr',
#   '2HATVLACGLUCteb',
#   '2HATVLACOXDhc',
#   '2HATVLAChc',
#   '2HATVLACteb',
#   '2HATVLACtep',
#   '2HATVLACthc',
#   '2HIBUPGLUC_Sitr',
#   '2HIBUPGLUC_Sthv',
#   '2HIBUP_Ritr',
#   '2HIBUP_Rthv',
#   '2HIBUP_SGLUhep',
#   '2HIBUP_Sitr',
#   '2HIBUP_Sthv',
#   '31DMThr',
#   '31DMTitr',
#   '31DMTtep',
#   '31DMTtu',
#   '35DHPVShc',
#   '35DHPVSitr',
#   '35DHPVStep',
#   '35DHPVSthc',
#   '35DSMVhep',
#   '35DSMVitr',
#   '35DSMVteb',
#   '3HIBUPGLUC_Sitr',
#   '3HIBUPGLUC_Sthv',
#   '3HIBUP_Ritr',
#   '3HIBUP_Rthv',
#   '3HIBUP_SGLUhep',
#   '3HIBUP_Sitr',
#   '3HIBUP_Sthv',
#   '3HLVSTAChep',
#   '3HLVSTACtbc',
#   '3HLVSTitr',
#   '3HPVSCOAhc',
#   '3HPVSCOAitm',
#   '3HPVSCOAitx',
#   '3HPVSTETCOAhcm',
#   '3HPVSTETCOAhcx',
#   '3HPVSTETCOAitm',
#   '3HPVSTETCOAitx',
#   '3HPVSTEThc',
#   '3HPVSTETteb',
#   '3HPVSTETtev',
#   '3HPVShc',
#   '3HPVSitr',
#   '3HPVSteb',
#   '3HPVStep',
#   '3HPVSthc',
#   '3HSMVACIDhep',
#   '3HSMVACIDteb',
#   '3HSMVhep',
#   '3HSMVitr',
#   '3ISPVShc',
#   '3ISPVSitr',
#   '3ISPVSteb',
#   '3ISPVStep',
#   '3ISPVSthc',
#   '3MEACMPhc',
#   '3MEACMPitr',
#   '3OHACMPhr',
#   '3OHACMPitr',
#   '3OHACMPtev',
#   '4BHGLZABCt',
#   '4BHGLZhr',
#   '4BHGLZitr',
#   '4BHGLZtev',
#   '4HATVACIDOXDhc',
#   '4HATVACIDhc',
#   '4HATVACIDitr',
#   '4HATVACIDteb',
#   '4HATVACIDtep',
#   '4HATVACIDthc',
#   '4HATVLACOXDhc',
#   '4HATVLAChc',
#   '4HATVLACitr',
#   '4HATVLACteb',
#   '4HATVLACtep',
#   '4HATVLACthc',
#   '4HMDGLUCitr',
#   '4HMDGLUCtev',
#   '4HMDZGLUChr',
#   '4OHMDZhr',
#   '4OHMDZitr',
#   '4OHMDZtev',
#   '56DHPVShc',
#   '56DHPVSitr',
#   '56DHPVSteb',
#   '56DHPVStev',
#   '56EPPVShc',
#   '56EPPVSitr',
#   '56EPPVSteb',
#   '56EPPVStev',
#   '5OHFVSGLUhc',
#   '5OHFVSGLUitr',
#   '5OHFVSGLUtev',
#   '5OHFVShc',
#   '5OHFVSitr',
#   '5OHFVSteb',
#   '6AHGLZABCt',
#   '6AHGLZhr',
#   '6AHGLZitr',
#   '6AHGLZtev',
#   '6BHGLZABCt',
#   '6BHGLZGLCABCt',
#   '6BHGLZGLChr',
#   '6BHGLZGLCitr',
#   '6BHGLZGLCtev',
#   '6BHGLZhr',
#   '6BHGLZitr',
#   '6BHGLZtev',
#   '6CSMVACIDhep',
#   '6CSMVACIDteb',
#   '6CSMVhep',
#   '6CSMVitr',
#   '6EPSteb',
#   '6EPVShc',
#   '6EPVStep',
#   '6EPVSthc',
#   '6HLVSTACIDitr',
#   '6HLVSTAChep',
#   '6HLVSTitr',
#   '6HLVSTthep',
#   '6HMSMVACIDhep',
#   '6HMSMVACIDteb',
#   '6HMSMVhep',
#   '6HMSMVitr',
#   '6HSMVACIDhep',
#   '6HSMVACIDteb',
#   '6HSMVhep',
#   '6HSMVitr',
#   '6MELACAChep',
#   '6MELVACIDitr',
#   '6MELVACtbc',
#   '6MELVSTitr',
#   '6MELVSTthep',
#   '6MSMVhep',
#   '6OHFVSGLUhc',
#   '6OHFVSGLUitr',
#   '6OHFVSGLUtev',
#   '6OHFVShc',
#   '6OHFVSitr',
#   '6OHFVSteb',
#   '7AHGLZABCt',
#   '7AHGLZhr',
#   '7AHGLZitr',
#   '7AHGLZtev',
#   '7BHGLZABCt',
#   '7BHGLZGLCABCt',
#   '7BHGLZGLChr',
#   '7BHGLZGLCitr',
#   '7BHGLZGLCtev',
#   '7BHGLZhr',
#   '7BHGLZitr',
#   '7BHGLZtev',
#   '7HPVShc',
#   '7HPVSitr',
#   '7HPVSteb',
#   '7HPVStev',
#   'ACMPGLUChr',
#   'ACMPGLUTTRsc',
#   'ACMPGLUTdt',
#   'ACMPGLUTitr',
#   'ACMPGLUTtep',
#   'ACMPGLUTthc',
#   'ACMPGLUitr',
#   'ACMPGLUtep',
#   'ACMPGLUthc',
#   'ACMPShc',
#   'ACMPdt',
#   'ACMPitr',
#   'ACMPthc',
#   'ACMPtu',
#   'ALLOP1tu',
#   'ALLOP2tu',
#   'ALLOPOXDhep',
#   'ALLOPtepvb',
#   'AM19CSALThr',
#   'AM19CShr',
#   'AM19CSitr',
#   'AM19CSteb',
#   'AM1A4NCShc',
#   'AM1A4NCSteb',
#   'AM1ACCShr',
#   'AM1ACCSitr',
#   'AM1ACCStev',
#   'AM1ACShr',
#   'AM1ACSitr',
#   'AM1ACSteb',
#   'AM1ACStep',
#   'AM1ALCShr',
#   'AM1ALCSitr',
#   'AM1ALCSteb',
#   'AM1ALCStep',
#   'AM1C4N9CShc',
#   'AM1C4N9CSteb',
#   'AM1C9CShr',
#   'AM1C9CSitr',
#   'AM1C9CSteb',
#   'AM1C9CStev',
#   'AM1CCShr',
#   'AM1CCSitr',
#   'AM1CCSteb',
#   'AM1CCStev',
#   'AM1CGLChr',
#   'AM1CGLCitr',
#   'AM1CGLCteb',
#   'AM1CSAhr',
#   'AM1CSAitr',
#   'AM1CSAtep',
#   'AM4N9CShc',
#   'AM4N9CShr',
#   'AM4N9CSitr',
#   'AM4N9CStev',
#   'AM4NC9CSteb',
#   'AM4NCShr',
#   'AM4NCSitr',
#   'AM4NCSteb',
#   'AM4NCStep',
#   'AM9CSAhr',
#   'AM9CSAitr',
#   'AM9CSAteb',
#   'AM9CSAtep',
#   'ATVACIDMCTtu',
#   'ATVACIDOATPtu',
#   'ATVACIDhc',
#   'ATVACIDhr',
#   'ATVACIDitr',
#   'ATVACIDtdu',
#   'ATVACIDtu',
#   'ATVACYLGLUChc',
#   'ATVETHGLUChc',
#   'ATVLACGLCURhc',
#   'ATVLACThc',
#   'ATVLACh2r',
#   'ATVLAChc',
#   'ATVLAChr',
#   'ATVLACitr',
#   'ATVLACtdhc',
#   'ATVLACtu',
#   'Am19CStev',
#   'Am1CSAteb',
#   'CARBIBUP_SGLUthv',
#   'CARIBUPGLU_Sitr',
#   'CARIBUP_Rthv',
#   'CARIBUP_SGLUhep',
#   'CARIBUP_Sitr',
#   'CARIBUP_Sthv',
#   'CRGLZABCt',
#   'CRGLZhr',
#   'CRGLZitr',
#   'CRGLZtev',
#   'CRVS1M24hc',
#   'CRVS1tev',
#   'CRVS23M24hc',
#   'CRVSATPthc',
#   'CRVSATPtu',
#   'CRVSM1SPhc',
#   'CRVSM1hc',
#   'CRVSM1hr',
#   'CRVSM1teb',
#   'CRVSM22hc',
#   'CRVSM22itr',
#   'CRVSM23hc',
#   'CRVSM23hr',
#   'CRVSM23teb',
#   'CRVSM23tev',
#   'CRVSM24itr',
#   'CRVSM24teb',
#   'CRVSM24tev',
#   'CRVSM31hc',
#   'CRVSM31itr',
#   'CRVSitr',
#   'CRVSthc',
#   'CRVStu',
#   'CSASULPhc',
#   'CSASULPteb',
#   'CSASULPtev',
#   'CSAitr',
#   'CSAtd',
#   'CSAtu',
#   'CVM1GLUChc',
#   'CVM23GLUChc',
#   'CYSACMPAChc',
#   'CYSACMPitr',
#   'CYSAMPtev',
#   'DELACCRVSM23hc',
#   'DEOXFVShc',
#   'DEOXFVSitx',
#   'DEOXFVStev',
#   'DESFVShc',
#   'DESFVSitr',
#   'DESFVSteb',
#   'DHGLZABCt',
#   'DHGLZhc',
#   'DHGLZtev',
#   'DSPVShc',
#   'DSPVSitr',
#   'DSPVSteb',
#   'DSPVStev',
#   'EPOXTAChr',
#   'EPOXTACitr',
#   'EPOXTACteb',
#   'EPOXTACtev',
#   'FVSCOAhc',
#   'FVSCOAitx',
#   'FVSGLUChc',
#   'FVSTETGLUhc',
#   'FVSTETGLUitr',
#   'FVSTETGLUtev',
#   'FVSTETitr',
#   'FVSTETtev',
#   'FVShc',
#   'FVSitr',
#   'FVSitx',
#   'FVSteb',
#   'FVStep',
#   'FVStu',
#   'GLC3MEACPhr',
#   'GLC3MEACPitr',
#   'GLC3MEACPtev',
#   'GLYitr',
#   'GLZABCteb',
#   'GLZitr',
#   'GLZtd',
#   'GTACMPhr',
#   'GTACMPitr',
#   'GTACMPtev',
#   'H2O2itr',
#   'IBUPGLUCitr',
#   'IBUPGLUCtchep',
#   'IBUPGLUCtpvb',
#   'IBUPGT_HEP',
#   'IBUP_RASCL1hep',
#   'IBUP_RCYP2hep',
#   'IBUP_RCYP3hep',
#   'IBUP_RCYPCARhep',
#   'IBUP_Ritr',
#   'IBUP_Rshep',
#   'IBUP_Rtdhep',
#   'IBUP_Rtdu',
#   'IBUP_SACOT2',
#   'IBUP_SCONJhep',
#   'IBUP_SCYP1hep',
#   'IBUP_SCYP2hep',
#   'IBUP_SCYP3hep',
#   'IBUP_SCYPCARhep',
#   'IBUP_Sitr',
#   'IBUP_Stbc',
#   'IBUP_Stdhep',
#   'IBUP_Stdu',
#   'ISOLVSTAChep',
#   'ISOLVSTtbc',
#   'LST4EXPTDhc',
#   'LST4EXPhr',
#   'LST4EXPitr',
#   'LST4EXPthc',
#   'LSTN1GLUChr',
#   'LSTN1GLUCitr',
#   'LSTN1GLUCtev',
#   'LSTNM1hr',
#   'LSTNM1itr',
#   'LSTNM1tev',
#   'LSTNM2hr',
#   'LSTNM2itr',
#   'LSTNM2tev',
#   'LSTNM4hr',
#   'LSTNM4itr',
#   'LSTNM4tev',
#   'LSTNM5hr',
#   'LSTNM5itr',
#   'LSTNM5tev',
#   'LSTNM7TDhc',
#   'LSTNM7hr',
#   'LSTNM7itr',
#   'LSTNM7thc',
#   'LSTNRATt',
#   'LSTNitr',
#   'LSTNtd',
#   'LSTNtu',
#   'LVACLAChep',
#   'LVSTACIDhep',
#   'LVSTACIDitr',
#   'LVSTACIDtu',
#   'LVSTACOXD6Hhep',
#   'LVSTACOXD6MEhep',
#   'LVSTOXD3Hhep',
#   'LVSTOXD6Hhep',
#   'LVSTOXD6METhep',
#   'LVSTPGPtu',
#   'LVSTitr',
#   'LVSTtu',
#   'MDZGLChr',
#   'MDZGLCitr',
#   'MDZGLCtev',
#   'MDZitr',
#   'MDZtd',
#   'MDZtu',
#   'MERACMPtep',
#   'MERACMPthc',
#   'MHGLZABCt',
#   'MHGLZhr',
#   'MHGLZitr',
#   'MHGLZtev',
#   'NAPQIhr',
#   'NDERSVhc',
#   'NDERSVitr',
#   'NDERSVteb',
#   'NFDACOXDhc',
#   'NFDACitr',
#   'NFDACtep',
#   'NFDDMEThr',
#   'NFDLAChc',
#   'NFDLACtep',
#   'NFDNPYitr',
#   'NFDNPYtep',
#   'NFDOHitr',
#   'NFDOHtep',
#   'NFDOXDhc',
#   'NFDtd',
#   'OXYP1CONJ',
#   'OXYP2CONJ',
#   'OXYPR1tehv',
#   'OXYPR7tehv',
#   'OXYPtepv',
#   'OXYPthc',
#   'PAPSitr',
#   'PAPitr',
#   'PROFVSCOAhc',
#   'PROFVSCOAitx',
#   'PROFVShc',
#   'PROFVStev',
#   'PTVSTATPtu',
#   'PTVSTGLUChc',
#   'PTVSTLAChc',
#   'PTVSTLACitr',
#   'PTVSTLACtev',
#   'PTVSTM13hr',
#   'PTVSTM13itr',
#   'PTVSTM13te',
#   'PTVSTM3eb',
#   'PTVSTM3hc',
#   'PTVSTM3itr',
#   'PTVSThc',
#   'PTVSTitr',
#   'PTVSTtep',
#   'PTVSTtu',
#   'PVSATPtu',
#   'PVSGLUChc',
#   'PVSGLUCitr',
#   'PVSGLUCteb',
#   'PVSGLUCtev',
#   'PVSHtu',
#   'PVSOATPtu',
#   'PVSitr',
#   'PVStep',
#   'RSVATPtu',
#   'RSVGLUChc',
#   'RSVLAChv',
#   'RSVLACitr',
#   'RSVLACteb',
#   'RSVSPONhc',
#   'RSVhc',
#   'RSVitr',
#   'RSVtev',
#   'RSVtu',
#   'S3MEACMPhc',
#   'S3MEACMPtev',
#   'SMVACIDATPteb',
#   'SMVACIDhep',
#   'SMVACIDitr',
#   'SMVACIDtev',
#   'SMVGLUCLAChep',
#   'SMVGLUChep',
#   'SMVHYDROhep',
#   'SMVLAChep',
#   'SMVitr',
#   'SMVthep',
#   'SMVtu',
#   'SMVtv',
#   'STACMPhc',
#   'STACMPtev',
#   'SULPACMPtev',
#   'TACRDtsc',
#   'TACRitr',
#   'TACRtu',
#   'TAURIBUP_Sthv',
#   'THRFVShc',
#   'THRFVStev',
#   'THSACMPhr',
#   'THSACMPitr',
#   'TLACFVShc',
#   'TLACFVSitr',
#   'TLACFVStev',
#   'TMACMPhr',
#   'TMACMPitr',
#   'TMDM1OATt',
#   'TMDM1hr',
#   'TMDM1itr',
#   'TMDM3OATt',
#   'TMDM3hr',
#   'TMDM3itr',
#   'TMDM5OATt',
#   'TMDM5hr',
#   'TMDM5itr',
#   'TMDOATPtsc',
#   'TMDOATtev',
#   'TMDOATthc',
#   'TMDitr',
#   'TMDtd',
#   'TRIPVShc',
#   'TRIPVSitr',
#   'TRIPVSteb',
#   'TRIPVStev',
#   'TSACGLUCtev',
#   'TSACMGLUChr',
#   'TSACMGLUCitr',
#   'TSACMSULhc',
#   'TSACMSULtev',
#   'UDPRIBc'},
#  'Xenobiotics metabolism': {'EX_lvstacid[e]', 'EX_ptvstm13[e]'},
#  'Protein formation': {'DM_PROTEIN', 'PROTEIN_BS'},
#  '': {'ACITLn',
#   'CITtn',
#   'DM_adprbp[n]',
#   'EX_adprbp[n]',
#   'LYSACn',
#   'OAAtn',
#   'R_SIRT1'}}

# %%
df_filtered
# Out:
#            10FTHFtm  11DOCRTSTRNtm  11DOCRTSTRNtr  2AMACHYD      2HBO   2HBt2  \
# V3_C005    0.000000       0.000000       0.000000       0.0  0.000000  1000.0
# V3_C009    0.000000       0.000000       0.000000       0.0  0.000000  1000.0
# V3_C010    0.000000       0.000000       0.000000       0.0  0.000000  1000.0
# V3_C016    0.000000       0.000000       0.000000       0.0  0.000000  1000.0
# V3_C018    0.000000       0.000000       0.000000       0.0  0.000000  1000.0
# ...             ...            ...            ...       ...       ...     ...
# M_C120   716.084653       0.000000       0.000000       0.0 -0.161985 -1000.0
# M_C115   764.403518       0.225739      -0.225739       0.0  0.000000 -1000.0
# M_C101     0.000000       0.000000       0.000000       0.0  0.000000 -1000.0
# M_C114     0.000000       0.000000       0.000000       0.0  0.000000 -1000.0
# M_C119     0.000000       0.000000       0.000000       0.0  0.000000 -1000.0
#
#          2HCO3_NAt  34HPPOR    3DSPHR      3HAO  ...  DM_4abut[c]  DM_srtn[c]  \
# V3_C005     1000.0      0.0  0.004922  0.000000  ...          0.0         0.0
# V3_C009     1000.0      0.0  0.004922  0.000000  ...          0.0         0.0
# V3_C010     1000.0      0.0  0.004922  0.000000  ...          0.0         0.0
# V3_C016     1000.0      0.0  0.004922  0.000000  ...          0.0         0.0
# V3_C018     1000.0      0.0  0.004922  0.000000  ...          0.0         0.0
# ...            ...      ...       ...       ...  ...          ...         ...
# M_C120      1000.0      0.0  0.004922  0.000000  ...          0.0         0.0
# M_C115      1000.0      0.0  0.004922  0.001017  ...          0.0         0.0
# M_C101      1000.0      0.0  0.004922  0.000000  ...          0.0         0.0
# M_C114      1000.0      0.0  0.004922  0.002968  ...          0.0         0.0
# M_C119      1000.0      0.0  0.004922  0.000000  ...          0.0         0.0
#
#          DM_ach[c]  DM_kynate[c]       DCMPtm     ATPS4mi  CYOR_u10mi  \
# V3_C005        0.0      0.035978  -980.563779   35.902643   23.606042
# V3_C009        0.0      0.035978  -974.798723   36.619729   24.084099
# V3_C010        0.0      0.035978  -974.798723   36.619729   24.084099
# V3_C016        0.0      0.035978  -974.798723   36.619729   24.084099
# V3_C018        0.0      0.035978  -974.798723   36.619729   24.084099
# ...            ...           ...          ...         ...         ...
# M_C120         0.0      0.000000 -1000.000000  297.405873  198.270582
# M_C115         0.0      0.000000 -1000.000000   30.961132   20.634940
# M_C101         0.0      0.000000 -1000.000000  294.952116  196.305690
# M_C114         0.0      0.000000 -1000.000000  359.128583  153.431953
# M_C119         0.0      0.000000 -1000.000000  454.072153  198.256300
#
#          NADH2_u10mi  CYOOm3i    CYOOm2i
# V3_C005     0.000000      0.0  12.296601
# V3_C009     0.000000      0.0  12.535630
# V3_C010     0.000000      0.0  12.535630
# V3_C016     0.000000      0.0  12.535630
# V3_C018     0.000000      0.0  12.535630
# ...              ...      ...        ...
# M_C120      0.000000      0.0  99.135291
# M_C115      0.000000      0.0  10.326192
# M_C101      0.000000      0.0  98.646426
# M_C114    128.980654      0.0  76.715976
# M_C119    156.687703      0.0  99.128150
#
# [84 rows x 2916 columns]

# %%
df_infants = df_filtered[~df_filtered.index.str.startswith("M_")]

# %%
microbiome_fluxes
# Out:
# {'V3_C005': 0.003893040293040293,
#  'V3_C009': 0.0,
#  'V3_C010': 0.0,
#  'V3_C016': 0.0,
#  'V3_C018': 0.0,
#  'V3_C019': 0.0025463372093023256,
#  'V3_C100': 0.0,
#  'V3_C101': 0.03131871640866878,
#  'V3_C105': 0.0,
#  'V3_C106': 0.0,
#  'V3_C110': 0.0,
#  'V3_C111': 0.0012065454545454545,
#  'V3_C112': 0.012766272040302265,
#  'V3_C113': 0.0,
#  'V3_C114': 0.0,
#  'V3_C117': 0.0,
#  'V3_C119': 0.0,
#  'V3_C120': 0.0,
#  'V4_C005': 0.0010748222222222222,
#  'V4_C009': 0.04255238095238095,
#  'V4_C010': 0.0,
#  'V4_C016': 0.040494044444444446,
#  'V4_C018': 0.0,
#  'V4_C019': 0.008518933333333334,
#  'V4_C100': 0.0028680952380952377,
#  'V4_C101': 0.021722133333333334,
#  'V4_C105': 0.0,
#  'V4_C106': 0.003804888888888889,
#  'V4_C110': 0.0,
#  'V4_C111': 0.0015543809523809523,
#  'V4_C112': 0.022705244444444442,
#  'V4_C113': 0.003717357142857143,
#  'V4_C114': 0.004144285714285714,
#  'V4_C117': 0.008384533333333333,
#  'V4_C119': 0.020096190476190476,
#  'V4_C120': 0.0005177555555555556,
#  'V5_C005': 0.013420025316455697,
#  'V5_C009': 0.008749150684931506,
#  'V5_C010': 0.03176671232876712,
#  'V5_C018': 0.004782260273972602,
#  'V5_C019': 0.00867504543609114,
#  'V5_C100': 0.00020868493150684897,
#  'V5_C101': 0.018965063291139242,
#  'V5_C105': 0.006289844123030064,
#  'V5_C106': 0.00032256962025316457,
#  'V5_C110': 0.0,
#  'V5_C111': 0.002597123287671233,
#  'V5_C112': 0.006680490011064684,
#  'V5_C113': 0.015538460799405717,
#  'V5_C114': 0.005000150684931507,
#  'V5_C117': 0.0,
#  'V5_C119': 0.003935041095890411,
#  'V5_C120': 0.00023041772151898766,
#  'V6_C005': 0.0064775154639175265,
#  'V6_C009': 0.018415955555555554,
#  'V6_C010': 0.01560081111111111,
#  'V6_C016': 0.02112882775592495,
#  'V6_C018': 0.01818657777777778,
#  'V6_C019': 0.011968958762886598,
#  'V6_C100': 0.007155788888888889,
#  'V6_C101': 0.0110280206185567,
#  'V6_C105': 0.009974192632492551,
#  'V6_C106': 0.011989742268041238,
#  'V6_C110': 0.0036549072164948453,
#  'V6_C111': 0.006205706727382501,
#  'V6_C112': 0.014050075684077267,
#  'V6_C113': 0.009139377777777779,
#  'V6_C114': 0.013315244444444445,
#  'V6_C117': 0.011031731958762886,
#  'V6_C119': 0.02050093702413311,
#  'V6_C120': 0.007541247422680412}

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

# Define root directory
root_dir = "Flux_vs_Butyrate"
os.makedirs(root_dir, exist_ok=True)

# Ensure butyrate flux matches df_infants index
butyrate_series = pd.Series(microbiome_fluxes).reindex(df_infants.index)

# Filter out samples with no butyrate flux
valid_samples = butyrate_series.dropna().index
df_valid = df_infants.loc[valid_samples]
butyrate_flux = butyrate_series.loc[valid_samples]

# Loop through each reaction (column)
for reaction in df_valid.columns:
    y = df_valid[reaction]

    # Skip if all values are 0 or NaN
    if y.isna().all() or (y == 0).all():
        continue

    # Calculate Pearson correlation
    try:
        r, p = pearsonr(butyrate_flux, y)
    except Exception as e:
        print(f"Skipping {reaction} due to error: {e}")
        continue

    # Start plotting
    plt.figure(figsize=(6, 4))
    sns.regplot(x=butyrate_flux, y=y, scatter_kws={'s': 30}, line_kws={'color': 'red'})
    plt.xlabel("Butyrate Flux (mmol/gDW/h)")
    plt.ylabel(f"Flux of {reaction}")
    plt.title(f"{reaction}\nPearson r = {r:.2f}, p = {p:.2e}")
    plt.tight_layout()

    # Determine subsystem and save path
    subsystem = rxn2subsystem.get(reaction, "Unknown_Subsystem")
    sub_dir = os.path.join(root_dir, subsystem)
    os.makedirs(sub_dir, exist_ok=True)
    file_path = os.path.join(sub_dir, f"{reaction}.png")

    plt.savefig(file_path, dpi=300)
    plt.close()
# Out:
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4847: NearConstantInputWarning: An input array is nearly constant; the computed correlation coefficient may be inaccurate.
#   warnings.warn(stats.NearConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))

# %%
rxn2name = {}
for r in cobraModel.reactions:
    r_id = r.id
    rxn2name[r_id] = cobraModel.reactions.get_by_id(r_id).name

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import spearmanr

# New root directory
root_dir = "fluxes_spearman"
os.makedirs(root_dir, exist_ok=True)

# Align butyrate fluxes with df_infants
butyrate_series = pd.Series(microbiome_fluxes).reindex(df_infants.index)

# Filter samples with valid butyrate flux
valid_samples = butyrate_series.dropna().index
df_valid = df_infants.loc[valid_samples]
butyrate_flux = butyrate_series.loc[valid_samples]

# Loop through each reaction
for reaction in df_valid.columns:
    y = df_valid[reaction]

    # Skip all-zero or NaN columns
    if y.isna().all() or (y == 0).all():
        continue

    # Spearman correlation
    try:
        r, p = spearmanr(butyrate_flux, y)
    except Exception as e:
        print(f"Skipping {reaction} due to error: {e}")
        continue

    # Only save if significant
    if p < 0.05:
        # Plotting
        plt.figure(figsize=(6, 4))
        sns.regplot(
            x=butyrate_flux,
            y=y,
            scatter_kws={'s': 30},
            line_kws={'color': 'red'},
            ci=None
        )
        plt.xlabel("Butyrate Flux (mmol/gDW/h)")
        rxn_name = rxn2name.get(reaction, reaction)
        plt.ylabel(f"Flux of {rxn_name}")
        plt.title(f"{rxn_name}\nSpearman r = {r:.2f}, p = {p:.2e}")
        plt.tight_layout()

        # Save path
        subsystem = rxn2subsystem.get(reaction, "Unknown_Subsystem")
        sub_dir = os.path.join(root_dir, subsystem)
        os.makedirs(sub_dir, exist_ok=True)
        file_path = os.path.join(sub_dir, f"{reaction}.png")

        plt.savefig(file_path, dpi=300)
        plt.close()
# Out:
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import spearmanr

# New root directory for this version
root_dir = "fluxes_spearman_nonzero"
os.makedirs(root_dir, exist_ok=True)

# Get butyrate fluxes and keep only samples with flux > 0
butyrate_series = pd.Series(microbiome_fluxes).reindex(df_infants.index)
nonzero_samples = butyrate_series[butyrate_series > 0].index

# Filter dataframe and butyrate flux accordingly
df_nonzero = df_infants.loc[nonzero_samples]
butyrate_flux = butyrate_series.loc[nonzero_samples]

# Loop through each reaction
for reaction in df_nonzero.columns:
    y = df_nonzero[reaction]

    # Skip reactions that are all 0 or NaN
    if y.isna().all() or (y == 0).all():
        continue

    # Spearman correlation
    try:
        r, p = spearmanr(butyrate_flux, y)
    except Exception as e:
        print(f"Skipping {reaction} due to error: {e}")
        continue

    # Only save significant correlations
    if p < 0.05:
        plt.figure(figsize=(6, 4))
        sns.regplot(
            x=butyrate_flux,
            y=y,
            scatter_kws={'s': 30},
            line_kws={'color': 'red'},
            ci=None
        )
        plt.xlabel("Butyrate Flux (mmol/gDW/h)")
        rxn_name = rxn2name.get(reaction, reaction)
        plt.ylabel(f"Flux of {rxn_name}")
        plt.title(f"{rxn_name}\nSpearman r = {r:.2f}, p = {p:.2e}")
        plt.tight_layout()

        # Save under correct subsystem folder
        subsystem = rxn2subsystem.get(reaction, "Unknown_Subsystem")
        sub_dir = os.path.join(root_dir, subsystem)
        os.makedirs(sub_dir, exist_ok=True)
        file_path = os.path.join(sub_dir, f"{reaction}.png")

        plt.savefig(file_path, dpi=300)
        plt.close()
# Out:
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
# C:\Users\jrp89\miniconda3\envs\cobrapy\lib\site-packages\scipy\stats\_stats_py.py:5445: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(warn_msg))
